-- %%
-- Dim_Periodo_Horario


INSERT INTO dim_periodo_horario(id_periodo, periodo, hora_inicio, hora_fim) 
VALUES (1, 'Manhã', '09:00', '11:59'),
(2, 'Tarde', '12:00', '17:59'),
(3, 'Noite', '18:00', '23:59');
