-- %%
-- Dim_Hospital



-- Inserir os dados dos hospitais
INSERT INTO DIM_HOSPITAL (id_hospital, nome_hospital) VALUES 
(1,'Hospital Samaritano'),
(2,'Hospital das Clínicas'),
(3,'Hospital Getúlio Vargas'),
(4,'Hospital Estadual'),
(5,'Hospital Geral de Fortaleza'),
(6,'Hospital Unimed'),
(7,'Hospital Municipal'),
(8,'Hospital Evangélico'),
(9,'Hospital Regional'),
(10,'Hospital São Paulo'),
(11,'Hospital Albert Einstein'),
(12,'Hospital Nossa Senhora das Graças'),
(13,'Hospital da Restauração'),
(14,'Hospital Infantil Sabará'),
(15,'Hospital Sírio-Libanês'),
(16,'Hospital Beneficência Portuguesa'),
(17,'Hospital de Base'),
(18,'Hospital Metropolitano'),
(19,'Hospital Universitário'),
(20,'Hospital Santa Casa de Misericórdia'),
(21,'Hospital Israelita Albert Einstein'),
(22,'Santa Casa de Misericórdia de São Paulo'),
(23,'Hospital Regional de Taguatinga'),
(24,'Hospital Estadual Mário Covas'),
(25,'Hospital de Base do Distrito Federal'),
(26,'Hospital Evangélico Mackenzie'),
(27,'Hospital João XXIII'),
(28,'Hospital do Coração'),
(29,'Hospital Municipal Dr. Moysés Deutsch'),
(30,'Hospital Santa Izabel'),
(31,'Hospital Santa Marcelina'),
(32,'Hospital Ana Nery'),
(33,'Hospital Metropolitano de Urgência e Emergência'),
(34,'Hospital Cristo Redentor'),
(35,'Hospital Universitário Clementino Fraga Filho'),
(36,'Hospital Universitário Walter Cantídio'),
(37,'Hospital Madre Teresa'),
(38,'Hospital Unimed Recife'),
(39,'Hospital das Forças Armadas'),
(40,'Hospital Regional do Oeste');
