-- %%
-- Dim_Local
INSERT INTO dim_local(d_local, nome_local, cidade, estado) 
VALUES (1, 'Internação Padrão', 'Teresina', 'PI'),
(2,'Quartos', 'Natal', 'RN'),
(3,'Oncologia', 'Vitória', 'ES'),
(4,'Quimioterapia', 'Belo Horizonte', 'MG'),
(5,'SUS', 'Natal', 'RN'),
(6,'Pediatria', 'Teresina', 'PI');
