-- %%
INSERT INTO fato_atendimento VALUES (2747,5,1,2,1,0630,88,1),
(2763,4,1,2,2,0420,124,2),
(2281,4,1,2,3,0615,26,1),
(2758,4,1,2,4,0415,91,2),
(2758,1,1,2,5,0410,31,1),
(3317,4,1,2,6,0610,42,2),
(2282,1,1,2,1,0620,71,2),
(2747,4,1,2,2,0420,90,1),
(2747,3,1,2,3,0415,23,1),
(4424,5,1,2,4,0430,67,2),
(2281,1,1,2,5,0620,15,2),
(2758,1,1,2,6,0630,34,2),
(2281,4,1,2,1,0420,110,2),
(2281,3,1,2,2,0625,83,2),
(2747,4,1,2,3,0410,62,1),
(2281,5,1,2,4,0615,84,1),
(2763,4,1,2,5,0620,20,2),
(2758,3,1,2,6,0625,60,2),
(2763,5,1,2,1,0610,101,2),
(3317,4,1,2,2,0440,89,2),
(2747,5,1,2,3,0630,70,2),
(2758,3,1,2,4,0615,20,2),
(4424,4,1,2,5,0625,94,2),
(3317,5,1,2,6,0615,116,2),
(2334,4,1,2,1,0640,26,2),
(2281,3,1,2,2,0610,113,1),
(2281,4,1,2,3,0625,45,2),
(2281,1,1,2,4,0620,103,2),
(4424,4,1,2,5,0440,68,2),
(2281,4,1,2,6,0615,121,2),
(2212,3,1,2,1,0625,98,2),
(4424,4,1,2,2,0440,94,2),
(2747,1,1,2,3,0625,70,2),
(4424,4,1,2,4,0620,74,1),
(2281,3,1,2,5,0640,72,2),
(2758,4,1,2,6,0615,110,1),
(2281,5,1,2,1,0630,44,1),
(2281,3,1,2,2,0620,39,2),
(2747,4,1,2,3,0630,27,2),
(2758,5,1,2,4,0630,50,2),
(2747,4,1,2,5,0610,54,2),
(2758,1,1,2,6,0625,95,2),
(2747,4,1,2,1,0440,71,2),
(2281,3,1,2,2,0615,71,1),
(2747,5,1,2,3,0615,18,2),
(2281,4,1,2,4,0615,112,2),
(2334,4,1,2,5,0610,99,2),
(2281,3,1,2,6,0420,95,2),
(3317,5,1,2,1,0420,71,2),
(2281,4,1,2,2,0610,54,2),
(2281,1,1,2,3,0415,30,2),
(2758,4,1,2,4,0620,99,2),
(2758,3,1,2,5,0420,27,1),
(4424,4,1,2,6,0430,24,2),
(2281,1,1,2,1,0630,124,2),
(2281,5,1,2,2,0640,94,2),
(2281,5,1,2,3,0620,71,2),
(2281,4,1,2,4,0610,73,2),
(3317,3,1,2,5,0630,88,1),
(2281,1,1,2,6,0625,110,1),
(3317,4,1,2,1,0630,125,1),
(2281,5,1,2,2,0425,83,2),
(2281,3,1,2,3,0620,120,1),
(4424,4,1,2,4,0410,27,2),
(2747,4,1,2,5,0425,123,1),
(3317,4,1,2,6,0440,110,2),
(2750,1,1,2,1,0630,79,2),
(2281,1,1,2,2,0610,58,1),
(2763,1,1,2,3,0625,62,1),
(2747,4,1,2,4,0610,112,2),
(4424,3,1,2,5,0615,92,1),
(2747,4,1,2,6,0640,59,2),
(2747,1,1,2,1,0640,109,1),
(2758,5,1,2,2,0630,62,2),
(4424,4,1,2,3,0630,24,1),
(2281,3,1,2,4,0620,88,2),
(2281,4,1,2,5,0630,117,1),
(4424,1,1,2,6,0415,70,2),
(2281,5,1,2,1,0620,74,2),
(3317,4,1,2,2,0610,93,2),
(4424,4,1,2,3,0630,72,2),
(2758,3,1,2,4,0615,22,2),
(2281,1,1,2,5,0615,46,2),
(2747,1,1,2,6,0640,38,2),
(2747,3,1,2,1,0420,24,2),
(2281,4,1,2,2,0620,99,2),
(2758,5,1,2,3,0625,121,2),
(2281,4,1,2,4,0610,101,1),
(2747,3,1,2,5,0440,121,2),
(2281,4,1,2,6,0610,21,2),
(3317,1,1,2,1,0410,43,2),
(4424,4,1,2,2,0640,19,2),
(2281,5,1,2,3,0615,72,2),
(2281,5,1,2,4,0615,45,2),
(2281,4,1,2,5,0620,23,2),
(3317,4,1,2,6,0430,40,2),
(2758,5,1,2,1,0415,119,2),
(3317,3,1,2,2,0625,56,2),
(2281,3,1,2,3,0630,36,1),
(2758,4,1,2,4,0415,50,2),
(2212,1,1,2,5,0640,18,2),
(2281,1,1,2,6,0440,61,1),
(3317,3,1,2,1,0630,116,2),
(2758,4,1,2,2,0440,74,2),
(2747,5,1,2,3,0625,90,2),
(2758,4,1,2,4,0640,122,1),
(3317,3,1,2,5,0425,98,1),
(2758,4,1,2,6,0615,125,2),
(2281,1,1,2,1,0630,78,2),
(2334,4,1,2,2,0640,79,2),
(2281,3,1,2,3,0625,78,2),
(2281,4,1,2,4,0630,32,2),
(2758,1,1,2,5,0630,65,2),
(2281,4,1,2,6,0640,105,2),
(2212,5,1,2,1,0430,68,1),
(2282,1,1,2,2,0630,107,2),
(2758,1,1,2,3,0620,86,1),
(2281,1,1,2,4,0610,55,2),
(4424,3,1,2,5,0640,65,1),
(2281,5,1,2,6,0615,71,2),
(2750,5,1,2,1,0425,86,1),
(3317,5,1,2,2,0630,98,2),
(2212,5,1,2,3,0425,122,2),
(2281,5,1,2,4,0420,16,1),
(2281,5,1,2,5,0620,38,1),
(2281,5,1,2,6,0430,111,2),
(4424,5,1,2,1,0415,29,2),
(2281,5,1,2,2,0425,73,2),
(2758,5,1,2,3,0625,101,2),
(2281,5,1,2,4,0640,89,2),
(2281,5,1,2,5,0440,19,2),
(2758,5,1,2,6,0430,72,1),
(2281,5,1,2,1,0625,45,1),
(2758,5,1,2,2,0625,68,1),
(2281,5,1,2,3,0620,74,2),
(2763,5,1,2,4,0620,67,2),
(2281,5,1,2,5,0625,52,1),
(2747,5,1,2,6,0625,99,2),
(2282,5,1,2,1,0625,82,2),
(3317,5,1,2,2,0430,118,2),
(3317,5,1,2,3,0610,82,2),
(3317,4,1,2,4,0625,20,2),
(2281,3,1,2,5,0415,44,2),
(3317,4,1,2,6,0630,25,2),
(3317,1,1,2,1,0615,106,1),
(2758,4,1,2,2,0615,54,2),
(4424,5,1,2,3,0610,32,1),
(2281,1,1,2,4,0610,71,1),
(2758,1,1,2,5,0625,76,2),
(4424,1,1,2,6,0620,88,2),
(2747,3,1,2,1,0440,111,2),
(2281,4,1,2,2,0430,72,2),
(2747,5,1,2,3,0630,59,2),
(2758,4,1,2,4,0630,121,2),
(2281,3,1,2,5,0625,111,2),
(2282,4,1,2,6,0630,73,2),
(2747,1,1,2,1,0630,93,2),
(2281,4,1,2,2,0640,119,2),
(2747,3,1,2,3,0620,36,2),
(2758,4,1,2,4,0410,83,2),
(2281,1,1,2,5,0430,83,1),
(2212,4,1,2,6,0630,88,1),
(3317,5,1,2,1,0440,50,1),
(2281,5,1,2,2,0620,116,2),
(2747,4,1,2,3,0615,56,2),
(2763,3,1,2,4,0610,20,2),
(2747,4,1,2,5,0410,90,2),
(2747,1,1,2,6,0420,103,2),
(2281,4,1,2,1,0415,28,1),
(2750,1,1,2,2,0430,23,2),
(3317,4,1,2,3,0610,107,2),
(2281,3,1,2,4,0410,61,2),
(2758,5,1,2,5,0615,90,2),
(2758,1,1,2,6,0415,95,2),
(4424,1,1,2,1,0410,36,1),
(2282,4,1,2,2,0625,118,1),
(2282,3,1,2,3,0610,78,1),
(2747,4,1,2,4,0410,62,1),
(2747,5,1,2,5,0640,109,2),
(2281,4,1,2,6,0610,108,2),
(4424,3,1,2,1,0425,84,2),
(2747,5,1,2,2,0625,72,2),
(2763,4,1,2,3,0420,28,2),
(4424,5,1,2,4,0410,120,1),
(2282,3,1,2,5,0615,23,2),
(2747,4,1,2,6,0420,74,2),
(2763,5,1,2,1,0625,102,1),
(2758,4,1,2,2,0440,72,1),
(2212,3,1,2,3,0440,113,2),
(4424,4,1,2,4,0415,83,1),
(2281,1,1,2,5,0630,106,2),
(2758,4,1,2,6,0415,114,2),
(3317,4,1,2,1,0440,90,2),
(2282,3,1,2,2,0625,21,2),
(2212,4,1,2,3,0410,59,2),
(2747,1,1,2,4,0620,35,1),
(2212,4,1,2,5,0630,58,2),
(3317,3,1,2,6,0425,123,2),
(2747,4,1,2,1,0610,26,1),
(2282,5,1,2,2,0625,72,1),
(4424,3,1,2,3,0630,34,1),
(2763,4,1,2,4,0610,85,2),
(3317,5,1,2,5,0630,81,2),
(2281,4,1,2,6,0630,29,1),
(2334,1,1,2,1,0620,87,2),
(4424,4,1,2,2,0620,64,2),
(2747,3,1,2,3,0425,19,1),
(2281,5,1,2,4,0630,37,2),
(4424,4,1,2,5,0415,61,2),
(2281,4,1,2,6,0640,102,2),
(2758,3,1,2,1,0615,90,2),
(2281,5,1,2,2,0615,69,2),
(4424,4,1,2,3,0625,101,1),
(4424,1,1,2,4,0630,86,2),
(4424,4,1,2,5,0610,58,1),
(2758,3,1,2,6,0640,79,1),
(2747,4,1,2,1,0615,27,2),
(2281,1,1,2,2,0610,98,1),
(2281,5,1,2,3,0425,115,2),
(2281,5,1,2,4,0410,114,1),
(2281,4,1,2,5,0630,15,2),
(2281,3,1,2,6,0410,115,2),
(2758,1,1,2,1,0610,64,1),
(2282,4,1,2,2,0615,96,1),
(3317,5,1,2,3,0625,98,2),
(2212,3,1,2,4,0420,34,2),
(2747,4,1,2,5,0610,73,1),
(2281,4,1,2,6,0620,114,1),
(2747,4,1,2,1,0625,76,2),
(2282,1,1,2,2,0630,16,2),
(3317,5,1,2,3,0620,70,1),
(2758,5,1,2,4,0440,80,1),
(2758,5,1,2,5,0615,123,1),
(2747,5,1,2,6,0620,29,2),
(2758,5,1,2,1,0410,85,2),
(3317,5,1,2,2,0430,120,2),
(3317,5,1,2,3,0640,68,1),
(3317,5,1,2,4,0620,72,1),
(2758,5,1,2,5,0615,102,2),
(2281,5,1,2,6,0625,60,1),
(4424,5,1,2,1,0610,80,2),
(2281,5,1,2,2,0610,74,1),
(2281,5,1,2,3,0630,77,1),
(4424,5,1,2,4,0640,113,1),
(4424,5,1,2,5,0620,125,2),
(2747,5,1,2,6,0425,97,2),
(2758,5,1,2,1,0440,26,2),
(3317,5,1,2,2,0625,16,2),
(2281,5,1,2,3,0440,83,2),
(2281,5,1,2,4,0625,87,2),
(2282,5,1,2,5,0630,106,2),
(2747,5,1,2,6,0630,79,2),
(2758,5,1,2,1,0620,72,2),
(2281,5,1,2,2,0615,43,2),
(2282,5,1,2,3,0625,81,2),
(4424,5,1,2,4,0625,38,2),
(2758,5,1,2,5,0610,76,2),
(3317,5,1,2,6,0640,20,2),
(2281,5,1,2,1,0425,22,1),
(3317,5,1,2,2,0630,107,2),
(2281,5,1,2,3,0640,115,1),
(2281,5,1,2,4,0430,114,1),
(2281,5,1,2,5,0640,67,1),
(2747,5,1,2,6,0610,124,1),
(2763,5,1,2,1,0610,111,2),
(2281,5,1,2,2,0425,47,2),
(2281,5,1,2,3,0640,110,2),
(4424,5,1,2,4,0610,26,2),
(2281,5,1,2,5,0640,81,2),
(2281,5,1,2,6,0415,59,2),
(2282,5,1,2,1,0630,48,2),
(2281,5,1,2,2,0615,117,2),
(2281,5,1,2,3,0610,48,2),
(4424,5,1,2,4,0425,114,1),
(4424,5,1,2,5,0610,112,2),
(2747,5,1,2,6,0610,77,2),
(2212,5,1,2,1,0430,124,1),
(2281,5,1,2,2,0420,119,2),
(2281,5,1,2,3,0410,33,2),
(2281,5,1,2,4,0415,115,2),
(2281,5,1,2,5,0430,95,2),
(2747,5,1,2,6,0615,95,1),
(2758,5,1,2,1,0410,55,2),
(2758,5,1,2,2,0640,114,2),
(4424,5,1,2,3,0440,31,2),
(2334,5,1,2,4,0415,74,1),
(2281,5,1,2,5,0415,90,2),
(2763,5,1,2,6,0610,59,2),
(2281,5,1,2,1,0425,48,2),
(2747,5,1,1,2,0640,95,1),
(2758,5,1,1,3,0625,67,2),
(2212,5,1,1,4,0415,94,2),
(2747,5,1,1,5,0430,83,2),
(2758,5,1,1,6,0630,122,2),
(3317,5,1,1,1,0440,113,2),
(2750,5,1,1,2,0425,75,1),
(2281,1,1,1,3,0615,108,2),
(4424,3,1,1,4,0615,77,2),
(4424,4,1,1,5,0630,84,2),
(2747,5,1,1,6,0620,23,2),
(2281,4,1,1,1,0640,21,1),
(2763,3,1,1,2,0410,121,2),
(2758,4,1,1,3,0640,116,1),
(2281,1,1,1,4,0610,92,2),
(2281,4,1,1,5,0640,61,1),
(2281,3,1,1,6,0410,81,2),
(2747,4,1,1,1,0625,17,2),
(2334,1,1,1,2,0640,110,1),
(2281,4,1,1,3,0410,84,2),
(2212,5,1,1,4,0640,101,1),
(2758,1,1,1,5,0625,29,1),
(2758,1,1,1,6,0610,113,2),
(2758,1,1,1,1,0625,71,2),
(2281,3,1,1,2,0425,29,1),
(2758,4,1,1,3,0640,72,1),
(2758,5,1,1,4,0430,63,2),
(2281,4,1,1,5,0630,38,2),
(2281,3,1,1,6,0615,68,2),
(2212,4,1,1,1,0630,72,2),
(4424,1,1,1,2,0620,125,2),
(3317,4,1,1,3,0620,55,2),
(2281,3,1,1,4,0425,112,2),
(3317,4,1,1,5,0640,69,1),
(2758,1,1,1,6,0625,65,1),
(2758,4,1,1,1,0615,81,2),
(2747,5,1,1,2,0615,39,2),
(2281,5,1,1,3,0620,36,2),
(2282,4,1,1,4,0425,68,1),
(2747,3,1,1,5,0620,40,2),
(3317,4,1,1,6,0410,92,1),
(2758,1,1,1,1,0625,71,2),
(2212,4,1,1,2,0640,112,1),
(3317,1,1,1,3,0640,57,2),
(2281,4,1,1,4,0625,16,1),
(2281,3,1,1,5,0640,79,2),
(2747,5,1,1,6,0425,107,2),
(2747,1,1,1,1,0440,75,1),
(2747,1,1,1,2,0620,74,2),
(4424,4,1,1,3,0440,71,2),
(2281,3,1,1,4,0630,114,2),
(3317,4,1,1,5,0620,35,2),
(4424,5,1,1,6,0615,84,2),
(2281,4,1,1,1,0625,36,2),
(2281,3,1,1,2,0420,75,2),
(2763,5,1,1,3,0625,38,2),
(2281,4,1,1,4,0640,29,2),
(4424,5,1,1,5,0415,80,2),
(4424,3,1,1,6,0420,111,1),
(3317,4,1,1,1,0620,40,1),
(2281,5,1,1,2,0620,70,2),
(2282,4,1,1,3,0640,124,1),
(2747,3,1,1,4,0615,29,1),
(2212,4,1,1,5,0615,43,2),
(3317,1,1,1,6,0610,106,1),
(2281,4,1,1,1,0630,36,2),
(2281,4,1,1,2,0640,95,2),
(4424,3,1,1,3,0615,51,2),
(2281,4,1,1,4,0640,93,2),
(2281,1,1,1,5,0630,63,2),
(4424,4,1,1,6,0415,51,2),
(2747,3,1,1,1,0640,83,2),
(3317,4,1,1,2,0610,49,2),
(2212,5,1,1,3,0425,91,1),
(2758,3,1,1,4,0425,99,1),
(4424,4,1,1,5,0610,71,2),
(2281,5,1,1,6,0415,17,2),
(4424,4,1,1,1,0440,104,1),
(2281,1,1,1,2,0620,64,1),
(2334,4,1,1,3,0440,25,1),
(2282,3,1,1,4,0425,77,2),
(2758,5,1,1,5,0610,19,1),
(2758,4,1,1,6,0625,101,2),
(2281,4,1,1,1,0440,85,1),
(2281,3,1,1,2,0610,114,1),
(2763,5,1,1,3,0440,68,2),
(3317,4,1,1,4,0615,20,2),
(4424,1,1,1,5,0640,24,1),
(2281,4,1,1,6,0640,110,2),
(2282,3,1,1,1,0620,88,1),
(2758,4,1,1,2,0410,125,1),
(2747,1,1,1,3,0620,109,2),
(2281,5,1,1,4,0425,116,1),
(3317,5,1,1,5,0625,64,2),
(2281,4,1,1,6,0615,115,1),
(2758,3,1,1,1,0615,75,1),
(2282,1,1,1,2,0610,39,2),
(2281,4,1,1,3,0615,28,1),
(4424,5,1,1,4,0615,52,1),
(2281,3,1,1,5,0625,60,2),
(2758,4,1,1,6,0610,38,2),
(2282,4,1,1,1,0430,88,2),
(2281,4,1,1,2,0625,58,2),
(2747,1,1,1,3,0430,18,2),
(2758,1,1,1,4,0610,92,1),
(2334,1,1,1,5,0615,101,2),
(4424,4,1,1,6,0415,100,2),
(4424,3,1,1,1,0625,120,1),
(2747,4,1,1,2,0630,18,2),
(4424,1,1,1,3,0610,30,2),
(3317,5,1,1,4,0640,18,2),
(3317,4,1,1,5,0630,89,1),
(2281,3,1,1,6,0415,114,2),
(2281,4,1,1,1,0430,121,1),
(2758,1,1,1,2,0620,119,2),
(2750,5,1,1,3,0625,119,1),
(2281,4,1,1,4,0415,43,2),
(2747,4,1,1,5,0640,79,2),
(2281,3,1,1,6,0615,106,1),
(2281,1,1,1,1,0610,79,2),
(2282,1,1,1,2,0640,124,2),
(3317,3,1,1,3,0640,101,2),
(4424,4,1,1,4,0640,33,2),
(2763,5,1,1,5,0625,61,1),
(2281,4,1,1,6,0615,92,1),
(4424,3,1,1,1,0615,116,2),
(2747,4,1,1,2,0640,84,2),
(2281,1,1,1,3,0410,72,2),
(2281,4,1,1,4,0630,22,2),
(2282,5,1,1,5,0430,112,2),
(4424,5,1,1,6,0625,59,1),
(2758,4,1,1,1,0425,103,1),
(2281,4,1,1,2,0430,19,2),
(2758,5,1,1,3,0425,51,2),
(2747,3,1,1,4,0625,106,2),
(3317,3,1,1,5,0615,41,1),
(2281,4,1,1,6,0615,70,2),
(4424,1,1,1,1,0625,100,2),
(2747,1,1,1,2,0620,35,2),
(3317,3,1,1,3,0625,97,1),
(2281,4,1,1,4,0440,125,2),
(2281,5,1,1,5,0630,17,1),
(4424,4,1,1,6,0620,47,2),
(2281,3,1,1,1,0640,83,2),
(2281,4,1,1,2,0620,26,1),
(2758,1,1,1,3,0420,118,1),
(2281,4,1,1,4,0610,40,2),
(2747,3,1,1,5,0425,17,2),
(2212,4,1,1,6,0620,48,2),
(2747,1,1,1,1,0440,25,2),
(4424,4,1,1,2,0610,106,2),
(3317,5,1,1,3,0420,121,2),
(2750,1,1,1,4,0615,81,2),
(2747,1,1,1,5,0610,86,2),
(2281,1,1,1,6,0410,48,1),
(2281,3,1,1,1,0640,60,2),
(2281,4,1,1,2,0630,34,2),
(2212,5,1,1,3,0625,91,2),
(2763,4,1,1,4,0640,108,2),
(2281,3,1,1,5,0420,117,2),
(2281,4,1,1,6,0640,66,2),
(2281,1,1,1,1,0630,111,2),
(4424,4,1,1,2,0615,26,2),
(2747,3,1,1,3,0625,78,1),
(2281,4,1,1,4,0620,42,2),
(4424,1,1,1,5,0610,65,2),
(2281,5,1,1,6,0615,21,1),
(2281,5,1,1,1,0640,123,2),
(4424,5,1,1,2,0410,100,1),
(3317,5,1,1,3,0425,78,2),
(2758,5,1,1,4,0610,60,2),
(2758,5,1,1,5,0440,30,1),
(2747,5,1,1,6,0610,121,2),
(2281,5,1,1,1,0625,61,1),
(2747,5,1,1,2,0430,73,2),
(3317,5,1,1,3,0625,104,2),
(2747,5,1,1,4,0425,83,2),
(2763,5,1,1,5,0625,26,2),
(2212,5,1,1,6,0615,17,2),
(2281,5,1,1,1,0430,120,2),
(2281,5,1,1,2,0425,26,2),
(2758,5,1,1,3,0615,101,1),
(4424,5,1,1,4,0610,71,2),
(2212,5,1,1,5,0610,77,1),
(4424,5,1,1,6,0425,54,2),
(2281,5,1,1,1,0640,23,1),
(4424,5,1,1,2,0620,115,2),
(2281,5,1,1,3,0430,100,2),
(2281,5,1,1,4,0630,70,2),
(2747,5,1,1,5,0625,29,1),
(2212,5,1,1,6,0620,54,2),
(2758,5,1,1,1,0625,115,1),
(2281,5,1,1,2,0415,20,2),
(2212,5,1,1,3,0610,22,2),
(2747,5,1,1,4,0640,112,2),
(2282,5,1,1,5,0610,121,2),
(2281,5,1,1,6,0640,64,2),
(2763,5,1,1,1,0430,16,2),
(2281,5,1,1,2,0425,102,1),
(2747,5,1,1,3,0610,124,1),
(2758,5,1,1,4,0630,122,1),
(2758,5,1,1,5,0625,120,2),
(2281,5,1,1,6,0425,112,1),
(2282,5,1,1,1,0630,55,2),
(2281,5,1,1,2,0440,53,2),
(2281,5,1,1,3,0625,96,2),
(3317,5,1,1,4,0615,38,1),
(4424,5,1,1,5,0430,54,2),
(2282,5,1,1,6,0415,52,2),
(2281,5,1,1,1,0440,69,1),
(2281,5,1,1,2,0640,41,2),
(2747,5,1,1,3,0630,33,1),
(2750,5,1,1,4,0620,18,2),
(2758,5,1,1,5,0610,31,2),
(3317,5,1,1,6,0440,36,2),
(2758,5,1,1,1,0625,106,2),
(4424,5,1,1,2,0640,97,2),
(2281,5,1,1,3,0625,115,1),
(2281,5,1,1,4,0425,57,1),
(2281,5,1,1,5,0615,39,2),
(2758,5,1,1,6,0415,115,2),
(2282,5,1,1,1,0640,56,1),
(2281,5,1,1,2,0420,63,1),
(2758,5,1,1,3,0610,57,2),
(2281,5,1,1,4,0440,19,2),
(2282,5,1,1,5,0420,41,2),
(2747,5,1,1,6,0415,82,2),
(4424,5,1,1,1,0630,51,2),
(2747,5,1,1,2,0610,46,2),
(2212,5,1,1,3,0630,104,2),
(2758,5,1,1,4,0615,65,2),
(2334,5,1,1,5,0410,100,1),
(3317,1,1,1,6,0620,122,2),
(2281,4,1,1,1,0630,91,1),
(2281,3,1,1,2,0420,40,2),
(2747,4,1,1,3,0415,102,2),
(2281,5,1,1,4,0620,80,1),
(3317,3,1,1,5,0620,42,2),
(2763,4,1,1,6,0415,47,2),
(2747,5,1,1,1,0625,57,2),
(2747,4,1,1,2,0625,92,2),
(2281,1,1,1,3,0620,38,2),
(2758,4,1,1,4,0425,21,1),
(2212,3,1,1,5,0440,79,1),
(2747,5,1,1,6,0625,37,2),
(2281,4,1,1,1,0620,49,2),
(2763,4,1,1,2,0625,64,2),
(2281,3,1,1,3,0620,87,2),
(3317,5,1,1,4,0630,79,2),
(2281,4,1,1,5,0620,28,2),
(2281,1,1,1,6,0425,104,1),
(2282,4,1,1,1,0420,89,2),
(2750,3,1,1,2,0625,49,2),
(4424,4,1,1,3,0615,99,2),
(2281,1,1,1,4,0420,101,2),
(2747,5,1,1,5,0440,35,2),
(2281,5,1,1,6,0415,100,2),
(2281,4,1,1,1,0610,116,1),
(2334,3,1,1,2,0620,117,1),
(2281,1,1,1,3,0430,55,2),
(2281,4,1,1,4,0420,91,1),
(2281,5,1,1,5,0420,73,2),
(2282,3,1,1,6,0610,41,2),
(2281,4,1,1,1,0630,101,2),
(2212,4,1,1,2,0640,53,2),
(2281,4,1,1,3,0620,119,2),
(3317,1,1,1,4,0420,111,1),
(3317,1,1,1,5,0430,15,1),
(4424,1,1,1,6,0410,26,2),
(4424,4,1,1,1,0640,48,1),
(3317,3,1,1,2,0640,103,2),
(2763,4,1,1,3,0415,106,2),
(2334,1,1,1,4,0610,63,2),
(2281,5,1,1,5,0440,118,2),
(4424,4,1,1,6,0610,102,1),
(2281,3,1,1,1,0610,21,2),
(2282,4,1,1,2,0630,66,2),
(4424,1,1,1,3,0640,46,2),
(2281,5,1,1,4,0625,37,2),
(2281,4,1,1,5,0440,60,2),
(2758,4,1,1,6,0640,27,2),
(2281,3,1,1,1,0425,30,2),
(2281,1,1,1,2,0610,62,2),
(2747,1,1,1,3,0630,68,1),
(2281,3,1,1,4,0610,79,2),
(2758,4,1,1,5,0420,59,2),
(2758,5,1,1,6,0430,91,2),
(2334,4,1,1,1,0425,80,2),
(2281,3,1,1,2,0620,106,2),
(2758,4,1,1,3,0415,99,2),
(2212,1,1,1,4,0615,70,2),
(3317,1,1,1,5,0610,100,1),
(3317,1,1,1,6,0640,36,2),
(2212,1,1,1,1,0615,109,2),
(4424,1,1,1,2,0410,86,1),
(2747,1,1,1,3,0630,22,2),
(2281,1,1,1,4,0425,47,1),
(2281,1,1,1,5,0620,95,2),
(2758,1,1,1,6,0640,89,2),
(2281,1,1,1,1,0440,33,1),
(2282,1,1,1,2,0415,31,2),
(4424,1,1,1,3,0640,116,1),
(2758,1,1,1,4,0625,102,2),
(2281,1,1,1,5,0410,24,2),
(2747,1,1,1,6,0610,29,2),
(4424,1,1,1,1,0440,60,1),
(2282,1,1,1,2,0610,32,2),
(2281,1,1,1,3,0610,83,2),
(3317,1,1,1,4,0425,63,1),
(2763,1,1,1,5,0615,76,2),
(2282,1,1,1,6,0415,24,1),
(2281,1,1,1,1,0615,21,2),
(2281,1,1,1,2,0425,61,1),
(2747,1,1,1,3,0415,23,2),
(4424,1,1,1,4,0640,45,2),
(2282,1,1,1,5,0640,21,2),
(3317,1,1,1,6,0610,20,2),
(2747,1,1,1,1,0640,27,2),
(2281,3,1,1,2,0625,94,2),
(2281,4,1,1,3,0630,124,2),
(2282,5,1,1,4,0410,64,2),
(4424,4,1,1,5,0630,112,1),
(2758,3,1,1,6,0625,66,1),
(2763,4,1,1,1,0620,29,1),
(2281,1,1,1,2,0625,96,2),
(2747,4,1,1,3,0415,104,2),
(2758,3,1,1,4,0640,39,2),
(2281,4,1,1,5,0615,118,2),
(4424,1,1,1,6,0620,110,2),
(2212,4,1,1,1,0640,16,2),
(2750,5,1,1,2,0620,57,2),
(4424,1,1,1,3,0640,45,1),
(4424,1,1,1,4,0625,113,2),
(4424,1,1,1,5,0630,96,2),
(3317,3,1,1,6,0440,28,2),
(2747,4,1,1,1,0415,65,2),
(2282,5,1,1,2,0420,50,2),
(2212,4,1,1,3,0625,74,1),
(2747,3,1,1,4,0430,65,2),
(2281,4,1,1,5,0410,70,1),
(3317,1,1,1,6,0610,69,1),
(3317,4,1,1,1,0415,92,1),
(2758,3,1,1,2,0425,88,1),
(2763,4,1,1,3,0630,21,1),
(3317,1,1,1,4,0640,36,2),
(2282,4,1,1,5,0630,122,2),
(2747,5,1,1,6,0410,28,2),
(2281,1,1,1,1,0410,119,1),
(2750,1,1,1,2,0620,21,2),
(2281,1,1,1,3,0640,60,1),
(2281,3,1,1,4,0615,24,2),
(4424,4,1,1,5,0410,88,1),
(2281,5,1,1,6,0440,73,2),
(2758,4,1,1,1,0425,91,1),
(2758,3,1,1,2,0630,97,2),
(2747,4,1,1,3,0430,45,2),
(2758,1,1,1,4,0640,65,1),
(2747,4,1,1,5,0420,82,2),
(2281,3,1,1,6,0440,77,2),
(2334,4,1,1,1,0415,121,1),
(2758,1,1,1,2,0640,29,1),
(2750,4,1,1,3,0625,94,1),
(3317,5,1,1,4,0630,16,2),
(2281,5,1,1,5,0620,68,2),
(2281,4,1,1,6,0620,84,2),
(2758,3,1,1,1,0610,87,1),
(2747,4,1,1,2,0425,104,2),
(2281,1,1,1,3,0615,43,2),
(4424,4,1,1,4,0610,94,1),
(2282,1,1,1,5,0440,46,2),
(2763,4,1,1,6,0610,104,1),
(2281,3,1,1,1,0610,87,2),
(2281,5,1,1,2,0625,88,2),
(2281,1,1,1,3,0420,89,2),
(2281,1,1,1,4,0420,96,2),
(2281,4,1,1,5,0440,43,2),
(2212,3,1,1,6,0640,89,2),
(4424,4,1,1,1,0440,114,2),
(4424,5,1,1,2,0620,39,1),
(2281,1,1,1,3,0425,57,1),
(2758,1,1,1,4,0625,45,1),
(4424,1,1,1,5,0640,85,2),
(2334,1,1,1,6,0625,98,2),
(2763,1,1,1,1,0610,22,2),
(3317,1,1,1,2,0425,52,2),
(2281,1,1,1,3,0620,24,2),
(2282,1,1,1,4,0625,71,2),
(4424,1,1,1,5,0620,50,2),
(2281,1,1,1,6,0425,20,2),
(2281,1,1,1,1,0415,99,2),
(2758,1,1,1,2,0415,118,2),
(4424,1,1,1,3,0620,30,2),
(2281,1,1,1,4,0615,17,2),
(2747,1,1,1,5,0415,67,1),
(2212,1,1,1,6,0620,79,1),
(2281,1,1,1,1,0415,121,2),
(2758,1,1,1,2,0620,24,1),
(2758,1,1,1,3,0610,92,2),
(2281,1,1,1,4,0610,92,1),
(4424,1,1,1,5,0620,68,1),
(2281,1,1,1,6,0625,73,2),
(3317,1,1,1,1,0610,110,1),
(2747,1,1,1,2,0630,80,1),
(2758,1,1,1,3,0615,20,2),
(2281,1,1,1,4,0620,59,2),
(2282,1,1,1,5,0610,36,2),
(4424,1,1,1,6,0420,41,2),
(2747,1,1,1,1,0430,15,1),
(2281,1,1,1,2,0425,48,2),
(3317,1,1,1,3,0415,40,2),
(2281,1,1,1,4,0610,114,2),
(2747,1,1,1,5,0630,52,1),
(2281,1,1,1,6,0610,67,2),
(2758,1,1,1,1,0610,57,1),
(2758,1,1,1,2,0415,79,2),
(2281,1,1,1,3,0420,95,1),
(2758,1,1,1,4,0630,31,1),
(2747,1,1,1,5,0440,17,2),
(2758,1,1,1,6,0630,72,1),
(2747,1,1,1,1,0615,76,2),
(4424,1,1,1,2,0615,86,1),
(2747,1,1,1,3,0620,28,1),
(3317,1,1,1,4,0620,36,1),
(4424,1,1,1,5,0415,95,1),
(4424,1,1,1,6,0430,55,2),
(2750,1,1,1,1,0640,40,2),
(2281,1,1,1,2,0620,23,2),
(4424,1,1,1,3,0620,51,2),
(2763,1,1,1,4,0610,86,2),
(2281,1,1,1,5,0640,82,2),
(2281,1,1,1,6,0440,122,1),
(2281,1,1,1,1,0615,86,2),
(2758,1,1,1,2,0425,105,2),
(3317,1,1,1,3,0420,71,2),
(3317,1,1,1,4,0625,57,2),
(2334,1,1,1,5,0640,100,2),
(2281,1,1,1,6,0425,25,1),
(2750,1,1,1,1,0640,21,2),
(2758,1,1,1,2,0425,67,2),
(4424,1,1,1,3,0640,48,2),
(2281,1,1,1,4,0625,113,1),
(2747,1,1,1,5,0615,16,2),
(2212,1,1,1,6,0620,60,2),
(2281,1,1,1,1,0620,118,2),
(2281,1,1,1,2,0610,107,1),
(2281,1,1,1,3,0615,44,1),
(4424,1,1,1,4,0425,26,2),
(2763,1,1,1,5,0415,75,2),
(2281,1,1,1,6,0620,93,2),
(2281,1,1,1,1,0420,39,1),
(3317,1,1,1,2,0620,69,2),
(2281,1,1,1,3,0610,48,1),
(4424,1,1,1,4,0620,118,1),
(4424,1,1,1,5,0620,29,2),
(2747,1,1,1,6,0620,40,1),
(2747,1,1,1,1,0620,77,2),
(4424,1,1,1,2,0620,58,2),
(2281,1,1,1,3,0440,107,2),
(4424,1,1,1,4,0410,53,1),
(2763,1,1,1,5,0630,74,1),
(2747,1,1,1,6,0615,99,1),
(2758,1,1,1,1,0625,110,1),
(2281,1,1,1,2,0625,79,2),
(3317,1,1,1,3,0430,51,2),
(4424,1,1,1,4,0615,112,2),
(2281,1,1,1,5,0615,68,2),
(2758,1,1,1,6,0625,74,2),
(2758,1,1,1,1,0630,74,1),
(2334,1,1,1,2,0620,125,1),
(2750,1,1,1,3,0640,105,1),
(2281,1,1,1,4,0615,57,1),
(2281,1,1,1,5,0620,76,2),
(2281,1,1,1,6,0640,63,2),
(2281,1,1,1,1,0625,16,2),
(2747,1,1,1,2,0630,92,2),
(2763,1,1,1,3,0440,20,2),
(2212,1,1,1,4,0420,31,2),
(2281,1,1,1,5,0415,74,1),
(2747,1,1,1,6,0625,35,2),
(2281,1,1,1,1,0620,96,1),
(2281,1,1,1,2,0620,60,2),
(2281,1,1,1,3,0440,99,2),
(2758,1,1,1,4,0430,86,2),
(2758,5,1,1,5,0625,86,2),
(2747,4,1,1,6,0625,124,2),
(3317,3,1,1,1,0625,74,2),
(3317,4,1,1,2,0415,74,2),
(2281,1,1,1,3,0620,73,1),
(2281,4,1,1,4,0410,94,2),
(2750,3,1,1,5,0415,124,2),
(2758,4,1,1,6,0630,113,2),
(2758,1,1,1,1,0625,41,2),
(2747,4,1,1,2,0425,35,1),
(4424,5,1,1,3,0625,68,1),
(2747,1,1,1,4,0625,73,1),
(4424,1,1,1,5,0415,62,2),
(4424,1,1,1,6,0625,61,2),
(2281,3,1,1,1,0415,124,2),
(2747,4,1,1,2,0620,75,2),
(2281,5,1,1,3,0615,76,2),
(2281,4,1,1,4,0640,84,2),
(2281,3,1,1,5,0620,38,2),
(4424,4,1,1,6,0625,112,1),
(2281,1,1,1,1,0640,122,2),
(2281,4,1,1,2,0410,64,2),
(2758,3,1,1,3,0615,15,2),
(2750,4,1,1,4,0430,22,1),
(2281,1,1,1,5,0620,63,1),
(2758,4,1,1,6,0615,112,1),
(4424,5,1,1,1,0430,45,1),
(2281,1,1,1,2,0630,119,2),
(2763,1,1,1,3,0640,88,2),
(2281,1,1,1,4,0620,42,2),
(2758,3,1,1,5,0615,67,2),
(2282,4,1,1,6,0625,60,2),
(2281,5,1,1,1,0640,59,2),
(2747,4,1,1,2,0625,17,2),
(2334,3,1,1,3,0640,111,1),
(4424,4,1,1,4,0625,26,1),
(4424,1,1,1,5,0430,122,1),
(3317,4,1,1,6,0640,95,1),
(4424,3,1,1,1,0610,70,2),
(3317,4,1,1,2,0630,56,1),
(3317,1,1,1,3,0410,83,2),
(2281,4,1,1,4,0440,87,2),
(2747,5,1,1,5,0640,65,2),
(4424,5,1,1,6,0410,26,1),
(2281,4,1,1,1,0420,58,2),
(3317,3,1,1,2,0620,86,1),
(2747,4,1,1,3,0425,56,2),
(3317,1,1,1,4,0615,39,1),
(2281,4,1,1,5,0430,116,1),
(2758,1,1,1,6,0410,123,1),
(2334,4,1,1,1,0620,111,1),
(2282,3,1,1,2,0615,52,2),
(4424,5,1,1,3,0625,56,1),
(2747,1,1,1,4,0625,78,2),
(2282,1,1,1,5,0420,52,2),
(2281,4,1,1,6,0425,122,2),
(2750,3,1,1,1,0420,69,2),
(2212,4,1,1,2,0415,67,1),
(3317,5,1,1,3,0415,26,1),
(2281,4,1,1,4,0425,28,2),
(2747,3,1,1,5,0625,45,1),
(3317,5,1,1,6,0640,99,1),
(2758,4,1,1,1,0420,34,1),
(4424,5,1,1,2,0440,94,2),
(2281,3,1,1,3,0615,15,1),
(2281,4,1,1,4,0640,112,2),
(4424,5,1,1,5,0440,51,2),
(2281,4,1,1,6,0640,66,2),
(4424,3,1,1,1,0430,73,2),
(4424,4,1,1,2,0630,32,2),
(2281,1,1,1,3,0420,108,2),
(2758,4,1,1,4,0625,97,1),
(4424,4,1,1,5,0430,49,2),
(3317,3,1,1,6,0640,67,2),
(2763,4,1,1,1,0615,101,2),
(2281,1,1,1,2,0430,89,2),
(2747,4,1,1,3,0440,58,2),
(4424,3,1,1,4,0420,19,1),
(2747,4,1,1,5,0625,67,2),
(2758,5,1,1,6,0625,51,1),
(2282,3,1,1,1,0630,17,1),
(4424,4,1,1,2,0625,105,2),
(2747,5,1,1,3,0620,71,1),
(2282,4,1,1,4,0625,101,2),
(3317,1,1,1,5,0625,87,2),
(4424,4,1,1,6,0425,27,2),
(3317,3,1,1,1,0430,78,2),
(4424,5,1,1,2,0620,92,2),
(2281,4,1,1,3,0420,60,1),
(2212,4,1,1,4,0640,86,1),
(2763,3,1,1,5,0640,115,2),
(2281,5,1,1,6,0630,55,2),
(2282,4,1,1,1,0620,52,2),
(2281,1,1,1,2,0610,116,1),
(2281,4,1,1,3,0620,56,1),
(2747,3,1,1,4,0620,78,2),
(2281,4,1,1,5,0415,26,2),
(2281,1,1,1,6,0430,66,2),
(2747,5,1,1,1,0640,85,1),
(2758,5,1,1,2,0640,65,1),
(2758,4,1,1,3,0615,86,2),
(2281,3,1,1,4,0410,57,2),
(2763,1,1,1,5,0620,77,2),
(2281,4,1,1,6,0615,93,1),
(2281,5,1,1,1,0615,53,2),
(2281,3,1,1,2,0425,69,2),
(2281,4,1,1,3,0610,78,1),
(2750,4,1,1,4,0630,99,2),
(2747,4,1,1,5,0615,113,2),
(4424,1,1,1,6,0620,26,2),
(2747,1,1,1,1,0610,72,2),
(2747,1,1,1,2,0440,91,1),
(2212,4,1,1,3,0640,96,2),
(2747,3,1,1,4,0615,33,2),
(3317,4,1,1,5,0425,84,2),
(2282,1,1,1,6,0615,55,2),
(3317,5,1,1,1,0620,69,1),
(2281,4,1,1,2,0640,19,2),
(2747,3,1,1,3,0615,76,1),
(4424,4,1,1,4,0610,113,1),
(2281,1,1,1,5,0425,72,2),
(3317,5,1,1,6,0615,29,1),
(2281,4,1,1,1,0440,43,2),
(2282,4,1,1,2,0625,39,2),
(4424,3,1,1,3,0420,47,1),
(2758,1,1,1,4,0630,45,2),
(4424,1,1,1,5,0640,50,2),
(2747,3,1,1,6,0630,117,1),
(3317,4,1,1,1,0625,117,2),
(2281,1,1,1,2,0420,91,1),
(2758,1,1,1,3,0625,30,1),
(4424,1,1,1,4,0420,85,1),
(2282,1,1,1,5,0625,45,2),
(2281,1,1,1,6,0430,15,2),
(2747,1,1,1,1,0615,72,1),
(3317,1,1,1,2,0425,34,2),
(4424,1,1,1,3,0425,102,2),
(2747,1,1,1,4,0625,88,1),
(2334,1,1,1,5,0410,69,2),
(2758,1,1,1,6,0630,76,2),
(2281,1,1,1,1,0625,123,2),
(2747,1,1,1,2,0625,34,1),
(2282,1,1,1,3,0440,80,2),
(2282,1,1,1,4,0620,123,2),
(4424,1,1,1,5,0625,73,2),
(2334,1,1,1,6,0625,23,1),
(2212,1,1,1,1,0610,33,2),
(2281,1,1,1,2,0620,62,2),
(2763,1,1,1,3,0630,96,2),
(3317,1,1,1,4,0425,71,2),
(3317,1,1,1,5,0610,34,1),
(2281,1,1,1,6,0615,33,2),
(4424,1,1,1,1,0630,53,2),
(3317,1,1,1,2,0625,118,2),
(2281,1,1,1,3,0440,49,1),
(2758,1,1,1,4,0640,90,2),
(2758,4,1,1,5,0640,65,2),
(2747,5,1,1,6,0640,93,1),
(2281,1,1,1,1,0620,27,2),
(4424,1,1,1,2,0425,116,1),
(4424,1,1,1,3,0640,32,2),
(4424,3,1,1,4,0410,78,2),
(2281,4,1,1,5,0415,107,1),
(2758,5,1,1,6,0630,70,2),
(2281,4,1,1,1,0630,61,1),
(4424,3,1,1,2,0625,82,2),
(2281,4,1,1,3,0630,73,2),
(2758,1,1,1,4,0640,51,2),
(2281,4,1,1,5,0625,121,2),
(2281,3,1,1,6,0625,48,1),
(3317,4,1,1,1,0620,27,2),
(3317,1,1,1,2,0420,68,2),
(4424,4,1,1,3,0420,76,2),
(2747,5,1,1,4,0630,118,2),
(2281,1,1,1,5,0420,114,2),
(4424,1,1,1,6,0630,86,2),
(2747,1,1,1,1,0640,72,2),
(3317,3,1,1,2,0625,123,2),
(4424,4,1,1,3,0430,67,2),
(4424,5,1,1,4,0440,32,2),
(2281,4,1,1,5,0430,118,2),
(2281,3,1,1,6,0430,120,2),
(2282,4,1,1,1,0440,89,2),
(2282,1,1,1,2,0615,47,2),
(2747,4,1,1,3,0425,103,2),
(2281,3,1,1,4,0630,31,2),
(2281,4,1,1,5,0610,41,1),
(2281,1,1,1,6,0615,77,2),
(2281,4,1,1,1,0420,35,2),
(2281,5,1,1,2,0615,45,1),
(3317,1,1,1,3,0615,95,1),
(4424,1,1,1,4,0415,74,1),
(2758,1,1,1,5,0410,106,2),
(4424,3,1,1,6,0620,18,1),
(2758,4,1,1,1,0630,44,2),
(2281,5,1,1,2,0415,52,1),
(2747,4,1,1,3,0620,50,2),
(2747,3,1,1,4,0615,66,1),
(2281,4,1,1,5,0420,81,2),
(2281,1,1,1,6,0430,109,1),
(2281,4,1,1,1,0615,19,1),
(2281,3,1,1,2,0630,25,1),
(2212,4,1,1,3,0415,71,2),
(3317,1,1,1,4,0425,46,2),
(2282,4,1,1,5,0410,82,2),
(3317,5,1,1,6,0625,80,1),
(2281,5,1,1,1,0620,108,1),
(4424,4,1,1,2,0640,81,1),
(2281,3,1,1,3,0615,46,2),
(4424,4,1,1,4,0640,125,2),
(2281,1,1,1,5,0425,86,2),
(2281,4,1,1,6,0425,25,2),
(2281,1,1,1,1,0630,79,1),
(2758,4,1,1,2,0430,118,2),
(4424,3,1,1,3,0640,119,1),
(3317,5,1,1,4,0420,58,2),
(2212,5,1,1,5,0630,47,1),
(2763,5,1,1,6,0625,88,2),
(2281,5,1,1,1,0615,117,1),
(4424,5,1,1,2,0440,89,2),
(2747,5,1,1,3,0610,121,1),
(2747,5,1,1,4,0430,83,1),
(2763,5,1,1,5,0615,57,2),
(2282,5,1,1,6,0640,98,1),
(4424,5,1,1,1,0610,120,2),
(2747,5,1,1,2,0410,113,2),
(2747,5,1,1,3,0615,122,1),
(2758,5,1,1,4,0615,123,1),
(2750,5,1,1,5,0420,111,2),
(2281,5,1,1,6,0615,65,2),
(2281,5,1,1,1,0410,91,2),
(2281,5,1,1,2,0420,63,2),
(2281,5,1,1,3,0610,54,2),
(2281,5,1,1,4,0610,21,1),
(3317,5,1,1,5,0640,50,2),
(2212,4,1,1,6,0630,109,1),
(2282,3,1,1,1,0610,76,2),
(4424,4,1,1,2,0625,45,2),
(2747,1,1,1,3,0625,19,2),
(2747,4,1,1,4,0640,107,2),
(4424,3,1,1,5,0625,53,1),
(2758,4,1,1,6,0640,118,1),
(2758,5,1,1,1,0615,66,1),
(2747,3,1,1,2,0615,111,2),
(2282,4,1,1,3,0610,101,2),
(2212,5,1,1,4,0640,49,2),
(2747,4,1,1,5,0610,60,1),
(2281,1,1,1,6,0630,58,2),
(2281,4,1,1,1,0420,86,2),
(2334,3,1,1,2,0420,64,1),
(3317,5,1,1,3,0625,120,2),
(2763,4,1,1,4,0610,120,2),
(2758,4,1,1,5,0420,119,2),
(2282,3,1,1,6,0410,20,2),
(4424,5,1,1,1,0615,108,2),
(2281,4,1,1,2,0630,37,2),
(2281,1,1,1,3,0630,57,2),
(2281,4,1,1,4,0440,90,2),
(4424,3,1,1,5,0430,118,1),
(2763,4,1,1,6,0620,92,1),
(3317,1,1,1,1,0640,63,2),
(2281,5,1,1,2,0625,30,2),
(2282,5,1,1,3,0630,35,1),
(2281,4,1,1,4,0420,88,1),
(2281,3,1,1,5,0425,15,2),
(2747,1,1,1,6,0640,100,2),
(2758,4,1,1,1,0425,117,1),
(2281,5,1,1,2,0610,97,2),
(2747,3,1,1,3,0440,65,2),
(2281,4,1,1,4,0620,125,2),
(2750,4,1,1,5,0630,29,2),
(2281,4,1,1,6,0415,94,1),
(2334,1,1,1,1,0620,95,2),
(2281,1,1,1,2,0440,34,1),
(3317,1,1,1,3,0415,59,2),
(2758,4,1,1,4,0620,106,2),
(2282,3,1,1,5,0440,120,2),
(2747,4,1,1,6,0630,55,2),
(3317,1,1,1,1,0640,104,1),
(2758,5,1,1,2,0430,84,2),
(2281,4,1,1,3,0610,33,2),
(2758,3,1,1,4,0615,92,2),
(2281,4,1,1,5,0615,120,1),
(2747,1,1,1,6,0640,115,2),
(2763,5,1,1,1,0625,97,1),
(2281,4,1,1,2,0415,123,2),
(2281,4,1,1,3,0615,28,2),
(2281,5,1,1,4,0440,95,2),
(2281,5,1,1,5,0415,33,2),
(2747,5,1,1,6,0415,99,2),
(2282,5,1,1,1,0620,35,2),
(2763,5,1,1,2,0430,74,1),
(2758,5,1,1,3,0610,121,2),
(4424,5,1,1,4,0615,18,1),
(4424,5,1,1,5,0425,28,2),
(2281,5,1,1,6,0620,50,1),
(3317,5,1,1,1,0430,49,1),
(2282,5,1,1,2,0430,78,1),
(2750,5,1,1,3,0625,39,1),
(4424,5,1,1,4,0630,111,2),
(4424,5,1,1,5,0615,84,2),
(2281,5,1,1,6,0640,27,2),
(2281,5,1,1,1,0430,44,1),
(2282,5,1,1,2,0430,105,2),
(3317,5,1,1,3,0625,43,2),
(3317,5,1,1,4,0615,63,2),
(2281,5,1,1,5,0620,22,1),
(2281,5,1,1,6,0430,76,2),
(4424,5,1,1,1,0430,71,2),
(2763,5,1,1,2,0610,54,1),
(2758,5,1,1,3,0610,29,2),
(4424,5,1,1,4,0625,102,2),
(2281,5,1,1,5,0640,46,2),
(2747,5,1,1,6,0640,80,2),
(2758,5,1,1,1,0615,122,2),
(2212,5,1,1,2,0610,48,2),
(2281,5,1,1,3,0640,54,1),
(2747,5,1,1,4,0640,47,2),
(3317,5,1,1,5,0425,105,2),
(2758,5,1,1,6,0430,90,1),
(2282,5,1,1,1,0440,29,1),
(2281,5,1,1,2,0625,90,2),
(2747,5,1,1,3,0640,39,1),
(4424,5,1,1,4,0640,19,2),
(2281,5,1,1,5,0620,15,2),
(4424,5,1,1,6,0620,71,1),
(2281,5,1,1,1,0620,84,1),
(2747,5,1,1,2,0615,115,2),
(2212,5,1,1,3,0415,38,2),
(2281,5,1,1,4,0630,103,2),
(2750,5,1,1,5,0610,70,2),
(2758,5,1,1,6,0410,80,2),
(2281,5,1,1,1,0440,49,1),
(2334,5,1,1,2,0615,22,2),
(4424,5,1,1,3,0430,45,2),
(2281,5,1,1,4,0440,90,1),
(2212,5,1,1,5,0410,79,2),
(2763,5,1,1,6,0620,44,2),
(4424,5,1,1,1,0420,115,1),
(2758,5,1,1,2,0640,34,2),
(2758,5,1,1,3,0625,19,1),
(2747,5,1,1,4,0640,53,2),
(3317,5,1,1,5,0610,117,1),
(2281,5,1,1,6,0610,20,2),
(2747,5,1,1,1,0615,27,1),
(3317,5,1,1,2,0610,33,2),
(4424,5,1,1,3,0615,21,1),
(2747,5,1,1,4,0610,55,1),
(2281,5,1,1,5,0440,16,1),
(2212,5,1,1,6,0640,103,2),
(2758,5,1,1,1,0615,76,2),
(2747,5,1,1,2,0610,87,2),
(2282,5,1,1,3,0620,60,2),
(2281,5,1,1,4,0610,29,1),
(2758,5,1,1,5,0640,51,1),
(3317,5,1,1,6,0625,56,2),
(2747,5,1,1,1,0640,97,2),
(2281,5,1,1,2,0430,81,1),
(2281,5,1,1,3,0630,28,2),
(2281,5,1,1,4,0640,15,2),
(2281,5,1,1,5,0615,32,2),
(2281,5,1,1,6,0430,98,2),
(2281,5,1,1,1,0630,23,2),
(2747,5,1,1,2,0610,31,2),
(2750,5,1,1,3,0610,31,2),
(2212,5,1,1,4,0630,102,2),
(2281,5,1,1,5,0640,89,1),
(2747,5,1,1,6,0620,88,1),
(2281,5,1,1,1,0640,114,2),
(2281,5,1,1,2,0630,102,1),
(2281,5,1,1,3,0610,48,2),
(2281,5,1,1,4,0420,73,2),
(4424,5,1,1,5,0625,48,1),
(2281,5,1,1,6,0630,122,2),
(2747,5,1,1,1,0630,56,2),
(2281,5,1,1,2,0630,33,1),
(2758,5,1,1,3,0640,55,2),
(4424,5,1,1,4,0615,79,1),
(4424,5,1,1,5,0610,21,2),
(2758,5,1,1,6,0620,103,2),
(3317,5,1,1,1,0625,69,2),
(2747,5,1,1,2,0415,113,1),
(3317,5,1,1,3,0615,78,1),
(2281,5,1,1,4,0425,59,2),
(2281,5,1,1,5,0420,88,2),
(2281,5,1,1,6,0615,20,1),
(2212,5,1,1,1,0615,121,2),
(2282,5,1,1,2,0420,27,2),
(2281,5,1,1,3,0610,106,1),
(2281,5,1,1,4,0625,42,2),
(4424,5,1,1,5,0630,125,2),
(2747,5,1,1,6,0630,44,1),
(3317,5,1,1,1,0625,108,1),
(2281,5,1,1,2,0625,24,2),
(4424,5,1,1,3,0610,74,2),
(2212,5,1,1,4,0610,24,2),
(3317,5,1,1,5,0630,31,2),
(2747,5,1,1,6,0620,104,1),
(2758,5,1,1,1,0425,54,2),
(2281,5,1,1,2,0615,90,2),
(2747,5,1,1,3,0640,69,2),
(2758,5,1,1,4,0415,104,1),
(2281,5,1,1,5,0425,87,2),
(2281,5,1,1,6,0625,57,2),
(2747,5,1,1,1,0630,115,2),
(4424,5,1,1,2,0625,111,1),
(2758,5,1,1,3,0610,56,2),
(3317,5,1,1,4,0415,62,2),
(2281,5,1,1,5,0420,50,2),
(4424,5,1,1,6,0625,105,1),
(2281,5,1,1,1,0440,64,2),
(4424,5,1,1,2,0415,21,1),
(2750,5,1,1,3,0420,19,2),
(2763,5,1,1,4,0630,41,2),
(2281,5,1,1,5,0410,122,2),
(2281,5,1,1,6,0415,35,1),
(4424,5,1,1,1,0410,71,1),
(2747,5,1,1,2,0625,119,1),
(3317,5,1,1,3,0420,111,1),
(2281,5,1,1,4,0430,22,1),
(4424,5,1,1,5,0620,34,2),
(2212,5,1,1,6,0610,34,1),
(2758,5,1,1,1,0640,65,2),
(2758,5,1,1,2,0615,28,2),
(2281,5,1,1,3,0630,46,2),
(2281,5,1,1,4,0440,33,1),
(2281,5,1,1,5,0610,90,2),
(2747,5,1,1,6,0630,78,2),
(4424,5,1,1,1,0420,17,2),
(2281,5,1,1,2,0625,18,2),
(2281,5,1,1,3,0410,43,2),
(2282,5,1,1,4,0420,105,1),
(2281,5,1,1,5,0425,115,2),
(2747,5,1,1,6,0620,96,1),
(2212,5,1,1,1,0640,91,2),
(2750,5,1,1,2,0430,93,2),
(4424,5,1,1,3,0420,54,2),
(2281,5,1,1,4,0620,105,2),
(4424,5,1,1,5,0610,84,2),
(2763,3,1,1,6,0420,79,1),
(2281,4,1,1,1,0415,79,1),
(2281,1,1,1,2,0640,65,1),
(2282,5,1,1,3,0620,29,2),
(2281,4,1,1,4,0640,84,1),
(2763,3,1,1,5,0615,86,2),
(2212,4,1,1,6,0615,86,1),
(2281,1,1,1,1,0620,117,2),
(4424,5,1,1,2,0440,122,2),
(2282,4,1,1,3,0410,100,2),
(2281,4,1,1,4,0615,94,1),
(2281,3,1,1,5,0620,85,1),
(2747,1,1,1,6,0440,21,1),
(2334,1,1,1,1,0625,53,1),
(3317,3,1,1,2,0610,69,2),
(4424,4,1,1,3,0430,33,1),
(2281,5,1,1,4,0610,121,2),
(2281,4,1,1,5,0620,36,1),
(2758,3,1,1,6,0440,106,2),
(2212,4,1,1,1,0440,62,2),
(2747,1,1,1,2,0625,40,2),
(2747,4,1,1,3,0425,43,1),
(2282,5,1,1,4,0610,63,2),
(4424,5,1,1,5,0630,90,1),
(2212,4,1,1,6,0610,57,2),
(2758,4,1,1,1,0640,37,2),
(4424,5,1,1,2,0615,119,2),
(2747,3,1,1,3,0615,74,2),
(2750,3,1,1,4,0620,69,2),
(2281,4,1,1,5,0630,111,1),
(2334,1,1,1,6,0610,17,2),
(2212,1,1,1,1,0610,124,2),
(2281,3,1,1,2,0620,41,2),
(2281,4,1,1,3,0610,111,2),
(4424,5,1,1,4,0610,26,2),
(2763,4,1,1,5,0610,60,1),
(2763,3,1,1,6,0440,101,1),
(2747,4,1,1,1,0640,30,1),
(2747,1,1,1,2,0430,48,2),
(2758,4,1,1,3,0630,111,1),
(2281,3,1,1,4,0620,123,2),
(3317,4,1,1,5,0630,118,1),
(4424,1,1,1,6,0430,40,1),
(2281,4,1,1,1,0620,71,1),
(2282,5,1,1,2,0410,125,2),
(4424,1,1,1,3,0630,32,2),
(4424,1,1,1,4,0420,103,2),
(2281,1,1,1,5,0440,27,2),
(2281,3,1,1,6,0615,103,1),
(3317,4,1,1,1,0410,117,2),
(2281,5,1,1,2,0415,84,1),
(3317,4,1,1,3,0620,29,2),
(2281,3,1,1,4,0625,54,2),
(3317,4,1,1,5,0640,101,2),
(2281,1,1,1,6,0640,29,1),
(2758,4,1,1,1,0430,83,1),
(2747,3,1,1,2,0420,111,2),
(2281,4,1,1,3,0615,31,2),
(4424,1,1,1,4,0630,79,2),
(4424,4,1,1,5,0615,50,1),
(2281,5,1,1,6,0610,36,2),
(2281,1,1,1,1,0630,60,2),
(4424,1,1,1,2,0415,46,2),
(4424,1,1,1,3,0620,84,1),
(2758,5,1,1,4,0625,20,1),
(2750,5,1,1,5,0640,27,2),
(4424,5,1,1,6,0415,26,1),
(2758,5,1,1,1,0630,112,1),
(2334,5,1,1,2,0420,118,2),
(4424,5,1,1,3,0620,80,2),
(2747,5,1,1,4,0425,82,2),
(3317,5,1,1,5,0625,74,1),
(2763,5,1,1,6,0640,29,1),
(2758,5,1,1,1,0615,67,2),
(2281,5,1,1,2,0420,73,2),
(2758,5,1,1,3,0630,31,1),
(2212,5,1,1,4,0625,111,1),
(2281,5,1,1,5,0625,72,1),
(4424,5,1,1,6,0630,104,1),
(2747,5,1,1,1,0610,67,2),
(2282,5,1,1,2,0640,99,2),
(4424,5,1,1,3,0630,27,2),
(4424,5,1,1,4,0615,74,2),
(3317,5,1,1,5,0420,33,1),
(2281,5,1,1,6,0420,22,1),
(2212,5,1,1,1,0430,71,1),
(2281,5,1,1,2,0625,36,1),
(2758,5,1,1,3,0615,115,2),
(4424,5,1,1,4,0440,39,2),
(4424,5,1,1,5,0440,116,2),
(2281,5,1,1,6,0620,65,2),
(2281,5,1,1,1,0615,70,2),
(2758,5,1,1,2,0630,28,1),
(4424,5,1,1,3,0440,33,1),
(2750,5,1,1,4,0625,56,2),
(4424,5,1,1,5,0615,32,1),
(2281,5,1,1,6,0620,61,2),
(2334,5,1,1,1,0610,35,2),
(4424,5,1,1,2,0640,48,1),
(4424,5,1,1,3,0430,20,1),
(2212,5,1,1,4,0615,102,1),
(4424,5,1,1,5,0420,58,1),
(2281,5,1,1,6,0630,92,2),
(2763,5,1,1,1,0610,105,2),
(4424,5,1,1,2,0415,45,2),
(4424,5,1,1,3,0415,73,1),
(2212,5,1,1,4,0425,27,1),
(2758,5,1,1,5,0610,69,1),
(2758,5,1,1,6,0640,118,1),
(2758,5,1,1,1,0440,31,1),
(2281,5,1,1,2,0625,88,1),
(2758,5,1,1,3,0430,113,2),
(2281,5,1,1,4,0420,72,2),
(2281,5,1,1,5,0415,60,2),
(2747,5,1,1,6,0610,37,2),
(2281,5,1,1,1,0425,46,2),
(2747,5,1,1,2,0415,59,2),
(3317,5,1,1,3,0620,43,2),
(2281,5,1,1,4,0630,111,1),
(2747,5,1,1,5,0430,40,1),
(2747,5,1,1,6,0610,23,1),
(2750,5,1,1,1,0610,87,2),
(2281,5,1,1,2,0620,72,2),
(4424,5,1,1,3,0640,55,2),
(2281,5,1,1,4,0430,103,2),
(2281,5,1,1,5,0640,107,1),
(2747,5,1,1,6,0615,77,2),
(2281,5,1,1,1,0620,121,2),
(2758,5,1,1,2,0620,66,2),
(2281,5,1,1,3,0610,61,2),
(2747,5,1,1,4,0610,36,2),
(2281,5,1,1,5,0430,83,2),
(2282,5,1,1,6,0440,17,2),
(2281,5,1,1,1,0410,46,2),
(2758,5,1,1,2,0610,53,1),
(2282,5,1,1,3,0610,68,1),
(2747,5,1,1,4,0615,51,2),
(2758,5,1,1,5,0430,64,1),
(3317,5,1,1,6,0415,37,1),
(2281,5,1,1,1,0620,113,2),
(3317,5,1,1,2,0620,79,2),
(3317,5,1,1,3,0620,60,1),
(4424,5,1,1,4,0615,86,1),
(2281,5,1,1,5,0630,108,2),
(2747,5,1,1,6,0630,50,1),
(4424,5,1,1,1,0610,122,2),
(2281,5,1,1,2,0640,17,2),
(2281,5,1,1,3,0630,58,2),
(2212,5,1,1,4,0625,42,2),
(2281,5,1,1,5,0630,119,1),
(2758,5,1,1,6,0630,68,1),
(2758,5,1,1,1,0615,66,1),
(2212,5,1,1,2,0625,88,1),
(2334,5,1,1,3,0620,112,1),
(2281,5,1,1,4,0625,65,1),
(2281,5,1,1,5,0440,75,2),
(4424,5,1,1,6,0415,39,2),
(4424,5,1,1,1,0625,86,2),
(2747,5,1,1,2,0640,115,2),
(2282,5,1,1,3,0630,35,2),
(2281,5,1,1,4,0625,98,1),
(4424,5,1,1,5,0615,73,1),
(2747,5,1,1,6,0640,95,2),
(3317,5,1,1,1,0620,107,1),
(2281,5,1,1,2,0630,91,1),
(4424,5,1,1,3,0430,46,2),
(3317,5,1,1,4,0630,46,2),
(2747,5,1,1,5,0440,55,2),
(2281,5,1,1,6,0415,47,2),
(2758,5,1,1,1,0440,124,1),
(2763,5,1,1,2,0620,38,1),
(2750,5,1,1,3,0430,21,2),
(2758,5,1,1,4,0630,40,2),
(4424,5,1,1,5,0625,18,2),
(2281,5,1,1,6,0640,66,1),
(2212,5,1,1,1,0620,124,1),
(2281,5,1,1,2,0430,121,2),
(2758,5,1,1,3,0640,86,2),
(2212,5,1,1,4,0610,98,2),
(2281,5,1,1,5,0415,95,2),
(2282,5,1,1,6,0640,27,2),
(2758,5,1,1,1,0620,24,1),
(3317,5,1,1,2,0420,20,2),
(2747,5,1,1,3,0640,90,1),
(2758,5,1,1,4,0410,53,1),
(4424,5,1,1,5,0610,59,2),
(2747,5,1,1,6,0640,121,2),
(2747,5,1,1,1,0615,46,1),
(3317,5,1,1,2,0610,21,2),
(2758,5,1,1,3,0615,125,1),
(4424,5,1,1,4,0640,22,2),
(2281,5,1,1,5,0415,91,1),
(2281,5,1,1,6,0620,33,2),
(2758,5,1,1,1,0630,75,2),
(2281,5,1,1,2,0610,125,2),
(2282,5,1,1,3,0610,111,1),
(2212,5,1,1,4,0440,45,2),
(2281,5,1,1,5,0430,20,1),
(4424,4,1,1,6,0610,94,2),
(2281,3,1,1,1,0430,90,2),
(2281,4,1,1,2,0610,20,2),
(2747,1,1,1,3,0625,80,1),
(4424,4,1,1,4,0615,59,2),
(2747,3,1,1,5,0420,111,1),
(2758,4,1,1,6,0430,79,2),
(2282,1,1,1,1,0610,23,1),
(2281,4,1,1,2,0625,27,1),
(2212,5,1,1,3,0610,88,2),
(3317,1,1,1,4,0625,89,2),
(2281,1,1,1,5,0625,56,2),
(2747,1,1,1,6,0640,94,2),
(2334,3,1,1,1,0630,43,2),
(2758,4,1,1,2,0640,17,2),
(2282,5,1,1,3,0610,93,2),
(3317,4,1,1,4,0610,24,2),
(2281,3,1,1,5,0620,18,2),
(2747,4,1,1,6,0625,117,2),
(2758,1,1,1,1,0610,51,2),
(2281,4,1,1,2,0620,28,2),
(2747,3,1,1,3,0640,122,2),
(2763,4,1,1,4,0640,19,1),
(2282,1,1,1,5,0420,78,1),
(2281,4,1,1,6,0610,23,2),
(2281,5,1,1,1,0440,22,2),
(2758,1,1,1,2,0420,104,2),
(2281,1,1,1,3,0630,27,2),
(3317,1,1,1,4,0620,50,1),
(4424,3,1,1,5,0630,60,2),
(2758,4,1,1,6,0615,15,1),
(2281,5,1,1,1,0410,17,2),
(2281,4,1,1,2,0620,72,1),
(4424,3,1,1,3,0615,120,2),
(2747,4,1,1,4,0640,58,2),
(2282,1,1,1,5,0410,82,2),
(2750,4,1,1,6,0625,61,1),
(2282,3,1,1,1,0640,109,2),
(3317,4,1,1,2,0420,122,2),
(3317,1,1,1,3,0630,88,2),
(2758,4,1,1,4,0625,73,1),
(2282,5,1,1,5,0420,34,2),
(2281,1,1,1,6,0630,105,1),
(4424,1,1,1,1,0615,67,1),
(2747,1,1,1,2,0420,66,2),
(4424,3,1,1,3,0610,29,2),
(2281,4,1,1,4,0640,87,1),
(2281,5,1,1,5,0610,125,1),
(2281,4,1,1,6,0420,16,2),
(2758,3,1,1,1,0610,27,2),
(2758,4,1,1,2,0625,60,1),
(2747,1,1,1,3,0620,81,2),
(2282,4,1,1,4,0425,60,1),
(2747,3,1,1,5,0620,18,1),
(2281,4,1,1,6,0630,23,2),
(2281,1,1,1,1,0610,79,2),
(4424,4,1,1,2,0420,23,2),
(2747,5,1,1,3,0610,18,1),
(4424,5,1,1,4,0610,97,2),
(2281,4,1,1,5,0610,64,1),
(2281,3,1,1,6,0640,51,1),
(2747,4,1,1,1,0620,68,1),
(2282,1,1,1,2,0430,56,1),
(2281,4,1,1,3,0610,52,2),
(2747,1,1,1,4,0620,114,2),
(2758,4,1,1,5,0630,83,2),
(3317,3,1,1,6,0630,23,2),
(2281,5,1,1,1,0615,25,2),
(3317,1,1,1,2,0640,70,1),
(2212,1,1,1,3,0420,117,2),
(2763,4,1,1,4,0425,69,1),
(2282,3,1,1,5,0410,28,2),
(2212,4,1,1,6,0630,17,2),
(2750,5,1,1,1,0610,31,1),
(4424,4,1,1,2,0415,57,2),
(2747,3,1,1,3,0630,53,2),
(2282,5,1,1,4,0620,89,1),
(2281,4,1,1,5,0620,96,2),
(2281,5,1,1,6,0610,115,2),
(2281,3,1,1,1,0640,35,2),
(2758,4,1,1,2,0640,58,2),
(2281,5,1,1,3,0425,110,1),
(2281,4,1,1,4,0425,115,2),
(4424,3,1,1,5,0620,93,1),
(3317,4,1,1,6,0620,27,2),
(2334,1,1,1,1,0410,73,2),
(2281,4,1,1,2,0440,79,2),
(2758,4,1,1,3,0410,106,2),
(4424,3,1,1,4,0440,78,2),
(2758,4,1,1,5,0425,28,2),
(4424,1,1,1,6,0610,113,2),
(2281,4,1,1,1,0625,34,1),
(2282,3,1,1,2,0630,110,2),
(3317,4,1,1,3,0620,52,2),
(2281,5,1,1,4,0615,55,2),
(2758,3,1,1,5,0415,99,1),
(2281,4,1,1,6,0620,36,1),
(2282,5,1,1,1,0630,32,2),
(3317,4,1,1,2,0630,89,2),
(2281,1,1,1,3,0610,64,2),
(2281,4,1,1,4,0640,99,1),
(2758,3,1,1,5,0610,15,2),
(2282,5,1,1,6,0410,114,2),
(2747,4,1,1,1,0615,84,2),
(2763,4,1,1,2,0620,82,2),
(2758,3,1,1,3,0420,72,2),
(2758,5,1,1,4,0615,123,2),
(4424,4,1,1,5,0440,46,2),
(2281,1,1,1,6,0610,84,2),
(2758,4,1,1,1,0630,103,1),
(3317,3,1,1,2,0625,56,2),
(2281,4,1,1,3,0640,47,1),
(4424,1,1,1,4,0615,73,2),
(2281,5,1,1,5,0640,91,2),
(2750,4,1,1,6,0630,35,2),
(2212,3,1,1,1,0415,53,2),
(2281,4,1,1,2,0615,60,2),
(2282,1,1,1,3,0610,124,1),
(2763,4,1,1,4,0640,63,2),
(2281,1,1,1,5,0430,91,1),
(3317,4,1,1,6,0610,15,2),
(3317,3,1,1,1,0625,110,1),
(3317,5,1,1,2,0620,51,2),
(2747,1,1,1,3,0630,67,1),
(2758,1,1,1,4,0410,65,1),
(2282,4,1,1,5,0415,41,1),
(2281,3,1,1,6,0410,84,1),
(4424,4,1,1,1,0420,97,2),
(4424,5,1,1,2,0615,63,1),
(2747,4,1,1,3,0625,28,2),
(2281,3,1,1,4,0630,58,2),
(2747,5,1,1,5,0440,119,2),
(2281,4,1,1,6,0630,82,2),
(2282,5,1,1,1,0620,119,1),
(2281,3,1,1,2,0420,55,2),
(2281,4,1,1,3,0640,124,2),
(2758,5,1,1,4,0630,52,2),
(2747,4,1,1,5,0410,103,2),
(2747,3,1,1,6,0610,113,2),
(2281,4,1,1,1,0625,92,2),
(4424,1,1,1,2,0410,50,2),
(2758,4,1,1,3,0620,50,1),
(2758,4,1,1,4,0615,79,2),
(2212,3,1,1,5,0610,99,2),
(2747,4,1,1,6,0425,125,1),
(2281,1,1,1,1,0610,90,2),
(2281,4,1,1,2,0620,37,2),
(2758,3,1,1,3,0620,47,1),
(2282,4,1,1,4,0615,31,2),
(2281,5,1,1,5,0610,119,2),
(3317,3,1,1,6,0425,112,2),
(4424,4,1,1,1,0620,59,1),
(2758,5,1,1,2,0630,30,2),
(2334,4,1,1,3,0440,59,2),
(3317,1,1,1,4,0610,73,1),
(2281,4,1,1,5,0615,112,1),
(2281,3,1,1,6,0620,19,2),
(2747,5,1,1,1,0610,16,1),
(2281,4,1,1,2,0415,100,2),
(2763,4,1,1,3,0640,15,2),
(2747,3,1,1,4,0620,17,2),
(4424,5,1,1,5,0420,116,1),
(2758,4,1,1,6,0640,120,1),
(3317,1,1,1,1,0630,97,2),
(2281,4,1,1,2,0610,80,1),
(3317,3,1,1,3,0610,59,1),
(2758,4,1,1,4,0625,59,2),
(4424,1,1,1,5,0640,45,2),
(2750,5,1,1,6,0430,73,1),
(2281,5,1,1,1,0640,52,2),
(3317,4,1,1,2,0625,55,2),
(2758,3,1,1,3,0425,57,2),
(4424,1,1,1,4,0410,28,1),
(2747,4,1,1,5,0430,78,2),
(4424,5,1,1,6,0610,34,2),
(2747,3,1,1,1,0630,99,2),
(2281,4,1,1,2,0640,21,1),
(2281,4,1,1,3,0415,62,2),
(2281,4,1,1,4,0625,125,1),
(2281,1,1,1,5,0615,46,2),
(2281,1,1,1,6,0615,53,1),
(2281,1,1,1,1,0640,60,2),
(2758,4,1,1,2,0610,23,1),
(4424,3,1,1,3,0640,120,2),
(4424,4,1,1,4,0630,25,2),
(2212,1,1,1,5,0420,50,1),
(3317,5,1,1,6,0415,68,2),
(2281,4,1,1,1,0640,123,2),
(4424,3,1,1,2,0625,112,2),
(2281,4,1,1,3,0415,82,2),
(4424,1,1,1,4,0625,69,2),
(2747,5,1,1,5,0430,53,1),
(2763,4,1,1,6,0625,46,1),
(2758,4,1,1,1,0630,74,1),
(2281,3,1,1,2,0615,72,1),
(2758,1,1,1,3,0640,110,2),
(2281,1,1,1,4,0615,15,2),
(2758,3,1,1,5,0610,86,2),
(2758,4,1,1,6,0615,22,1),
(2747,5,1,1,1,0615,45,2),
(2281,4,1,1,2,0620,67,1),
(2282,3,1,1,3,0415,61,2),
(2763,4,1,1,4,0640,111,2),
(2281,1,1,1,5,0615,68,2),
(2281,4,1,1,6,0620,109,2),
(2281,5,1,1,1,0410,28,2),
(2747,5,1,1,2,0440,114,2),
(3317,4,1,1,3,0425,110,2),
(2750,4,1,1,4,0425,100,2),
(2758,5,1,1,5,0425,102,2),
(2281,3,1,1,6,0620,112,1),
(2747,3,1,1,1,0615,121,2),
(4424,4,1,1,2,0610,55,2),
(2758,1,1,1,3,0410,84,2),
(4424,1,1,1,4,0630,65,2),
(2281,3,1,1,5,0430,78,2),
(2282,4,1,1,6,0620,29,1),
(2281,5,1,1,1,0630,75,1),
(4424,4,1,1,2,0620,121,2),
(3317,3,1,1,3,0430,105,1),
(2747,4,1,1,4,0440,88,2),
(2758,1,1,1,5,0625,55,2),
(2747,4,1,1,6,0640,98,2),
(2763,3,1,1,1,0630,39,2),
(4424,4,1,1,2,0610,36,1),
(2758,1,1,1,3,0420,35,2),
(4424,4,1,1,4,0415,67,2),
(2281,5,1,1,5,0410,99,1),
(2281,1,1,1,6,0620,54,1),
(2281,1,1,1,1,0430,95,2),
(2763,1,1,1,2,0625,115,2),
(4424,3,1,1,3,0630,15,2),
(2212,4,1,1,4,0625,39,2),
(3317,5,1,1,5,0425,51,2),
(3317,4,1,1,6,0630,20,2),
(2747,3,1,1,1,0625,112,2),
(2758,4,1,1,2,0615,50,2),
(3317,1,1,1,3,0425,17,1),
(4424,4,1,1,4,0615,41,1),
(2281,3,1,1,5,0625,88,2),
(2281,4,1,1,6,0615,115,1),
(2758,1,1,1,1,0615,120,2),
(2758,4,1,1,2,0620,17,2),
(4424,5,1,1,3,0615,25,1),
(2747,1,1,1,4,0410,33,2),
(2282,1,1,1,5,0440,72,2),
(2747,1,1,1,6,0610,74,2),
(3317,3,1,1,1,0415,83,2),
(2281,4,1,1,2,0615,119,2),
(2758,5,1,1,3,0610,98,2),
(2281,4,1,1,4,0610,53,2),
(2758,3,1,1,5,0625,22,2),
(2747,4,1,1,6,0430,109,2),
(2281,1,1,1,1,0615,45,2),
(2281,4,1,1,2,0610,120,2),
(2282,3,1,1,3,0610,121,2),
(2281,4,1,1,4,0625,110,2),
(2281,1,1,1,5,0615,75,2),
(2747,4,1,1,6,0425,22,2),
(2281,5,1,1,1,0415,54,1),
(2281,1,1,1,2,0415,47,1),
(3317,1,1,1,3,0425,120,2),
(4424,1,1,1,4,0610,17,2),
(2212,3,1,1,5,0640,36,2),
(3317,4,1,1,6,0640,73,2),
(2747,5,1,1,1,0410,54,1),
(2281,4,1,1,2,0615,23,2),
(2281,3,1,1,3,0430,72,1),
(4424,4,1,1,4,0610,17,1),
(2281,1,1,1,5,0415,66,2),
(4424,4,1,1,6,0425,18,2),
(2758,3,1,1,1,0625,109,2),
(2282,4,1,1,2,0630,93,1),
(2747,1,1,1,3,0630,70,1),
(2763,4,1,1,4,0415,70,2),
(2281,5,1,1,5,0615,42,2),
(2281,5,1,1,6,0615,124,1),
(4424,4,1,1,1,0610,54,2),
(4424,3,1,1,2,0425,62,2),
(4424,4,1,1,3,0640,102,2),
(2212,1,1,1,4,0610,57,2),
(2281,4,1,1,5,0625,114,1),
(4424,1,1,1,6,0610,45,2),
(3317,4,1,1,1,0625,22,2),
(2747,3,1,1,2,0440,98,2),
(2281,5,1,1,3,0630,59,1),
(4424,1,1,1,4,0620,110,1),
(3317,1,1,1,5,0610,65,2),
(2763,4,1,1,6,0640,86,2),
(2282,3,1,1,1,0615,92,2),
(2281,4,1,1,2,0620,98,2),
(2281,5,1,1,3,0425,99,2),
(2747,4,1,1,4,0410,103,1),
(2758,3,1,1,5,0430,79,2),
(2758,5,1,1,6,0610,66,2),
(2747,4,1,1,1,0615,36,2),
(2282,5,1,1,2,0615,47,2),
(2758,3,1,1,3,0630,100,2),
(2281,4,1,1,4,0630,88,2),
(2747,5,1,1,5,0625,40,2),
(2281,4,1,1,6,0630,20,1),
(2282,3,1,1,1,0625,86,1),
(2747,4,1,1,2,0640,45,1),
(2281,1,1,1,3,0420,25,2),
(3317,4,1,1,4,0415,33,1),
(4424,4,1,1,5,0620,80,2),
(2747,3,1,1,6,0630,25,1),
(4424,4,1,1,1,0615,76,2),
(2282,1,1,1,2,0615,38,2),
(2758,4,1,1,3,0440,86,2),
(2747,3,1,1,4,0420,20,2),
(2281,4,1,1,5,0615,116,1),
(2281,5,1,1,6,0610,74,1),
(4424,3,1,1,1,0640,96,2),
(2281,4,1,1,2,0620,32,1),
(2281,5,1,1,3,0620,61,2),
(4424,4,1,1,4,0630,39,2),
(2758,1,1,1,5,0620,87,1),
(2747,4,1,1,6,0640,41,2),
(2281,3,1,1,1,0620,112,2),
(4424,5,1,1,2,0640,119,2),
(2281,4,1,1,3,0615,28,2),
(2281,4,1,1,4,0640,52,2),
(2281,3,1,1,5,0620,36,2),
(4424,5,1,1,6,0615,112,1),
(2281,4,1,1,1,0440,85,2),
(2281,1,1,1,2,0440,84,2),
(3317,4,1,1,3,0625,51,2),
(4424,3,1,1,4,0420,47,1),
(2747,4,1,1,5,0620,56,1),
(2763,1,1,1,6,0610,117,2),
(2281,5,1,1,1,0620,117,1),
(2750,5,1,1,2,0640,54,2),
(2747,4,1,1,3,0425,75,2),
(2334,3,1,1,4,0430,54,1),
(2747,1,1,1,5,0415,108,1),
(2281,4,1,1,6,0430,76,2),
(2281,5,1,1,1,0640,16,2),
(2281,3,1,1,2,0425,87,2),
(2281,4,1,1,3,0620,24,2),
(2282,4,1,1,4,0415,31,2),
(4424,4,1,1,5,0630,88,2),
(2747,1,1,1,6,0630,120,2),
(2281,1,1,1,1,0430,81,1),
(2281,1,1,1,2,0440,108,2),
(4424,4,1,1,3,0620,111,2),
(2758,3,1,1,4,0610,125,3),
(3317,4,1,1,5,0425,21,3),
(2281,1,1,1,6,0615,27,2),
(2747,5,1,1,1,0430,38,1),
(3317,4,1,1,2,0430,88,2),
(2334,3,1,1,3,0625,42,3),
(2281,4,1,1,4,0610,55,2),
(2281,1,1,1,5,0625,30,1),
(2758,5,1,1,6,0625,109,3),
(2282,4,1,1,1,0615,54,2),
(2281,4,1,1,2,0615,106,2),
(4424,3,1,1,3,0410,24,3),
(2212,1,1,1,4,0410,119,2),
(2758,1,1,1,5,0630,21,2),
(2750,3,1,1,6,0620,58,2),
(2758,4,1,1,1,0640,70,3),
(2763,5,1,1,2,0640,30,3),
(4424,4,1,2,3,0640,106,3),
(4424,3,1,2,4,0430,24,2),
(2281,4,1,2,5,0640,91,3),
(2758,1,1,2,6,0630,117,1),
(2763,4,1,2,1,0425,35,3),
(2747,5,1,2,2,0640,34,1),
(2758,5,1,2,3,0415,87,2),
(4424,4,1,2,4,0630,62,2),
(2747,4,1,2,5,0615,53,3),
(3317,5,1,2,6,0640,41,1),
(2281,3,1,2,1,0625,41,3),
(2212,3,1,2,2,0640,87,3),
(2763,4,1,2,3,0415,54,2),
(2281,1,1,2,4,0415,113,2),
(2281,1,1,2,5,0625,124,1),
(2281,3,1,2,6,0410,120,1),
(2281,4,1,2,1,0630,39,3),
(4424,5,1,2,2,0420,20,3),
(2282,4,1,2,3,0425,29,3),
(2212,3,1,2,4,0620,35,3),
(2282,4,1,2,5,0410,43,3),
(2747,1,1,2,6,0610,15,1),
(2334,4,1,2,1,0410,64,1),
(4424,3,1,2,2,0625,74,1),
(3317,4,1,2,3,0610,80,3),
(2281,1,1,2,4,0420,52,3),
(4424,4,1,2,5,0625,50,1),
(2282,5,1,2,6,0610,123,1),
(4424,1,1,2,1,0615,125,3),
(2281,1,1,2,2,0610,104,1),
(2758,1,1,2,3,0615,75,3),
(2747,3,1,2,4,0625,61,2),
(2281,4,1,2,5,0640,15,3),
(2334,5,1,2,6,0630,95,2),
(3317,4,1,2,1,0630,31,3),
(4424,3,1,2,2,0640,96,1),
(2281,4,1,2,3,0415,89,2),
(3317,1,1,2,4,0425,93,1),
(2281,4,1,2,5,0615,64,2),
(4424,3,1,2,6,0410,65,1),
(2747,4,1,2,1,0430,83,3),
(2281,1,1,2,2,0620,74,1),
(2758,4,1,2,3,0610,41,2),
(2281,5,1,2,4,0620,110,2),
(2747,1,1,2,5,0620,96,2),
(3317,1,1,2,6,0415,20,2),
(2212,1,1,2,1,0410,60,2),
(2763,3,1,2,2,0625,17,1),
(2758,4,1,2,3,0630,105,3),
(2281,5,1,2,4,0410,41,3),
(2758,4,1,2,5,0415,110,3),
(2281,3,1,2,6,0640,85,3),
(2758,4,1,2,1,0630,53,3),
(3317,1,1,2,2,0640,52,2),
(4424,4,1,2,3,0425,55,2),
(4424,3,1,2,4,0440,66,3),
(2281,4,1,2,5,0620,105,3),
(2281,1,1,2,6,0610,47,3),
(2758,4,1,2,1,0420,82,1),
(2281,5,1,2,2,0615,121,3),
(4424,1,1,2,3,0640,80,2),
(2281,1,1,2,4,0410,104,2),
(3317,1,1,2,5,0625,93,2),
(2747,3,1,2,6,0620,117,3),
(4424,4,1,2,1,0625,57,2),
(2763,5,1,2,2,0630,54,1),
(2281,4,1,2,3,0425,118,1),
(2763,3,1,2,4,0430,55,3),
(2747,4,1,2,5,0620,118,1),
(2747,1,1,2,6,0420,39,2),
(3317,4,1,2,1,0610,29,3),
(2747,3,1,2,2,0620,76,3),
(2750,4,1,2,3,0610,34,2),
(2281,1,1,2,4,0630,87,3),
(2281,4,1,2,5,0615,38,3),
(2758,5,1,2,6,0640,66,2),
(2758,5,1,2,1,0610,33,1),
(2212,4,1,2,2,0630,114,1),
(2281,3,1,2,3,0620,116,3),
(4424,4,1,2,4,0410,103,3),
(2281,1,1,2,5,0415,88,1),
(2763,4,1,2,6,0615,114,3),
(2747,1,1,2,1,0415,34,2),
(2281,4,1,2,2,0610,30,3),
(4424,3,1,2,3,0410,62,1),
(2281,5,1,2,4,0415,86,1),
(2747,1,1,2,5,0410,15,1),
(2747,1,1,2,6,0440,78,3),
(4424,4,1,2,1,0410,21,2),
(2758,3,1,2,2,0640,105,1),
(2747,4,1,2,3,0420,61,3),
(2281,5,1,2,4,0610,96,3),
(4424,4,1,2,5,0610,63,3),
(4424,3,1,2,6,0425,78,1),
(2281,5,1,2,1,0610,81,1),
(3317,4,1,2,2,0620,90,3),
(2758,5,1,2,3,0420,36,3),
(2750,3,1,2,4,0615,80,1),
(2758,4,1,2,5,0640,46,1),
(4424,5,1,2,6,0615,102,3),
(4424,4,1,2,1,0430,38,1),
(2281,3,1,2,2,0625,69,2),
(3317,4,1,2,3,0620,90,1),
(2281,1,1,2,4,0615,80,3),
(2281,4,1,2,5,0610,104,2),
(2281,4,1,2,6,0615,81,1),
(3317,3,1,2,1,0425,72,2),
(2281,4,1,2,2,0415,118,3),
(2281,1,1,2,3,0620,73,3),
(2212,4,1,2,4,0610,70,3),
(2747,3,1,2,5,0640,37,2),
(2334,4,1,2,6,0610,19,2),
(4424,5,1,2,1,0410,119,3),
(2281,3,1,2,2,0425,110,3),
(2747,4,1,2,3,0620,120,2),
(2281,5,1,2,4,0640,58,3),
(2747,4,1,2,5,0410,20,3),
(2747,1,1,2,6,0640,89,1),
(3317,4,1,2,1,0640,61,1),
(2281,3,1,2,2,0625,18,1),
(2281,5,1,2,3,0410,55,1),
(2747,4,1,2,4,0420,67,1),
(4424,4,1,2,5,0415,43,1),
(3317,3,1,2,6,0610,26,2),
(3317,5,1,2,1,0615,63,3),
(2281,4,1,2,2,0630,60,1),
(2281,1,1,2,3,0610,58,1),
(2281,4,1,2,4,0440,75,1),
(2281,3,1,2,5,0625,53,2),
(2747,4,1,2,6,0615,115,3),
(2281,1,1,2,1,0630,117,3),
(3317,5,1,2,2,0615,103,3),
(3317,4,1,2,3,0625,45,1),
(3317,3,1,2,4,0415,113,3),
(4424,4,1,2,5,0610,76,1),
(2281,1,1,2,6,0630,94,3),
(2212,4,1,2,1,0630,26,1),
(2758,1,1,2,2,0430,125,2),
(4424,4,1,2,3,0610,59,1),
(2747,3,1,2,4,0610,102,1),
(2282,5,1,2,5,0410,18,1),
(4424,1,1,2,6,0615,84,3),
(3317,1,1,2,1,0615,60,2),
(2281,4,1,2,2,0620,109,3),
(2281,3,1,2,3,0420,31,3),
(2212,4,1,2,4,0630,68,3),
(2281,5,1,2,5,0415,63,2),
(2747,4,1,2,6,0610,58,2),
(2281,3,1,2,1,0640,109,2),
(4424,5,1,2,2,0625,78,2),
(2747,4,1,2,3,0625,67,2),
(2281,5,1,2,4,0415,124,2),
(4424,3,1,2,5,0620,54,1),
(4424,4,1,2,6,0620,44,1),
(2747,5,1,2,1,0630,120,1),
(3317,4,1,2,2,0620,125,2),
(2281,3,1,2,3,0625,21,3),
(4424,4,1,2,4,0640,27,3),
(2334,1,1,2,5,0630,19,2),
(4424,4,1,2,6,0440,108,2),
(2281,4,1,2,1,0430,95,2),
(2747,3,1,2,2,0430,26,1),
(4424,4,1,2,3,0410,106,1),
(4424,1,1,2,4,0430,49,2),
(2281,4,1,2,5,0415,54,3),
(2212,3,1,2,6,0420,93,3),
(4424,4,1,2,1,0410,59,3),
(2758,5,1,2,2,0430,74,2),
(2758,3,1,2,3,0430,48,1),
(3317,4,1,2,4,0640,74,2),
(2281,5,1,2,5,0410,111,1),
(2212,4,1,2,6,0615,98,3),
(2281,1,1,2,1,0615,27,2),
(2763,4,1,2,2,0615,31,1),
(4424,3,1,2,3,0610,96,3),
(2758,5,1,2,4,0430,75,2),
(2281,4,1,2,5,0610,46,3),
(4424,4,1,2,6,0610,44,2),
(2212,3,1,2,1,0415,17,3),
(4424,5,1,2,2,0440,102,1),
(2282,4,1,2,3,0610,36,3),
(2281,1,1,2,4,0615,69,2),
(2281,4,1,2,5,0615,16,3),
(2747,3,1,2,6,0410,88,3),
(2281,4,1,2,1,0610,65,3),
(2758,1,1,2,2,0425,50,2),
(2281,5,1,2,3,0640,60,2),
(3317,5,1,2,4,0610,119,2),
(2763,4,1,2,5,0625,20,3),
(4424,3,1,2,6,0610,105,1),
(2747,1,1,2,1,0640,20,3),
(3317,4,1,2,2,0620,62,3),
(2281,5,1,2,3,0640,91,2),
(2281,3,1,2,4,0420,19,3),
(2281,4,1,2,5,0610,121,3),
(2282,4,1,2,6,0410,24,3),
(2282,4,1,2,1,0640,105,1),
(3317,1,1,2,2,0620,90,2),
(2281,1,1,2,3,0625,29,1),
(2758,1,1,2,4,0425,30,3),
(2281,4,1,2,5,0620,40,3),
(4424,3,1,2,6,0410,47,2),
(2282,4,1,2,1,0425,103,3),
(2281,1,1,2,2,0615,69,3),
(2281,5,1,2,3,0610,73,1),
(2758,4,1,2,4,0615,20,3),
(2281,3,1,2,5,0625,75,2),
(3317,4,1,2,6,0640,115,3),
(2750,1,1,2,1,0440,56,2),
(2212,5,1,2,2,0440,121,1),
(2334,4,1,2,3,0615,91,3),
(4424,4,1,2,4,0425,48,3),
(2281,3,1,2,5,0625,50,1),
(2281,1,1,2,6,0430,34,2),
(2747,1,1,2,1,0610,118,1),
(2212,3,1,2,2,0620,114,2),
(2281,4,1,2,3,0620,79,2),
(3317,5,1,2,4,0430,55,3),
(2282,4,1,2,5,0625,83,2),
(4424,3,1,2,6,0640,25,3),
(2763,4,1,2,1,0615,106,2),
(2763,1,1,2,2,0620,65,3),
(2281,4,1,2,3,0620,43,3),
(4424,5,1,2,4,0620,119,3),
(4424,5,1,2,5,0630,107,1),
(2212,4,1,2,6,0640,125,3),
(4424,4,1,2,1,0420,106,1),
(2281,5,1,2,2,0430,30,1),
(2763,3,1,2,3,0640,76,2),
(2334,3,1,2,4,0410,74,1),
(2281,4,1,2,5,0610,86,2),
(2747,1,1,2,6,0625,25,2),
(2758,1,1,2,1,0630,88,3),
(3317,3,1,2,2,0610,70,3),
(4424,4,1,2,3,0440,101,2),
(3317,5,1,2,4,0430,27,1),
(2747,4,1,2,5,0440,73,3),
(2758,3,1,2,6,0640,38,2),
(2763,4,1,2,1,0615,121,3),
(2281,1,1,2,2,0425,15,1),
(2747,4,1,2,3,0615,111,2),
(2282,3,1,2,4,0620,79,1),
(2281,4,1,2,5,0425,50,2),
(2758,1,1,2,6,0615,106,3),
(2281,4,1,2,1,0625,91,1),
(2281,5,1,2,2,0610,55,3),
(4424,1,1,2,3,0615,118,1),
(2758,1,1,2,4,0620,83,3),
(3317,1,1,2,5,0630,103,2),
(2212,3,1,2,6,0640,40,1),
(2747,2,1,2,1,0615,105,3),
(3317,5,1,2,2,0620,125,3),
(2747,4,1,2,3,0620,25,2),
(2281,3,1,2,4,0420,27,2),
(2281,2,1,2,5,0425,61,3),
(2758,1,1,2,6,0625,103,1),
(2758,4,1,2,1,0630,80,3),
(2747,3,1,2,2,0430,116,1),
(2758,2,1,2,3,0420,78,1),
(2747,1,1,2,4,0625,18,1),
(2281,4,1,2,5,0630,102,3),
(2747,5,1,2,6,0440,42,1),
(2281,1,1,2,1,0420,100,2),
(2281,1,1,2,2,0415,124,1),
(2282,1,1,2,3,0630,70,2),
(2282,3,1,2,4,0630,38,1),
(2281,2,1,2,5,0630,106,2),
(2281,5,1,2,6,0620,51,2),
(2281,4,1,2,1,0415,71,3),
(2763,3,1,2,2,0625,62,3),
(2281,2,1,2,3,0610,76,1),
(2758,1,1,2,4,0420,57,3),
(2747,4,1,2,5,0630,58,1),
(2282,3,1,26,6,0615,60,1),
(2212,2,1,26,1,0620,86,1),
(2281,1,1,26,2,0630,80,1),
(2747,4,1,26,3,0630,91,3),
(2747,5,1,26,4,0640,35,1),
(4424,1,1,26,5,0440,105,2),
(2281,1,1,26,6,0425,15,1),
(4424,1,1,26,1,0630,112,2),
(2334,3,1,26,2,0610,81,2),
(2281,2,1,26,3,0625,93,1),
(2281,5,1,26,4,0625,54,1),
(2747,4,1,26,5,0625,26,2),
(2281,3,1,26,6,0410,74,2),
(2281,2,1,26,1,0610,64,2),
(2758,1,1,26,2,0615,78,1),
(2758,4,1,26,3,0625,102,3),
(2212,3,1,26,4,0610,37,2),
(2758,2,1,26,5,0440,71,3),
(2282,1,1,26,6,0615,95,2),
(2281,4,1,26,1,0615,67,1),
(2763,5,1,26,2,0415,21,1),
(2750,5,1,26,3,0630,61,2),
(2747,4,1,26,4,0625,89,1),
(2747,3,1,26,5,0430,32,2),
(4424,2,1,26,6,0625,29,3),
(2282,1,1,26,1,0420,71,2),
(2281,4,1,26,2,0420,65,3),
(4424,1,1,26,3,0430,73,2),
(2212,2,1,26,4,0440,112,2),
(2758,3,1,26,5,0615,25,2),
(2747,5,1,26,6,0610,112,3),
(2282,1,1,26,1,0630,39,1),
(2763,1,1,26,2,0425,30,3),
(4424,2,1,26,3,0440,96,3),
(3317,3,1,26,4,0630,46,2),
(4424,4,1,26,5,0625,81,1),
(2747,5,1,26,6,0630,122,1),
(2212,2,1,26,1,0620,119,2),
(2282,3,1,26,2,0415,103,2),
(2281,5,1,26,3,0615,74,1),
(2758,2,1,26,4,0640,117,1),
(2750,5,1,26,5,0640,69,2),
(2281,3,1,26,6,0620,39,2),
(2281,4,1,26,1,0630,48,1),
(4424,5,1,26,2,0625,125,1),
(2747,4,1,26,3,0425,42,2),
(2281,3,1,26,4,0630,82,3),
(2281,2,1,26,5,0640,37,3),
(3317,1,1,26,6,0410,47,2),
(2747,4,1,26,1,0620,62,1),
(2281,4,1,26,2,0620,114,1),
(3317,3,1,26,3,0640,114,2),
(2758,2,1,26,4,0640,17,3),
(2758,1,1,26,5,0615,64,2),
(2212,2,1,26,6,0610,37,2),
(2281,3,1,26,1,0620,33,1),
(4424,4,1,26,2,0625,70,1),
(2281,5,1,26,3,0625,30,1),
(4424,3,1,26,4,0610,32,3),
(2281,2,1,26,5,0625,85,1),
(2747,5,1,26,6,0625,121,1),
(3317,4,1,26,1,0430,21,3),
(2281,1,1,26,2,0610,66,3),
(2747,2,1,26,3,0610,38,1),
(2281,3,1,26,4,0615,92,1),
(2282,5,1,26,5,0625,114,2),
(2281,4,1,26,6,0620,45,2),
(2281,2,1,26,1,0415,18,1),
(2750,3,1,26,2,0630,96,2),
(2747,5,1,26,3,0620,77,2),
(2747,4,1,26,4,0440,90,3),
(4424,1,1,26,5,0610,89,3),
(2281,4,1,26,6,0615,89,1),
(4424,3,1,26,1,0610,101,3),
(2758,2,1,26,2,0620,107,3),
(2758,1,1,26,3,0630,78,3),
(2747,5,1,26,4,0415,29,1),
(4424,5,1,26,5,0630,125,1),
(2747,2,1,26,6,0625,108,2),
(4424,3,1,26,1,0640,45,2),
(2747,1,1,26,2,0410,83,2),
(2758,4,1,26,3,0430,115,2),
(2281,5,1,26,4,0420,80,2),
(2763,3,1,26,5,0630,54,1),
(4424,2,1,26,6,0420,118,2),
(2747,2,1,26,1,0415,40,3),
(2281,2,1,26,2,0615,93,1),
(2281,1,1,26,3,0415,19,3),
(4424,1,1,26,4,0615,80,1),
(2750,1,1,26,5,0630,67,1),
(2758,4,1,26,6,0630,21,1),
(2281,3,1,26,1,0640,38,1),
(2281,2,1,26,2,0620,111,2),
(2281,1,1,26,3,0610,112,2),
(2212,5,1,26,4,0640,17,1),
(4424,4,1,26,5,0630,47,2),
(2282,3,1,26,6,0425,22,1),
(2281,2,1,26,1,0620,74,3),
(2758,1,1,26,2,0440,99,3),
(2281,5,1,26,3,0640,51,1),
(2282,4,1,26,4,0610,26,3),
(3317,2,1,26,5,0420,103,3),
(2281,3,1,26,6,0640,21,2),
(2334,1,1,26,1,0425,35,2),
(2281,1,1,26,2,0620,119,1),
(2281,3,1,26,3,0615,121,2),
(2281,2,1,26,4,0615,97,3),
(4424,5,1,26,5,0625,78,2),
(2758,4,1,26,6,0410,115,2),
(2747,3,1,26,1,0625,32,3),
(3317,2,1,26,2,0630,46,3),
(3317,1,1,26,3,0630,34,3),
(2281,4,1,26,4,0415,113,3),
(2747,5,1,26,5,0625,27,2),
(4424,5,1,26,6,0430,59,1),
(4424,4,1,26,1,0615,76,1),
(2747,4,1,26,2,0615,71,3),
(2758,5,1,26,3,0410,104,1),
(2281,3,1,26,4,0615,61,2),
(3317,3,1,26,5,0440,15,2),
(2763,2,1,26,6,0410,100,1),
(2747,1,1,26,1,0625,72,3),
(4424,1,1,26,2,0615,38,3),
(2281,3,1,26,3,0625,45,1),
(4424,2,1,26,4,0615,37,1),
(2282,5,1,26,5,0610,72,3),
(2281,4,1,26,6,0440,97,3),
(2750,3,1,26,1,0420,98,2),
(2281,2,1,26,2,0415,35,3),
(3317,1,1,26,3,0430,101,1),
(4424,4,1,26,4,0630,49,1),
(2747,3,1,26,5,0615,38,3),
(4424,2,1,26,6,0640,57,3),
(2281,1,1,26,1,0625,54,2),
(2758,4,1,26,2,0630,45,2),
(2282,5,1,26,3,0610,76,1),
(3317,1,1,26,4,0430,30,3),
(2758,1,1,26,5,0425,125,3),
(2334,1,1,26,6,0615,114,2),
(2747,3,1,26,1,0620,108,1),
(4424,2,1,26,2,0625,90,3),
(2758,5,1,26,3,0610,61,2),
(2281,4,1,26,4,0620,33,2),
(3317,3,1,26,5,0620,70,1),
(2281,2,1,26,6,0615,115,3),
(2747,1,1,26,1,0415,100,2),
(2763,4,1,26,2,0640,81,2),
(4424,3,1,26,3,0440,87,2),
(2281,2,1,26,4,0415,47,2),
(2281,1,1,26,5,0620,98,2),
(3317,4,1,26,6,0415,39,3),
(2763,5,1,26,1,0410,98,3),
(2281,1,1,26,2,0620,124,3),
(2281,1,1,26,3,0430,35,1),
(4424,1,1,26,4,0615,96,1),
(2747,3,1,26,5,0410,39,1),
(2758,2,1,26,6,0610,109,1),
(4424,5,1,26,1,0640,18,1),
(2281,4,1,26,2,0420,18,2),
(4424,3,1,26,3,0630,92,3),
(2281,2,1,26,4,0640,22,3),
(2747,1,1,26,5,0640,19,3),
(2758,4,1,26,6,0610,121,1),
(2763,3,1,26,1,0615,52,1),
(3317,2,1,26,2,0410,22,2),
(3317,1,1,26,3,0620,72,1),
(2212,4,1,26,4,0630,36,1),
(4424,5,1,26,5,0610,105,1),
(2334,1,1,26,6,0625,115,3),
(2281,1,1,26,1,0640,87,2),
(2747,1,1,26,2,0625,16,1),
(2750,3,1,26,3,0420,34,2),
(2281,2,1,26,4,0410,54,2),
(2281,5,1,26,5,0425,26,1),
(2747,4,1,26,6,0640,57,2),
(2758,3,1,26,1,0420,41,3),
(2758,2,1,26,2,0620,95,3),
(2212,1,1,26,3,0630,75,1),
(4424,4,1,26,4,0615,47,1),
(2763,3,1,26,5,0640,104,2),
(2282,2,1,26,6,0610,65,2),
(2747,1,1,26,1,0620,117,2),
(2281,4,1,26,2,0640,95,3),
(2747,5,1,26,3,0425,117,3),
(2212,5,1,26,4,0430,66,3),
(2281,4,1,26,5,0415,98,3),
(2281,3,1,26,6,0420,125,3),
(4424,2,1,26,1,0610,37,1),
(4424,1,1,26,2,0415,36,3),
(2763,4,1,26,3,0420,72,2),
(2281,1,1,26,4,0615,109,3),
(2758,2,1,26,5,0430,82,2),
(2281,3,1,26,6,0415,72,1),
(2747,5,1,26,1,0625,107,2),
(2281,1,1,26,2,0610,31,3),
(2747,1,1,26,3,0420,47,1),
(2281,2,1,26,4,0440,88,3),
(2747,3,1,26,5,0620,78,1),
(3317,4,1,26,6,0630,31,1),
(2281,5,1,26,1,0620,116,2),
(2747,2,1,26,2,0640,112,1),
(2281,3,1,26,3,0610,18,2),
(2763,5,1,26,4,0620,113,1),
(2281,2,1,26,5,0630,55,2),
(4424,5,1,26,6,0420,38,1),
(2334,3,1,26,1,0625,61,1),
(2763,4,1,26,2,0415,25,3),
(2281,5,1,26,3,0640,52,3),
(2281,4,1,26,4,0615,74,2),
(2747,3,1,26,5,0620,117,3),
(2281,2,1,26,6,0620,21,2),
(2281,1,1,26,1,0620,18,2),
(2747,4,1,26,2,0420,91,1),
(3317,4,1,26,3,0410,25,3),
(2281,3,1,26,4,0615,33,1),
(2758,2,1,26,5,0610,79,1),
(3317,1,1,26,6,0615,90,3),
(2281,2,1,26,1,0615,99,1),
(2747,3,1,26,2,0610,54,1),
(2763,4,1,26,3,0630,28,2),
(4424,5,1,26,4,0630,79,1),
(2750,3,1,26,5,0630,35,1),
(2281,2,1,26,6,0615,33,2),
(2747,5,1,26,1,0630,71,3),
(4424,4,1,26,2,0425,23,3),
(2282,1,1,26,3,0615,81,1),
(2281,2,1,26,4,0420,107,1),
(3317,3,1,26,5,0630,112,2),
(2282,5,1,26,6,0620,41,3),
(2763,4,1,26,1,0625,40,3),
(2747,2,1,26,2,0410,94,2),
(2281,3,1,26,3,0610,70,2),
(2747,5,1,26,4,0625,99,2),
(2281,4,1,26,5,0420,70,1),
(2758,1,1,26,6,0420,35,2),
(2281,4,1,26,1,0410,18,2),
(2282,3,1,26,2,0415,78,2),
(2747,2,1,26,3,0625,79,2),
(2281,1,1,26,4,0620,102,1),
(4424,5,1,26,5,0420,16,1),
(2281,4,1,26,6,0640,59,3),
(4424,3,1,26,1,0620,106,3),
(2747,2,1,26,2,0420,102,1),
(3317,1,1,26,3,0620,81,1),
(2281,4,1,26,4,0640,123,3),
(2281,1,1,26,5,0625,88,3),
(4424,2,1,26,6,0410,39,3),
(2281,3,1,26,1,0640,77,2),
(2750,5,1,26,2,0630,117,1),
(2747,1,1,26,3,0410,42,1),
(2281,1,1,26,4,0420,113,3),
(3317,2,1,26,5,0640,76,1),
(4424,3,1,26,6,0640,89,2),
(2281,4,1,26,1,0420,93,2),
(2758,5,1,26,2,0625,79,1),
(2747,2,1,26,3,0610,106,2),
(2758,3,1,26,4,0625,67,3),
(2281,5,1,26,5,0610,105,3),
(2747,2,1,26,6,0640,110,2),
(2281,5,1,26,1,0615,35,2),
(2747,3,1,26,2,0615,71,1),
(3317,4,1,26,3,0610,79,2),
(2758,5,1,26,4,0630,69,3),
(4424,4,1,26,5,0615,111,2),
(2281,3,1,26,6,0620,27,3),
(2281,2,1,26,1,0625,55,1),
(2282,1,1,26,2,0610,54,1),
(2281,4,1,26,3,0615,98,1),
(2758,4,1,26,4,0425,40,2),
(2334,3,1,26,5,0640,103,3),
(2747,2,1,26,6,0615,105,2),
(2758,1,1,26,1,0625,75,1),
(2281,2,1,26,2,0640,43,2),
(2281,3,1,26,3,0615,58,1),
(3317,4,1,26,4,0610,48,3),
(2281,5,1,26,5,0620,111,3),
(2212,3,1,26,6,0640,48,2),
(4424,2,1,26,1,0640,101,3),
(4424,5,1,26,2,0615,113,2),
(2282,4,1,26,3,0610,76,3),
(2758,1,1,26,4,0425,102,3),
(4424,2,1,26,5,0620,25,3),
(2281,3,1,26,6,0430,43,3),
(2758,5,1,26,1,0630,100,1),
(2763,4,1,26,2,0620,61,2),
(2763,2,1,26,3,0630,37,3),
(2281,3,1,26,4,0625,65,3),
(2758,5,1,26,5,0615,52,1),
(2281,4,1,26,6,0610,35,3),
(3317,1,1,26,1,0415,102,3),
(4424,4,1,26,2,0630,110,3),
(2281,3,1,26,3,0640,102,1),
(2747,2,1,26,4,0615,46,3),
(2747,1,1,26,5,0630,30,3),
(2282,5,1,26,6,0440,112,2),
(2747,5,1,26,1,0620,44,2),
(2281,2,1,26,2,0415,61,2),
(2763,3,1,26,3,0420,118,2),
(2281,1,1,26,4,0615,99,2),
(2212,4,1,26,5,0630,77,2),
(2763,5,1,26,6,0610,71,2),
(2281,3,1,26,1,0630,48,3),
(2747,2,1,26,2,0630,69,2),
(4424,2,1,26,3,0625,121,3),
(2747,2,1,26,4,0615,35,3),
(2758,1,1,26,5,0625,124,1),
(3317,1,1,26,6,0615,73,1),
(4424,1,1,26,1,0615,88,1),
(2750,4,1,26,2,0415,71,1),
(2282,3,1,26,3,0640,64,1),
(2281,2,1,26,4,0625,122,1),
(3317,1,1,26,5,0410,98,2),
(2747,5,1,26,6,0625,27,1),
(2747,4,1,26,1,0610,35,2),
(2281,3,1,26,2,0440,110,1),
(2281,2,1,26,3,0410,88,1),
(2281,1,1,26,4,0415,103,1),
(2281,5,1,26,5,0410,67,1),
(2763,4,1,26,6,0640,71,3),
(4424,2,1,26,1,0640,28,2),
(2281,3,1,26,2,0640,116,3),
(2281,1,1,26,3,0415,103,1),
(2747,1,1,26,4,0625,65,1),
(2281,3,1,26,5,0410,23,1),
(2758,2,1,26,6,0625,26,2),
(2747,5,1,26,1,0630,43,2),
(2747,4,1,26,2,0630,52,1),
(2758,3,1,26,3,0420,18,3),
(2758,2,1,26,4,0425,64,2),
(4424,1,1,26,5,0430,103,2),
(2281,4,1,26,6,0625,55,2),
(2281,5,1,26,1,0625,123,3),
(2281,5,1,26,2,0440,58,2),
(3317,4,1,26,3,0610,63,3),
(2281,4,1,26,4,0640,28,1),
(2281,5,1,26,5,0640,68,1),
(2281,3,1,26,6,0410,72,3),
(2281,3,1,26,1,0420,123,3),
(2282,2,1,26,2,0615,98,1),
(2758,1,1,26,3,0610,39,3),
(2747,1,1,26,4,0420,64,2),
(2758,3,1,26,5,0615,37,2),
(2281,2,1,26,6,0420,32,3),
(2281,5,1,26,1,0625,50,2),
(4424,4,1,26,2,0615,110,2),
(2758,3,1,26,3,0640,122,1),
(4424,2,1,26,4,0630,75,3),
(4424,1,1,26,5,0440,99,2),
(2281,4,1,26,6,0640,73,3),
(2747,3,1,26,1,0625,99,3),
(2747,2,1,26,2,0425,70,1),
(2212,1,1,26,3,0415,106,1),
(2763,4,1,26,4,0610,54,2),
(3317,5,1,26,5,0625,90,3),
(2282,1,1,26,6,0615,81,3),
(2758,1,1,26,1,0420,43,1),
(2747,1,1,26,2,0615,105,1),
(2281,3,1,26,3,0625,85,3),
(2747,2,1,26,4,0410,17,3),
(2281,5,1,26,5,0625,119,3),
(2281,4,1,26,6,0620,34,2),
(2758,3,1,26,1,0430,76,1),
(3317,2,1,26,2,0625,121,3),
(2281,1,1,26,3,0630,102,1),
(2281,4,1,26,4,0630,99,1),
(3317,3,1,26,5,0420,125,3),
(4424,2,1,26,6,0615,89,2),
(2281,1,1,26,1,0620,17,1),
(2281,4,1,26,2,0640,53,3),
(2747,5,1,26,3,0640,92,2),
(2758,1,1,26,4,0610,16,3),
(2763,1,1,26,5,0620,42,3),
(2758,1,1,26,6,0610,35,2),
(2282,3,1,26,1,0630,115,3),
(2763,2,1,26,2,0615,92,2),
(2281,5,1,26,3,0630,82,3),
(4424,4,1,26,4,0630,55,3),
(2281,3,1,26,5,0620,84,1),
(3317,2,1,26,6,0630,86,1),
(4424,1,1,26,1,0620,78,2),
(3317,4,1,26,2,0640,63,1),
(2758,3,1,26,3,0640,46,3),
(4424,2,1,26,4,0640,16,3),
(2747,1,1,26,5,0615,94,1),
(4424,4,1,26,6,0415,90,3),
(4424,5,1,26,1,0625,89,3),
(2747,1,1,26,2,0410,71,1),
(2281,1,1,26,3,0640,57,3),
(4424,1,1,26,4,0630,93,2),
(2758,3,1,26,5,0640,108,2),
(2281,2,1,26,6,0430,112,3),
(4424,5,1,26,1,0625,114,3),
(2282,4,1,26,2,0630,73,3),
(2281,3,1,26,3,0610,100,2),
(2281,2,1,26,4,0630,71,2),
(3317,1,1,26,5,0430,85,2),
(2763,4,1,26,6,0425,55,1),
(2747,3,1,26,1,0615,76,2),
(2758,2,1,26,2,0625,29,1),
(2282,1,1,26,3,0640,45,1),
(2747,4,1,26,4,0640,82,3),
(2281,5,1,26,5,0610,16,2),
(2281,5,1,26,6,0620,18,1),
(2747,4,1,26,1,0615,26,2),
(2758,3,1,26,2,0625,44,2),
(4424,2,1,26,3,0640,20,1),
(2750,1,1,26,4,0610,31,1),
(3317,4,1,26,5,0625,56,3),
(2281,1,1,26,6,0640,59,3),
(4424,2,1,26,1,0630,17,1),
(2282,3,1,26,2,0610,85,1),
(2281,5,1,26,3,0420,67,1),
(2281,1,1,26,4,0625,43,3),
(2747,1,1,26,5,0615,70,1),
(2281,2,1,1,6,0620,91,2),
(2758,3,1,1,1,0430,56,1),
(2758,4,1,1,2,0410,107,1),
(2282,5,1,1,3,0420,59,1),
(4424,2,1,1,4,0615,95,2),
(2334,3,1,1,5,0420,72,2),
(2747,5,1,1,6,0625,89,1),
(2763,2,1,1,1,0610,111,3),
(4424,5,1,1,2,0630,46,3),
(2758,3,1,1,3,0620,40,1),
(2281,4,1,1,4,0615,80,2),
(2282,5,1,1,5,0425,79,2),
(2281,4,1,1,6,0410,52,2),
(2747,3,1,1,1,0630,65,1),
(3317,2,1,1,2,0420,97,1),
(4424,1,1,1,3,0625,94,2),
(2282,4,1,1,4,0420,83,1),
(2281,4,1,1,5,0420,32,1),
(2763,3,1,1,6,0625,19,3),
(2281,2,1,1,1,0610,108,1),
(2281,1,1,1,2,0410,90,1),
(2212,2,1,1,3,0440,101,2),
(2747,3,1,1,4,0630,66,2),
(2747,4,1,1,5,0625,92,3),
(2758,5,1,1,6,0620,122,2),
(4424,3,1,1,1,0640,62,2),
(2758,2,1,1,2,0640,125,2),
(2281,5,1,1,3,0620,65,2),
(2747,4,1,1,4,0620,66,2),
(2758,1,1,1,5,0425,125,2),
(2747,2,1,1,6,0620,47,2),
(2747,3,1,1,1,0620,18,2),
(2281,5,1,1,2,0640,85,3),
(2758,4,1,1,3,0430,112,1),
(2750,2,1,1,4,0410,45,1),
(3317,3,1,1,5,0640,51,2),
(2281,5,1,1,6,0425,70,1),
(2334,4,1,1,1,0440,28,3),
(2281,1,1,1,2,0420,34,2),
(4424,4,1,1,3,0430,117,1),
(4424,3,1,1,4,0415,17,3),
(2747,2,1,1,5,0440,80,3),
(2281,1,1,1,6,0640,112,1),
(2747,5,1,1,1,0610,125,3),
(2758,5,1,1,2,0615,16,3),
(2334,2,1,1,3,0425,48,2),
(2747,3,1,1,4,0420,99,2),
(2282,1,1,1,5,0420,62,1),
(2763,4,1,1,6,0620,106,3),
(4424,5,1,1,1,0440,44,1),
(4424,3,1,1,2,0630,23,2),
(2281,2,1,1,3,0415,49,2),
(2281,2,1,1,4,0420,100,3),
(2212,2,1,1,5,0610,81,3),
(4424,1,1,1,6,0620,76,2),
(2281,1,1,1,1,0440,58,1),
(3317,1,1,1,2,0625,47,1),
(2747,4,1,1,3,0610,114,2),
(2282,3,1,1,4,0610,119,3),
(2747,2,1,1,5,0640,123,3),
(2281,1,1,1,6,0440,87,2),
(2758,5,1,1,1,0615,50,1),
(2281,4,1,1,2,0610,120,1),
(2763,3,1,1,3,0615,81,3),
(3317,2,1,1,4,0440,52,1),
(2212,1,1,1,5,0615,52,2),
(4424,5,1,1,6,0630,85,3),
(2281,4,1,1,1,0415,95,2),
(2758,2,1,1,2,0620,39,2),
(3317,3,1,1,3,0610,104,1),
(2334,1,1,1,4,0640,114,1),
(2281,1,1,1,5,0620,17,1),
(2747,3,1,1,6,0640,30,1),
(2281,2,1,1,1,0610,69,2),
(2758,5,1,1,2,0615,91,1),
(2758,4,1,1,3,0630,88,3),
(2281,3,1,1,4,0620,32,1),
(2747,2,1,1,5,0620,94,3),
(2747,1,1,1,6,0625,64,2),
(2281,4,1,1,1,0620,75,1),
(2281,5,1,1,2,0610,22,1),
(2758,5,1,1,3,0415,119,2),
(2758,4,1,1,4,0610,115,2),
(2282,4,1,1,5,0630,84,3),
(3317,5,1,1,6,0440,82,1),
(2281,3,1,1,1,0630,33,2),
(2747,3,1,1,2,0640,112,1),
(2281,2,1,1,3,0410,101,2),
(4424,1,1,1,4,0615,35,2),
(2334,1,1,1,5,0610,45,2),
(2281,3,1,1,6,0440,72,1),
(4424,2,1,1,1,0630,119,2),
(2750,5,1,1,2,0610,93,3),
(2281,4,1,1,3,0430,91,3),
(2758,3,1,1,4,0620,27,3),
(2747,2,1,1,5,0425,17,3),
(2747,1,1,1,6,0410,118,3),
(2281,4,1,1,1,0625,100,3),
(2281,3,1,1,2,0410,68,3),
(2281,2,1,1,3,0620,66,2),
(2281,1,1,1,4,0440,58,1),
(2281,4,1,1,5,0625,121,2),
(2763,5,1,1,6,0420,25,3),
(2747,1,1,1,1,0420,93,2),
(3317,1,1,1,2,0415,111,3),
(4424,1,1,1,3,0630,78,1),
(3317,3,1,1,4,0610,110,1),
(2758,2,1,1,5,0430,82,2),
(2212,5,1,1,6,0640,30,1),
(2758,4,1,1,1,0625,25,3),
(2281,3,1,1,2,0625,50,3),
(3317,2,1,1,3,0410,90,1),
(2747,1,1,1,4,0640,90,2),
(2282,4,1,1,5,0420,117,2),
(2758,3,1,1,6,0625,64,3),
(2763,2,1,1,1,0440,39,3),
(2281,1,1,1,2,0415,15,3),
(2758,4,1,1,3,0430,75,2),
(4424,5,1,1,4,0440,35,1),
(2281,1,1,1,5,0410,43,1),
(4424,1,1,1,6,0425,48,2),
(2212,1,1,1,1,0415,42,2),
(2334,3,1,1,2,0425,87,1),
(4424,2,1,1,3,0640,53,2),
(2281,5,1,1,4,0615,109,3),
(2281,4,1,1,5,0630,62,3),
(3317,3,1,1,6,0415,116,1),
(2758,2,1,1,1,0615,69,2),
(2758,1,1,1,2,0640,82,3),
(3317,4,1,1,3,0440,18,1),
(2281,3,1,1,4,0625,61,3),
(2281,2,1,1,5,0440,122,3),
(2281,1,1,1,6,0415,48,1),
(2212,4,1,1,1,0610,47,1),
(3317,5,1,1,2,0620,39,2),
(2282,1,1,1,3,0620,109,1),
(2747,1,1,1,4,0440,69,2),
(2281,1,1,1,5,0615,100,1),
(4424,3,1,1,6,0620,107,2),
(4424,2,1,1,1,0425,72,1),
(2281,5,1,1,2,0625,67,3),
(4424,4,1,1,3,0620,81,1),
(2212,3,1,1,4,0430,93,2),
(2763,2,1,1,5,0640,44,3),
(3317,1,1,1,6,0640,100,2),
(2747,4,1,1,1,0430,32,2),
(2758,3,1,1,2,0625,38,3),
(2758,2,1,1,3,0640,124,2),
(2758,1,1,1,4,0610,92,3),
(2281,4,1,1,5,0415,60,1),
(2747,5,1,1,6,0615,19,3),
(2763,5,1,1,1,0620,98,3),
(4424,4,1,1,2,0415,111,1),
(2281,3,1,1,3,0610,96,2),
(2281,2,1,1,4,0440,73,2),
(2758,1,1,1,5,0440,112,1),
(3317,4,1,1,6,0630,55,1),
(2747,1,1,1,1,0430,56,3),
(2747,2,1,1,2,0425,108,3),
(3317,3,1,1,3,0620,73,1),
(2282,5,1,1,4,0410,30,1),
(2281,1,1,1,5,0620,114,1),
(2212,1,1,1,6,0615,58,2),
(2281,2,1,1,1,0615,44,2),
(2747,3,1,1,2,0610,55,2),
(2281,4,1,1,3,0610,96,3),
(2212,5,1,1,4,0430,18,2),
(4424,2,1,1,5,0640,100,3),
(2281,3,1,1,6,0610,79,1),
(2281,5,1,1,1,0625,27,2),
(2758,2,1,1,2,0410,36,3),
(2282,5,1,1,3,0425,99,3),
(2747,3,1,1,4,0630,113,3),
(2747,4,1,1,5,0615,98,1),
(3317,5,1,1,6,0615,78,2),
(2281,4,1,1,1,0630,98,1),
(4424,3,1,16,2,0615,55,2),
(2763,2,1,16,3,0440,85,3),
(2758,1,1,16,4,0440,50,3),
(2281,4,1,16,5,0625,118,2),
(3317,4,1,16,6,0620,25,2),
(2758,3,1,16,1,0610,116,1),
(2747,2,1,16,2,0410,112,2),
(2282,1,1,16,3,0615,122,2),
(2281,2,1,16,4,0610,122,2),
(2758,3,1,16,5,0440,101,1),
(2281,4,1,16,6,0610,34,3),
(2758,5,1,16,1,0430,106,2),
(2763,3,1,16,2,0625,94,2),
(2212,2,1,16,3,0625,100,2),
(2282,5,1,16,4,0620,75,1),
(3317,4,1,16,5,0415,61,2),
(3317,1,1,16,6,0625,18,3),
(2758,2,1,16,1,0615,91,1),
(4424,3,1,16,2,0620,15,2),
(2281,5,1,16,3,0420,109,3),
(2758,4,1,16,4,0620,38,1),
(2281,2,1,16,5,0415,48,2),
(4424,3,1,16,6,0420,22,2),
(2281,5,1,16,1,0640,93,3),
(2747,4,1,16,2,0630,55,2),
(3317,1,1,16,3,0425,33,3),
(2282,4,1,16,4,0615,117,3),
(3317,3,1,16,5,0610,77,1),
(2763,2,1,16,6,0630,111,3),
(2281,1,1,16,1,0625,63,2),
(2747,5,1,16,2,0625,68,3),
(2281,4,1,16,3,0625,16,1),
(3317,3,1,16,4,0420,117,2),
(2747,2,1,16,5,0625,117,3),
(3317,1,1,16,6,0640,24,2),
(2281,4,1,16,1,0420,79,3),
(2281,1,1,16,2,0440,98,2),
(2758,2,1,16,3,0630,37,1),
(2758,3,1,16,4,0620,24,3),
(4424,5,1,16,5,0425,78,1),
(2758,1,1,16,6,0430,117,1),
(3317,1,1,16,1,0620,87,1),
(2758,2,1,16,2,0420,25,2),
(2763,3,1,16,3,0430,29,1),
(2334,4,1,16,4,0625,16,1),
(3317,5,1,16,5,0410,73,2),
(2281,2,1,16,6,0430,21,1),
(2281,3,1,16,1,0620,44,3),
(4424,5,1,16,2,0440,68,3),
(4424,2,1,16,3,0440,116,3),
(2212,5,1,16,4,0640,90,2),
(2747,3,1,16,5,0610,65,2),
(2281,4,1,16,6,0620,70,1),
(3317,5,1,16,1,0440,91,2),
(4424,4,1,16,2,0630,124,1),
(2281,3,1,16,3,0415,110,2),
(2281,2,1,16,4,0630,25,3),
(2747,1,1,16,5,0620,51,2),
(4424,4,1,16,6,0420,29,2),
(2281,4,1,16,1,0630,22,2),
(4424,3,1,16,2,0420,40,1),
(3317,2,1,16,3,0625,84,1),
(2747,1,1,16,4,0615,49,2),
(2281,2,1,16,5,0415,59,3),
(2747,3,1,16,6,0415,80,3),
(2281,4,1,16,1,0415,112,3),
(2334,5,1,16,2,0610,102,2),
(2281,3,1,16,3,0415,58,3),
(2758,2,1,16,4,0640,19,3),
(2747,5,1,16,5,0640,105,3),
(2281,4,1,16,6,0420,88,2),
(2281,1,1,16,1,0630,48,2),
(2212,2,1,16,2,0615,39,2),
(2758,3,1,16,3,0625,118,3),
(2281,5,1,16,4,0620,74,1),
(2282,4,1,16,5,0425,43,2),
(2747,2,1,16,6,0420,75,3),
(2281,3,1,16,1,0630,81,2),
(2758,5,1,16,2,0640,90,2),
(3317,4,1,16,3,0620,15,2),
(2763,1,1,16,4,0630,24,3),
(2281,4,1,16,5,0640,91,3),
(2281,3,1,16,6,0620,82,3),
(3317,2,1,16,1,0425,27,3),
(2758,1,1,16,2,0630,21,2),
(2281,5,1,16,3,0440,96,2),
(4424,5,1,16,4,0610,69,1),
(2763,2,1,16,5,0625,97,2),
(4424,3,1,16,6,0615,109,2),
(4424,1,1,16,1,0620,76,3),
(2281,4,1,16,2,0630,65,1),
(2747,5,1,16,3,0415,112,3),
(4424,3,1,16,4,0440,53,1),
(2747,2,1,16,5,0410,80,3),
(2212,2,1,16,6,0415,15,3),
(2281,2,1,16,1,0630,76,2),
(4424,1,1,16,2,0430,110,2),
(2281,1,1,16,3,0630,99,1),
(2281,1,1,16,4,0640,17,2),
(2281,4,1,16,5,0615,92,3),
(2747,3,1,16,6,0615,80,1),
(2212,2,1,16,1,0625,25,2),
(2758,1,1,16,2,0640,20,2),
(2282,5,1,16,3,0640,31,2),
(2282,4,1,16,4,0610,72,2),
(2334,3,1,16,5,0620,63,2),
(2758,2,1,16,6,0615,101,1),
(2281,1,1,16,1,0640,122,2),
(2747,5,1,16,2,0625,26,2),
(4424,4,1,16,3,0640,72,1),
(2758,2,1,16,4,0420,101,3),
(2212,3,1,16,5,0615,107,1),
(4424,1,1,16,6,0415,122,3),
(2750,1,1,16,1,0620,72,1),
(2281,3,1,16,2,0425,119,3),
(4424,2,1,16,3,0625,63,2),
(2763,5,1,16,4,0425,96,3),
(2282,4,1,16,5,0610,81,1),
(2758,3,1,16,6,0415,100,2),
(2747,2,1,16,1,0630,96,1),
(2758,1,1,16,2,0410,31,1),
(2281,4,1,16,3,0610,121,3),
(2281,5,1,16,4,0625,46,2),
(3317,5,1,16,5,0615,79,1),
(2763,4,1,16,6,0430,55,2),
(2282,4,1,16,1,0615,49,3),
(2281,5,1,16,2,0630,121,1),
(2747,3,1,16,3,0610,24,2),
(4424,3,1,16,4,0425,27,1),
(3317,2,1,16,5,0625,116,2),
(2334,1,1,16,6,0625,20,1),
(2212,1,1,16,1,0620,95,3),
(2282,3,1,16,2,0425,59,2),
(2212,2,1,16,3,0625,84,2),
(2758,5,1,16,4,0425,25,1),
(2747,4,1,16,5,0440,22,2),
(2281,3,1,16,6,0410,73,1),
(3317,2,1,16,1,0620,107,1),
(2747,1,1,16,2,0630,74,3),
(4424,4,1,16,3,0620,72,3),
(3317,3,1,16,4,0640,115,3),
(3317,2,1,16,5,0410,58,1),
(4424,1,1,16,6,0615,85,2),
(2281,4,1,16,1,0640,53,2),
(2281,5,1,16,2,0430,76,1),
(2282,1,1,16,3,0430,81,1),
(2763,1,1,16,4,0620,44,2),
(2281,1,1,16,5,0430,58,3),
(2281,3,1,16,6,0640,106,2),
(4424,2,1,16,1,0620,64,3),
(3317,5,1,16,2,0620,56,2),
(4424,4,1,16,3,0625,88,1),
(2763,3,1,16,4,0610,18,1),
(4424,2,1,16,5,0630,101,1),
(2281,1,1,16,6,0420,28,3),
(2281,4,1,16,1,0615,97,3),
(4424,3,1,16,2,0625,61,3),
(3317,2,1,16,3,0625,67,3),
(2747,1,1,16,4,0625,82,2),
(2334,4,1,16,5,0410,36,1),
(2282,5,1,16,6,0610,56,1),
(2747,1,1,16,1,0430,68,3),
(2758,1,1,16,2,0625,115,1),
(2281,1,1,16,3,0425,112,3),
(2281,3,1,16,4,0410,63,3),
(2747,2,1,16,5,0640,89,3),
(4424,5,1,16,6,0630,61,3),
(2750,4,1,16,1,0640,48,2),
(2282,3,1,16,2,0610,83,2),
(2281,2,1,16,3,0425,68,2),
(2747,1,1,16,4,0610,99,3),
(2758,4,1,16,5,0615,59,1),
(3317,3,1,16,6,0610,54,1),
(2747,2,1,16,1,0420,59,2),
(2281,1,1,16,2,0625,79,3),
(3317,4,1,16,3,0620,32,2),
(2281,5,1,16,4,0625,18,3),
(2282,1,1,16,5,0620,82,1),
(2763,1,1,16,6,0425,69,3),
(2281,1,1,16,1,0410,97,3),
(2747,3,1,16,2,0615,87,1),
(4424,2,1,16,3,0630,46,3),
(2747,5,1,16,4,0630,107,3),
(2747,4,1,16,5,0620,95,1),
(4424,3,1,16,6,0615,82,2),
(2281,2,1,16,1,0615,96,3),
(3317,1,1,16,2,0430,125,2),
(2281,4,1,16,3,0620,36,2),
(2281,3,1,16,4,0640,37,2),
(2758,2,1,16,5,0640,82,2),
(2758,1,1,16,6,0420,44,1),
(2281,4,1,16,1,0610,98,3),
(2281,5,1,16,2,0620,117,3),
(4424,5,1,16,3,0420,15,1),
(2281,4,1,16,4,0610,40,1),
(2281,3,1,16,5,0440,18,3),
(4424,2,1,16,6,0415,59,2),
(4424,1,1,16,1,0425,101,2),
(2212,4,1,16,2,0640,57,2),
(2747,1,1,16,3,0630,67,3),
(2282,2,1,16,4,0620,73,2),
(2747,3,1,16,5,0620,15,2),
(2281,5,1,16,6,0410,36,3),
(4424,1,1,16,1,0415,79,2),
(2747,1,1,16,2,0410,40,1),
(2282,4,1,16,3,0620,41,3),
(2281,3,1,16,4,0615,46,2),
(2758,4,1,16,5,0615,97,2),
(2758,5,1,16,6,0430,100,2),
(2281,4,1,16,1,0615,117,1),
(2282,3,1,16,2,0430,60,1),
(2281,5,1,16,3,0415,83,1),
(2281,4,1,16,4,0640,45,2),
(4424,5,1,16,5,0415,50,2),
(3317,3,1,16,6,0610,71,3),
(2282,4,1,16,1,0630,18,2),
(2212,5,1,16,2,0410,22,1),
(4424,4,1,16,3,0410,102,3),
(4424,3,1,16,4,0620,26,3),
(2763,4,1,16,5,0425,47,3),
(3317,1,1,16,6,0625,65,2),
(2758,4,1,16,1,0615,38,1),
(3317,4,1,16,2,0410,40,1),
(4424,3,1,16,3,0420,84,1),
(2281,4,1,16,4,0620,81,3),
(2281,1,1,16,5,0620,94,2),
(2212,4,1,16,6,0620,120,3),
(2763,3,1,16,1,0615,46,3),
(2758,4,1,16,2,0440,21,3),
(2758,5,1,16,3,0640,39,1),
(2281,3,1,16,4,0620,116,1),
(2281,4,1,16,5,0640,25,3),
(2281,5,1,16,6,0620,101,3),
(4424,4,1,16,1,0425,20,1),
(2282,1,1,16,2,0630,116,3),
(2281,4,1,16,3,0630,58,2),
(2758,3,1,16,4,0610,61,3),
(2281,5,1,16,5,0620,52,3),
(4424,4,1,16,6,0615,78,3),
(2747,4,1,16,1,0420,50,1),
(2747,3,1,16,2,0615,15,1),
(2747,5,1,16,3,0415,41,1),
(2747,4,1,16,4,0415,49,2),
(2281,1,1,16,5,0415,123,1),
(2281,4,1,16,6,0425,71,3),
(2758,3,1,16,1,0420,38,1),
(2747,4,1,16,2,0425,97,2),
(4424,1,1,16,3,0430,107,1),
(2750,5,1,16,4,0410,39,2),
(2281,5,1,16,5,0640,81,1),
(2281,4,1,16,6,0615,92,1),
(2212,3,1,16,1,0440,125,2),
(4424,1,1,16,2,0630,33,1),
(2758,4,1,16,3,0625,120,1),
(4424,5,1,16,4,0620,80,2),
(2282,3,1,16,5,0615,39,3),
(2281,4,1,16,6,0610,71,2),
(4424,4,1,16,1,0615,40,2),
(3317,4,1,16,2,0420,25,1),
(2758,1,1,16,3,0410,107,2),
(3317,1,1,16,4,0640,123,3),
(4424,1,1,16,5,0625,87,1),
(2282,4,1,16,6,0625,62,1),
(2281,3,1,16,1,0430,92,1),
(2758,4,1,16,2,0625,95,3),
(2758,1,1,16,3,0640,47,2),
(2750,5,1,16,4,0630,80,3),
(3317,4,1,16,5,0615,122,2),
(4424,3,1,16,6,0640,29,3),
(2281,4,1,16,1,0440,58,3),
(2281,1,1,16,2,0420,75,2),
(3317,5,1,16,3,0430,96,1),
(2281,4,1,16,4,0630,83,3),
(2758,4,1,16,5,0430,18,2),
(2763,3,1,16,6,0610,39,3),
(2281,1,1,16,1,0610,61,1),
(2281,1,1,16,2,0610,53,1),
(2281,3,1,16,3,0430,107,3),
(4424,4,1,16,4,0415,115,1),
(2747,5,1,16,5,0415,63,3),
(4424,4,1,16,6,0640,111,3),
(2758,3,1,16,1,0620,21,1),
(2212,4,1,16,2,0630,108,3),
(2758,1,1,16,3,0610,81,1),
(2282,4,1,16,4,0410,45,3),
(2212,5,1,16,5,0620,109,1),
(2747,5,1,16,6,0615,88,1),
(2763,4,1,16,1,0410,28,3),
(2282,4,1,16,2,0640,52,1),
(2281,5,1,16,3,0630,92,3),
(2281,3,1,16,4,0425,29,2),
(3317,3,1,16,5,0440,43,1),
(2747,4,1,16,6,0410,111,3),
(2334,1,1,16,1,0620,87,1),
(2281,1,1,16,2,0440,103,3),
(2281,3,1,16,3,0620,34,3),
(2758,4,1,16,4,0430,103,1),
(3317,5,1,16,5,0620,46,3),
(2281,4,1,16,6,0420,53,2),
(2747,3,1,16,1,0625,16,1),
(2212,4,1,16,2,0620,111,1),
(2758,1,1,16,3,0425,81,3),
(2281,4,1,16,4,0425,43,3),
(2281,3,1,16,5,0620,62,3),
(2212,4,1,16,6,0630,25,2),
(2281,1,1,16,1,0425,121,1),
(3317,4,1,16,2,0625,62,3),
(2282,5,1,16,3,0625,36,2),
(2281,1,1,16,4,0430,27,1),
(2281,1,1,16,5,0610,107,1),
(2747,1,1,16,6,0410,43,3),
(2763,3,1,16,1,0430,53,1),
(2281,4,1,16,2,0640,24,1),
(2758,5,1,16,3,0420,115,2),
(2763,4,1,16,4,0615,39,3),
(2281,3,1,16,5,0610,24,1),
(4424,4,1,16,6,0640,20,2),
(4424,1,1,16,1,0610,23,2),
(2281,4,1,16,2,0620,45,3),
(3317,3,1,16,3,0615,16,1),
(2747,4,1,16,4,0415,95,2),
(2747,1,1,16,5,0425,36,1),
(2281,4,1,16,6,0620,64,3),
(2747,5,1,16,1,0630,29,2),
(3317,1,1,16,2,0625,106,1),
(2281,1,1,16,3,0620,34,3),
(2212,1,1,16,4,0620,63,1),
(2281,3,1,16,5,0610,56,1),
(2758,4,1,16,6,0625,35,3),
(2763,5,1,16,1,0615,116,1),
(2281,4,1,16,2,0615,65,1),
(2281,3,1,16,3,0620,49,2),
(4424,4,1,16,4,0615,28,3),
(2758,1,1,16,5,0615,73,2),
(2281,4,1,16,6,0430,79,1),
(3317,3,1,16,1,0640,65,3),
(3317,4,1,16,2,0610,85,1),
(2281,1,1,16,3,0630,68,1),
(2747,4,1,16,4,0410,19,3),
(2763,5,1,16,5,0630,72,2),
(4424,1,1,16,6,0630,16,2),
(2747,1,1,16,1,0415,55,3),
(2282,1,1,16,2,0420,77,2),
(3317,3,1,16,3,0625,35,3),
(2281,4,1,16,4,0640,70,3),
(2281,5,1,16,5,0615,45,1),
(2281,4,1,16,6,0440,16,1),
(4424,3,1,16,1,0420,115,3),
(2281,4,1,16,2,0630,24,2),
(2281,1,1,16,3,0630,48,1),
(2747,4,1,16,4,0640,15,3),
(2758,3,1,16,5,0620,43,1),
(2281,4,1,16,6,0630,120,2),
(4424,1,1,16,1,0625,109,3),
(2747,4,1,16,2,0610,102,1),
(3317,5,1,16,3,0420,40,1),
(2281,5,1,16,4,0625,40,2),
(4424,4,1,16,5,0440,55,2),
(2282,3,1,16,6,0420,108,3),
(4424,4,1,16,1,0425,63,2),
(2763,1,1,16,2,0610,104,2),
(2750,4,1,16,3,0440,56,3),
(2281,1,1,16,4,0620,27,3),
(2281,4,1,16,5,0430,103,2),
(2758,3,1,16,6,0640,32,1),
(4424,5,1,16,1,0420,85,2),
(2763,1,1,16,2,0440,71,2),
(3317,1,1,16,3,0640,103,3),
(2281,4,1,16,4,0425,96,2),
(2758,3,1,16,5,0625,26,2),
(2747,4,1,16,6,0640,65,2),
(2758,5,1,16,1,0420,35,2),
(2747,4,1,16,2,0430,77,2),
(2747,3,1,16,3,0615,79,2),
(2281,5,1,16,4,0625,105,3),
(2758,4,1,16,5,0625,72,1),
(2758,5,1,16,6,0640,65,3),
(2281,3,1,16,1,0615,36,1),
(4424,4,1,16,2,0440,30,2),
(2212,5,1,16,3,0615,44,2),
(2281,4,1,16,4,0610,58,1),
(2747,3,1,16,5,0425,116,3),
(2281,4,1,16,6,0625,116,2),
(3317,1,1,16,1,0620,40,2),
(2281,4,1,16,2,0620,34,1),
(4424,4,1,16,3,0620,15,3),
(4424,3,1,16,4,0630,115,3),
(2212,4,1,16,5,0615,94,2),
(2758,1,1,16,6,0440,93,2),
(2758,4,1,16,1,0430,43,2),
(2758,3,1,16,2,0615,112,2),
(2282,4,1,16,3,0410,65,3),
(2281,5,1,16,4,0620,73,1),
(2282,3,1,16,5,0410,88,2),
(2281,4,1,16,6,0415,44,1),
(2281,5,1,16,1,0420,69,2),
(4424,4,1,16,2,0415,68,1),
(2763,1,1,16,3,0420,86,1),
(3317,4,1,16,4,0615,74,3),
(2747,3,1,16,5,0630,62,3),
(2281,5,1,16,6,0625,79,2),
(2281,4,1,16,1,0410,94,1),
(2281,4,1,16,2,0615,48,3),
(2281,3,1,16,3,0625,101,3),
(4424,5,1,16,4,0610,41,1),
(2334,4,1,16,5,0640,21,1),
(2281,1,1,16,6,0630,96,1),
(3317,4,1,16,1,0620,123,1),
(2281,3,1,16,2,0640,112,2),
(2758,4,1,16,3,0620,124,2),
(4424,1,1,16,4,0610,119,2),
(2282,5,1,16,5,0625,114,3),
(2747,4,1,16,6,0615,109,2),
(2212,3,1,16,1,0615,105,1),
(2281,4,1,16,2,0425,40,2),
(2281,1,1,16,3,0640,90,2),
(3317,4,1,16,4,0625,86,2),
(2281,1,1,16,5,0415,93,3),
(2747,4,1,16,6,0625,54,1),
(2747,3,1,16,1,0615,29,3),
(2281,5,1,16,2,0630,75,3),
(4424,1,1,16,3,0415,122,2),
(2747,1,1,16,4,0620,78,3),
(2281,4,1,16,5,0615,28,2),
(2758,3,1,16,6,0610,18,1),
(2747,4,1,16,1,0630,60,1),
(2212,5,1,16,2,0610,45,3),
(2281,4,1,16,3,0430,114,3),
(2281,3,1,16,4,0625,77,2),
(4424,5,1,16,5,0625,61,2),
(2334,4,1,16,6,0610,61,1),
(2281,5,1,16,1,0625,82,3),
(4424,3,1,16,2,0420,112,3),
(2212,4,1,16,3,0415,125,2),
(2747,5,1,16,4,0620,29,1),
(2281,4,1,16,5,0615,60,3),
(2747,3,1,16,6,0440,79,3),
(2281,4,1,16,1,0620,83,2),
(2281,1,1,16,2,0610,117,2),
(2281,4,1,16,3,0640,28,3),
(2747,4,1,16,4,0630,119,3),
(2758,3,1,16,5,0415,53,2),
(2763,4,1,16,6,0620,94,2),
(2281,1,1,16,1,0625,43,2),
(2763,4,1,16,2,0440,87,3),
(2281,3,1,16,3,0430,50,3),
(2281,4,1,16,4,0440,56,2),
(2758,5,1,16,5,0610,22,1),
(3317,3,1,16,6,0615,22,3),
(2758,4,1,16,1,0615,62,1),
(2281,5,1,16,2,0615,35,1),
(2334,4,1,16,3,0430,78,2),
(2281,1,1,16,4,0630,25,1),
(4424,4,1,16,5,0630,75,2),
(2281,3,1,16,6,0410,93,1),
(4424,5,1,16,1,0610,108,2),
(2747,4,1,16,2,0610,115,2),
(2281,4,1,16,3,0640,55,3),
(3317,3,1,16,4,0640,106,2),
(2747,5,1,16,5,0430,93,1),
(3317,4,1,16,6,0425,69,3),
(2212,1,1,16,1,0615,85,1),
(2281,4,1,16,2,0420,29,1),
(3317,3,1,16,3,0420,96,3),
(2758,4,1,16,4,0440,69,1),
(2281,1,1,16,5,0425,69,2),
(2282,5,1,16,6,0610,34,3),
(2758,5,1,16,1,0630,61,2),
(2747,4,1,16,2,0440,25,3),
(2750,3,1,16,3,0615,23,3),
(4424,1,1,16,4,0415,84,2),
(2281,4,1,16,5,0610,95,1),
(2747,5,1,16,6,0615,36,2),
(4424,3,1,16,1,0630,26,1),
(2758,4,1,16,2,0615,25,3),
(4424,4,1,16,3,0415,90,3),
(2281,4,1,16,4,0425,87,2),
(2763,1,1,16,5,0420,59,2),
(3317,1,1,16,6,0410,19,3),
(2282,1,1,16,1,0620,125,2),
(2212,4,1,16,2,0625,30,2),
(4424,3,1,16,3,0630,85,3),
(2281,4,1,16,4,0430,56,1),
(3317,1,1,16,5,0625,22,1),
(2281,5,1,16,6,0440,116,3),
(2334,4,1,16,1,0610,63,2),
(4424,3,1,16,2,0630,124,1),
(2763,4,1,16,3,0610,68,3),
(2282,1,1,16,4,0615,40,2),
(4424,5,1,16,5,0615,109,1),
(2747,4,1,16,6,0430,120,1),
(4424,4,1,16,1,0625,32,2),
(2281,3,1,16,2,0640,23,3),
(2747,1,1,16,3,0620,27,3),
(2758,1,1,16,4,0620,28,2),
(4424,3,1,16,5,0640,31,1),
(3317,4,1,16,6,0640,102,1),
(2281,5,1,16,1,0610,64,1),
(2281,4,1,16,2,0630,83,2),
(2281,3,1,16,3,0625,30,1),
(2758,4,1,16,4,0420,42,3),
(3317,1,1,16,5,0430,62,2),
(2281,4,1,16,6,0625,103,1),
(2281,5,1,16,1,0615,44,3),
(4424,5,1,16,2,0625,47,1),
(2758,4,1,16,3,0425,40,2),
(2281,4,1,16,4,0630,75,1),
(2747,5,1,16,5,0620,82,2),
(2281,3,1,16,6,0625,94,3),
(2282,3,1,16,1,0410,92,3),
(2212,4,1,16,2,0610,90,1),
(2747,1,1,16,3,0625,125,2),
(2281,1,1,16,4,0625,21,3),
(2281,3,1,16,5,0440,65,3),
(2747,4,1,16,6,0625,117,3),
(2747,5,1,16,1,0420,54,3),
(2281,4,1,16,2,0410,120,1),
(2758,3,1,16,3,0610,69,3),
(2281,4,1,16,4,0610,80,2),
(2281,1,1,16,5,0610,23,3),
(4424,4,1,16,6,0610,84,2),
(2281,3,1,16,1,0630,104,2),
(2282,4,1,16,2,0620,85,1),
(2334,1,1,16,3,0620,108,2),
(3317,4,1,16,4,0630,44,3),
(2282,5,1,16,5,0620,33,1),
(2763,1,1,16,6,0630,76,1),
(4424,1,1,16,1,0415,49,3),
(2282,1,1,16,2,0620,46,3),
(2758,3,1,16,3,0610,76,1),
(2747,4,1,16,4,0640,89,2),
(3317,5,1,16,5,0610,18,2),
(2281,4,1,16,6,0410,22,1),
(2281,3,1,16,1,0640,70,1),
(3317,4,1,16,2,0420,50,2),
(2747,1,1,16,3,0420,30,2),
(2758,4,1,16,4,0410,78,3),
(2758,3,1,16,5,0440,93,3),
(3317,4,1,16,6,0610,93,1),
(4424,1,1,16,1,0630,62,2),
(2758,4,1,16,2,0625,94,3),
(4424,5,1,16,3,0615,73,1),
(2281,1,1,16,4,0425,108,2),
(2747,1,1,16,5,0620,59,2),
(2758,1,1,16,6,0620,125,2),
(2281,3,1,16,1,0610,38,3),
(2750,4,1,16,2,0420,50,2),
(2281,5,1,16,3,0440,121,1),
(4424,4,1,16,4,0615,118,3),
(2281,3,1,16,5,0440,114,1),
(2747,4,1,16,6,0640,102,1),
(2747,1,1,16,1,0625,66,3),
(3317,4,1,16,2,0410,121,3),
(2212,3,1,16,3,0630,95,1),
(2212,4,1,16,4,0620,92,1),
(2281,1,1,16,5,0415,105,3),
(4424,4,1,16,6,0625,95,3),
(2763,5,1,16,1,0420,48,3),
(2281,1,1,16,2,0615,54,3),
(2758,1,1,16,3,0640,48,2),
(3317,1,1,16,4,0615,73,3),
(2281,3,1,16,5,0640,94,3),
(4424,4,1,16,6,0615,100,2),
(2281,5,1,16,1,0640,47,2),
(2750,4,1,16,2,0630,64,2),
(3317,3,1,16,3,0630,99,3),
(2282,4,1,16,4,0420,24,1),
(4424,1,1,16,5,0410,35,1),
(2758,4,1,16,6,0615,121,2),
(2212,3,1,16,1,0630,64,1),
(2281,4,1,16,2,0625,30,2),
(2747,1,1,16,3,0630,24,2),
(4424,4,1,16,4,0615,59,1),
(2758,5,1,16,5,0615,15,2),
(2334,5,1,16,6,0625,16,1),
(2281,4,1,16,1,0625,124,2),
(2758,3,1,16,2,0410,73,1),
(2281,4,1,16,3,0425,22,3),
(2212,1,1,16,4,0425,57,3),
(4424,4,1,16,5,0625,122,3),
(2758,1,1,16,6,0625,21,1),
(3317,4,1,16,1,0615,52,3),
(2281,3,1,16,2,0625,70,1),
(2763,5,1,16,3,0640,51,3),
(4424,1,1,16,4,0625,91,1),
(2282,1,1,16,5,0610,28,1),
(2281,4,1,16,6,0630,77,3),
(2281,3,1,16,1,0620,25,2),
(2281,4,1,16,2,0415,60,2),
(4424,5,1,16,3,0615,28,3),
(2747,4,1,16,4,0630,119,3),
(2747,3,1,16,5,0430,61,2),
(4424,5,1,16,6,0610,39,2),
(2763,4,1,16,1,0440,93,1),
(2747,5,1,16,2,0625,26,1),
(2281,3,1,16,3,0615,40,2),
(2758,4,1,16,4,0610,86,3),
(4424,5,1,16,5,0420,19,2),
(2758,4,1,16,6,0620,81,2),
(2281,3,1,16,1,0430,75,3),
(2747,4,1,16,2,0640,118,2),
(3317,1,1,16,3,0415,22,1),
(3317,4,1,16,4,0630,41,2),
(2281,4,1,16,5,0430,36,3),
(2758,3,1,16,6,0640,20,1),
(3317,4,1,16,1,0610,102,1),
(3317,1,1,16,2,0615,104,1),
(2281,4,1,16,3,0625,16,3),
(2747,3,1,16,4,0620,92,1),
(2281,4,1,16,5,0425,92,3),
(2281,5,1,16,6,0640,94,1),
(2281,3,1,16,1,0425,56,1),
(2281,4,1,16,2,0430,88,1),
(2212,5,1,16,3,0610,38,3),
(3317,4,1,16,4,0425,121,2),
(2281,1,1,16,5,0620,112,2),
(2747,4,1,16,6,0620,71,2),
(2281,3,1,16,1,0615,31,2),
(2281,5,1,16,2,0415,36,2),
(2212,4,1,16,3,0420,102,2),
(2281,4,1,16,4,0640,93,3),
(2281,3,1,16,5,0425,116,2),
(4424,5,1,16,6,0640,65,3),
(2747,4,1,16,1,0630,87,1),
(2281,1,1,16,2,0440,87,2),
(2758,4,1,16,3,0615,94,3),
(2334,3,1,16,4,0415,20,3),
(2747,4,1,16,5,0630,88,2),
(4424,1,1,16,6,0440,112,3),
(4424,5,1,16,1,0625,118,3),
(2747,5,1,16,2,0620,21,2),
(2281,4,1,16,3,0430,45,2),
(2281,3,1,16,4,0615,33,2),
(2281,1,1,16,5,0415,101,3),
(2747,4,1,16,6,0630,106,1),
(2281,5,1,16,1,0620,117,1),
(2282,3,1,16,2,0625,51,1),
(2212,4,1,16,3,0625,21,3),
(2212,4,1,16,4,0610,82,1),
(2750,4,1,16,5,0620,26,1),
(2747,1,1,16,6,0625,110,2),
(2747,1,1,16,1,0425,75,2),
(3317,1,1,16,2,0615,26,3),
(2281,4,1,16,3,0415,76,1),
(2282,3,1,16,4,0630,105,2),
(2281,4,1,16,5,0430,29,1),
(2758,1,1,16,6,0410,71,3),
(2758,5,1,16,1,0620,46,1),
(3317,4,1,16,2,0625,122,1),
(2281,3,1,16,3,0610,112,2),
(2281,4,1,16,4,0625,38,1),
(2282,1,1,16,5,0410,59,1),
(4424,5,1,16,6,0430,83,1),
(3317,4,1,16,1,0415,85,1),
(2281,4,1,16,2,0410,70,2),
(4424,3,1,16,3,0425,19,3),
(2281,1,1,16,4,0625,49,2),
(4424,1,1,16,5,0625,81,3),
(3317,3,1,16,6,0640,84,2),
(2281,4,1,16,1,0615,48,1),
(2763,5,1,16,2,0630,61,1),
(2747,4,1,16,3,0615,70,3),
(2747,3,1,16,4,0620,71,3),
(2747,4,1,16,5,0615,75,3),
(2281,1,1,16,6,0625,67,2),
(4424,4,1,16,1,0440,45,3),
(2281,5,1,16,2,0630,117,3),
(2281,5,1,16,3,0420,50,3),
(4424,4,1,16,4,0640,108,3),
(2282,4,1,16,5,0610,35,3),
(3317,5,1,16,6,0630,77,3),
(2747,3,1,16,1,0610,82,3),
(2334,3,1,16,2,0640,26,1),
(2281,4,1,16,3,0430,64,1),
(2758,1,1,16,4,0610,26,3),
(2747,1,1,16,5,0615,71,3),
(2747,3,1,16,6,0410,100,1),
(2747,4,1,16,1,0640,48,3),
(2758,5,1,16,2,0620,59,3),
(2281,4,1,16,3,0640,62,3),
(2281,3,1,16,4,0620,55,3),
(2281,4,1,16,5,0615,44,2),
(4424,1,1,16,6,0440,85,2),
(2758,4,1,16,1,0610,60,2),
(2281,3,1,16,2,0610,41,1),
(2212,4,1,16,3,0625,33,1),
(2281,1,1,16,4,0610,37,1),
(2747,4,1,16,5,0625,33,3),
(2763,5,1,16,6,0440,100,2),
(2281,1,1,16,1,0610,75,1),
(2758,1,1,16,2,0440,18,3),
(2750,1,1,16,3,0625,35,3),
(2758,3,1,16,4,0425,29,3),
(2281,4,1,16,5,0610,73,3),
(4424,5,1,16,6,0625,53,2),
(2281,4,1,16,1,0415,117,2),
(2281,3,1,16,2,0425,35,2),
(2281,4,1,16,3,0420,77,1),
(2334,1,1,16,4,0620,87,1),
(2282,4,1,16,5,0625,108,2),
(2758,3,1,16,6,0630,110,2),
(2747,4,1,16,1,0640,75,3),
(2281,1,1,16,2,0640,113,1),
(4424,4,1,16,3,0615,22,2),
(2281,5,1,16,4,0630,74,1),
(2281,1,1,16,5,0610,17,1),
(4424,1,1,16,6,0640,72,1),
(3317,1,1,16,1,0610,25,1),
(2212,3,1,16,2,0440,124,2),
(2281,4,1,16,3,0425,92,3),
(3317,5,1,16,4,0640,51,3),
(2281,4,1,16,5,0620,17,3),
(2281,3,1,16,6,0640,106,2),
(2758,4,1,16,1,0610,35,1),
(2763,1,1,16,2,0610,55,1),
(4424,4,1,16,3,0625,79,1),
(2282,3,1,16,4,0430,66,2),
(2281,4,1,16,5,0615,76,2),
(4424,1,1,16,6,0440,99,3),
(2747,4,1,16,1,0640,110,2),
(3317,5,1,16,2,0625,122,2),
(2747,1,1,16,3,0440,107,1),
(2758,1,1,16,4,0620,78,2),
(2281,1,1,16,5,0625,47,2),
(3317,3,1,16,6,0625,28,1),
(2281,4,1,16,1,0615,51,3),
(2758,5,1,16,2,0615,84,3),
(2281,4,1,16,3,0620,64,3),
(2281,3,1,16,4,0625,101,2),
(3317,4,1,16,5,0610,116,1),
(2758,1,1,16,6,0610,99,2),
(3317,4,1,16,1,0625,122,1),
(2281,3,1,16,2,0430,23,2),
(2763,4,1,16,3,0640,117,2),
(2281,1,1,16,4,0440,90,1),
(2747,4,1,16,5,0620,80,3),
(2281,5,1,16,6,0425,93,3),
(2282,5,1,16,1,0625,69,2),
(2758,4,1,16,2,0620,95,1),
(2763,3,1,16,3,0640,106,1),
(2281,4,1,16,4,0625,34,2),
(4424,1,1,16,5,0410,19,1),
(4424,4,1,16,6,0640,75,1),
(2281,1,1,16,1,0620,50,2),
(2281,4,1,16,2,0630,17,3),
(2281,3,1,16,3,0625,123,2),
(3317,5,1,16,4,0630,74,1),
(4424,1,1,16,5,0625,77,2),
(2281,1,1,16,6,0440,106,3),
(2758,4,1,16,1,0630,61,3),
(2281,3,1,16,2,0630,16,3),
(2763,4,1,16,3,0415,45,2),
(2747,5,1,16,4,0410,91,2),
(2281,4,1,16,5,0625,97,2),
(2758,3,1,16,6,0640,35,3),
(2763,5,1,16,1,0640,35,3),
(2747,4,1,16,2,0640,50,2),
(2212,5,1,16,3,0620,76,1),
(4424,3,1,16,4,0630,100,1),
(2334,4,1,16,5,0630,105,3),
(3317,5,1,16,6,0640,91,1),
(3317,4,1,16,1,0420,60,2),
(2758,3,1,16,2,0430,113,1),
(2281,4,1,16,3,0615,122,2),
(4424,1,1,16,4,0620,97,2),
(4424,4,1,16,5,0615,28,2),
(2281,4,1,16,6,0410,89,3),
(3317,3,1,16,1,0640,46,3),
(2334,4,1,16,2,0410,94,3),
(2212,1,1,16,3,0430,111,3),
(2281,4,1,16,4,0610,68,3),
(2281,3,1,16,5,0625,87,3),
(4424,4,1,16,6,0440,38,1),
(2281,5,1,16,1,0615,92,1),
(2747,3,1,16,2,0430,65,3),
(2758,4,1,16,3,0625,112,2),
(2747,5,1,16,4,0615,98,1),
(4424,4,1,16,5,0630,116,1),
(2281,1,1,16,6,0630,15,3),
(2758,4,1,16,1,0615,22,1),
(2747,3,1,16,2,0440,77,1),
(2281,5,1,16,3,0440,117,2),
(2747,4,1,16,4,0610,58,3),
(2212,4,1,16,5,0630,73,2),
(2747,3,1,16,6,0610,97,3),
(3317,5,1,16,1,0440,16,2),
(4424,4,1,16,2,0440,111,1),
(3317,1,1,16,3,0410,79,3),
(2758,4,1,16,4,0425,39,2),
(4424,3,1,16,5,0410,100,1),
(2281,4,1,16,6,0440,21,3),
(2747,1,1,16,1,0410,75,1),
(2281,5,1,16,2,0420,70,2),
(2281,4,1,16,3,0625,121,1),
(2281,3,1,16,4,0615,58,2),
(2747,4,1,16,5,0430,38,3),
(4424,1,1,16,6,0410,66,1),
(2763,4,1,16,1,0430,25,3),
(2763,1,1,16,2,0640,26,2),
(2281,4,1,16,3,0410,32,2),
(2281,3,1,16,4,0640,36,1),
(2758,5,1,16,5,0425,77,2),
(2212,1,1,16,6,0625,54,2),
(2281,1,1,16,1,0615,83,3),
(2747,4,1,16,2,0610,53,3),
(2282,3,1,16,3,0425,94,1),
(2281,4,1,16,4,0415,23,1),
(2281,5,1,16,5,0620,47,3),
(3317,4,1,16,6,0425,87,1),
(2212,3,1,16,1,0620,85,2),
(4424,5,1,16,2,0640,35,1),
(2281,4,1,16,3,0620,54,3),
(2334,5,1,16,4,0425,86,1),
(2281,3,1,16,5,0425,22,3),
(2281,4,1,16,6,0440,98,1),
(2758,5,1,16,1,0410,118,3),
(2282,4,1,16,2,0640,22,2),
(3317,3,1,16,3,0615,95,2),
(2763,4,1,16,4,0415,117,3),
(2747,1,1,16,5,0420,44,3),
(2281,4,1,16,6,0625,120,2),
(2758,4,1,16,1,0630,112,3),
(2281,3,1,16,2,0620,78,1),
(2212,4,1,16,3,0410,21,2),
(2747,1,1,16,4,0425,92,3),
(4424,4,1,16,5,0430,73,1),
(2747,3,1,16,6,0615,54,2),
(2758,4,1,16,1,0640,75,1),
(2282,5,1,16,2,0430,113,3),
(2758,3,1,16,3,0625,120,2),
(2334,4,1,16,4,0640,55,1),
(2281,5,1,16,5,0610,56,2),
(2281,4,1,16,6,0430,103,2),
(2281,1,1,16,1,0610,24,3),
(3317,4,1,16,2,0615,80,2),
(4424,3,1,16,3,0420,72,2),
(4424,5,1,16,4,0440,18,3),
(2281,4,1,16,5,0430,59,3),
(2212,4,1,16,6,0620,87,3),
(2750,3,1,16,1,0625,25,3),
(3317,5,1,16,2,0640,122,1),
(3317,4,1,16,3,0410,102,2),
(3317,1,1,16,4,0610,47,1),
(2281,4,1,16,5,0630,42,3),
(2281,3,1,16,6,0640,40,2),
(2282,4,1,16,1,0630,82,2),
(2281,1,1,16,2,0610,111,3),
(2212,5,1,16,3,0625,74,2),
(2281,5,1,16,4,0625,92,2),
(2758,4,1,16,5,0620,35,3),
(4424,3,1,16,6,0610,106,1),
(4424,1,1,16,1,0440,23,3),
(2281,4,1,16,2,0415,30,1),
(3317,5,1,16,3,0630,118,3),
(2758,3,1,16,4,0430,39,3),
(2282,4,1,16,5,0425,109,1),
(2758,4,1,16,6,0625,116,3),
(2747,4,1,16,1,0440,88,2),
(2281,1,1,16,2,0615,123,3),
(2281,1,1,16,3,0620,103,1),
(2281,1,1,16,4,0640,114,1),
(2747,4,1,16,5,0425,23,2),
(2334,3,1,16,6,0615,116,1),
(2747,4,1,16,1,0430,115,3),
(3317,1,1,16,2,0620,64,1),
(2758,5,1,16,3,0630,115,2),
(2758,4,1,16,4,0610,29,3),
(2747,3,1,16,5,0625,24,2),
(2282,4,1,16,6,0415,30,1),
(2281,1,1,16,1,0625,72,2),
(2281,5,1,16,2,0625,18,2),
(2282,4,1,16,3,0625,37,3),
(2758,4,1,16,4,0410,61,3),
(2747,3,1,16,5,0610,80,2),
(2747,1,1,16,6,0415,21,1),
(3317,1,1,16,1,0610,68,1),
(4424,3,1,16,2,0640,106,1),
(2747,4,1,16,3,0610,119,3),
(2282,5,1,16,4,0420,99,3),
(2763,4,1,16,5,0630,55,1),
(2281,3,1,16,6,0630,78,1),
(2281,4,1,16,1,0415,53,2),
(2281,1,1,16,2,0615,57,1),
(3317,4,1,16,3,0630,100,3),
(2281,5,1,16,4,0610,69,1),
(4424,5,1,16,5,0620,111,3),
(2281,4,1,16,6,0420,21,3),
(2281,4,1,16,1,0425,96,1),
(2281,5,1,16,2,0630,102,3),
(2758,3,1,16,3,0420,109,2),
(2758,3,1,16,4,0610,51,1),
(2758,4,1,16,5,0610,107,3),
(2750,1,1,16,6,0640,119,2),
(2212,1,1,16,1,0620,102,2),
(2747,3,1,16,2,0615,77,2),
(3317,4,1,16,3,0615,44,2),
(2758,5,1,16,4,0620,88,3),
(3317,4,1,16,5,0430,32,2),
(2281,3,1,16,6,0425,89,1),
(2758,4,1,16,1,0630,29,1),
(2281,1,1,16,2,0610,59,2),
(3317,4,1,16,3,0610,103,1),
(2212,3,1,16,4,0410,97,3),
(2747,4,1,16,5,0610,48,1),
(2747,1,1,16,6,0410,15,2),
(2281,4,1,16,1,0640,31,3),
(2281,5,1,16,2,0415,92,2),
(4424,1,1,16,3,0440,85,1),
(2281,1,1,16,4,0610,86,3),
(2281,1,1,16,5,0410,21,3),
(2282,3,1,16,6,0440,102,1),
(2763,4,1,16,1,0640,58,3),
(2281,5,1,16,2,0410,109,1),
(2281,4,1,16,3,0610,28,2),
(2747,3,1,16,4,0610,42,3),
(2758,4,1,16,5,0615,57,2),
(2747,1,1,16,6,0610,78,3),
(4424,4,1,16,1,0625,73,2),
(2281,3,1,16,2,0425,81,2),
(2282,4,1,16,3,0625,58,1),
(2212,1,1,16,4,0640,76,1),
(2758,4,1,16,5,0615,53,3),
(2281,5,1,16,6,0625,28,1),
(3317,1,1,16,1,0420,121,2),
(4424,1,1,16,2,0420,68,1),
(4424,1,1,16,3,0610,38,2),
(2758,3,1,16,4,0415,56,1),
(2281,4,1,16,5,0430,32,1),
(2758,5,1,16,6,0630,113,3),
(2281,4,1,16,1,0620,17,1),
(2750,3,1,16,2,0625,17,2),
(2334,4,1,16,3,0410,85,2),
(4424,1,1,16,4,0420,108,2),
(2282,4,1,16,5,0610,31,1),
(2758,3,1,16,6,0640,85,3),
(2281,4,1,16,1,0630,57,2),
(3317,1,1,16,2,0610,45,1),
(2747,4,1,16,3,0610,81,1),
(4424,5,1,16,4,0410,18,1),
(2212,1,1,16,5,0610,39,1),
(2212,1,1,16,6,0430,96,2),
(2281,1,1,16,1,0630,121,1),
(4424,3,1,16,2,0430,45,1),
(2763,4,1,16,3,0615,67,2),
(3317,5,1,16,4,0640,26,2),
(2281,4,1,16,5,0440,44,1),
(2281,3,1,16,6,0415,27,2),
(2281,4,1,16,1,0615,73,3),
(2747,1,1,16,2,0630,24,3),
(2282,4,1,16,3,0610,53,3),
(3317,3,1,16,4,0625,34,3),
(2281,2,1,16,5,0610,82,1),
(2281,1,1,16,6,0440,27,1),
(4424,4,1,16,1,0420,124,1),
(2747,5,1,16,2,0640,21,2),
(4424,5,1,16,3,0615,19,3),
(2758,4,1,16,4,0610,84,1),
(2747,3,1,16,5,0620,112,2),
(2758,2,1,16,6,0430,45,1),
(3317,1,1,16,1,0420,111,1),
(2758,4,1,16,2,0420,32,1),
(2758,1,1,16,3,0640,73,2),
(2281,2,1,16,4,0410,113,3),
(4424,3,1,16,5,0625,24,2),
(2758,5,1,16,6,0425,115,2),
(2281,1,1,16,1,0610,103,2),
(2281,1,1,16,2,0620,41,2),
(2281,2,1,16,3,0430,111,3),
(3317,3,1,16,4,0420,18,1),
(2282,4,1,16,5,0610,78,2),
(2747,5,1,16,6,0610,21,1),
(2747,2,1,16,1,0615,92,2),
(2281,3,1,16,2,0430,78,1),
(2281,5,1,16,3,0630,100,1),
(2212,2,1,16,4,0610,104,3),
(2281,5,1,16,5,0410,118,3),
(3317,3,1,16,6,0620,20,1),
(2282,4,1,16,1,0640,22,1),
(2758,5,1,16,2,0630,16,3),
(2763,4,1,16,3,0620,22,3),
(3317,3,1,16,4,0415,59,1),
(2747,2,1,16,5,0415,76,1),
(2758,1,1,16,6,0440,52,1),
(2747,4,1,16,1,0615,125,1),
(2281,4,1,16,2,0430,16,3),
(4424,3,1,16,3,0620,98,3),
(2281,2,1,16,4,0610,49,1),
(2747,1,1,16,5,0615,85,1),
(2758,2,1,16,6,0430,62,1),
(2212,3,1,16,1,0630,72,3),
(2747,4,1,16,2,0420,114,1),
(3317,5,1,16,3,0425,40,2),
(2281,3,1,16,4,0610,125,1),
(2281,2,1,16,5,0625,27,3),
(2281,5,1,16,6,0410,95,2),
(2281,4,1,16,1,0610,38,2),
(2281,1,1,16,2,0615,24,2),
(4424,2,1,16,3,0640,92,2),
(2282,3,1,16,4,0430,43,1),
(2281,5,1,16,5,0415,59,3),
(2758,4,1,16,6,0625,70,2),
(2758,2,1,16,1,0420,37,2),
(2763,3,1,16,2,0410,76,1),
(2281,5,1,16,3,0410,103,1),
(3317,4,1,16,4,0640,93,1),
(2281,1,1,16,5,0625,24,1),
(3317,4,1,16,6,0430,39,2),
(4424,3,1,16,1,0410,59,1),
(2747,2,1,16,2,0640,124,1),
(3317,1,1,16,3,0440,68,3),
(2281,5,1,16,4,0615,29,1),
(4424,5,1,16,5,0640,98,1),
(2281,2,1,16,6,0610,36,1),
(4424,3,1,16,1,0415,66,3),
(2747,1,1,16,2,0625,94,2),
(2334,4,1,16,3,0415,52,2),
(2758,5,1,16,4,0415,82,1),
(2747,3,1,16,5,0610,41,3),
(2747,2,1,16,6,0630,34,1),
(4424,2,1,16,1,0610,19,2),
(2747,2,1,16,2,0430,71,1),
(2281,1,1,16,3,0420,42,1),
(2212,1,1,16,4,0625,94,1),
(2281,1,1,16,5,0630,89,3),
(3317,4,1,16,6,0620,84,1),
(2281,3,1,16,1,0615,30,2),
(2212,2,1,16,2,0630,48,2),
(2758,1,1,16,3,0415,33,1),
(2282,5,1,16,4,0615,22,1),
(2212,4,1,16,5,0610,70,2),
(3317,3,1,16,6,0610,73,1),
(4424,2,1,16,1,0415,48,3),
(2758,1,1,16,2,0415,109,1),
(2750,5,1,16,3,0630,88,1),
(2281,4,1,16,4,0425,48,1),
(2747,2,1,16,5,0610,72,2),
(2281,3,1,16,6,0625,85,2),
(2281,1,1,16,1,0615,78,3),
(2747,1,1,16,2,0425,40,2),
(4424,3,1,16,3,0440,100,2),
(2281,2,1,16,4,0630,124,2),
(2281,5,1,16,5,0640,28,1),
(2281,4,1,16,6,0620,50,1),
(2281,3,1,16,1,0440,48,2),
(4424,2,1,16,2,0610,124,1),
(3317,1,1,16,3,0410,31,3),
(2747,4,1,16,4,0615,107,2),
(2281,5,1,16,5,0420,92,3),
(4424,5,1,16,6,0415,42,1),
(2281,4,1,16,1,0640,80,2),
(2281,4,1,16,2,0620,113,2),
(2747,5,1,16,3,0610,88,2),
(2281,3,1,16,4,0440,28,3),
(3317,3,1,16,5,0430,78,3),
(2750,2,1,16,6,0620,53,3),
(2281,1,1,16,1,0620,31,3),
(2281,1,1,16,2,0410,101,3),
(2758,3,1,16,3,0610,24,2),
(2212,2,1,16,4,0620,25,2),
(2212,5,1,16,5,0615,111,1),
(2747,4,1,16,6,0610,75,2),
(2281,3,1,16,1,0630,26,1),
(4424,2,1,16,2,0425,24,3),
(2747,1,1,16,3,0615,72,1),
(2334,4,1,16,4,0630,100,3),
(2281,3,1,16,5,0430,40,2),
(2282,2,1,16,6,0415,38,2),
(2281,1,1,16,1,0415,35,3),
(4424,4,1,16,2,0610,114,1),
(2281,5,1,16,3,0630,74,2),
(2758,1,1,16,4,0640,78,3),
(2281,1,1,16,5,0410,47,2),
(2281,1,1,16,6,0625,73,2),
(2212,3,1,16,1,0630,55,1),
(3317,2,1,16,2,0610,79,3),
(2763,5,1,16,3,0625,113,3),
(2747,4,1,16,4,0625,17,1),
(2747,3,1,16,5,0640,16,2),
(3317,2,1,16,6,0625,42,2),
(2281,1,1,16,1,0620,35,1),
(2758,4,1,16,2,0625,90,2),
(2747,3,1,16,3,0620,52,3),
(2282,2,1,16,4,0610,117,3),
(2747,1,1,16,5,0415,86,1),
(3317,4,1,16,6,0610,65,2),
(4424,5,1,16,1,0440,55,2),
(4424,1,1,16,2,0430,120,1),
(3317,1,1,16,3,0615,81,2),
(2281,1,1,16,4,0620,59,3),
(2747,3,1,16,5,0610,61,3),
(2758,2,1,16,6,0610,60,1),
(2212,5,1,16,1,0610,113,2),
(2281,4,1,16,2,0640,23,1),
(4424,3,1,16,3,0615,111,1),
(2758,2,1,16,4,0625,102,2),
(3317,1,1,16,5,0415,59,2),
(2281,4,1,16,6,0620,82,3),
(2212,3,1,16,1,0610,117,1),
(3317,2,1,16,2,0410,33,2),
(2281,1,1,16,3,0615,65,1),
(2758,4,1,16,4,0610,41,3),
(2747,5,1,16,5,0410,63,1),
(2282,1,1,16,6,0620,65,2),
(2747,1,1,16,1,0615,16,2),
(2281,1,1,16,2,0440,113,1),
(2281,3,1,16,3,0430,59,2),
(2758,2,1,16,4,0420,57,1),
(4424,5,1,16,5,0615,105,1),
(2763,4,1,16,6,0610,24,1),
(2281,3,1,16,1,0625,29,1),
(2281,2,1,16,2,0615,121,1),
(4424,1,1,16,3,0430,76,2),
(2281,4,1,16,4,0620,115,1),
(2281,3,1,16,5,0415,44,1),
(3317,2,1,16,6,0430,87,1),
(4424,1,1,16,1,0640,46,2),
(2758,4,1,16,2,0430,23,1),
(3317,5,1,16,3,0610,118,1),
(2281,5,1,16,4,0625,41,1),
(2747,4,1,16,5,0440,116,1),
(4424,3,1,16,6,0425,116,1),
(2212,2,1,16,1,0610,114,1),
(2281,1,1,16,2,0625,113,1),
(2758,4,1,16,3,0425,35,1),
(2281,1,1,16,4,0620,29,1),
(2281,2,1,16,5,0425,49,2),
(2334,3,1,16,6,0430,59,2),
(2758,5,1,16,1,0630,68,2),
(2281,1,1,16,2,0410,65,2),
(2282,1,1,16,3,0420,84,2),
(2747,2,1,16,4,0640,20,1),
(2758,3,1,16,5,0610,118,1),
(2281,4,1,16,6,0440,60,1),
(2758,5,1,16,1,0610,100,1),
(4424,2,1,16,2,0625,73,1),
(2281,3,1,16,3,0640,107,2),
(4424,5,1,16,4,0630,90,2),
(2281,2,1,16,5,0440,21,1),
(2281,5,1,16,6,0610,27,2),
(3317,3,1,16,1,0630,73,2),
(2281,4,1,16,2,0410,88,1),
(2747,5,1,16,3,0640,62,1),
(2747,4,1,16,4,0620,22,2),
(4424,3,1,16,5,0610,64,2),
(2282,2,1,16,6,0420,81,1),
(3317,1,1,16,1,0630,74,1),
(2281,4,1,16,2,0415,72,2),
(3317,4,1,16,3,0630,78,1),
(2758,3,1,16,4,0615,53,1),
(3317,2,1,16,5,0615,87,2),
(2281,1,1,16,6,0425,88,2),
(2758,2,1,16,1,0630,38,1),
(2281,3,1,16,2,0610,30,1),
(2281,4,1,16,3,0430,72,1),
(2758,5,1,16,4,0615,39,1),
(2747,3,1,16,5,0430,104,1),
(2281,2,1,16,6,0420,77,2),
(2747,5,1,16,1,0615,21,1),
(2281,4,1,16,2,0420,63,1),
(2281,1,1,16,3,0440,79,2),
(2758,2,1,16,4,0625,95,1),
(2281,3,1,16,5,0610,35,1),
(2212,5,1,16,6,0420,110,2),
(4424,4,1,16,1,0625,61,1),
(2747,2,1,16,2,0615,41,2),
(2281,3,1,16,3,0410,94,1),
(2750,5,1,16,4,0425,117,1),
(4424,4,1,16,5,0620,72,2),
(2212,1,1,16,6,0610,90,2),
(4424,4,1,16,1,0430,20,1),
(2281,3,1,16,2,0625,110,2),
(2281,2,1,16,3,0640,50,2),
(2282,1,1,16,4,0420,105,2),
(2281,5,1,16,5,0625,61,1),
(4424,4,1,16,6,0415,22,1),
(2281,3,1,16,1,0420,39,1),
(2281,2,1,16,2,0610,33,2),
(2281,1,1,16,3,0440,29,2),
(2758,4,1,16,4,0625,125,1),
(2334,1,1,16,5,0620,43,2),
(4424,2,1,16,6,0615,125,1),
(2281,3,1,16,1,0615,80,2),
(4424,5,1,16,2,0440,93,2),
(2281,1,1,16,3,0640,74,1),
(3317,1,1,16,4,0620,23,2),
(2281,2,1,16,5,0620,81,1),
(2282,3,1,16,6,0630,117,1),
(2763,4,1,16,1,0640,61,1),
(2758,5,1,16,2,0425,75,2),
(2281,2,1,16,3,0420,102,2),
(4424,3,1,16,4,0425,118,2),
(2758,5,1,16,5,0430,119,1),
(2758,2,1,16,6,0615,33,1),
(3317,5,1,16,1,0415,36,2),
(2281,3,1,16,2,0615,104,1),
(2758,4,1,16,3,0630,23,1),
(2282,5,1,16,4,0630,89,1),
(2282,4,1,16,5,0410,51,2),
(3317,3,1,16,6,0630,116,1),
(4424,2,1,16,1,0630,120,1),
(4424,1,1,16,2,0415,37,1),
(2747,4,1,16,3,0625,22,1),
(2747,4,1,16,4,0410,41,2),
(2758,3,1,16,5,0640,94,1),
(4424,2,1,16,6,0625,68,1),
(2747,1,1,16,1,0625,88,1),
(2281,2,1,16,2,0640,57,1),
(2334,3,1,16,3,0625,89,2),
(2212,4,1,16,4,0640,60,2),
(2747,5,1,16,5,0440,100,1),
(2281,3,1,16,6,0415,116,1),
(2212,2,1,16,1,0610,88,1),
(2763,5,1,16,2,0610,65,1),
(2758,4,1,16,3,0620,28,2),
(2281,1,1,16,4,0620,43,1),
(2282,2,1,16,5,0430,54,2),
(2281,3,1,16,6,0415,94,2),
(4424,5,1,16,1,0630,72,1),
(4424,4,1,16,2,0625,79,2),
(2282,2,1,16,3,0430,93,1),
(2747,3,1,16,4,0420,116,1),
(3317,5,1,16,5,0630,16,2),
(2281,4,1,16,6,0610,73,1),
(2212,1,1,16,1,0625,58,1),
(4424,4,1,16,2,0625,125,1),
(3317,3,1,16,3,0620,79,1),
(2281,2,1,16,4,0640,81,1),
(2281,1,1,16,5,0630,40,1),
(2763,5,1,16,6,0430,80,2),
(2281,5,1,16,1,0610,71,1),
(2747,2,1,16,2,0610,61,2),
(4424,3,1,16,3,0425,43,1),
(2758,1,1,16,4,0420,93,1),
(2758,4,1,16,5,0430,60,2),
(2282,5,1,16,6,0610,49,2),
(2281,3,1,16,1,0410,45,1),
(2750,2,1,16,2,0615,100,1),
(2281,2,1,16,3,0640,57,2),
(2281,2,1,16,4,0425,21,1),
(4424,1,1,16,5,0440,99,1),
(2758,1,1,16,6,0640,28,1),
(2281,1,1,16,1,0620,116,1),
(2758,4,1,16,2,0415,64,2),
(4424,3,1,16,3,0620,52,2),
(2212,2,1,16,4,0420,17,1),
(4424,1,1,16,5,0625,49,2),
(3317,5,1,16,6,0620,109,1),
(2281,4,1,16,1,0630,56,1),
(2758,3,1,16,2,0620,94,1),
(2281,2,1,16,3,0640,91,1),
(2281,1,1,16,4,0610,93,1),
(4424,5,1,16,5,0620,115,1),
(2747,4,1,16,6,0630,82,2),
(2758,2,1,16,1,0620,67,1),
(3317,3,1,16,2,0630,123,1),
(2212,1,1,16,3,0610,107,2),
(3317,1,1,16,4,0630,90,1),
(2282,3,1,16,5,0620,113,1),
(2282,2,1,16,6,0610,67,1),
(2758,5,1,16,1,0425,79,1),
(2758,4,1,16,2,0630,33,1),
(2763,3,1,16,3,0615,39,2),
(2747,2,1,16,4,0415,53,2),
(4424,1,1,16,5,0625,51,1),
(2281,4,1,16,6,0430,95,1),
(2758,5,1,16,1,0625,22,2),
(4424,5,1,16,2,0425,74,1),
(2281,4,1,16,3,0640,43,1),
(2750,4,1,16,4,0615,26,1),
(2281,5,1,16,5,0615,74,1),
(2747,3,1,16,6,0425,104,2),
(4424,3,1,16,1,0425,88,2),
(2281,2,1,16,2,0615,88,2),
(4424,1,1,16,3,0425,53,1),
(2763,1,1,16,4,0640,22,1),
(3317,3,1,16,5,0625,97,1),
(2747,2,1,16,6,0415,119,1),
(2334,5,1,16,1,0640,74,1),
(2281,4,1,16,2,0630,97,1),
(2281,3,1,16,3,0615,118,1),
(3317,2,1,16,4,0425,109,2),
(2747,1,1,16,5,0630,43,1),
(2282,4,1,16,6,0420,95,2),
(2212,3,1,16,1,0430,99,2),
(2281,2,1,16,2,0410,118,2),
(2758,1,1,16,3,0415,85,2),
(2281,4,1,16,4,0410,67,1),
(2747,5,1,16,5,0625,81,1),
(2758,1,1,16,6,0630,78,2),
(4424,1,1,16,1,0615,70,2),
(2758,1,1,16,2,0440,102,1),
(2763,3,1,16,3,0620,27,2),
(2758,2,1,16,4,0430,65,1),
(2281,5,1,16,5,0430,34,1),
(3317,4,1,16,6,0425,104,2),
(2281,3,1,16,1,0640,25,1),
(2281,2,1,16,2,0430,82,2),
(2763,1,1,16,3,0615,41,1),
(4424,4,1,16,4,0410,83,1),
(2747,3,1,16,5,0640,49,1),
(3317,2,1,16,6,0625,72,1),
(2747,1,1,16,1,0610,25,1),
(2281,4,1,16,2,0440,66,1),
(2750,5,1,16,3,0615,107,2),
(2758,1,1,16,4,0640,28,1),
(2747,1,1,16,5,0615,93,2),
(2758,1,1,16,6,0620,114,2),
(2281,3,1,16,1,0620,108,1),
(2758,2,1,16,2,0620,115,1),
(2281,5,1,16,3,0625,44,1),
(2281,4,1,16,4,0420,32,2),
(2763,3,1,16,5,0440,99,1),
(2750,2,1,16,6,0610,43,1),
(4424,1,1,16,1,0440,22,1),
(2281,4,1,16,2,0615,27,1),
(2281,3,1,16,3,0420,115,2),
(2281,2,1,16,4,0420,43,1),
(2282,1,1,16,5,0625,101,2),
(3317,4,1,16,6,0440,63,1),
(2282,5,1,16,1,0625,17,1),
(2212,1,1,16,2,0430,98,2),
(2747,1,1,16,3,0625,116,1),
(3317,1,1,16,4,0415,81,1),
(2281,3,1,16,5,0640,105,1),
(2758,2,1,16,6,0620,99,1),
(2281,5,1,16,1,0410,83,1),
(2281,4,1,16,2,0640,89,1),
(2763,3,1,16,3,0625,19,1),
(2747,2,1,16,4,0625,111,2),
(4424,1,1,16,5,0625,84,2),
(2281,4,1,16,6,0615,107,1),
(2747,3,1,16,1,0620,63,1),
(2747,2,1,16,2,0425,121,1),
(3317,1,1,16,3,0630,30,1),
(2758,4,1,16,4,0630,66,1),
(4424,5,1,16,5,0410,80,1),
(2281,5,1,16,6,0440,73,1),
(2281,4,1,16,1,0630,89,1),
(2281,3,1,16,2,0610,19,2),
(2281,2,1,16,3,0625,54,2),
(2281,1,1,16,4,0625,63,2),
(2758,4,1,16,5,0625,35,1),
(3317,1,1,16,6,0430,67,2),
(4424,2,1,16,1,0610,67,2),
(2747,3,1,16,2,0615,35,2),
(2747,5,1,16,3,0430,119,2),
(2334,1,1,16,4,0440,59,2),
(2758,1,1,16,5,0615,83,2),
(2281,2,1,16,6,0625,87,1),
(2282,3,1,16,1,0630,68,1),
(2281,4,1,16,2,0415,60,1),
(2212,5,1,16,3,0415,115,1),
(2758,2,1,16,4,0620,123,2),
(2281,3,1,16,5,0640,36,1),
(3317,5,1,16,6,0640,73,1),
(2758,2,1,16,1,0625,58,2),
(2758,5,1,16,2,0620,116,1),
(2281,3,1,16,3,0630,123,2),
(4424,4,1,16,4,0420,65,2),
(4424,5,1,16,5,0630,20,2),
(3317,4,1,16,6,0615,118,1),
(2212,3,1,16,1,0410,31,2),
(2282,2,1,16,2,0630,50,1),
(4424,1,1,16,3,0415,82,2),
(2281,4,1,16,4,0625,49,1),
(3317,4,1,16,5,0625,95,1),
(2750,3,1,16,6,0420,59,2),
(2747,2,1,16,1,0625,95,1),
(2763,1,1,16,2,0630,42,1),
(3317,2,1,16,3,0610,103,1),
(2281,3,1,16,4,0615,59,1),
(2281,4,1,16,5,0415,48,2),
(2281,5,1,16,6,0410,112,1),
(4424,3,1,16,1,0425,31,2),
(3317,2,1,16,2,0610,60,1),
(2747,5,1,16,3,0610,23,1),
(2758,4,1,16,4,0620,109,1),
(2281,1,1,16,5,0610,93,2),
(3317,2,1,16,6,0620,80,1),
(4424,3,1,16,1,0420,87,1),
(2758,5,1,16,2,0615,101,1),
(2281,4,1,16,3,0420,41,1),
(2747,2,1,16,4,0620,91,2),
(2281,3,1,16,5,0640,34,1),
(2281,5,1,16,6,0615,117,1),
(2747,4,1,16,1,0620,68,1),
(2282,1,1,16,2,0620,115,2),
(2281,4,1,16,3,0625,61,1),
(2763,3,1,16,4,0610,45,1),
(2750,2,1,16,5,0640,37,1),
(4424,1,1,16,6,0640,45,1),
(4424,5,1,16,1,0640,102,1),
(2747,5,1,16,2,0610,61,2),
(2334,2,1,16,3,0625,101,1),
(2747,3,1,16,4,0625,53,1),
(2763,1,1,16,5,0615,107,1),
(2747,4,1,16,6,0640,40,2),
(4424,5,1,16,1,0630,89,1),
(2281,3,1,16,2,0640,75,1),
(2281,2,1,16,3,0630,45,2),
(2747,2,1,16,4,0425,45,1),
(2758,2,1,16,5,0440,19,2),
(2747,1,1,16,6,0615,86,1),
(3317,1,1,16,1,0625,65,1),
(4424,1,1,16,2,0625,34,1),
(2758,4,1,16,3,0630,86,1),
(3317,3,1,16,4,0410,21,1),
(2212,2,1,16,5,0610,63,1),
(2747,1,1,16,6,0430,19,1),
(2281,5,1,16,1,0430,17,1),
(4424,4,1,16,2,0625,89,2),
(4424,3,1,16,3,0640,82,2),
(2281,2,1,16,4,0420,122,2),
(2281,1,1,16,5,0410,38,2),
(2747,5,1,16,6,0410,120,1),
(2758,4,1,16,1,0640,17,1),
(2758,2,1,16,2,0415,122,2),
(2281,3,1,16,3,0615,81,2),
(2281,1,1,16,4,0625,87,1),
(2282,1,1,16,5,0630,91,1),
(2281,3,1,16,6,0640,110,2),
(2281,2,1,16,1,0615,60,1),
(2747,5,1,16,2,0620,75,1),
(2281,4,1,16,3,0625,61,1),
(2758,3,1,16,4,0415,22,1),
(2212,2,1,16,5,0615,37,1),
(3317,1,1,16,6,0630,106,2),
(2747,4,1,16,1,0425,33,2),
(2750,5,1,16,2,0420,124,1),
(3317,5,1,16,3,0430,105,2),
(2281,4,1,16,4,0410,57,1),
(2758,4,1,16,5,0610,109,1),
(2281,5,1,16,6,0420,105,1),
(2282,3,1,16,1,0440,21,1),
(4424,3,1,16,2,0430,16,1),
(4424,2,1,16,3,0610,117,2),
(4424,1,1,16,4,0610,28,1),
(2758,1,1,16,5,0610,57,2),
(2281,3,1,16,6,0625,69,1),
(2747,2,1,16,1,0615,41,1),
(4424,5,1,16,2,0640,90,1),
(4424,4,1,16,3,0615,55,2),
(2763,3,1,16,4,0620,121,1),
(2281,2,1,16,5,0610,74,1),
(2747,1,1,16,6,0440,31,1),
(2758,4,1,16,1,0420,28,2),
(4424,3,1,16,2,0630,66,1),
(2281,2,1,16,3,0610,124,1),
(2281,1,1,16,4,0425,97,2),
(2281,4,1,16,5,0430,46,2),
(2281,5,1,16,6,0625,115,1),
(3317,1,1,16,1,0625,114,1),
(2281,1,1,16,2,0425,49,1),
(2282,1,1,16,3,0610,78,1),
(2281,3,1,16,4,0425,56,1),
(2281,2,1,16,5,0440,64,1),
(2747,5,1,16,6,0610,33,1),
(4424,4,1,16,1,0630,77,1),
(2758,3,1,16,2,0430,78,2),
(2747,2,1,16,3,0420,32,1),
(2282,1,1,16,4,0425,64,1),
(3317,4,1,16,5,0640,36,1),
(2281,3,1,16,6,0620,115,1),
(2281,2,1,16,1,0430,42,2),
(2281,1,1,16,2,0620,82,2),
(2281,4,1,16,3,0640,18,2),
(2212,5,1,16,4,0630,51,1),
(2758,1,1,16,5,0625,51,2),
(2281,1,1,16,6,0410,43,2),
(3317,1,1,16,1,0610,117,1),
(2763,3,1,16,2,0440,103,2),
(2758,2,1,16,3,0420,98,1),
(2750,5,1,16,4,0425,113,2),
(2758,4,1,16,5,0415,29,1),
(3317,3,1,16,6,0420,84,2),
(2763,2,1,16,1,0640,55,1),
(4424,1,1,16,2,0640,26,1),
(2281,4,1,16,3,0430,121,1),
(2750,3,1,16,4,0620,114,1),
(2281,2,1,16,5,0625,82,1),
(2281,1,1,16,6,0420,106,1),
(2747,4,1,16,1,0410,20,1),
(2334,5,1,16,2,0615,16,1),
(2281,1,1,16,3,0425,62,1),
(2763,1,1,16,4,0630,25,2),
(3317,1,1,16,5,0625,16,1),
(4424,3,1,16,6,0425,32,1),
(2763,2,1,16,1,0640,68,2),
(2281,5,1,16,2,0420,39,1),
(2747,4,1,16,3,0610,68,1),
(3317,3,1,16,4,0415,30,1),
(2747,2,1,16,5,0630,29,1),
(4424,1,1,16,6,0630,115,1),
(2747,4,1,16,1,0615,70,1),
(2281,3,1,16,2,0410,122,2),
(2281,2,1,16,3,0440,37,1),
(4424,1,1,16,4,0615,23,1),
(2758,4,1,16,5,0615,63,1),
(2281,5,1,16,6,0430,107,2),
(4424,5,1,16,1,0440,21,2),
(2282,4,1,16,2,0630,110,1),
(2758,3,1,16,3,0615,49,1),
(2281,2,1,16,4,0640,80,1),
(4424,1,1,16,5,0630,98,2),
(3317,4,1,16,6,0630,22,2),
(2281,1,1,16,1,0630,58,1),
(2281,2,1,16,2,0410,96,1),
(2282,3,1,16,3,0630,85,1),
(2747,5,1,16,4,0640,95,2),
(2334,1,1,16,5,0630,15,1),
(2282,1,1,16,6,0640,23,1),
(4424,2,1,16,1,0625,23,1),
(2281,3,1,16,2,0430,37,1),
(2281,4,1,16,3,0425,59,1),
(2282,5,1,16,4,0430,96,1),
(2212,2,1,16,5,0620,94,1),
(2758,3,1,16,6,0415,17,1),
(2281,5,1,16,1,0625,116,1),
(2758,2,1,16,2,0615,31,1),
(2758,5,1,16,3,0640,40,2),
(2758,3,1,16,4,0410,26,1),
(2281,4,1,16,5,0625,119,2),
(2281,5,1,16,6,0625,98,1),
(3317,4,1,16,1,0630,18,1),
(3317,3,1,16,2,0640,117,1),
(4424,2,1,16,3,0640,114,2),
(2758,1,1,16,4,0640,123,1),
(2758,4,1,16,5,0615,18,1),
(2758,4,1,16,6,0430,108,2),
(2747,3,1,16,1,0410,15,1),
(2758,2,1,16,2,0420,76,1),
(2758,1,1,16,3,0625,108,1),
(2763,2,1,16,4,0430,67,1),
(2282,3,1,16,5,0620,72,1),
(2281,4,1,16,6,0610,71,2),
(2281,5,1,16,1,0630,122,2),
(2282,3,1,16,2,0410,32,1),
(2763,2,1,16,3,0430,18,2),
(2281,5,1,16,4,0425,116,2),
(2281,4,1,16,5,0615,68,1),
(2281,1,1,16,6,0640,92,2),
(3317,2,1,16,1,0610,39,1),
(2281,3,1,16,2,0420,55,1),
(4424,5,1,16,3,0640,53,1),
(2750,4,1,16,4,0610,112,1),
(2212,2,1,16,5,0610,115,1),
(2281,3,1,16,6,0620,55,2),
(2281,5,1,16,1,0610,78,1),
(3317,4,1,16,2,0615,23,1),
(2282,1,1,16,3,0620,20,1),
(2281,4,1,16,4,0620,75,1),
(2747,3,1,16,5,0630,76,1),
(2747,2,1,16,6,0620,112,1),
(2763,1,1,16,1,0610,42,2),
(2758,5,1,16,2,0625,68,1),
(2281,4,1,16,3,0615,99,2),
(2281,3,1,16,4,0430,104,1),
(2281,2,1,16,5,0610,81,1),
(2282,1,1,16,6,0625,25,2),
(2747,4,1,16,1,0640,93,1),
(2281,1,1,16,2,0420,76,1),
(2758,2,1,16,3,0610,63,1),
(2747,3,1,16,4,0620,82,1),
(2281,5,1,16,5,0620,54,1),
(4424,1,1,16,6,0610,87,1),
(4424,1,1,16,1,0420,74,2),
(4424,2,1,16,2,0630,83,2),
(3317,3,1,16,3,0610,28,2),
(2281,4,1,16,4,0625,123,2),
(2763,5,1,16,5,0615,32,2),
(2281,2,1,16,6,0640,27,1),
(2281,3,1,16,1,0410,108,1),
(2281,5,1,16,2,0625,97,1),
(2281,2,1,16,3,0615,67,2),
(3317,5,1,16,4,0610,59,1),
(4424,3,1,16,5,0610,51,1),
(2747,4,1,16,6,0625,105,1),
(4424,5,1,16,1,0620,93,2),
(2281,4,1,16,2,0640,26,1),
(2758,3,1,16,3,0610,89,2),
(4424,2,1,16,4,0615,60,2),
(2281,1,1,16,5,0430,108,1),
(2758,4,1,16,6,0420,18,1),
(2763,4,1,16,1,0440,67,1),
(3317,3,1,16,2,0625,119,1),
(3317,2,1,16,3,0610,97,2),
(2747,1,1,16,4,0425,62,2),
(2763,2,1,16,5,0630,87,1),
(2747,3,1,16,6,0630,89,1);
