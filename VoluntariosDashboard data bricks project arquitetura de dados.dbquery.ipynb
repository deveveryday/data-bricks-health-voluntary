-- %%
CREATE DATABASE IF NOT EXISTS dw_health_dashboard;
-- drop database dw_health_dashboard;
-- drop table dim_atividade;
-- drop table dim_data_atendimento;
-- drop table dim_hospital;
-- drop table dim_local;
-- drop table dim_voluntario;
-- drop table fato_atendimento;
USE dw_health_dashboard;

CREATE OR REPLACE TABLE dim_data_atendimento (
    id_data_atendimento INT,
    data_atendimento DATE,
    inicio STRING,
    fim STRING
)
USING DELTA;
CREATE OR REPLACE TABLE dim_hospital (
    id_hospital INT,
    nome_hospital STRING
)
USING DELTA;

CREATE OR REPLACE TABLE dim_local (
    id_local INT,
    nome_local STRING,
    cidade STRING,
    estado STRING
)
USING DELTA;
CREATE OR REPLACE TABLE dim_atividade (
    id_atividade INT,
    nome_atividade STRING
)
USING DELTA;

CREATE OR REPLACE TABLE dim_voluntario (
    id_voluntario INT,
    nome_voluntario STRING,
    idade INT,
    genero STRING
)
USING DELTA;

CREATE OR REPLACE TABLE fato_atendimento (
    id_voluntario INT,
    id_atividade INT,
    id_data_atendimento INT,
    id_hospital INT,
    id_local INT,
    total_horas INT,
    total_pessoas INT
)
USING DELTA;

-- FATO_ATENDIMENTO

INSERT INTO fato_atendimento VALUES (2747,1,1,1,1,0630,88),
(2763,1,1,2,2,0420,124),
(2281,1,1,3,3,0615,26),
(2758,1,1,4,4,0415,91),
(2758,1,1,5,5,0410,31),
(3317,1,1,6,6,0610,42),
(2282,1,1,7,1,0620,71),
(2747,1,1,8,2,0420,90),
(2747,1,1,9,3,0415,23),
(4424,1,1,10,4,0430,67),
(2281,1,1,11,5,0620,15),
(2758,1,1,12,6,0630,34),
(2281,1,1,13,1,0420,110),
(2281,1,1,14,2,0625,83),
(2747,1,1,15,3,0410,62),
(2281,1,1,16,4,0615,84),
(2763,1,1,17,5,0620,20),
(2758,1,1,18,6,0625,60),
(2763,1,1,19,1,0610,101),
(3317,1,1,20,2,0440,89),
(2747,1,1,21,3,0630,70),
(2758,1,1,22,4,0615,20),
(4424,1,1,23,5,0625,94),
(3317,1,1,24,6,0615,116),
(2334,1,1,25,1,0640,26),
(2281,1,1,26,2,0610,113),
(2281,1,1,27,3,0625,45),
(2281,1,1,28,4,0620,103),
(4424,1,1,29,5,0440,68),
(2281,1,1,30,6,0615,121),
(2212,1,1,31,1,0625,98),
(4424,1,1,32,2,0440,94),
(2747,1,1,33,3,0625,70),
(4424,1,1,34,4,0620,74),
(2281,1,1,35,5,0640,72),
(2758,1,1,36,6,0615,110),
(2281,1,1,37,1,0630,44),
(2281,1,1,38,2,0620,39),
(2747,1,1,39,3,0630,27),
(2758,1,1,40,4,0630,50),
(2747,1,1,1,5,0610,54),
(2758,1,1,1,6,0625,95),
(2747,1,1,1,1,0440,71),
(2281,1,1,1,2,0615,71),
(2747,1,1,1,3,0615,18),
(2281,1,1,1,4,0615,112),
(2334,1,1,1,5,0610,99),
(2281,1,1,1,6,0420,95),
(3317,1,1,1,1,0420,71),
(2281,1,1,1,2,0610,54),
(2281,1,1,1,3,0415,30),
(2758,1,1,1,4,0620,99),
(2758,1,1,1,5,0420,27),
(4424,1,1,1,6,0430,24),
(2281,1,1,1,1,0630,124),
(2281,1,1,1,2,0640,94),
(2281,1,1,1,3,0620,71),
(2281,1,1,1,4,0610,73),
(3317,1,1,1,5,0630,88),
(2281,1,1,1,6,0625,110),
(3317,1,1,1,1,0630,125),
(2281,1,1,1,2,0425,83),
(2281,1,1,1,3,0620,120),
(4424,1,1,1,4,0410,27),
(2747,1,1,1,5,0425,123),
(3317,1,1,1,6,0440,110),
(2750,1,1,1,1,0630,79),
(2281,1,1,1,2,0610,58),
(2763,1,1,1,3,0625,62),
(2747,1,1,1,4,0610,112),
(4424,1,1,1,5,0615,92),
(2747,1,1,1,6,0640,59),
(2747,1,1,1,1,0640,109),
(2758,1,1,1,2,0630,62),
(4424,1,1,1,3,0630,24),
(2281,1,1,1,4,0620,88),
(2281,1,1,1,5,0630,117),
(4424,1,1,1,6,0415,70),
(2281,1,1,1,1,0620,74),
(3317,1,1,1,2,0610,93),
(4424,1,1,1,3,0630,72),
(2758,1,1,1,4,0615,22),
(2281,1,1,1,5,0615,46),
(2747,1,1,1,6,0640,38),
(2747,1,1,1,1,0420,24),
(2281,1,1,1,2,0620,99),
(2758,1,1,1,3,0625,121),
(2281,1,1,1,4,0610,101),
(2747,1,1,1,5,0440,121),
(2281,1,1,1,6,0610,21),
(3317,1,1,1,1,0410,43),
(4424,1,1,1,2,0640,19),
(2281,1,1,1,3,0615,72),
(2281,1,1,1,4,0615,45),
(2281,1,1,1,5,0620,23),
(3317,1,1,1,6,0430,40),
(2758,1,1,1,1,0415,119),
(3317,1,1,1,2,0625,56),
(2281,1,1,1,3,0630,36),
(2758,1,1,1,4,0415,50),
(2212,1,1,1,5,0640,18),
(2281,1,1,1,6,0440,61),
(3317,1,1,1,1,0630,116),
(2758,1,1,1,2,0440,74),
(2747,1,1,1,3,0625,90),
(2758,1,1,1,4,0640,122),
(3317,1,1,1,5,0425,98),
(2758,1,1,1,6,0615,125),
(2281,1,1,1,1,0630,78),
(2334,1,1,1,2,0640,79),
(2281,1,1,1,3,0625,78),
(2281,1,1,1,4,0630,32),
(2758,1,1,1,5,0630,65),
(2281,1,1,1,6,0640,105),
(2212,1,1,1,1,0430,68),
(2282,1,1,1,2,0630,107),
(2758,1,1,1,3,0620,86),
(2281,1,1,1,4,0610,55),
(4424,1,1,1,5,0640,65),
(2281,1,1,1,6,0615,71),
(2750,1,1,1,1,0425,86),
(3317,1,1,1,2,0630,98),
(2212,1,1,1,3,0425,122),
(2281,1,1,1,4,0420,16),
(2281,1,1,1,5,0620,38),
(2281,1,1,1,6,0430,111),
(4424,1,1,1,1,0415,29),
(2281,1,1,1,2,0425,73),
(2758,1,1,1,3,0625,101),
(2281,1,1,1,4,0640,89),
(2281,1,1,1,5,0440,19),
(2758,1,1,1,6,0430,72),
(2281,1,1,1,1,0625,45),
(2758,1,1,1,2,0625,68),
(2281,1,1,1,3,0620,74),
(2763,1,1,1,4,0620,67),
(2281,1,1,1,5,0625,52),
(2747,1,1,1,6,0625,99),
(2282,1,1,1,1,0625,82),
(3317,1,1,1,2,0430,118),
(3317,1,1,1,3,0610,82),
(3317,1,1,1,4,0625,20),
(2281,1,1,1,5,0415,44),
(3317,1,1,1,6,0630,25),
(3317,1,1,1,1,0615,106),
(2758,1,1,1,2,0615,54),
(4424,1,1,1,3,0610,32),
(2281,1,1,1,4,0610,71),
(2758,1,1,1,5,0625,76),
(4424,1,1,1,6,0620,88),
(2747,1,1,1,1,0440,111),
(2281,1,1,1,2,0430,72),
(2747,1,1,1,3,0630,59),
(2758,1,1,1,4,0630,121),
(2281,1,1,1,5,0625,111),
(2282,1,1,1,6,0630,73),
(2747,1,1,1,1,0630,93),
(2281,1,1,1,2,0640,119),
(2747,1,1,1,3,0620,36),
(2758,1,1,1,4,0410,83),
(2281,1,1,1,5,0430,83),
(2212,1,1,1,6,0630,88),
(3317,1,1,1,1,0440,50),
(2281,1,1,1,2,0620,116),
(2747,1,1,1,3,0615,56),
(2763,1,1,1,4,0610,20),
(2747,1,1,1,5,0410,90),
(2747,1,1,1,6,0420,103),
(2281,1,1,1,1,0415,28),
(2750,1,1,1,2,0430,23),
(3317,1,1,1,3,0610,107),
(2281,1,1,1,4,0410,61),
(2758,1,1,1,5,0615,90),
(2758,1,1,1,6,0415,95),
(4424,1,1,1,1,0410,36),
(2282,1,1,1,2,0625,118),
(2282,1,1,1,3,0610,78),
(2747,1,1,1,4,0410,62),
(2747,1,1,1,5,0640,109),
(2281,1,1,1,6,0610,108),
(4424,1,1,1,1,0425,84),
(2747,1,1,1,2,0625,72),
(2763,1,1,1,3,0420,28),
(4424,1,1,1,4,0410,120),
(2282,1,1,1,5,0615,23),
(2747,1,1,1,6,0420,74),
(2763,1,1,1,1,0625,102),
(2758,1,1,1,2,0440,72),
(2212,1,1,1,3,0440,113),
(4424,1,1,1,4,0415,83),
(2281,1,1,1,5,0630,106),
(2758,1,1,1,6,0415,114),
(3317,1,1,1,1,0440,90),
(2282,1,1,1,2,0625,21),
(2212,1,1,1,3,0410,59),
(2747,1,1,1,4,0620,35),
(2212,1,1,1,5,0630,58),
(3317,1,1,1,6,0425,123),
(2747,1,1,1,1,0610,26),
(2282,1,1,1,2,0625,72),
(4424,1,1,1,3,0630,34),
(2763,1,1,1,4,0610,85),
(3317,1,1,1,5,0630,81),
(2281,1,1,1,6,0630,29),
(2334,1,1,1,1,0620,87),
(4424,1,1,1,2,0620,64),
(2747,1,1,1,3,0425,19),
(2281,1,1,1,4,0630,37),
(4424,1,1,1,5,0415,61),
(2281,1,1,1,6,0640,102),
(2758,1,1,1,1,0615,90),
(2281,1,1,1,2,0615,69),
(4424,1,1,1,3,0625,101),
(4424,1,1,1,4,0630,86),
(4424,1,1,1,5,0610,58),
(2758,1,1,1,6,0640,79),
(2747,1,1,1,1,0615,27),
(2281,1,1,1,2,0610,98),
(2281,1,1,1,3,0425,115),
(2281,1,1,1,4,0410,114),
(2281,1,1,1,5,0630,15),
(2281,1,1,1,6,0410,115),
(2758,1,1,1,1,0610,64),
(2282,1,1,1,2,0615,96),
(3317,1,1,1,3,0625,98),
(2212,1,1,1,4,0420,34),
(2747,1,1,1,5,0610,73),
(2281,1,1,1,6,0620,114),
(2747,1,1,1,1,0625,76),
(2282,1,1,1,2,0630,16),
(3317,1,1,1,3,0620,70),
(2758,1,1,1,4,0440,80),
(2758,1,1,1,5,0615,123),
(2747,1,1,1,6,0620,29),
(2758,1,1,1,1,0410,85),
(3317,1,1,1,2,0430,120),
(3317,1,1,1,3,0640,68),
(3317,1,1,1,4,0620,72),
(2758,1,1,1,5,0615,102),
(2281,1,1,1,6,0625,60),
(4424,1,1,1,1,0610,80),
(2281,1,1,1,2,0610,74),
(2281,1,1,1,3,0630,77),
(4424,1,1,1,4,0640,113),
(4424,1,1,1,5,0620,125),
(2747,1,1,1,6,0425,97),
(2758,1,1,1,1,0440,26),
(3317,1,1,1,2,0625,16),
(2281,1,1,1,3,0440,83),
(2281,1,1,1,4,0625,87),
(2282,1,1,1,5,0630,106),
(2747,1,1,1,6,0630,79),
(2758,1,1,1,1,0620,72),
(2281,1,1,1,2,0615,43),
(2282,1,1,1,3,0625,81),
(4424,1,1,1,4,0625,38),
(2758,1,1,1,5,0610,76),
(3317,1,1,1,6,0640,20),
(2281,1,1,1,1,0425,22),
(3317,1,1,1,2,0630,107),
(2281,1,1,1,3,0640,115),
(2281,1,1,1,4,0430,114),
(2281,1,1,1,5,0640,67),
(2747,1,1,1,6,0610,124),
(2763,1,1,1,1,0610,111),
(2281,1,1,1,2,0425,47),
(2281,1,1,1,3,0640,110),
(4424,1,1,1,4,0610,26),
(2281,1,1,1,5,0640,81),
(2281,1,1,1,6,0415,59),
(2282,1,1,1,1,0630,48),
(2281,1,1,1,2,0615,117),
(2281,1,1,1,3,0610,48),
(4424,1,1,1,4,0425,114),
(4424,1,1,1,5,0610,112),
(2747,1,1,1,6,0610,77),
(2212,1,1,1,1,0430,124),
(2281,1,1,1,2,0420,119),
(2281,1,1,1,3,0410,33),
(2281,1,1,1,4,0415,115),
(2281,1,1,1,5,0430,95),
(2747,1,1,1,6,0615,95),
(2758,1,1,1,1,0410,55),
(2758,1,1,1,2,0640,114),
(4424,1,1,1,3,0440,31),
(2334,1,1,1,4,0415,74),
(2281,1,1,1,5,0415,90),
(2763,1,1,1,6,0610,59),
(2281,1,1,1,1,0425,48),
(2747,1,1,1,2,0640,95),
(2758,1,1,1,3,0625,67),
(2212,1,1,1,4,0415,94),
(2747,1,1,1,5,0430,83),
(2758,1,1,1,6,0630,122),
(3317,1,1,1,1,0440,113),
(2750,1,1,1,2,0425,75),
(2281,1,1,1,3,0615,108),
(4424,1,1,1,4,0615,77),
(4424,1,1,1,5,0630,84),
(2747,1,1,1,6,0620,23),
(2281,1,1,1,1,0640,21),
(2763,1,1,1,2,0410,121),
(2758,1,1,1,3,0640,116),
(2281,1,1,1,4,0610,92),
(2281,1,1,1,5,0640,61),
(2281,1,1,1,6,0410,81),
(2747,1,1,1,1,0625,17),
(2334,1,1,1,2,0640,110),
(2281,1,1,1,3,0410,84),
(2212,1,1,1,4,0640,101),
(2758,1,1,1,5,0625,29),
(2758,1,1,1,6,0610,113),
(2758,1,1,1,1,0625,71),
(2281,1,1,1,2,0425,29),
(2758,1,1,1,3,0640,72),
(2758,1,1,1,4,0430,63),
(2281,1,1,1,5,0630,38),
(2281,1,1,1,6,0615,68),
(2212,1,1,1,1,0630,72),
(4424,1,1,1,2,0620,125),
(3317,1,1,1,3,0620,55),
(2281,1,1,1,4,0425,112),
(3317,1,1,1,5,0640,69),
(2758,1,1,1,6,0625,65),
(2758,1,1,1,1,0615,81),
(2747,1,1,1,2,0615,39),
(2281,1,1,1,3,0620,36),
(2282,1,1,1,4,0425,68),
(2747,1,1,1,5,0620,40),
(3317,1,1,1,6,0410,92),
(2758,1,1,1,1,0625,71),
(2212,1,1,1,2,0640,112),
(3317,1,1,1,3,0640,57),
(2281,1,1,1,4,0625,16),
(2281,1,1,1,5,0640,79),
(2747,1,1,1,6,0425,107),
(2747,1,1,1,1,0440,75),
(2747,1,1,1,2,0620,74),
(4424,1,1,1,3,0440,71),
(2281,1,1,1,4,0630,114),
(3317,1,1,1,5,0620,35),
(4424,1,1,1,6,0615,84),
(2281,1,1,1,1,0625,36),
(2281,1,1,1,2,0420,75),
(2763,1,1,1,3,0625,38),
(2281,1,1,1,4,0640,29),
(4424,1,1,1,5,0415,80),
(4424,1,1,1,6,0420,111),
(3317,1,1,1,1,0620,40),
(2281,1,1,1,2,0620,70),
(2282,1,1,1,3,0640,124),
(2747,1,1,1,4,0615,29),
(2212,1,1,1,5,0615,43),
(3317,1,1,1,6,0610,106),
(2281,1,1,1,1,0630,36),
(2281,1,1,1,2,0640,95),
(4424,1,1,1,3,0615,51),
(2281,1,1,1,4,0640,93),
(2281,1,1,1,5,0630,63),
(4424,1,1,1,6,0415,51),
(2747,1,1,1,1,0640,83),
(3317,1,1,1,2,0610,49),
(2212,1,1,1,3,0425,91),
(2758,1,1,1,4,0425,99),
(4424,1,1,1,5,0610,71),
(2281,1,1,1,6,0415,17),
(4424,1,1,1,1,0440,104),
(2281,1,1,1,2,0620,64),
(2334,1,1,1,3,0440,25),
(2282,1,1,1,4,0425,77),
(2758,1,1,1,5,0610,19),
(2758,1,1,1,6,0625,101),
(2281,1,1,1,1,0440,85),
(2281,1,1,1,2,0610,114),
(2763,1,1,1,3,0440,68),
(3317,1,1,1,4,0615,20),
(4424,1,1,1,5,0640,24),
(2281,1,1,1,6,0640,110),
(2282,1,1,1,1,0620,88),
(2758,1,1,1,2,0410,125),
(2747,1,1,1,3,0620,109),
(2281,1,1,1,4,0425,116),
(3317,1,1,1,5,0625,64),
(2281,1,1,1,6,0615,115),
(2758,1,1,1,1,0615,75),
(2282,1,1,1,2,0610,39),
(2281,1,1,1,3,0615,28),
(4424,1,1,1,4,0615,52),
(2281,1,1,1,5,0625,60),
(2758,1,1,1,6,0610,38),
(2282,1,1,1,1,0430,88),
(2281,1,1,1,2,0625,58),
(2747,1,1,1,3,0430,18),
(2758,1,1,1,4,0610,92),
(2334,1,1,1,5,0615,101),
(4424,1,1,1,6,0415,100),
(4424,1,1,1,1,0625,120),
(2747,1,1,1,2,0630,18),
(4424,1,1,1,3,0610,30),
(3317,1,1,1,4,0640,18),
(3317,1,1,1,5,0630,89),
(2281,1,1,1,6,0415,114),
(2281,1,1,1,1,0430,121),
(2758,1,1,1,2,0620,119),
(2750,1,1,1,3,0625,119),
(2281,1,1,1,4,0415,43),
(2747,1,1,1,5,0640,79),
(2281,1,1,1,6,0615,106),
(2281,1,1,1,1,0610,79),
(2282,1,1,1,2,0640,124),
(3317,1,1,1,3,0640,101),
(4424,1,1,1,4,0640,33),
(2763,1,1,1,5,0625,61),
(2281,1,1,1,6,0615,92),
(4424,1,1,1,1,0615,116),
(2747,1,1,1,2,0640,84),
(2281,1,1,1,3,0410,72),
(2281,1,1,1,4,0630,22),
(2282,1,1,1,5,0430,112),
(4424,1,1,1,6,0625,59),
(2758,1,1,1,1,0425,103),
(2281,1,1,1,2,0430,19),
(2758,1,1,1,3,0425,51),
(2747,1,1,1,4,0625,106),
(3317,1,1,1,5,0615,41),
(2281,1,1,1,6,0615,70),
(4424,1,1,1,1,0625,100),
(2747,1,1,1,2,0620,35),
(3317,1,1,1,3,0625,97),
(2281,1,1,1,4,0440,125),
(2281,1,1,1,5,0630,17),
(4424,1,1,1,6,0620,47),
(2281,1,1,1,1,0640,83),
(2281,1,1,1,2,0620,26),
(2758,1,1,1,3,0420,118),
(2281,1,1,1,4,0610,40),
(2747,1,1,1,5,0425,17),
(2212,1,1,1,6,0620,48),
(2747,1,1,1,1,0440,25),
(4424,1,1,1,2,0610,106),
(3317,1,1,1,3,0420,121),
(2750,1,1,1,4,0615,81),
(2747,1,1,1,5,0610,86),
(2281,1,1,1,6,0410,48),
(2281,1,1,1,1,0640,60),
(2281,1,1,1,2,0630,34),
(2212,1,1,1,3,0625,91),
(2763,1,1,1,4,0640,108),
(2281,1,1,1,5,0420,117),
(2281,1,1,1,6,0640,66),
(2281,1,1,1,1,0630,111),
(4424,1,1,1,2,0615,26),
(2747,1,1,1,3,0625,78),
(2281,1,1,1,4,0620,42),
(4424,1,1,1,5,0610,65),
(2281,1,1,1,6,0615,21),
(2281,1,1,1,1,0640,123),
(4424,1,1,1,2,0410,100),
(3317,1,1,1,3,0425,78),
(2758,1,1,1,4,0610,60),
(2758,1,1,1,5,0440,30),
(2747,1,1,1,6,0610,121),
(2281,1,1,1,1,0625,61),
(2747,1,1,1,2,0430,73),
(3317,1,1,1,3,0625,104),
(2747,1,1,1,4,0425,83),
(2763,1,1,1,5,0625,26),
(2212,1,1,1,6,0615,17),
(2281,1,1,1,1,0430,120),
(2281,1,1,1,2,0425,26),
(2758,1,1,1,3,0615,101),
(4424,1,1,1,4,0610,71),
(2212,1,1,1,5,0610,77),
(4424,1,1,1,6,0425,54),
(2281,1,1,1,1,0640,23),
(4424,1,1,1,2,0620,115),
(2281,1,1,1,3,0430,100),
(2281,1,1,1,4,0630,70),
(2747,1,1,1,5,0625,29),
(2212,1,1,1,6,0620,54),
(2758,1,1,1,1,0625,115),
(2281,1,1,1,2,0415,20),
(2212,1,1,1,3,0610,22),
(2747,1,1,1,4,0640,112),
(2282,1,1,1,5,0610,121),
(2281,1,1,1,6,0640,64),
(2763,1,1,1,1,0430,16),
(2281,1,1,1,2,0425,102),
(2747,1,1,1,3,0610,124),
(2758,1,1,1,4,0630,122),
(2758,1,1,1,5,0625,120),
(2281,1,1,1,6,0425,112),
(2282,1,1,1,1,0630,55),
(2281,1,1,1,2,0440,53),
(2281,1,1,1,3,0625,96),
(3317,1,1,1,4,0615,38),
(4424,1,1,1,5,0430,54),
(2282,1,1,1,6,0415,52),
(2281,1,1,1,1,0440,69),
(2281,1,1,1,2,0640,41),
(2747,1,1,1,3,0630,33),
(2750,1,1,1,4,0620,18),
(2758,1,1,1,5,0610,31),
(3317,1,1,1,6,0440,36),
(2758,1,1,1,1,0625,106),
(4424,1,1,1,2,0640,97),
(2281,1,1,1,3,0625,115),
(2281,1,1,1,4,0425,57),
(2281,1,1,1,5,0615,39),
(2758,1,1,1,6,0415,115),
(2282,1,1,1,1,0640,56),
(2281,1,1,1,2,0420,63),
(2758,1,1,1,3,0610,57),
(2281,1,1,1,4,0440,19),
(2282,1,1,1,5,0420,41),
(2747,1,1,1,6,0415,82),
(4424,1,1,1,1,0630,51),
(2747,1,1,1,2,0610,46),
(2212,1,1,1,3,0630,104),
(2758,1,1,1,4,0615,65),
(2334,1,1,1,5,0410,100),
(3317,1,1,1,6,0620,122),
(2281,1,1,1,1,0630,91),
(2281,1,1,1,2,0420,40),
(2747,1,1,1,3,0415,102),
(2281,1,1,1,4,0620,80),
(3317,1,1,1,5,0620,42),
(2763,1,1,1,6,0415,47),
(2747,1,1,1,1,0625,57),
(2747,1,1,1,2,0625,92),
(2281,1,1,1,3,0620,38),
(2758,1,1,1,4,0425,21),
(2212,1,1,1,5,0440,79),
(2747,1,1,1,6,0625,37),
(2281,1,1,1,1,0620,49),
(2763,1,1,1,2,0625,64),
(2281,1,1,1,3,0620,87),
(3317,1,1,1,4,0630,79),
(2281,1,1,1,5,0620,28),
(2281,1,1,1,6,0425,104),
(2282,1,1,1,1,0420,89),
(2750,1,1,1,2,0625,49),
(4424,1,1,1,3,0615,99),
(2281,1,1,1,4,0420,101),
(2747,1,1,1,5,0440,35),
(2281,1,1,1,6,0415,100),
(2281,1,1,1,1,0610,116),
(2334,1,1,1,2,0620,117),
(2281,1,1,1,3,0430,55),
(2281,1,1,1,4,0420,91),
(2281,1,1,1,5,0420,73),
(2282,1,1,1,6,0610,41),
(2281,1,1,1,1,0630,101),
(2212,1,1,1,2,0640,53),
(2281,1,1,1,3,0620,119),
(3317,1,1,1,4,0420,111),
(3317,1,1,1,5,0430,15),
(4424,1,1,1,6,0410,26),
(4424,1,1,1,1,0640,48),
(3317,1,1,1,2,0640,103),
(2763,1,1,1,3,0415,106),
(2334,1,1,1,4,0610,63),
(2281,1,1,1,5,0440,118),
(4424,1,1,1,6,0610,102),
(2281,1,1,1,1,0610,21),
(2282,1,1,1,2,0630,66),
(4424,1,1,1,3,0640,46),
(2281,1,1,1,4,0625,37),
(2281,1,1,1,5,0440,60),
(2758,1,1,1,6,0640,27),
(2281,1,1,1,1,0425,30),
(2281,1,1,1,2,0610,62),
(2747,1,1,1,3,0630,68),
(2281,1,1,1,4,0610,79),
(2758,1,1,1,5,0420,59),
(2758,1,1,1,6,0430,91),
(2334,1,1,1,1,0425,80),
(2281,1,1,1,2,0620,106),
(2758,1,1,1,3,0415,99),
(2212,1,1,1,4,0615,70),
(3317,1,1,1,5,0610,100),
(3317,1,1,1,6,0640,36),
(2212,1,1,1,1,0615,109),
(4424,1,1,1,2,0410,86),
(2747,1,1,1,3,0630,22),
(2281,1,1,1,4,0425,47),
(2281,1,1,1,5,0620,95),
(2758,1,1,1,6,0640,89),
(2281,1,1,1,1,0440,33),
(2282,1,1,1,2,0415,31),
(4424,1,1,1,3,0640,116),
(2758,1,1,1,4,0625,102),
(2281,1,1,1,5,0410,24),
(2747,1,1,1,6,0610,29),
(4424,1,1,1,1,0440,60),
(2282,1,1,1,2,0610,32),
(2281,1,1,1,3,0610,83),
(3317,1,1,1,4,0425,63),
(2763,1,1,1,5,0615,76),
(2282,1,1,1,6,0415,24),
(2281,1,1,1,1,0615,21),
(2281,1,1,1,2,0425,61),
(2747,1,1,1,3,0415,23),
(4424,1,1,1,4,0640,45),
(2282,1,1,1,5,0640,21),
(3317,1,1,1,6,0610,20),
(2747,1,1,1,1,0640,27),
(2281,1,1,1,2,0625,94),
(2281,1,1,1,3,0630,124),
(2282,1,1,1,4,0410,64),
(4424,1,1,1,5,0630,112),
(2758,1,1,1,6,0625,66),
(2763,1,1,1,1,0620,29),
(2281,1,1,1,2,0625,96),
(2747,1,1,1,3,0415,104),
(2758,1,1,1,4,0640,39),
(2281,1,1,1,5,0615,118),
(4424,1,1,1,6,0620,110),
(2212,1,1,1,1,0640,16),
(2750,1,1,1,2,0620,57),
(4424,1,1,1,3,0640,45),
(4424,1,1,1,4,0625,113),
(4424,1,1,1,5,0630,96),
(3317,1,1,1,6,0440,28),
(2747,1,1,1,1,0415,65),
(2282,1,1,1,2,0420,50),
(2212,1,1,1,3,0625,74),
(2747,1,1,1,4,0430,65),
(2281,1,1,1,5,0410,70),
(3317,1,1,1,6,0610,69),
(3317,1,1,1,1,0415,92),
(2758,1,1,1,2,0425,88),
(2763,1,1,1,3,0630,21),
(3317,1,1,1,4,0640,36),
(2282,1,1,1,5,0630,122),
(2747,1,1,1,6,0410,28),
(2281,1,1,1,1,0410,119),
(2750,1,1,1,2,0620,21),
(2281,1,1,1,3,0640,60),
(2281,1,1,1,4,0615,24),
(4424,1,1,1,5,0410,88),
(2281,1,1,1,6,0440,73),
(2758,1,1,1,1,0425,91),
(2758,1,1,1,2,0630,97),
(2747,1,1,1,3,0430,45),
(2758,1,1,1,4,0640,65),
(2747,1,1,1,5,0420,82),
(2281,1,1,1,6,0440,77),
(2334,1,1,1,1,0415,121),
(2758,1,1,1,2,0640,29),
(2750,1,1,1,3,0625,94),
(3317,1,1,1,4,0630,16),
(2281,1,1,1,5,0620,68),
(2281,1,1,1,6,0620,84),
(2758,1,1,1,1,0610,87),
(2747,1,1,1,2,0425,104),
(2281,1,1,1,3,0615,43),
(4424,1,1,1,4,0610,94),
(2282,1,1,1,5,0440,46),
(2763,1,1,1,6,0610,104),
(2281,1,1,1,1,0610,87),
(2281,1,1,1,2,0625,88),
(2281,1,1,1,3,0420,89),
(2281,1,1,1,4,0420,96),
(2281,1,1,1,5,0440,43),
(2212,1,1,1,6,0640,89),
(4424,1,1,1,1,0440,114),
(4424,1,1,1,2,0620,39),
(2281,1,1,1,3,0425,57),
(2758,1,1,1,4,0625,45),
(4424,1,1,1,5,0640,85),
(2334,1,1,1,6,0625,98),
(2763,1,1,1,1,0610,22),
(3317,1,1,1,2,0425,52),
(2281,1,1,1,3,0620,24),
(2282,1,1,1,4,0625,71),
(4424,1,1,1,5,0620,50),
(2281,1,1,1,6,0425,20),
(2281,1,1,1,1,0415,99),
(2758,1,1,1,2,0415,118),
(4424,1,1,1,3,0620,30),
(2281,1,1,1,4,0615,17),
(2747,1,1,1,5,0415,67),
(2212,1,1,1,6,0620,79),
(2281,1,1,1,1,0415,121),
(2758,1,1,1,2,0620,24),
(2758,1,1,1,3,0610,92),
(2281,1,1,1,4,0610,92),
(4424,1,1,1,5,0620,68),
(2281,1,1,1,6,0625,73),
(3317,1,1,1,1,0610,110),
(2747,1,1,1,2,0630,80),
(2758,1,1,1,3,0615,20),
(2281,1,1,1,4,0620,59),
(2282,1,1,1,5,0610,36),
(4424,1,1,1,6,0420,41),
(2747,1,1,1,1,0430,15),
(2281,1,1,1,2,0425,48),
(3317,1,1,1,3,0415,40),
(2281,1,1,1,4,0610,114),
(2747,1,1,1,5,0630,52),
(2281,1,1,1,6,0610,67),
(2758,1,1,1,1,0610,57),
(2758,1,1,1,2,0415,79),
(2281,1,1,1,3,0420,95),
(2758,1,1,1,4,0630,31),
(2747,1,1,1,5,0440,17),
(2758,1,1,1,6,0630,72),
(2747,1,1,1,1,0615,76),
(4424,1,1,1,2,0615,86),
(2747,1,1,1,3,0620,28),
(3317,1,1,1,4,0620,36),
(4424,1,1,1,5,0415,95),
(4424,1,1,1,6,0430,55),
(2750,1,1,1,1,0640,40),
(2281,1,1,1,2,0620,23),
(4424,1,1,1,3,0620,51),
(2763,1,1,1,4,0610,86),
(2281,1,1,1,5,0640,82),
(2281,1,1,1,6,0440,122),
(2281,1,1,1,1,0615,86),
(2758,1,1,1,2,0425,105),
(3317,1,1,1,3,0420,71),
(3317,1,1,1,4,0625,57),
(2334,1,1,1,5,0640,100),
(2281,1,1,1,6,0425,25),
(2750,1,1,1,1,0640,21),
(2758,1,1,1,2,0425,67),
(4424,1,1,1,3,0640,48),
(2281,1,1,1,4,0625,113),
(2747,1,1,1,5,0615,16),
(2212,1,1,1,6,0620,60),
(2281,1,1,1,1,0620,118),
(2281,1,1,1,2,0610,107),
(2281,1,1,1,3,0615,44),
(4424,1,1,1,4,0425,26),
(2763,1,1,1,5,0415,75),
(2281,1,1,1,6,0620,93),
(2281,1,1,1,1,0420,39),
(3317,1,1,1,2,0620,69),
(2281,1,1,1,3,0610,48),
(4424,1,1,1,4,0620,118),
(4424,1,1,1,5,0620,29),
(2747,1,1,1,6,0620,40),
(2747,1,1,1,1,0620,77),
(4424,1,1,1,2,0620,58),
(2281,1,1,1,3,0440,107),
(4424,1,1,1,4,0410,53),
(2763,1,1,1,5,0630,74),
(2747,1,1,1,6,0615,99),
(2758,1,1,1,1,0625,110),
(2281,1,1,1,2,0625,79),
(3317,1,1,1,3,0430,51),
(4424,1,1,1,4,0615,112),
(2281,1,1,1,5,0615,68),
(2758,1,1,1,6,0625,74),
(2758,1,1,1,1,0630,74),
(2334,1,1,1,2,0620,125),
(2750,1,1,1,3,0640,105),
(2281,1,1,1,4,0615,57),
(2281,1,1,1,5,0620,76),
(2281,1,1,1,6,0640,63),
(2281,1,1,1,1,0625,16),
(2747,1,1,1,2,0630,92),
(2763,1,1,1,3,0440,20),
(2212,1,1,1,4,0420,31),
(2281,1,1,1,5,0415,74),
(2747,1,1,1,6,0625,35),
(2281,1,1,1,1,0620,96),
(2281,1,1,1,2,0620,60),
(2281,1,1,1,3,0440,99),
(2758,1,1,1,4,0430,86),
(2758,1,1,1,5,0625,86),
(2747,1,1,1,6,0625,124),
(3317,1,1,1,1,0625,74),
(3317,1,1,1,2,0415,74),
(2281,1,1,1,3,0620,73),
(2281,1,1,1,4,0410,94),
(2750,1,1,1,5,0415,124),
(2758,1,1,1,6,0630,113),
(2758,1,1,1,1,0625,41),
(2747,1,1,1,2,0425,35),
(4424,1,1,1,3,0625,68),
(2747,1,1,1,4,0625,73),
(4424,1,1,1,5,0415,62),
(4424,1,1,1,6,0625,61),
(2281,1,1,1,1,0415,124),
(2747,1,1,1,2,0620,75),
(2281,1,1,1,3,0615,76),
(2281,1,1,1,4,0640,84),
(2281,1,1,1,5,0620,38),
(4424,1,1,1,6,0625,112),
(2281,1,1,1,1,0640,122),
(2281,1,1,1,2,0410,64),
(2758,1,1,1,3,0615,15),
(2750,1,1,1,4,0430,22),
(2281,1,1,1,5,0620,63),
(2758,1,1,1,6,0615,112),
(4424,1,1,1,1,0430,45),
(2281,1,1,1,2,0630,119),
(2763,1,1,1,3,0640,88),
(2281,1,1,1,4,0620,42),
(2758,1,1,1,5,0615,67),
(2282,1,1,1,6,0625,60),
(2281,1,1,1,1,0640,59),
(2747,1,1,1,2,0625,17),
(2334,1,1,1,3,0640,111),
(4424,1,1,1,4,0625,26),
(4424,1,1,1,5,0430,122),
(3317,1,1,1,6,0640,95),
(4424,1,1,1,1,0610,70),
(3317,1,1,1,2,0630,56),
(3317,1,1,1,3,0410,83),
(2281,1,1,1,4,0440,87),
(2747,1,1,1,5,0640,65),
(4424,1,1,1,6,0410,26),
(2281,1,1,1,1,0420,58),
(3317,1,1,1,2,0620,86),
(2747,1,1,1,3,0425,56),
(3317,1,1,1,4,0615,39),
(2281,1,1,1,5,0430,116),
(2758,1,1,1,6,0410,123),
(2334,1,1,1,1,0620,111),
(2282,1,1,1,2,0615,52),
(4424,1,1,1,3,0625,56),
(2747,1,1,1,4,0625,78),
(2282,1,1,1,5,0420,52),
(2281,1,1,1,6,0425,122),
(2750,1,1,1,1,0420,69),
(2212,1,1,1,2,0415,67),
(3317,1,1,1,3,0415,26),
(2281,1,1,1,4,0425,28),
(2747,1,1,1,5,0625,45),
(3317,1,1,1,6,0640,99),
(2758,1,1,1,1,0420,34),
(4424,1,1,1,2,0440,94),
(2281,1,1,1,3,0615,15),
(2281,1,1,1,4,0640,112),
(4424,1,1,1,5,0440,51),
(2281,1,1,1,6,0640,66),
(4424,1,1,1,1,0430,73),
(4424,1,1,1,2,0630,32),
(2281,1,1,1,3,0420,108),
(2758,1,1,1,4,0625,97),
(4424,1,1,1,5,0430,49),
(3317,1,1,1,6,0640,67),
(2763,1,1,1,1,0615,101),
(2281,1,1,1,2,0430,89),
(2747,1,1,1,3,0440,58),
(4424,1,1,1,4,0420,19),
(2747,1,1,1,5,0625,67),
(2758,1,1,1,6,0625,51),
(2282,1,1,1,1,0630,17),
(4424,1,1,1,2,0625,105),
(2747,1,1,1,3,0620,71),
(2282,1,1,1,4,0625,101),
(3317,1,1,1,5,0625,87),
(4424,1,1,1,6,0425,27),
(3317,1,1,1,1,0430,78),
(4424,1,1,1,2,0620,92),
(2281,1,1,1,3,0420,60),
(2212,1,1,1,4,0640,86),
(2763,1,1,1,5,0640,115),
(2281,1,1,1,6,0630,55),
(2282,1,1,1,1,0620,52),
(2281,1,1,1,2,0610,116),
(2281,1,1,1,3,0620,56),
(2747,1,1,1,4,0620,78),
(2281,1,1,1,5,0415,26),
(2281,1,1,1,6,0430,66),
(2747,1,1,1,1,0640,85),
(2758,1,1,1,2,0640,65),
(2758,1,1,1,3,0615,86),
(2281,1,1,1,4,0410,57),
(2763,1,1,1,5,0620,77),
(2281,1,1,1,6,0615,93),
(2281,1,1,1,1,0615,53),
(2281,1,1,1,2,0425,69),
(2281,1,1,1,3,0610,78),
(2750,1,1,1,4,0630,99),
(2747,1,1,1,5,0615,113),
(4424,1,1,1,6,0620,26),
(2747,1,1,1,1,0610,72),
(2747,1,1,1,2,0440,91),
(2212,1,1,1,3,0640,96),
(2747,1,1,1,4,0615,33),
(3317,1,1,1,5,0425,84),
(2282,1,1,1,6,0615,55),
(3317,1,1,1,1,0620,69),
(2281,1,1,1,2,0640,19),
(2747,1,1,1,3,0615,76),
(4424,1,1,1,4,0610,113),
(2281,1,1,1,5,0425,72),
(3317,1,1,1,6,0615,29),
(2281,1,1,1,1,0440,43),
(2282,1,1,1,2,0625,39),
(4424,1,1,1,3,0420,47),
(2758,1,1,1,4,0630,45),
(4424,1,1,1,5,0640,50),
(2747,1,1,1,6,0630,117),
(3317,1,1,1,1,0625,117),
(2281,1,1,1,2,0420,91),
(2758,1,1,1,3,0625,30),
(4424,1,1,1,4,0420,85),
(2282,1,1,1,5,0625,45),
(2281,1,1,1,6,0430,15),
(2747,1,1,1,1,0615,72),
(3317,1,1,1,2,0425,34),
(4424,1,1,1,3,0425,102),
(2747,1,1,1,4,0625,88),
(2334,1,1,1,5,0410,69),
(2758,1,1,1,6,0630,76),
(2281,1,1,1,1,0625,123),
(2747,1,1,1,2,0625,34),
(2282,1,1,1,3,0440,80),
(2282,1,1,1,4,0620,123),
(4424,1,1,1,5,0625,73),
(2334,1,1,1,6,0625,23),
(2212,1,1,1,1,0610,33),
(2281,1,1,1,2,0620,62),
(2763,1,1,1,3,0630,96),
(3317,1,1,1,4,0425,71),
(3317,1,1,1,5,0610,34),
(2281,1,1,1,6,0615,33),
(4424,1,1,1,1,0630,53),
(3317,1,1,1,2,0625,118),
(2281,1,1,1,3,0440,49),
(2758,1,1,1,4,0640,90),
(2758,1,1,1,5,0640,65),
(2747,1,1,1,6,0640,93),
(2281,1,1,1,1,0620,27),
(4424,1,1,1,2,0425,116),
(4424,1,1,1,3,0640,32),
(4424,1,1,1,4,0410,78),
(2281,1,1,1,5,0415,107),
(2758,1,1,1,6,0630,70),
(2281,1,1,1,1,0630,61),
(4424,1,1,1,2,0625,82),
(2281,1,1,1,3,0630,73),
(2758,1,1,1,4,0640,51),
(2281,1,1,1,5,0625,121),
(2281,1,1,1,6,0625,48),
(3317,1,1,1,1,0620,27),
(3317,1,1,1,2,0420,68),
(4424,1,1,1,3,0420,76),
(2747,1,1,1,4,0630,118),
(2281,1,1,1,5,0420,114),
(4424,1,1,1,6,0630,86),
(2747,1,1,1,1,0640,72),
(3317,1,1,1,2,0625,123),
(4424,1,1,1,3,0430,67),
(4424,1,1,1,4,0440,32),
(2281,1,1,1,5,0430,118),
(2281,1,1,1,6,0430,120),
(2282,1,1,1,1,0440,89),
(2282,1,1,1,2,0615,47),
(2747,1,1,1,3,0425,103),
(2281,1,1,1,4,0630,31),
(2281,1,1,1,5,0610,41),
(2281,1,1,1,6,0615,77),
(2281,1,1,1,1,0420,35),
(2281,1,1,1,2,0615,45),
(3317,1,1,1,3,0615,95),
(4424,1,1,1,4,0415,74),
(2758,1,1,1,5,0410,106),
(4424,1,1,1,6,0620,18),
(2758,1,1,1,1,0630,44),
(2281,1,1,1,2,0415,52),
(2747,1,1,1,3,0620,50),
(2747,1,1,1,4,0615,66),
(2281,1,1,1,5,0420,81),
(2281,1,1,1,6,0430,109),
(2281,1,1,1,1,0615,19),
(2281,1,1,1,2,0630,25),
(2212,1,1,1,3,0415,71),
(3317,1,1,1,4,0425,46),
(2282,1,1,1,5,0410,82),
(3317,1,1,1,6,0625,80),
(2281,1,1,1,1,0620,108),
(4424,1,1,1,2,0640,81),
(2281,1,1,1,3,0615,46),
(4424,1,1,1,4,0640,125),
(2281,1,1,1,5,0425,86),
(2281,1,1,1,6,0425,25),
(2281,1,1,1,1,0630,79),
(2758,1,1,1,2,0430,118),
(4424,1,1,1,3,0640,119),
(3317,1,1,1,4,0420,58),
(2212,1,1,1,5,0630,47),
(2763,1,1,1,6,0625,88),
(2281,1,1,1,1,0615,117),
(4424,1,1,1,2,0440,89),
(2747,1,1,1,3,0610,121),
(2747,1,1,1,4,0430,83),
(2763,1,1,1,5,0615,57),
(2282,1,1,1,6,0640,98),
(4424,1,1,1,1,0610,120),
(2747,1,1,1,2,0410,113),
(2747,1,1,1,3,0615,122),
(2758,1,1,1,4,0615,123),
(2750,1,1,1,5,0420,111),
(2281,1,1,1,6,0615,65),
(2281,1,1,1,1,0410,91),
(2281,1,1,1,2,0420,63),
(2281,1,1,1,3,0610,54),
(2281,1,1,1,4,0610,21),
(3317,1,1,1,5,0640,50),
(2212,1,1,1,6,0630,109),
(2282,1,1,1,1,0610,76),
(4424,1,1,1,2,0625,45),
(2747,1,1,1,3,0625,19),
(2747,1,1,1,4,0640,107),
(4424,1,1,1,5,0625,53),
(2758,1,1,1,6,0640,118),
(2758,1,1,1,1,0615,66),
(2747,1,1,1,2,0615,111),
(2282,1,1,1,3,0610,101),
(2212,1,1,1,4,0640,49),
(2747,1,1,1,5,0610,60),
(2281,1,1,1,6,0630,58),
(2281,1,1,1,1,0420,86),
(2334,1,1,1,2,0420,64),
(3317,1,1,1,3,0625,120),
(2763,1,1,1,4,0610,120),
(2758,1,1,1,5,0420,119),
(2282,1,1,1,6,0410,20),
(4424,1,1,1,1,0615,108),
(2281,1,1,1,2,0630,37),
(2281,1,1,1,3,0630,57),
(2281,1,1,1,4,0440,90),
(4424,1,1,1,5,0430,118),
(2763,1,1,1,6,0620,92),
(3317,1,1,1,1,0640,63),
(2281,1,1,1,2,0625,30),
(2282,1,1,1,3,0630,35),
(2281,1,1,1,4,0420,88),
(2281,1,1,1,5,0425,15),
(2747,1,1,1,6,0640,100),
(2758,1,1,1,1,0425,117),
(2281,1,1,1,2,0610,97),
(2747,1,1,1,3,0440,65),
(2281,1,1,1,4,0620,125),
(2750,1,1,1,5,0630,29),
(2281,1,1,1,6,0415,94),
(2334,1,1,1,1,0620,95),
(2281,1,1,1,2,0440,34),
(3317,1,1,1,3,0415,59),
(2758,1,1,1,4,0620,106),
(2282,1,1,1,5,0440,120),
(2747,1,1,1,6,0630,55),
(3317,1,1,1,1,0640,104),
(2758,1,1,1,2,0430,84),
(2281,1,1,1,3,0610,33),
(2758,1,1,1,4,0615,92),
(2281,1,1,1,5,0615,120),
(2747,1,1,1,6,0640,115),
(2763,1,1,1,1,0625,97),
(2281,1,1,1,2,0415,123),
(2281,1,1,1,3,0615,28),
(2281,1,1,1,4,0440,95),
(2281,1,1,1,5,0415,33),
(2747,1,1,1,6,0415,99),
(2282,1,1,1,1,0620,35),
(2763,1,1,1,2,0430,74),
(2758,1,1,1,3,0610,121),
(4424,1,1,1,4,0615,18),
(4424,1,1,1,5,0425,28),
(2281,1,1,1,6,0620,50),
(3317,1,1,1,1,0430,49),
(2282,1,1,1,2,0430,78),
(2750,1,1,1,3,0625,39),
(4424,1,1,1,4,0630,111),
(4424,1,1,1,5,0615,84),
(2281,1,1,1,6,0640,27),
(2281,1,1,1,1,0430,44),
(2282,1,1,1,2,0430,105),
(3317,1,1,1,3,0625,43),
(3317,1,1,1,4,0615,63),
(2281,1,1,1,5,0620,22),
(2281,1,1,1,6,0430,76),
(4424,1,1,1,1,0430,71),
(2763,1,1,1,2,0610,54),
(2758,1,1,1,3,0610,29),
(4424,1,1,1,4,0625,102),
(2281,1,1,1,5,0640,46),
(2747,1,1,1,6,0640,80),
(2758,1,1,1,1,0615,122),
(2212,1,1,1,2,0610,48),
(2281,1,1,1,3,0640,54),
(2747,1,1,1,4,0640,47),
(3317,1,1,1,5,0425,105),
(2758,1,1,1,6,0430,90),
(2282,1,1,1,1,0440,29),
(2281,1,1,1,2,0625,90),
(2747,1,1,1,3,0640,39),
(4424,1,1,1,4,0640,19),
(2281,1,1,1,5,0620,15),
(4424,1,1,1,6,0620,71),
(2281,1,1,1,1,0620,84),
(2747,1,1,1,2,0615,115),
(2212,1,1,1,3,0415,38),
(2281,1,1,1,4,0630,103),
(2750,1,1,1,5,0610,70),
(2758,1,1,1,6,0410,80),
(2281,1,1,1,1,0440,49),
(2334,1,1,1,2,0615,22),
(4424,1,1,1,3,0430,45),
(2281,1,1,1,4,0440,90),
(2212,1,1,1,5,0410,79),
(2763,1,1,1,6,0620,44),
(4424,1,1,1,1,0420,115),
(2758,1,1,1,2,0640,34),
(2758,1,1,1,3,0625,19),
(2747,1,1,1,4,0640,53),
(3317,1,1,1,5,0610,117),
(2281,1,1,1,6,0610,20),
(2747,1,1,1,1,0615,27),
(3317,1,1,1,2,0610,33),
(4424,1,1,1,3,0615,21),
(2747,1,1,1,4,0610,55),
(2281,1,1,1,5,0440,16),
(2212,1,1,1,6,0640,103),
(2758,1,1,1,1,0615,76),
(2747,1,1,1,2,0610,87),
(2282,1,1,1,3,0620,60),
(2281,1,1,1,4,0610,29),
(2758,1,1,1,5,0640,51),
(3317,1,1,1,6,0625,56),
(2747,1,1,1,1,0640,97),
(2281,1,1,1,2,0430,81),
(2281,1,1,1,3,0630,28),
(2281,1,1,1,4,0640,15),
(2281,1,1,1,5,0615,32),
(2281,1,1,1,6,0430,98),
(2281,1,1,1,1,0630,23),
(2747,1,1,1,2,0610,31),
(2750,1,1,1,3,0610,31),
(2212,1,1,1,4,0630,102),
(2281,1,1,1,5,0640,89),
(2747,1,1,1,6,0620,88),
(2281,1,1,1,1,0640,114),
(2281,1,1,1,2,0630,102),
(2281,1,1,1,3,0610,48),
(2281,1,1,1,4,0420,73),
(4424,1,1,1,5,0625,48),
(2281,1,1,1,6,0630,122),
(2747,1,1,1,1,0630,56),
(2281,1,1,1,2,0630,33),
(2758,1,1,1,3,0640,55),
(4424,1,1,1,4,0615,79),
(4424,1,1,1,5,0610,21),
(2758,1,1,1,6,0620,103),
(3317,1,1,1,1,0625,69),
(2747,1,1,1,2,0415,113),
(3317,1,1,1,3,0615,78),
(2281,1,1,1,4,0425,59),
(2281,1,1,1,5,0420,88),
(2281,1,1,1,6,0615,20),
(2212,1,1,1,1,0615,121),
(2282,1,1,1,2,0420,27),
(2281,1,1,1,3,0610,106),
(2281,1,1,1,4,0625,42),
(4424,1,1,1,5,0630,125),
(2747,1,1,1,6,0630,44),
(3317,1,1,1,1,0625,108),
(2281,1,1,1,2,0625,24),
(4424,1,1,1,3,0610,74),
(2212,1,1,1,4,0610,24),
(3317,1,1,1,5,0630,31),
(2747,1,1,1,6,0620,104),
(2758,1,1,1,1,0425,54),
(2281,1,1,1,2,0615,90),
(2747,1,1,1,3,0640,69),
(2758,1,1,1,4,0415,104),
(2281,1,1,1,5,0425,87),
(2281,1,1,1,6,0625,57),
(2747,1,1,1,1,0630,115),
(4424,1,1,1,2,0625,111),
(2758,1,1,1,3,0610,56),
(3317,1,1,1,4,0415,62),
(2281,1,1,1,5,0420,50),
(4424,1,1,1,6,0625,105),
(2281,1,1,1,1,0440,64),
(4424,1,1,1,2,0415,21),
(2750,1,1,1,3,0420,19),
(2763,1,1,1,4,0630,41),
(2281,1,1,1,5,0410,122),
(2281,1,1,1,6,0415,35),
(4424,1,1,1,1,0410,71),
(2747,1,1,1,2,0625,119),
(3317,1,1,1,3,0420,111),
(2281,1,1,1,4,0430,22),
(4424,1,1,1,5,0620,34),
(2212,1,1,1,6,0610,34),
(2758,1,1,1,1,0640,65),
(2758,1,1,1,2,0615,28),
(2281,1,1,1,3,0630,46),
(2281,1,1,1,4,0440,33),
(2281,1,1,1,5,0610,90),
(2747,1,1,1,6,0630,78),
(4424,1,1,1,1,0420,17),
(2281,1,1,1,2,0625,18),
(2281,1,1,1,3,0410,43),
(2282,1,1,1,4,0420,105),
(2281,1,1,1,5,0425,115),
(2747,1,1,1,6,0620,96),
(2212,1,1,1,1,0640,91),
(2750,1,1,1,2,0430,93),
(4424,1,1,1,3,0420,54),
(2281,1,1,1,4,0620,105),
(4424,1,1,1,5,0610,84),
(2763,1,1,1,6,0420,79),
(2281,1,1,1,1,0415,79),
(2281,1,1,1,2,0640,65),
(2282,1,1,1,3,0620,29),
(2281,1,1,1,4,0640,84),
(2763,1,1,1,5,0615,86),
(2212,1,1,1,6,0615,86),
(2281,1,1,1,1,0620,117),
(4424,1,1,1,2,0440,122),
(2282,1,1,1,3,0410,100),
(2281,1,1,1,4,0615,94),
(2281,1,1,1,5,0620,85),
(2747,1,1,1,6,0440,21),
(2334,1,1,1,1,0625,53),
(3317,1,1,1,2,0610,69),
(4424,1,1,1,3,0430,33),
(2281,1,1,1,4,0610,121),
(2281,1,1,1,5,0620,36),
(2758,1,1,1,6,0440,106),
(2212,1,1,1,1,0440,62),
(2747,1,1,1,2,0625,40),
(2747,1,1,1,3,0425,43),
(2282,1,1,1,4,0610,63),
(4424,1,1,1,5,0630,90),
(2212,1,1,1,6,0610,57),
(2758,1,1,1,1,0640,37),
(4424,1,1,1,2,0615,119),
(2747,1,1,1,3,0615,74),
(2750,1,1,1,4,0620,69),
(2281,1,1,1,5,0630,111),
(2334,1,1,1,6,0610,17),
(2212,1,1,1,1,0610,124),
(2281,1,1,1,2,0620,41),
(2281,1,1,1,3,0610,111),
(4424,1,1,1,4,0610,26),
(2763,1,1,1,5,0610,60),
(2763,1,1,1,6,0440,101),
(2747,1,1,1,1,0640,30),
(2747,1,1,1,2,0430,48),
(2758,1,1,1,3,0630,111),
(2281,1,1,1,4,0620,123),
(3317,1,1,1,5,0630,118),
(4424,1,1,1,6,0430,40),
(2281,1,1,1,1,0620,71),
(2282,1,1,1,2,0410,125),
(4424,1,1,1,3,0630,32),
(4424,1,1,1,4,0420,103),
(2281,1,1,1,5,0440,27),
(2281,1,1,1,6,0615,103),
(3317,1,1,1,1,0410,117),
(2281,1,1,1,2,0415,84),
(3317,1,1,1,3,0620,29),
(2281,1,1,1,4,0625,54),
(3317,1,1,1,5,0640,101),
(2281,1,1,1,6,0640,29),
(2758,1,1,1,1,0430,83),
(2747,1,1,1,2,0420,111),
(2281,1,1,1,3,0615,31),
(4424,1,1,1,4,0630,79),
(4424,1,1,1,5,0615,50),
(2281,1,1,1,6,0610,36),
(2281,1,1,1,1,0630,60),
(4424,1,1,1,2,0415,46),
(4424,1,1,1,3,0620,84),
(2758,1,1,1,4,0625,20),
(2750,1,1,1,5,0640,27),
(4424,1,1,1,6,0415,26),
(2758,1,1,1,1,0630,112),
(2334,1,1,1,2,0420,118),
(4424,1,1,1,3,0620,80),
(2747,1,1,1,4,0425,82),
(3317,1,1,1,5,0625,74),
(2763,1,1,1,6,0640,29),
(2758,1,1,1,1,0615,67),
(2281,1,1,1,2,0420,73),
(2758,1,1,1,3,0630,31),
(2212,1,1,1,4,0625,111),
(2281,1,1,1,5,0625,72),
(4424,1,1,1,6,0630,104),
(2747,1,1,1,1,0610,67),
(2282,1,1,1,2,0640,99),
(4424,1,1,1,3,0630,27),
(4424,1,1,1,4,0615,74),
(3317,1,1,1,5,0420,33),
(2281,1,1,1,6,0420,22),
(2212,1,1,1,1,0430,71),
(2281,1,1,1,2,0625,36),
(2758,1,1,1,3,0615,115),
(4424,1,1,1,4,0440,39),
(4424,1,1,1,5,0440,116),
(2281,1,1,1,6,0620,65),
(2281,1,1,1,1,0615,70),
(2758,1,1,1,2,0630,28),
(4424,1,1,1,3,0440,33),
(2750,1,1,1,4,0625,56),
(4424,1,1,1,5,0615,32),
(2281,1,1,1,6,0620,61),
(2334,1,1,1,1,0610,35),
(4424,1,1,1,2,0640,48),
(4424,1,1,1,3,0430,20),
(2212,1,1,1,4,0615,102),
(4424,1,1,1,5,0420,58),
(2281,1,1,1,6,0630,92),
(2763,1,1,1,1,0610,105),
(4424,1,1,1,2,0415,45),
(4424,1,1,1,3,0415,73),
(2212,1,1,1,4,0425,27),
(2758,1,1,1,5,0610,69),
(2758,1,1,1,6,0640,118),
(2758,1,1,1,1,0440,31),
(2281,1,1,1,2,0625,88),
(2758,1,1,1,3,0430,113),
(2281,1,1,1,4,0420,72),
(2281,1,1,1,5,0415,60),
(2747,1,1,1,6,0610,37),
(2281,1,1,1,1,0425,46),
(2747,1,1,1,2,0415,59),
(3317,1,1,1,3,0620,43),
(2281,1,1,1,4,0630,111),
(2747,1,1,1,5,0430,40),
(2747,1,1,1,6,0610,23),
(2750,1,1,1,1,0610,87),
(2281,1,1,1,2,0620,72),
(4424,1,1,1,3,0640,55),
(2281,1,1,1,4,0430,103),
(2281,1,1,1,5,0640,107),
(2747,1,1,1,6,0615,77),
(2281,1,1,1,1,0620,121),
(2758,1,1,1,2,0620,66),
(2281,1,1,1,3,0610,61),
(2747,1,1,1,4,0610,36),
(2281,1,1,1,5,0430,83),
(2282,1,1,1,6,0440,17),
(2281,1,1,1,1,0410,46),
(2758,1,1,1,2,0610,53),
(2282,1,1,1,3,0610,68),
(2747,1,1,1,4,0615,51),
(2758,1,1,1,5,0430,64),
(3317,1,1,1,6,0415,37),
(2281,1,1,1,1,0620,113),
(3317,1,1,1,2,0620,79),
(3317,1,1,1,3,0620,60),
(4424,1,1,1,4,0615,86),
(2281,1,1,1,5,0630,108),
(2747,1,1,1,6,0630,50),
(4424,1,1,1,1,0610,122),
(2281,1,1,1,2,0640,17),
(2281,1,1,1,3,0630,58),
(2212,1,1,1,4,0625,42),
(2281,1,1,1,5,0630,119),
(2758,1,1,1,6,0630,68),
(2758,1,1,1,1,0615,66),
(2212,1,1,1,2,0625,88),
(2334,1,1,1,3,0620,112),
(2281,1,1,1,4,0625,65),
(2281,1,1,1,5,0440,75),
(4424,1,1,1,6,0415,39),
(4424,1,1,1,1,0625,86),
(2747,1,1,1,2,0640,115),
(2282,1,1,1,3,0630,35),
(2281,1,1,1,4,0625,98),
(4424,1,1,1,5,0615,73),
(2747,1,1,1,6,0640,95),
(3317,1,1,1,1,0620,107),
(2281,1,1,1,2,0630,91),
(4424,1,1,1,3,0430,46),
(3317,1,1,1,4,0630,46),
(2747,1,1,1,5,0440,55),
(2281,1,1,1,6,0415,47),
(2758,1,1,1,1,0440,124),
(2763,1,1,1,2,0620,38),
(2750,1,1,1,3,0430,21),
(2758,1,1,1,4,0630,40),
(4424,1,1,1,5,0625,18),
(2281,1,1,1,6,0640,66),
(2212,1,1,1,1,0620,124),
(2281,1,1,1,2,0430,121),
(2758,1,1,1,3,0640,86),
(2212,1,1,1,4,0610,98),
(2281,1,1,1,5,0415,95),
(2282,1,1,1,6,0640,27),
(2758,1,1,1,1,0620,24),
(3317,1,1,1,2,0420,20),
(2747,1,1,1,3,0640,90),
(2758,1,1,1,4,0410,53),
(4424,1,1,1,5,0610,59),
(2747,1,1,1,6,0640,121),
(2747,1,1,1,1,0615,46),
(3317,1,1,1,2,0610,21),
(2758,1,1,1,3,0615,125),
(4424,1,1,1,4,0640,22),
(2281,1,1,1,5,0415,91),
(2281,1,1,1,6,0620,33),
(2758,1,1,1,1,0630,75),
(2281,1,1,1,2,0610,125),
(2282,1,1,1,3,0610,111),
(2212,1,1,1,4,0440,45),
(2281,1,1,1,5,0430,20),
(4424,1,1,1,6,0610,94),
(2281,1,1,1,1,0430,90),
(2281,1,1,1,2,0610,20),
(2747,1,1,1,3,0625,80),
(4424,1,1,1,4,0615,59),
(2747,1,1,1,5,0420,111),
(2758,1,1,1,6,0430,79),
(2282,1,1,1,1,0610,23),
(2281,1,1,1,2,0625,27),
(2212,1,1,1,3,0610,88),
(3317,1,1,1,4,0625,89),
(2281,1,1,1,5,0625,56),
(2747,1,1,1,6,0640,94),
(2334,1,1,1,1,0630,43),
(2758,1,1,1,2,0640,17),
(2282,1,1,1,3,0610,93),
(3317,1,1,1,4,0610,24),
(2281,1,1,1,5,0620,18),
(2747,1,1,1,6,0625,117),
(2758,1,1,1,1,0610,51),
(2281,1,1,1,2,0620,28),
(2747,1,1,1,3,0640,122),
(2763,1,1,1,4,0640,19),
(2282,1,1,1,5,0420,78),
(2281,1,1,1,6,0610,23),
(2281,1,1,1,1,0440,22),
(2758,1,1,1,2,0420,104),
(2281,1,1,1,3,0630,27),
(3317,1,1,1,4,0620,50),
(4424,1,1,1,5,0630,60),
(2758,1,1,1,6,0615,15),
(2281,1,1,1,1,0410,17),
(2281,1,1,1,2,0620,72),
(4424,1,1,1,3,0615,120),
(2747,1,1,1,4,0640,58),
(2282,1,1,1,5,0410,82),
(2750,1,1,1,6,0625,61),
(2282,1,1,1,1,0640,109),
(3317,1,1,1,2,0420,122),
(3317,1,1,1,3,0630,88),
(2758,1,1,1,4,0625,73),
(2282,1,1,1,5,0420,34),
(2281,1,1,1,6,0630,105),
(4424,1,1,1,1,0615,67),
(2747,1,1,1,2,0420,66),
(4424,1,1,1,3,0610,29),
(2281,1,1,1,4,0640,87),
(2281,1,1,1,5,0610,125),
(2281,1,1,1,6,0420,16),
(2758,1,1,1,1,0610,27),
(2758,1,1,1,2,0625,60),
(2747,1,1,1,3,0620,81),
(2282,1,1,1,4,0425,60),
(2747,1,1,1,5,0620,18),
(2281,1,1,1,6,0630,23),
(2281,1,1,1,1,0610,79),
(4424,1,1,1,2,0420,23),
(2747,1,1,1,3,0610,18),
(4424,1,1,1,4,0610,97),
(2281,1,1,1,5,0610,64),
(2281,1,1,1,6,0640,51),
(2747,1,1,1,1,0620,68),
(2282,1,1,1,2,0430,56),
(2281,1,1,1,3,0610,52),
(2747,1,1,1,4,0620,114),
(2758,1,1,1,5,0630,83),
(3317,1,1,1,6,0630,23),
(2281,1,1,1,1,0615,25),
(3317,1,1,1,2,0640,70),
(2212,1,1,1,3,0420,117),
(2763,1,1,1,4,0425,69),
(2282,1,1,1,5,0410,28),
(2212,1,1,1,6,0630,17),
(2750,1,1,1,1,0610,31),
(4424,1,1,1,2,0415,57),
(2747,1,1,1,3,0630,53),
(2282,1,1,1,4,0620,89),
(2281,1,1,1,5,0620,96),
(2281,1,1,1,6,0610,115),
(2281,1,1,1,1,0640,35),
(2758,1,1,1,2,0640,58),
(2281,1,1,1,3,0425,110),
(2281,1,1,1,4,0425,115),
(4424,1,1,1,5,0620,93),
(3317,1,1,1,6,0620,27),
(2334,1,1,1,1,0410,73),
(2281,1,1,1,2,0440,79),
(2758,1,1,1,3,0410,106),
(4424,1,1,1,4,0440,78),
(2758,1,1,1,5,0425,28),
(4424,1,1,1,6,0610,113),
(2281,1,1,1,1,0625,34),
(2282,1,1,1,2,0630,110),
(3317,1,1,1,3,0620,52),
(2281,1,1,1,4,0615,55),
(2758,1,1,1,5,0415,99),
(2281,1,1,1,6,0620,36),
(2282,1,1,1,1,0630,32),
(3317,1,1,1,2,0630,89),
(2281,1,1,1,3,0610,64),
(2281,1,1,1,4,0640,99),
(2758,1,1,1,5,0610,15),
(2282,1,1,1,6,0410,114),
(2747,1,1,1,1,0615,84),
(2763,1,1,1,2,0620,82),
(2758,1,1,1,3,0420,72),
(2758,1,1,1,4,0615,123),
(4424,1,1,1,5,0440,46),
(2281,1,1,1,6,0610,84),
(2758,1,1,1,1,0630,103),
(3317,1,1,1,2,0625,56),
(2281,1,1,1,3,0640,47),
(4424,1,1,1,4,0615,73),
(2281,1,1,1,5,0640,91),
(2750,1,1,1,6,0630,35),
(2212,1,1,1,1,0415,53),
(2281,1,1,1,2,0615,60),
(2282,1,1,1,3,0610,124),
(2763,1,1,1,4,0640,63),
(2281,1,1,1,5,0430,91),
(3317,1,1,1,6,0610,15),
(3317,1,1,1,1,0625,110),
(3317,1,1,1,2,0620,51),
(2747,1,1,1,3,0630,67),
(2758,1,1,1,4,0410,65),
(2282,1,1,1,5,0415,41),
(2281,1,1,1,6,0410,84),
(4424,1,1,1,1,0420,97),
(4424,1,1,1,2,0615,63),
(2747,1,1,1,3,0625,28),
(2281,1,1,1,4,0630,58),
(2747,1,1,1,5,0440,119),
(2281,1,1,1,6,0630,82),
(2282,1,1,1,1,0620,119),
(2281,1,1,1,2,0420,55),
(2281,1,1,1,3,0640,124),
(2758,1,1,1,4,0630,52),
(2747,1,1,1,5,0410,103),
(2747,1,1,1,6,0610,113),
(2281,1,1,1,1,0625,92),
(4424,1,1,1,2,0410,50),
(2758,1,1,1,3,0620,50),
(2758,1,1,1,4,0615,79),
(2212,1,1,1,5,0610,99),
(2747,1,1,1,6,0425,125),
(2281,1,1,1,1,0610,90),
(2281,1,1,1,2,0620,37),
(2758,1,1,1,3,0620,47),
(2282,1,1,1,4,0615,31),
(2281,1,1,1,5,0610,119),
(3317,1,1,1,6,0425,112),
(4424,1,1,1,1,0620,59),
(2758,1,1,1,2,0630,30),
(2334,1,1,1,3,0440,59),
(3317,1,1,1,4,0610,73),
(2281,1,1,1,5,0615,112),
(2281,1,1,1,6,0620,19),
(2747,1,1,1,1,0610,16),
(2281,1,1,1,2,0415,100),
(2763,1,1,1,3,0640,15),
(2747,1,1,1,4,0620,17),
(4424,1,1,1,5,0420,116),
(2758,1,1,1,6,0640,120),
(3317,1,1,1,1,0630,97),
(2281,1,1,1,2,0610,80),
(3317,1,1,1,3,0610,59),
(2758,1,1,1,4,0625,59),
(4424,1,1,1,5,0640,45),
(2750,1,1,1,6,0430,73),
(2281,1,1,1,1,0640,52),
(3317,1,1,1,2,0625,55),
(2758,1,1,1,3,0425,57),
(4424,1,1,1,4,0410,28),
(2747,1,1,1,5,0430,78),
(4424,1,1,1,6,0610,34),
(2747,1,1,1,1,0630,99),
(2281,1,1,1,2,0640,21),
(2281,1,1,1,3,0415,62),
(2281,1,1,1,4,0625,125),
(2281,1,1,1,5,0615,46),
(2281,1,1,1,6,0615,53),
(2281,1,1,1,1,0640,60),
(2758,1,1,1,2,0610,23),
(4424,1,1,1,3,0640,120),
(4424,1,1,1,4,0630,25),
(2212,1,1,1,5,0420,50),
(3317,1,1,1,6,0415,68),
(2281,1,1,1,1,0640,123),
(4424,1,1,1,2,0625,112),
(2281,1,1,1,3,0415,82),
(4424,1,1,1,4,0625,69),
(2747,1,1,1,5,0430,53),
(2763,1,1,1,6,0625,46),
(2758,1,1,1,1,0630,74),
(2281,1,1,1,2,0615,72),
(2758,1,1,1,3,0640,110),
(2281,1,1,1,4,0615,15),
(2758,1,1,1,5,0610,86),
(2758,1,1,1,6,0615,22),
(2747,1,1,1,1,0615,45),
(2281,1,1,1,2,0620,67),
(2282,1,1,1,3,0415,61),
(2763,1,1,1,4,0640,111),
(2281,1,1,1,5,0615,68),
(2281,1,1,1,6,0620,109),
(2281,1,1,1,1,0410,28),
(2747,1,1,1,2,0440,114),
(3317,1,1,1,3,0425,110),
(2750,1,1,1,4,0425,100),
(2758,1,1,1,5,0425,102),
(2281,1,1,1,6,0620,112),
(2747,1,1,1,1,0615,121),
(4424,1,1,1,2,0610,55),
(2758,1,1,1,3,0410,84),
(4424,1,1,1,4,0630,65),
(2281,1,1,1,5,0430,78),
(2282,1,1,1,6,0620,29),
(2281,1,1,1,1,0630,75),
(4424,1,1,1,2,0620,121),
(3317,1,1,1,3,0430,105),
(2747,1,1,1,4,0440,88),
(2758,1,1,1,5,0625,55),
(2747,1,1,1,6,0640,98),
(2763,1,1,1,1,0630,39),
(4424,1,1,1,2,0610,36),
(2758,1,1,1,3,0420,35),
(4424,1,1,1,4,0415,67),
(2281,1,1,1,5,0410,99),
(2281,1,1,1,6,0620,54),
(2281,1,1,1,1,0430,95),
(2763,1,1,1,2,0625,115),
(4424,1,1,1,3,0630,15),
(2212,1,1,1,4,0625,39),
(3317,1,1,1,5,0425,51),
(3317,1,1,1,6,0630,20),
(2747,1,1,1,1,0625,112),
(2758,1,1,1,2,0615,50),
(3317,1,1,1,3,0425,17),
(4424,1,1,1,4,0615,41),
(2281,1,1,1,5,0625,88),
(2281,1,1,1,6,0615,115),
(2758,1,1,1,1,0615,120),
(2758,1,1,1,2,0620,17),
(4424,1,1,1,3,0615,25),
(2747,1,1,1,4,0410,33),
(2282,1,1,1,5,0440,72),
(2747,1,1,1,6,0610,74),
(3317,1,1,1,1,0415,83),
(2281,1,1,1,2,0615,119),
(2758,1,1,1,3,0610,98),
(2281,1,1,1,4,0610,53),
(2758,1,1,1,5,0625,22),
(2747,1,1,1,6,0430,109),
(2281,1,1,1,1,0615,45),
(2281,1,1,1,2,0610,120),
(2282,1,1,1,3,0610,121),
(2281,1,1,1,4,0625,110),
(2281,1,1,1,5,0615,75),
(2747,1,1,1,6,0425,22),
(2281,1,1,1,1,0415,54),
(2281,1,1,1,2,0415,47),
(3317,1,1,1,3,0425,120),
(4424,1,1,1,4,0610,17),
(2212,1,1,1,5,0640,36),
(3317,1,1,1,6,0640,73),
(2747,1,1,1,1,0410,54),
(2281,1,1,1,2,0615,23),
(2281,1,1,1,3,0430,72),
(4424,1,1,1,4,0610,17),
(2281,1,1,1,5,0415,66),
(4424,1,1,1,6,0425,18),
(2758,1,1,1,1,0625,109),
(2282,1,1,1,2,0630,93),
(2747,1,1,1,3,0630,70),
(2763,1,1,1,4,0415,70),
(2281,1,1,1,5,0615,42),
(2281,1,1,1,6,0615,124),
(4424,1,1,1,1,0610,54),
(4424,1,1,1,2,0425,62),
(4424,1,1,1,3,0640,102),
(2212,1,1,1,4,0610,57),
(2281,1,1,1,5,0625,114),
(4424,1,1,1,6,0610,45),
(3317,1,1,1,1,0625,22),
(2747,1,1,1,2,0440,98),
(2281,1,1,1,3,0630,59),
(4424,1,1,1,4,0620,110),
(3317,1,1,1,5,0610,65),
(2763,1,1,1,6,0640,86),
(2282,1,1,1,1,0615,92),
(2281,1,1,1,2,0620,98),
(2281,1,1,1,3,0425,99),
(2747,1,1,1,4,0410,103),
(2758,1,1,1,5,0430,79),
(2758,1,1,1,6,0610,66),
(2747,1,1,1,1,0615,36),
(2282,1,1,1,2,0615,47),
(2758,1,1,1,3,0630,100),
(2281,1,1,1,4,0630,88),
(2747,1,1,1,5,0625,40),
(2281,1,1,1,6,0630,20),
(2282,1,1,1,1,0625,86),
(2747,1,1,1,2,0640,45),
(2281,1,1,1,3,0420,25),
(3317,1,1,1,4,0415,33),
(4424,1,1,1,5,0620,80),
(2747,1,1,1,6,0630,25),
(4424,1,1,1,1,0615,76),
(2282,1,1,1,2,0615,38),
(2758,1,1,1,3,0440,86),
(2747,1,1,1,4,0420,20),
(2281,1,1,1,5,0615,116),
(2281,1,1,1,6,0610,74),
(4424,1,1,1,1,0640,96),
(2281,1,1,1,2,0620,32),
(2281,1,1,1,3,0620,61),
(4424,1,1,1,4,0630,39),
(2758,1,1,1,5,0620,87),
(2747,1,1,1,6,0640,41),
(2281,1,1,1,1,0620,112),
(4424,1,1,1,2,0640,119),
(2281,1,1,1,3,0615,28),
(2281,1,1,1,4,0640,52),
(2281,1,1,1,5,0620,36),
(4424,1,1,1,6,0615,112),
(2281,1,1,1,1,0440,85),
(2281,1,1,1,2,0440,84),
(3317,1,1,1,3,0625,51),
(4424,1,1,1,4,0420,47),
(2747,1,1,1,5,0620,56),
(2763,1,1,1,6,0610,117),
(2281,1,1,1,1,0620,117),
(2750,1,1,1,2,0640,54),
(2747,1,1,1,3,0425,75),
(2334,1,1,1,4,0430,54),
(2747,1,1,1,5,0415,108),
(2281,1,1,1,6,0430,76),
(2281,1,1,1,1,0640,16),
(2281,1,1,1,2,0425,87),
(2281,1,1,1,3,0620,24),
(2282,1,1,1,4,0415,31),
(4424,1,1,1,5,0630,88),
(2747,1,1,1,6,0630,120),
(2281,1,1,1,1,0430,81),
(2281,1,1,1,2,0440,108),
(4424,1,1,1,3,0620,111),
(2758,1,1,1,4,0610,125),
(3317,1,1,1,5,0425,21),
(2281,1,1,1,6,0615,27),
(2747,1,1,1,1,0430,38),
(3317,1,1,1,2,0430,88),
(2334,1,1,1,3,0625,42),
(2281,1,1,1,4,0610,55),
(2281,1,1,1,5,0625,30),
(2758,1,1,1,6,0625,109),
(2282,1,1,1,1,0615,54),
(2281,1,1,1,2,0615,106),
(4424,1,1,1,3,0410,24),
(2212,1,1,1,4,0410,119),
(2758,1,1,1,5,0630,21),
(2750,1,1,1,6,0620,58),
(2758,1,1,1,1,0640,70),
(2763,1,1,1,2,0640,30),
(4424,1,1,1,3,0640,106),
(4424,1,1,1,4,0430,24),
(2281,1,1,1,5,0640,91),
(2758,1,1,1,6,0630,117),
(2763,1,1,1,1,0425,35),
(2747,1,1,1,2,0640,34),
(2758,1,1,1,3,0415,87),
(4424,1,1,1,4,0630,62),
(2747,1,1,1,5,0615,53),
(3317,1,1,1,6,0640,41),
(2281,1,1,1,1,0625,41),
(2212,1,1,1,2,0640,87),
(2763,1,1,1,3,0415,54),
(2281,1,1,1,4,0415,113),
(2281,1,1,1,5,0625,124),
(2281,1,1,1,6,0410,120),
(2281,1,1,1,1,0630,39),
(4424,1,1,1,2,0420,20),
(2282,1,1,1,3,0425,29),
(2212,1,1,1,4,0620,35),
(2282,1,1,1,5,0410,43),
(2747,1,1,1,6,0610,15),
(2334,1,1,1,1,0410,64),
(4424,1,1,1,2,0625,74),
(3317,1,1,1,3,0610,80),
(2281,1,1,1,4,0420,52),
(4424,1,1,1,5,0625,50),
(2282,1,1,1,6,0610,123),
(4424,1,1,1,1,0615,125),
(2281,1,1,1,2,0610,104),
(2758,1,1,1,3,0615,75),
(2747,1,1,1,4,0625,61),
(2281,1,1,1,5,0640,15),
(2334,1,1,1,6,0630,95),
(3317,1,1,1,1,0630,31),
(4424,1,1,1,2,0640,96),
(2281,1,1,1,3,0415,89),
(3317,1,1,1,4,0425,93),
(2281,1,1,1,5,0615,64),
(4424,1,1,1,6,0410,65),
(2747,1,1,1,1,0430,83),
(2281,1,1,1,2,0620,74),
(2758,1,1,1,3,0610,41),
(2281,1,1,1,4,0620,110),
(2747,1,1,1,5,0620,96),
(3317,1,1,1,6,0415,20),
(2212,1,1,1,1,0410,60),
(2763,1,1,1,2,0625,17),
(2758,1,1,1,3,0630,105),
(2281,1,1,1,4,0410,41),
(2758,1,1,1,5,0415,110),
(2281,1,1,1,6,0640,85),
(2758,1,1,1,1,0630,53),
(3317,1,1,1,2,0640,52),
(4424,1,1,1,3,0425,55),
(4424,1,1,1,4,0440,66),
(2281,1,1,1,5,0620,105),
(2281,1,1,1,6,0610,47),
(2758,1,1,1,1,0420,82),
(2281,1,1,1,2,0615,121),
(4424,1,1,1,3,0640,80),
(2281,1,1,1,4,0410,104),
(3317,1,1,1,5,0625,93),
(2747,1,1,1,6,0620,117),
(4424,1,1,1,1,0625,57),
(2763,1,1,1,2,0630,54),
(2281,1,1,1,3,0425,118),
(2763,1,1,1,4,0430,55),
(2747,1,1,1,5,0620,118),
(2747,1,1,1,6,0420,39),
(3317,1,1,1,1,0610,29),
(2747,1,1,1,2,0620,76),
(2750,1,1,1,3,0610,34),
(2281,1,1,1,4,0630,87),
(2281,1,1,1,5,0615,38),
(2758,1,1,1,6,0640,66),
(2758,1,1,1,1,0610,33),
(2212,1,1,1,2,0630,114),
(2281,1,1,1,3,0620,116),
(4424,1,1,1,4,0410,103),
(2281,1,1,1,5,0415,88),
(2763,1,1,1,6,0615,114),
(2747,1,1,1,1,0415,34),
(2281,1,1,1,2,0610,30),
(4424,1,1,1,3,0410,62),
(2281,1,1,1,4,0415,86),
(2747,1,1,1,5,0410,15),
(2747,1,1,1,6,0440,78),
(4424,1,1,1,1,0410,21),
(2758,1,1,1,2,0640,105),
(2747,1,1,1,3,0420,61),
(2281,1,1,1,4,0610,96),
(4424,1,1,1,5,0610,63),
(4424,1,1,1,6,0425,78),
(2281,1,1,1,1,0610,81),
(3317,1,1,1,2,0620,90),
(2758,1,1,1,3,0420,36),
(2750,1,1,1,4,0615,80),
(2758,1,1,1,5,0640,46),
(4424,1,1,1,6,0615,102),
(4424,1,1,1,1,0430,38),
(2281,1,1,1,2,0625,69),
(3317,1,1,1,3,0620,90),
(2281,1,1,1,4,0615,80),
(2281,1,1,1,5,0610,104),
(2281,1,1,1,6,0615,81),
(3317,1,1,1,1,0425,72),
(2281,1,1,1,2,0415,118),
(2281,1,1,1,3,0620,73),
(2212,1,1,1,4,0610,70),
(2747,1,1,1,5,0640,37),
(2334,1,1,1,6,0610,19),
(4424,1,1,1,1,0410,119),
(2281,1,1,1,2,0425,110),
(2747,1,1,1,3,0620,120),
(2281,1,1,1,4,0640,58),
(2747,1,1,1,5,0410,20),
(2747,1,1,1,6,0640,89),
(3317,1,1,1,1,0640,61),
(2281,1,1,1,2,0625,18),
(2281,1,1,1,3,0410,55),
(2747,1,1,1,4,0420,67),
(4424,1,1,1,5,0415,43),
(3317,1,1,1,6,0610,26),
(3317,1,1,1,1,0615,63),
(2281,1,1,1,2,0630,60),
(2281,1,1,1,3,0610,58),
(2281,1,1,1,4,0440,75),
(2281,1,1,1,5,0625,53),
(2747,1,1,1,6,0615,115),
(2281,1,1,1,1,0630,117),
(3317,1,1,1,2,0615,103),
(3317,1,1,1,3,0625,45),
(3317,1,1,1,4,0415,113),
(4424,1,1,1,5,0610,76),
(2281,1,1,1,6,0630,94),
(2212,1,1,1,1,0630,26),
(2758,1,1,1,2,0430,125),
(4424,1,1,1,3,0610,59),
(2747,1,1,1,4,0610,102),
(2282,1,1,1,5,0410,18),
(4424,1,1,1,6,0615,84),
(3317,1,1,1,1,0615,60),
(2281,1,1,1,2,0620,109),
(2281,1,1,1,3,0420,31),
(2212,1,1,1,4,0630,68),
(2281,1,1,1,5,0415,63),
(2747,1,1,1,6,0610,58),
(2281,1,1,1,1,0640,109),
(4424,1,1,1,2,0625,78),
(2747,1,1,1,3,0625,67),
(2281,1,1,1,4,0415,124),
(4424,1,1,1,5,0620,54),
(4424,1,1,1,6,0620,44),
(2747,1,1,1,1,0630,120),
(3317,1,1,1,2,0620,125),
(2281,1,1,1,3,0625,21),
(4424,1,1,1,4,0640,27),
(2334,1,1,1,5,0630,19),
(4424,1,1,1,6,0440,108),
(2281,1,1,1,1,0430,95),
(2747,1,1,1,2,0430,26),
(4424,1,1,1,3,0410,106),
(4424,1,1,1,4,0430,49),
(2281,1,1,1,5,0415,54),
(2212,1,1,1,6,0420,93),
(4424,1,1,1,1,0410,59),
(2758,1,1,1,2,0430,74),
(2758,1,1,1,3,0430,48),
(3317,1,1,1,4,0640,74),
(2281,1,1,1,5,0410,111),
(2212,1,1,1,6,0615,98),
(2281,1,1,1,1,0615,27),
(2763,1,1,1,2,0615,31),
(4424,1,1,1,3,0610,96),
(2758,1,1,1,4,0430,75),
(2281,1,1,1,5,0610,46),
(4424,1,1,1,6,0610,44),
(2212,1,1,1,1,0415,17),
(4424,1,1,1,2,0440,102),
(2282,1,1,1,3,0610,36),
(2281,1,1,1,4,0615,69),
(2281,1,1,1,5,0615,16),
(2747,1,1,1,6,0410,88),
(2281,1,1,1,1,0610,65),
(2758,1,1,1,2,0425,50),
(2281,1,1,1,3,0640,60),
(3317,1,1,1,4,0610,119),
(2763,1,1,1,5,0625,20),
(4424,1,1,1,6,0610,105),
(2747,1,1,1,1,0640,20),
(3317,1,1,1,2,0620,62),
(2281,1,1,1,3,0640,91),
(2281,1,1,1,4,0420,19),
(2281,1,1,1,5,0610,121),
(2282,1,1,1,6,0410,24),
(2282,1,1,1,1,0640,105),
(3317,1,1,1,2,0620,90),
(2281,1,1,1,3,0625,29),
(2758,1,1,1,4,0425,30),
(2281,1,1,1,5,0620,40),
(4424,1,1,1,6,0410,47),
(2282,1,1,1,1,0425,103),
(2281,1,1,1,2,0615,69),
(2281,1,1,1,3,0610,73),
(2758,1,1,1,4,0615,20),
(2281,1,1,1,5,0625,75),
(3317,1,1,1,6,0640,115),
(2750,1,1,1,1,0440,56),
(2212,1,1,1,2,0440,121),
(2334,1,1,1,3,0615,91),
(4424,1,1,1,4,0425,48),
(2281,1,1,1,5,0625,50),
(2281,1,1,1,6,0430,34),
(2747,1,1,1,1,0610,118),
(2212,1,1,1,2,0620,114),
(2281,1,1,1,3,0620,79),
(3317,1,1,1,4,0430,55),
(2282,1,1,1,5,0625,83),
(4424,1,1,1,6,0640,25),
(2763,1,1,1,1,0615,106),
(2763,1,1,1,2,0620,65),
(2281,1,1,1,3,0620,43),
(4424,1,1,1,4,0620,119),
(4424,1,1,1,5,0630,107),
(2212,1,1,1,6,0640,125),
(4424,1,1,1,1,0420,106),
(2281,1,1,1,2,0430,30),
(2763,1,1,1,3,0640,76),
(2334,1,1,1,4,0410,74),
(2281,1,1,1,5,0610,86),
(2747,1,1,1,6,0625,25),
(2758,1,1,1,1,0630,88),
(3317,1,1,1,2,0610,70),
(4424,1,1,1,3,0440,101),
(3317,1,1,1,4,0430,27),
(2747,1,1,1,5,0440,73),
(2758,1,1,1,6,0640,38),
(2763,1,1,1,1,0615,121),
(2281,1,1,1,2,0425,15),
(2747,1,1,1,3,0615,111),
(2282,1,1,1,4,0620,79),
(2281,1,1,1,5,0425,50),
(2758,1,1,1,6,0615,106),
(2281,1,1,1,1,0625,91),
(2281,1,1,1,2,0610,55),
(4424,1,1,1,3,0615,118),
(2758,1,1,1,4,0620,83),
(3317,1,1,1,5,0630,103),
(2212,1,1,1,6,0640,40),
(2747,1,1,1,1,0615,105),
(3317,1,1,1,2,0620,125),
(2747,1,1,1,3,0620,25),
(2281,1,1,1,4,0420,27),
(2281,1,1,1,5,0425,61),
(2758,1,1,1,6,0625,103),
(2758,1,1,1,1,0630,80),
(2747,1,1,1,2,0430,116),
(2758,1,1,1,3,0420,78),
(2747,1,1,1,4,0625,18),
(2281,1,1,1,5,0630,102),
(2747,1,1,1,6,0440,42),
(2281,1,1,1,1,0420,100),
(2281,1,1,1,2,0415,124),
(2282,1,1,1,3,0630,70),
(2282,1,1,1,4,0630,38),
(2281,1,1,1,5,0630,106),
(2281,1,1,1,6,0620,51),
(2281,1,1,1,1,0415,71),
(2763,1,1,1,2,0625,62),
(2281,1,1,1,3,0610,76),
(2758,1,1,1,4,0420,57),
(2747,1,1,1,5,0630,58),
(2282,1,1,1,6,0615,60),
(2212,1,1,1,1,0620,86),
(2281,1,1,1,2,0630,80),
(2747,1,1,1,3,0630,91),
(2747,1,1,1,4,0640,35),
(4424,1,1,1,5,0440,105),
(2281,1,1,1,6,0425,15),
(4424,1,1,1,1,0630,112),
(2334,1,1,1,2,0610,81),
(2281,1,1,1,3,0625,93),
(2281,1,1,1,4,0625,54),
(2747,1,1,1,5,0625,26),
(2281,1,1,1,6,0410,74),
(2281,1,1,1,1,0610,64),
(2758,1,1,1,2,0615,78),
(2758,1,1,1,3,0625,102),
(2212,1,1,1,4,0610,37),
(2758,1,1,1,5,0440,71),
(2282,1,1,1,6,0615,95),
(2281,1,1,1,1,0615,67),
(2763,1,1,1,2,0415,21),
(2750,1,1,1,3,0630,61),
(2747,1,1,1,4,0625,89),
(2747,1,1,1,5,0430,32),
(4424,1,1,1,6,0625,29),
(2282,1,1,1,1,0420,71),
(2281,1,1,1,2,0420,65),
(4424,1,1,1,3,0430,73),
(2212,1,1,1,4,0440,112),
(2758,1,1,1,5,0615,25),
(2747,1,1,1,6,0610,112),
(2282,1,1,1,1,0630,39),
(2763,1,1,1,2,0425,30),
(4424,1,1,1,3,0440,96),
(3317,1,1,1,4,0630,46),
(4424,1,1,1,5,0625,81),
(2747,1,1,1,6,0630,122),
(2212,1,1,1,1,0620,119),
(2282,1,1,1,2,0415,103),
(2281,1,1,1,3,0615,74),
(2758,1,1,1,4,0640,117),
(2750,1,1,1,5,0640,69),
(2281,1,1,1,6,0620,39),
(2281,1,1,1,1,0630,48),
(4424,1,1,1,2,0625,125),
(2747,1,1,1,3,0425,42),
(2281,1,1,1,4,0630,82),
(2281,1,1,1,5,0640,37),
(3317,1,1,1,6,0410,47),
(2747,1,1,1,1,0620,62),
(2281,1,1,1,2,0620,114),
(3317,1,1,1,3,0640,114),
(2758,1,1,1,4,0640,17),
(2758,1,1,1,5,0615,64),
(2212,1,1,1,6,0610,37),
(2281,1,1,1,1,0620,33),
(4424,1,1,1,2,0625,70),
(2281,1,1,1,3,0625,30),
(4424,1,1,1,4,0610,32),
(2281,1,1,1,5,0625,85),
(2747,1,1,1,6,0625,121),
(3317,1,1,1,1,0430,21),
(2281,1,1,1,2,0610,66),
(2747,1,1,1,3,0610,38),
(2281,1,1,1,4,0615,92),
(2282,1,1,1,5,0625,114),
(2281,1,1,1,6,0620,45),
(2281,1,1,1,1,0415,18),
(2750,1,1,1,2,0630,96),
(2747,1,1,1,3,0620,77),
(2747,1,1,1,4,0440,90),
(4424,1,1,1,5,0610,89),
(2281,1,1,1,6,0615,89),
(4424,1,1,1,1,0610,101),
(2758,1,1,1,2,0620,107),
(2758,1,1,1,3,0630,78),
(2747,1,1,1,4,0415,29),
(4424,1,1,1,5,0630,125),
(2747,1,1,1,6,0625,108),
(4424,1,1,1,1,0640,45),
(2747,1,1,1,2,0410,83),
(2758,1,1,1,3,0430,115),
(2281,1,1,1,4,0420,80),
(2763,1,1,1,5,0630,54),
(4424,1,1,1,6,0420,118),
(2747,1,1,1,1,0415,40),
(2281,1,1,1,2,0615,93),
(2281,1,1,1,3,0415,19),
(4424,1,1,1,4,0615,80),
(2750,1,1,1,5,0630,67),
(2758,1,1,1,6,0630,21),
(2281,1,1,1,1,0640,38),
(2281,1,1,1,2,0620,111),
(2281,1,1,1,3,0610,112),
(2212,1,1,1,4,0640,17),
(4424,1,1,1,5,0630,47),
(2282,1,1,1,6,0425,22),
(2281,1,1,1,1,0620,74),
(2758,1,1,1,2,0440,99),
(2281,1,1,1,3,0640,51),
(2282,1,1,1,4,0610,26),
(3317,1,1,1,5,0420,103),
(2281,1,1,1,6,0640,21),
(2334,1,1,1,1,0425,35),
(2281,1,1,1,2,0620,119),
(2281,1,1,1,3,0615,121),
(2281,1,1,1,4,0615,97),
(4424,1,1,1,5,0625,78),
(2758,1,1,1,6,0410,115),
(2747,1,1,1,1,0625,32),
(3317,1,1,1,2,0630,46),
(3317,1,1,1,3,0630,34),
(2281,1,1,1,4,0415,113),
(2747,1,1,1,5,0625,27),
(4424,1,1,1,6,0430,59),
(4424,1,1,1,1,0615,76),
(2747,1,1,1,2,0615,71),
(2758,1,1,1,3,0410,104),
(2281,1,1,1,4,0615,61),
(3317,1,1,1,5,0440,15),
(2763,1,1,1,6,0410,100),
(2747,1,1,1,1,0625,72),
(4424,1,1,1,2,0615,38),
(2281,1,1,1,3,0625,45),
(4424,1,1,1,4,0615,37),
(2282,1,1,1,5,0610,72),
(2281,1,1,1,6,0440,97),
(2750,1,1,1,1,0420,98),
(2281,1,1,1,2,0415,35),
(3317,1,1,1,3,0430,101),
(4424,1,1,1,4,0630,49),
(2747,1,1,1,5,0615,38),
(4424,1,1,1,6,0640,57),
(2281,1,1,1,1,0625,54),
(2758,1,1,1,2,0630,45),
(2282,1,1,1,3,0610,76),
(3317,1,1,1,4,0430,30),
(2758,1,1,1,5,0425,125),
(2334,1,1,1,6,0615,114),
(2747,1,1,1,1,0620,108),
(4424,1,1,1,2,0625,90),
(2758,1,1,1,3,0610,61),
(2281,1,1,1,4,0620,33),
(3317,1,1,1,5,0620,70),
(2281,1,1,1,6,0615,115),
(2747,1,1,1,1,0415,100),
(2763,1,1,1,2,0640,81),
(4424,1,1,1,3,0440,87),
(2281,1,1,1,4,0415,47),
(2281,1,1,1,5,0620,98),
(3317,1,1,1,6,0415,39),
(2763,1,1,1,1,0410,98),
(2281,1,1,1,2,0620,124),
(2281,1,1,1,3,0430,35),
(4424,1,1,1,4,0615,96),
(2747,1,1,1,5,0410,39),
(2758,1,1,1,6,0610,109),
(4424,1,1,1,1,0640,18),
(2281,1,1,1,2,0420,18),
(4424,1,1,1,3,0630,92),
(2281,1,1,1,4,0640,22),
(2747,1,1,1,5,0640,19),
(2758,1,1,1,6,0610,121),
(2763,1,1,1,1,0615,52),
(3317,1,1,1,2,0410,22),
(3317,1,1,1,3,0620,72),
(2212,1,1,1,4,0630,36),
(4424,1,1,1,5,0610,105),
(2334,1,1,1,6,0625,115),
(2281,1,1,1,1,0640,87),
(2747,1,1,1,2,0625,16),
(2750,1,1,1,3,0420,34),
(2281,1,1,1,4,0410,54),
(2281,1,1,1,5,0425,26),
(2747,1,1,1,6,0640,57),
(2758,1,1,1,1,0420,41),
(2758,1,1,1,2,0620,95),
(2212,1,1,1,3,0630,75),
(4424,1,1,1,4,0615,47),
(2763,1,1,1,5,0640,104),
(2282,1,1,1,6,0610,65),
(2747,1,1,1,1,0620,117),
(2281,1,1,1,2,0640,95),
(2747,1,1,1,3,0425,117),
(2212,1,1,1,4,0430,66),
(2281,1,1,1,5,0415,98),
(2281,1,1,1,6,0420,125),
(4424,1,1,1,1,0610,37),
(4424,1,1,1,2,0415,36),
(2763,1,1,1,3,0420,72),
(2281,1,1,1,4,0615,109),
(2758,1,1,1,5,0430,82),
(2281,1,1,1,6,0415,72),
(2747,1,1,1,1,0625,107),
(2281,1,1,1,2,0610,31),
(2747,1,1,1,3,0420,47),
(2281,1,1,1,4,0440,88),
(2747,1,1,1,5,0620,78),
(3317,1,1,1,6,0630,31),
(2281,1,1,1,1,0620,116),
(2747,1,1,1,2,0640,112),
(2281,1,1,1,3,0610,18),
(2763,1,1,1,4,0620,113),
(2281,1,1,1,5,0630,55),
(4424,1,1,1,6,0420,38),
(2334,1,1,1,1,0625,61),
(2763,1,1,1,2,0415,25),
(2281,1,1,1,3,0640,52),
(2281,1,1,1,4,0615,74),
(2747,1,1,1,5,0620,117),
(2281,1,1,1,6,0620,21),
(2281,1,1,1,1,0620,18),
(2747,1,1,1,2,0420,91),
(3317,1,1,1,3,0410,25),
(2281,1,1,1,4,0615,33),
(2758,1,1,1,5,0610,79),
(3317,1,1,1,6,0615,90),
(2281,1,1,1,1,0615,99),
(2747,1,1,1,2,0610,54),
(2763,1,1,1,3,0630,28),
(4424,1,1,1,4,0630,79),
(2750,1,1,1,5,0630,35),
(2281,1,1,1,6,0615,33),
(2747,1,1,1,1,0630,71),
(4424,1,1,1,2,0425,23),
(2282,1,1,1,3,0615,81),
(2281,1,1,1,4,0420,107),
(3317,1,1,1,5,0630,112),
(2282,1,1,1,6,0620,41),
(2763,1,1,1,1,0625,40),
(2747,1,1,1,2,0410,94),
(2281,1,1,1,3,0610,70),
(2747,1,1,1,4,0625,99),
(2281,1,1,1,5,0420,70),
(2758,1,1,1,6,0420,35),
(2281,1,1,1,1,0410,18),
(2282,1,1,1,2,0415,78),
(2747,1,1,1,3,0625,79),
(2281,1,1,1,4,0620,102),
(4424,1,1,1,5,0420,16),
(2281,1,1,1,6,0640,59),
(4424,1,1,1,1,0620,106),
(2747,1,1,1,2,0420,102),
(3317,1,1,1,3,0620,81),
(2281,1,1,1,4,0640,123),
(2281,1,1,1,5,0625,88),
(4424,1,1,1,6,0410,39),
(2281,1,1,1,1,0640,77),
(2750,1,1,1,2,0630,117),
(2747,1,1,1,3,0410,42),
(2281,1,1,1,4,0420,113),
(3317,1,1,1,5,0640,76),
(4424,1,1,1,6,0640,89),
(2281,1,1,1,1,0420,93),
(2758,1,1,1,2,0625,79),
(2747,1,1,1,3,0610,106),
(2758,1,1,1,4,0625,67),
(2281,1,1,1,5,0610,105),
(2747,1,1,1,6,0640,110),
(2281,1,1,1,1,0615,35),
(2747,1,1,1,2,0615,71),
(3317,1,1,1,3,0610,79),
(2758,1,1,1,4,0630,69),
(4424,1,1,1,5,0615,111),
(2281,1,1,1,6,0620,27),
(2281,1,1,1,1,0625,55),
(2282,1,1,1,2,0610,54),
(2281,1,1,1,3,0615,98),
(2758,1,1,1,4,0425,40),
(2334,1,1,1,5,0640,103),
(2747,1,1,1,6,0615,105),
(2758,1,1,1,1,0625,75),
(2281,1,1,1,2,0640,43),
(2281,1,1,1,3,0615,58),
(3317,1,1,1,4,0610,48),
(2281,1,1,1,5,0620,111),
(2212,1,1,1,6,0640,48),
(4424,1,1,1,1,0640,101),
(4424,1,1,1,2,0615,113),
(2282,1,1,1,3,0610,76),
(2758,1,1,1,4,0425,102),
(4424,1,1,1,5,0620,25),
(2281,1,1,1,6,0430,43),
(2758,1,1,1,1,0630,100),
(2763,1,1,1,2,0620,61),
(2763,1,1,1,3,0630,37),
(2281,1,1,1,4,0625,65),
(2758,1,1,1,5,0615,52),
(2281,1,1,1,6,0610,35),
(3317,1,1,1,1,0415,102),
(4424,1,1,1,2,0630,110),
(2281,1,1,1,3,0640,102),
(2747,1,1,1,4,0615,46),
(2747,1,1,1,5,0630,30),
(2282,1,1,1,6,0440,112),
(2747,1,1,1,1,0620,44),
(2281,1,1,1,2,0415,61),
(2763,1,1,1,3,0420,118),
(2281,1,1,1,4,0615,99),
(2212,1,1,1,5,0630,77),
(2763,1,1,1,6,0610,71),
(2281,1,1,1,1,0630,48),
(2747,1,1,1,2,0630,69),
(4424,1,1,1,3,0625,121),
(2747,1,1,1,4,0615,35),
(2758,1,1,1,5,0625,124),
(3317,1,1,1,6,0615,73),
(4424,1,1,1,1,0615,88),
(2750,1,1,1,2,0415,71),
(2282,1,1,1,3,0640,64),
(2281,1,1,1,4,0625,122),
(3317,1,1,1,5,0410,98),
(2747,1,1,1,6,0625,27),
(2747,1,1,1,1,0610,35),
(2281,1,1,1,2,0440,110),
(2281,1,1,1,3,0410,88),
(2281,1,1,1,4,0415,103),
(2281,1,1,1,5,0410,67),
(2763,1,1,1,6,0640,71),
(4424,1,1,1,1,0640,28),
(2281,1,1,1,2,0640,116),
(2281,1,1,1,3,0415,103),
(2747,1,1,1,4,0625,65),
(2281,1,1,1,5,0410,23),
(2758,1,1,1,6,0625,26),
(2747,1,1,1,1,0630,43),
(2747,1,1,1,2,0630,52),
(2758,1,1,1,3,0420,18),
(2758,1,1,1,4,0425,64),
(4424,1,1,1,5,0430,103),
(2281,1,1,1,6,0625,55),
(2281,1,1,1,1,0625,123),
(2281,1,1,1,2,0440,58),
(3317,1,1,1,3,0610,63),
(2281,1,1,1,4,0640,28),
(2281,1,1,1,5,0640,68),
(2281,1,1,1,6,0410,72),
(2281,1,1,1,1,0420,123),
(2282,1,1,1,2,0615,98),
(2758,1,1,1,3,0610,39),
(2747,1,1,1,4,0420,64),
(2758,1,1,1,5,0615,37),
(2281,1,1,1,6,0420,32),
(2281,1,1,1,1,0625,50),
(4424,1,1,1,2,0615,110),
(2758,1,1,1,3,0640,122),
(4424,1,1,1,4,0630,75),
(4424,1,1,1,5,0440,99),
(2281,1,1,1,6,0640,73),
(2747,1,1,1,1,0625,99),
(2747,1,1,1,2,0425,70),
(2212,1,1,1,3,0415,106),
(2763,1,1,1,4,0610,54),
(3317,1,1,1,5,0625,90),
(2282,1,1,1,6,0615,81),
(2758,1,1,1,1,0420,43),
(2747,1,1,1,2,0615,105),
(2281,1,1,1,3,0625,85),
(2747,1,1,1,4,0410,17),
(2281,1,1,1,5,0625,119),
(2281,1,1,1,6,0620,34),
(2758,1,1,1,1,0430,76),
(3317,1,1,1,2,0625,121),
(2281,1,1,1,3,0630,102),
(2281,1,1,1,4,0630,99),
(3317,1,1,1,5,0420,125),
(4424,1,1,1,6,0615,89),
(2281,1,1,1,1,0620,17),
(2281,1,1,1,2,0640,53),
(2747,1,1,1,3,0640,92),
(2758,1,1,1,4,0610,16),
(2763,1,1,1,5,0620,42),
(2758,1,1,1,6,0610,35),
(2282,1,1,1,1,0630,115),
(2763,1,1,1,2,0615,92),
(2281,1,1,1,3,0630,82),
(4424,1,1,1,4,0630,55),
(2281,1,1,1,5,0620,84),
(3317,1,1,1,6,0630,86),
(4424,1,1,1,1,0620,78),
(3317,1,1,1,2,0640,63),
(2758,1,1,1,3,0640,46),
(4424,1,1,1,4,0640,16),
(2747,1,1,1,5,0615,94),
(4424,1,1,1,6,0415,90),
(4424,1,1,1,1,0625,89),
(2747,1,1,1,2,0410,71),
(2281,1,1,1,3,0640,57),
(4424,1,1,1,4,0630,93),
(2758,1,1,1,5,0640,108),
(2281,1,1,1,6,0430,112),
(4424,1,1,1,1,0625,114),
(2282,1,1,1,2,0630,73),
(2281,1,1,1,3,0610,100),
(2281,1,1,1,4,0630,71),
(3317,1,1,1,5,0430,85),
(2763,1,1,1,6,0425,55),
(2747,1,1,1,1,0615,76),
(2758,1,1,1,2,0625,29),
(2282,1,1,1,3,0640,45),
(2747,1,1,1,4,0640,82),
(2281,1,1,1,5,0610,16),
(2281,1,1,1,6,0620,18),
(2747,1,1,1,1,0615,26),
(2758,1,1,1,2,0625,44),
(4424,1,1,1,3,0640,20),
(2750,1,1,1,4,0610,31),
(3317,1,1,1,5,0625,56),
(2281,1,1,1,6,0640,59),
(4424,1,1,1,1,0630,17),
(2282,1,1,1,2,0610,85),
(2281,1,1,1,3,0420,67),
(2281,1,1,1,4,0625,43),
(2747,1,1,1,5,0615,70),
(2281,1,1,1,6,0620,91),
(2758,1,1,1,1,0430,56),
(2758,1,1,1,2,0410,107),
(2282,1,1,1,3,0420,59),
(4424,1,1,1,4,0615,95),
(2334,1,1,1,5,0420,72),
(2747,1,1,1,6,0625,89),
(2763,1,1,1,1,0610,111),
(4424,1,1,1,2,0630,46),
(2758,1,1,1,3,0620,40),
(2281,1,1,1,4,0615,80),
(2282,1,1,1,5,0425,79),
(2281,1,1,1,6,0410,52),
(2747,1,1,1,1,0630,65),
(3317,1,1,1,2,0420,97),
(4424,1,1,1,3,0625,94),
(2282,1,1,1,4,0420,83),
(2281,1,1,1,5,0420,32),
(2763,1,1,1,6,0625,19),
(2281,1,1,1,1,0610,108),
(2281,1,1,1,2,0410,90),
(2212,1,1,1,3,0440,101),
(2747,1,1,1,4,0630,66),
(2747,1,1,1,5,0625,92),
(2758,1,1,1,6,0620,122),
(4424,1,1,1,1,0640,62),
(2758,1,1,1,2,0640,125),
(2281,1,1,1,3,0620,65),
(2747,1,1,1,4,0620,66),
(2758,1,1,1,5,0425,125),
(2747,1,1,1,6,0620,47),
(2747,1,1,1,1,0620,18),
(2281,1,1,1,2,0640,85),
(2758,1,1,1,3,0430,112),
(2750,1,1,1,4,0410,45),
(3317,1,1,1,5,0640,51),
(2281,1,1,1,6,0425,70),
(2334,1,1,1,1,0440,28),
(2281,1,1,1,2,0420,34),
(4424,1,1,1,3,0430,117),
(4424,1,1,1,4,0415,17),
(2747,1,1,1,5,0440,80),
(2281,1,1,1,6,0640,112),
(2747,1,1,1,1,0610,125),
(2758,1,1,1,2,0615,16),
(2334,1,1,1,3,0425,48),
(2747,1,1,1,4,0420,99),
(2282,1,1,1,5,0420,62),
(2763,1,1,1,6,0620,106),
(4424,1,1,1,1,0440,44),
(4424,1,1,1,2,0630,23),
(2281,1,1,1,3,0415,49),
(2281,1,1,1,4,0420,100),
(2212,1,1,1,5,0610,81),
(4424,1,1,1,6,0620,76),
(2281,1,1,1,1,0440,58),
(3317,1,1,1,2,0625,47),
(2747,1,1,1,3,0610,114),
(2282,1,1,1,4,0610,119),
(2747,1,1,1,5,0640,123),
(2281,1,1,1,6,0440,87),
(2758,1,1,1,1,0615,50),
(2281,1,1,1,2,0610,120),
(2763,1,1,1,3,0615,81),
(3317,1,1,1,4,0440,52),
(2212,1,1,1,5,0615,52),
(4424,1,1,1,6,0630,85),
(2281,1,1,1,1,0415,95),
(2758,1,1,1,2,0620,39),
(3317,1,1,1,3,0610,104),
(2334,1,1,1,4,0640,114),
(2281,1,1,1,5,0620,17),
(2747,1,1,1,6,0640,30),
(2281,1,1,1,1,0610,69),
(2758,1,1,1,2,0615,91),
(2758,1,1,1,3,0630,88),
(2281,1,1,1,4,0620,32),
(2747,1,1,1,5,0620,94),
(2747,1,1,1,6,0625,64),
(2281,1,1,1,1,0620,75),
(2281,1,1,1,2,0610,22),
(2758,1,1,1,3,0415,119),
(2758,1,1,1,4,0610,115),
(2282,1,1,1,5,0630,84),
(3317,1,1,1,6,0440,82),
(2281,1,1,1,1,0630,33),
(2747,1,1,1,2,0640,112),
(2281,1,1,1,3,0410,101),
(4424,1,1,1,4,0615,35),
(2334,1,1,1,5,0610,45),
(2281,1,1,1,6,0440,72),
(4424,1,1,1,1,0630,119),
(2750,1,1,1,2,0610,93),
(2281,1,1,1,3,0430,91),
(2758,1,1,1,4,0620,27),
(2747,1,1,1,5,0425,17),
(2747,1,1,1,6,0410,118),
(2281,1,1,1,1,0625,100),
(2281,1,1,1,2,0410,68),
(2281,1,1,1,3,0620,66),
(2281,1,1,1,4,0440,58),
(2281,1,1,1,5,0625,121),
(2763,1,1,1,6,0420,25),
(2747,1,1,1,1,0420,93),
(3317,1,1,1,2,0415,111),
(4424,1,1,1,3,0630,78),
(3317,1,1,1,4,0610,110),
(2758,1,1,1,5,0430,82),
(2212,1,1,1,6,0640,30),
(2758,1,1,1,1,0625,25),
(2281,1,1,1,2,0625,50),
(3317,1,1,1,3,0410,90),
(2747,1,1,1,4,0640,90),
(2282,1,1,1,5,0420,117),
(2758,1,1,1,6,0625,64),
(2763,1,1,1,1,0440,39),
(2281,1,1,1,2,0415,15),
(2758,1,1,1,3,0430,75),
(4424,1,1,1,4,0440,35),
(2281,1,1,1,5,0410,43),
(4424,1,1,1,6,0425,48),
(2212,1,1,1,1,0415,42),
(2334,1,1,1,2,0425,87),
(4424,1,1,1,3,0640,53),
(2281,1,1,1,4,0615,109),
(2281,1,1,1,5,0630,62),
(3317,1,1,1,6,0415,116),
(2758,1,1,1,1,0615,69),
(2758,1,1,1,2,0640,82),
(3317,1,1,1,3,0440,18),
(2281,1,1,1,4,0625,61),
(2281,1,1,1,5,0440,122),
(2281,1,1,1,6,0415,48),
(2212,1,1,1,1,0610,47),
(3317,1,1,1,2,0620,39),
(2282,1,1,1,3,0620,109),
(2747,1,1,1,4,0440,69),
(2281,1,1,1,5,0615,100),
(4424,1,1,1,6,0620,107),
(4424,1,1,1,1,0425,72),
(2281,1,1,1,2,0625,67),
(4424,1,1,1,3,0620,81),
(2212,1,1,1,4,0430,93),
(2763,1,1,1,5,0640,44),
(3317,1,1,1,6,0640,100),
(2747,1,1,1,1,0430,32),
(2758,1,1,1,2,0625,38),
(2758,1,1,1,3,0640,124),
(2758,1,1,1,4,0610,92),
(2281,1,1,1,5,0415,60),
(2747,1,1,1,6,0615,19),
(2763,1,1,1,1,0620,98),
(4424,1,1,1,2,0415,111),
(2281,1,1,1,3,0610,96),
(2281,1,1,1,4,0440,73),
(2758,1,1,1,5,0440,112),
(3317,1,1,1,6,0630,55),
(2747,1,1,1,1,0430,56),
(2747,1,1,1,2,0425,108),
(3317,1,1,1,3,0620,73),
(2282,1,1,1,4,0410,30),
(2281,1,1,1,5,0620,114),
(2212,1,1,1,6,0615,58),
(2281,1,1,1,1,0615,44),
(2747,1,1,1,2,0610,55),
(2281,1,1,1,3,0610,96),
(2212,1,1,1,4,0430,18),
(4424,1,1,1,5,0640,100),
(2281,1,1,1,6,0610,79),
(2281,1,1,1,1,0625,27),
(2758,1,1,1,2,0410,36),
(2282,1,1,1,3,0425,99),
(2747,1,1,1,4,0630,113),
(2747,1,1,1,5,0615,98),
(3317,1,1,1,6,0615,78),
(2281,1,1,1,1,0630,98),
(4424,1,1,1,2,0615,55),
(2763,1,1,1,3,0440,85),
(2758,1,1,1,4,0440,50),
(2281,1,1,1,5,0625,118),
(3317,1,1,1,6,0620,25),
(2758,1,1,1,1,0610,116),
(2747,1,1,1,2,0410,112),
(2282,1,1,1,3,0615,122),
(2281,1,1,1,4,0610,122),
(2758,1,1,1,5,0440,101),
(2281,1,1,1,6,0610,34),
(2758,1,1,1,1,0430,106),
(2763,1,1,1,2,0625,94),
(2212,1,1,1,3,0625,100),
(2282,1,1,1,4,0620,75),
(3317,1,1,1,5,0415,61),
(3317,1,1,1,6,0625,18),
(2758,1,1,1,1,0615,91),
(4424,1,1,1,2,0620,15),
(2281,1,1,1,3,0420,109),
(2758,1,1,1,4,0620,38),
(2281,1,1,1,5,0415,48),
(4424,1,1,1,6,0420,22),
(2281,1,1,1,1,0640,93),
(2747,1,1,1,2,0630,55),
(3317,1,1,1,3,0425,33),
(2282,1,1,1,4,0615,117),
(3317,1,1,1,5,0610,77),
(2763,1,1,1,6,0630,111),
(2281,1,1,1,1,0625,63),
(2747,1,1,1,2,0625,68),
(2281,1,1,1,3,0625,16),
(3317,1,1,1,4,0420,117),
(2747,1,1,1,5,0625,117),
(3317,1,1,1,6,0640,24),
(2281,1,1,1,1,0420,79),
(2281,1,1,1,2,0440,98),
(2758,1,1,1,3,0630,37),
(2758,1,1,1,4,0620,24),
(4424,1,1,1,5,0425,78),
(2758,1,1,1,6,0430,117),
(3317,1,1,1,1,0620,87),
(2758,1,1,1,2,0420,25),
(2763,1,1,1,3,0430,29),
(2334,1,1,1,4,0625,16),
(3317,1,1,1,5,0410,73),
(2281,1,1,1,6,0430,21),
(2281,1,1,1,1,0620,44),
(4424,1,1,1,2,0440,68),
(4424,1,1,1,3,0440,116),
(2212,1,1,1,4,0640,90),
(2747,1,1,1,5,0610,65),
(2281,1,1,1,6,0620,70),
(3317,1,1,1,1,0440,91),
(4424,1,1,1,2,0630,124),
(2281,1,1,1,3,0415,110),
(2281,1,1,1,4,0630,25),
(2747,1,1,1,5,0620,51),
(4424,1,1,1,6,0420,29),
(2281,1,1,1,1,0630,22),
(4424,1,1,1,2,0420,40),
(3317,1,1,1,3,0625,84),
(2747,1,1,1,4,0615,49),
(2281,1,1,1,5,0415,59),
(2747,1,1,1,6,0415,80),
(2281,1,1,1,1,0415,112),
(2334,1,1,1,2,0610,102),
(2281,1,1,1,3,0415,58),
(2758,1,1,1,4,0640,19),
(2747,1,1,1,5,0640,105),
(2281,1,1,1,6,0420,88),
(2281,1,1,1,1,0630,48),
(2212,1,1,1,2,0615,39),
(2758,1,1,1,3,0625,118),
(2281,1,1,1,4,0620,74),
(2282,1,1,1,5,0425,43),
(2747,1,1,1,6,0420,75),
(2281,1,1,1,1,0630,81),
(2758,1,1,1,2,0640,90),
(3317,1,1,1,3,0620,15),
(2763,1,1,1,4,0630,24),
(2281,1,1,1,5,0640,91),
(2281,1,1,1,6,0620,82),
(3317,1,1,1,1,0425,27),
(2758,1,1,1,2,0630,21),
(2281,1,1,1,3,0440,96),
(4424,1,1,1,4,0610,69),
(2763,1,1,1,5,0625,97),
(4424,1,1,1,6,0615,109),
(4424,1,1,1,1,0620,76),
(2281,1,1,1,2,0630,65),
(2747,1,1,1,3,0415,112),
(4424,1,1,1,4,0440,53),
(2747,1,1,1,5,0410,80),
(2212,1,1,1,6,0415,15),
(2281,1,1,1,1,0630,76),
(4424,1,1,1,2,0430,110),
(2281,1,1,1,3,0630,99),
(2281,1,1,1,4,0640,17),
(2281,1,1,1,5,0615,92),
(2747,1,1,1,6,0615,80),
(2212,1,1,1,1,0625,25),
(2758,1,1,1,2,0640,20),
(2282,1,1,1,3,0640,31),
(2282,1,1,1,4,0610,72),
(2334,1,1,1,5,0620,63),
(2758,1,1,1,6,0615,101),
(2281,1,1,1,1,0640,122),
(2747,1,1,1,2,0625,26),
(4424,1,1,1,3,0640,72),
(2758,1,1,1,4,0420,101),
(2212,1,1,1,5,0615,107),
(4424,1,1,1,6,0415,122),
(2750,1,1,1,1,0620,72),
(2281,1,1,1,2,0425,119),
(4424,1,1,1,3,0625,63),
(2763,1,1,1,4,0425,96),
(2282,1,1,1,5,0610,81),
(2758,1,1,1,6,0415,100),
(2747,1,1,1,1,0630,96),
(2758,1,1,1,2,0410,31),
(2281,1,1,1,3,0610,121),
(2281,1,1,1,4,0625,46),
(3317,1,1,1,5,0615,79),
(2763,1,1,1,6,0430,55),
(2282,1,1,1,1,0615,49),
(2281,1,1,1,2,0630,121),
(2747,1,1,1,3,0610,24),
(4424,1,1,1,4,0425,27),
(3317,1,1,1,5,0625,116),
(2334,1,1,1,6,0625,20),
(2212,1,1,1,1,0620,95),
(2282,1,1,1,2,0425,59),
(2212,1,1,1,3,0625,84),
(2758,1,1,1,4,0425,25),
(2747,1,1,1,5,0440,22),
(2281,1,1,1,6,0410,73),
(3317,1,1,1,1,0620,107),
(2747,1,1,1,2,0630,74),
(4424,1,1,1,3,0620,72),
(3317,1,1,1,4,0640,115),
(3317,1,1,1,5,0410,58),
(4424,1,1,1,6,0615,85),
(2281,1,1,1,1,0640,53),
(2281,1,1,1,2,0430,76),
(2282,1,1,1,3,0430,81),
(2763,1,1,1,4,0620,44),
(2281,1,1,1,5,0430,58),
(2281,1,1,1,6,0640,106),
(4424,1,1,1,1,0620,64),
(3317,1,1,1,2,0620,56),
(4424,1,1,1,3,0625,88),
(2763,1,1,1,4,0610,18),
(4424,1,1,1,5,0630,101),
(2281,1,1,1,6,0420,28),
(2281,1,1,1,1,0615,97),
(4424,1,1,1,2,0625,61),
(3317,1,1,1,3,0625,67),
(2747,1,1,1,4,0625,82),
(2334,1,1,1,5,0410,36),
(2282,1,1,1,6,0610,56),
(2747,1,1,1,1,0430,68),
(2758,1,1,1,2,0625,115),
(2281,1,1,1,3,0425,112),
(2281,1,1,1,4,0410,63),
(2747,1,1,1,5,0640,89),
(4424,1,1,1,6,0630,61),
(2750,1,1,1,1,0640,48),
(2282,1,1,1,2,0610,83),
(2281,1,1,1,3,0425,68),
(2747,1,1,1,4,0610,99),
(2758,1,1,1,5,0615,59),
(3317,1,1,1,6,0610,54),
(2747,1,1,1,1,0420,59),
(2281,1,1,1,2,0625,79),
(3317,1,1,1,3,0620,32),
(2281,1,1,1,4,0625,18),
(2282,1,1,1,5,0620,82),
(2763,1,1,1,6,0425,69),
(2281,1,1,1,1,0410,97),
(2747,1,1,1,2,0615,87),
(4424,1,1,1,3,0630,46),
(2747,1,1,1,4,0630,107),
(2747,1,1,1,5,0620,95),
(4424,1,1,1,6,0615,82),
(2281,1,1,1,1,0615,96),
(3317,1,1,1,2,0430,125),
(2281,1,1,1,3,0620,36),
(2281,1,1,1,4,0640,37),
(2758,1,1,1,5,0640,82),
(2758,1,1,1,6,0420,44),
(2281,1,1,1,1,0610,98),
(2281,1,1,1,2,0620,117),
(4424,1,1,1,3,0420,15),
(2281,1,1,1,4,0610,40),
(2281,1,1,1,5,0440,18),
(4424,1,1,1,6,0415,59),
(4424,1,1,1,1,0425,101),
(2212,1,1,1,2,0640,57),
(2747,1,1,1,3,0630,67),
(2282,1,1,1,4,0620,73),
(2747,1,1,1,5,0620,15),
(2281,1,1,1,6,0410,36),
(4424,1,1,1,1,0415,79),
(2747,1,1,1,2,0410,40),
(2282,1,1,1,3,0620,41),
(2281,1,1,1,4,0615,46),
(2758,1,1,1,5,0615,97),
(2758,1,1,1,6,0430,100),
(2281,1,1,1,1,0615,117),
(2282,1,1,1,2,0430,60),
(2281,1,1,1,3,0415,83),
(2281,1,1,1,4,0640,45),
(4424,1,1,1,5,0415,50),
(3317,1,1,1,6,0610,71),
(2282,1,1,1,1,0630,18),
(2212,1,1,1,2,0410,22),
(4424,1,1,1,3,0410,102),
(4424,1,1,1,4,0620,26),
(2763,1,1,1,5,0425,47),
(3317,1,1,1,6,0625,65),
(2758,1,1,1,1,0615,38),
(3317,1,1,1,2,0410,40),
(4424,1,1,1,3,0420,84),
(2281,1,1,1,4,0620,81),
(2281,1,1,1,5,0620,94),
(2212,1,1,1,6,0620,120),
(2763,1,1,1,1,0615,46),
(2758,1,1,1,2,0440,21),
(2758,1,1,1,3,0640,39),
(2281,1,1,1,4,0620,116),
(2281,1,1,1,5,0640,25),
(2281,1,1,1,6,0620,101),
(4424,1,1,1,1,0425,20),
(2282,1,1,1,2,0630,116),
(2281,1,1,1,3,0630,58),
(2758,1,1,1,4,0610,61),
(2281,1,1,1,5,0620,52),
(4424,1,1,1,6,0615,78),
(2747,1,1,1,1,0420,50),
(2747,1,1,1,2,0615,15),
(2747,1,1,1,3,0415,41),
(2747,1,1,1,4,0415,49),
(2281,1,1,1,5,0415,123),
(2281,1,1,1,6,0425,71),
(2758,1,1,1,1,0420,38),
(2747,1,1,1,2,0425,97),
(4424,1,1,1,3,0430,107),
(2750,1,1,1,4,0410,39),
(2281,1,1,1,5,0640,81),
(2281,1,1,1,6,0615,92),
(2212,1,1,1,1,0440,125),
(4424,1,1,1,2,0630,33),
(2758,1,1,1,3,0625,120),
(4424,1,1,1,4,0620,80),
(2282,1,1,1,5,0615,39),
(2281,1,1,1,6,0610,71),
(4424,1,1,1,1,0615,40),
(3317,1,1,1,2,0420,25),
(2758,1,1,1,3,0410,107),
(3317,1,1,1,4,0640,123),
(4424,1,1,1,5,0625,87),
(2282,1,1,1,6,0625,62),
(2281,1,1,1,1,0430,92),
(2758,1,1,1,2,0625,95),
(2758,1,1,1,3,0640,47),
(2750,1,1,1,4,0630,80),
(3317,1,1,1,5,0615,122),
(4424,1,1,1,6,0640,29),
(2281,1,1,1,1,0440,58),
(2281,1,1,1,2,0420,75),
(3317,1,1,1,3,0430,96),
(2281,1,1,1,4,0630,83),
(2758,1,1,1,5,0430,18),
(2763,1,1,1,6,0610,39),
(2281,1,1,1,1,0610,61),
(2281,1,1,1,2,0610,53),
(2281,1,1,1,3,0430,107),
(4424,1,1,1,4,0415,115),
(2747,1,1,1,5,0415,63),
(4424,1,1,1,6,0640,111),
(2758,1,1,1,1,0620,21),
(2212,1,1,1,2,0630,108),
(2758,1,1,1,3,0610,81),
(2282,1,1,1,4,0410,45),
(2212,1,1,1,5,0620,109),
(2747,1,1,1,6,0615,88),
(2763,1,1,1,1,0410,28),
(2282,1,1,1,2,0640,52),
(2281,1,1,1,3,0630,92),
(2281,1,1,1,4,0425,29),
(3317,1,1,1,5,0440,43),
(2747,1,1,1,6,0410,111),
(2334,1,1,1,1,0620,87),
(2281,1,1,1,2,0440,103),
(2281,1,1,1,3,0620,34),
(2758,1,1,1,4,0430,103),
(3317,1,1,1,5,0620,46),
(2281,1,1,1,6,0420,53),
(2747,1,1,1,1,0625,16),
(2212,1,1,1,2,0620,111),
(2758,1,1,1,3,0425,81),
(2281,1,1,1,4,0425,43),
(2281,1,1,1,5,0620,62),
(2212,1,1,1,6,0630,25),
(2281,1,1,1,1,0425,121),
(3317,1,1,1,2,0625,62),
(2282,1,1,1,3,0625,36),
(2281,1,1,1,4,0430,27),
(2281,1,1,1,5,0610,107),
(2747,1,1,1,6,0410,43),
(2763,1,1,1,1,0430,53),
(2281,1,1,1,2,0640,24),
(2758,1,1,1,3,0420,115),
(2763,1,1,1,4,0615,39),
(2281,1,1,1,5,0610,24),
(4424,1,1,1,6,0640,20),
(4424,1,1,1,1,0610,23),
(2281,1,1,1,2,0620,45),
(3317,1,1,1,3,0615,16),
(2747,1,1,1,4,0415,95),
(2747,1,1,1,5,0425,36),
(2281,1,1,1,6,0620,64),
(2747,1,1,1,1,0630,29),
(3317,1,1,1,2,0625,106),
(2281,1,1,1,3,0620,34),
(2212,1,1,1,4,0620,63),
(2281,1,1,1,5,0610,56),
(2758,1,1,1,6,0625,35),
(2763,1,1,1,1,0615,116),
(2281,1,1,1,2,0615,65),
(2281,1,1,1,3,0620,49),
(4424,1,1,1,4,0615,28),
(2758,1,1,1,5,0615,73),
(2281,1,1,1,6,0430,79),
(3317,1,1,1,1,0640,65),
(3317,1,1,1,2,0610,85),
(2281,1,1,1,3,0630,68),
(2747,1,1,1,4,0410,19),
(2763,1,1,1,5,0630,72),
(4424,1,1,1,6,0630,16),
(2747,1,1,1,1,0415,55),
(2282,1,1,1,2,0420,77),
(3317,1,1,1,3,0625,35),
(2281,1,1,1,4,0640,70),
(2281,1,1,1,5,0615,45),
(2281,1,1,1,6,0440,16),
(4424,1,1,1,1,0420,115),
(2281,1,1,1,2,0630,24),
(2281,1,1,1,3,0630,48),
(2747,1,1,1,4,0640,15),
(2758,1,1,1,5,0620,43),
(2281,1,1,1,6,0630,120),
(4424,1,1,1,1,0625,109),
(2747,1,1,1,2,0610,102),
(3317,1,1,1,3,0420,40),
(2281,1,1,1,4,0625,40),
(4424,1,1,1,5,0440,55),
(2282,1,1,1,6,0420,108),
(4424,1,1,1,1,0425,63),
(2763,1,1,1,2,0610,104),
(2750,1,1,1,3,0440,56),
(2281,1,1,1,4,0620,27),
(2281,1,1,1,5,0430,103),
(2758,1,1,1,6,0640,32),
(4424,1,1,1,1,0420,85),
(2763,1,1,1,2,0440,71),
(3317,1,1,1,3,0640,103),
(2281,1,1,1,4,0425,96),
(2758,1,1,1,5,0625,26),
(2747,1,1,1,6,0640,65),
(2758,1,1,1,1,0420,35),
(2747,1,1,1,2,0430,77),
(2747,1,1,1,3,0615,79),
(2281,1,1,1,4,0625,105),
(2758,1,1,1,5,0625,72),
(2758,1,1,1,6,0640,65),
(2281,1,1,1,1,0615,36),
(4424,1,1,1,2,0440,30),
(2212,1,1,1,3,0615,44),
(2281,1,1,1,4,0610,58),
(2747,1,1,1,5,0425,116),
(2281,1,1,1,6,0625,116),
(3317,1,1,1,1,0620,40),
(2281,1,1,1,2,0620,34),
(4424,1,1,1,3,0620,15),
(4424,1,1,1,4,0630,115),
(2212,1,1,1,5,0615,94),
(2758,1,1,1,6,0440,93),
(2758,1,1,1,1,0430,43),
(2758,1,1,1,2,0615,112),
(2282,1,1,1,3,0410,65),
(2281,1,1,1,4,0620,73),
(2282,1,1,1,5,0410,88),
(2281,1,1,1,6,0415,44),
(2281,1,1,1,1,0420,69),
(4424,1,1,1,2,0415,68),
(2763,1,1,1,3,0420,86),
(3317,1,1,1,4,0615,74),
(2747,1,1,1,5,0630,62),
(2281,1,1,1,6,0625,79),
(2281,1,1,1,1,0410,94),
(2281,1,1,1,2,0615,48),
(2281,1,1,1,3,0625,101),
(4424,1,1,1,4,0610,41),
(2334,1,1,1,5,0640,21),
(2281,1,1,1,6,0630,96),
(3317,1,1,1,1,0620,123),
(2281,1,1,1,2,0640,112),
(2758,1,1,1,3,0620,124),
(4424,1,1,1,4,0610,119),
(2282,1,1,1,5,0625,114),
(2747,1,1,1,6,0615,109),
(2212,1,1,1,1,0615,105),
(2281,1,1,1,2,0425,40),
(2281,1,1,1,3,0640,90),
(3317,1,1,1,4,0625,86),
(2281,1,1,1,5,0415,93),
(2747,1,1,1,6,0625,54),
(2747,1,1,1,1,0615,29),
(2281,1,1,1,2,0630,75),
(4424,1,1,1,3,0415,122),
(2747,1,1,1,4,0620,78),
(2281,1,1,1,5,0615,28),
(2758,1,1,1,6,0610,18),
(2747,1,1,1,1,0630,60),
(2212,1,1,1,2,0610,45),
(2281,1,1,1,3,0430,114),
(2281,1,1,1,4,0625,77),
(4424,1,1,1,5,0625,61),
(2334,1,1,1,6,0610,61),
(2281,1,1,1,1,0625,82),
(4424,1,1,1,2,0420,112),
(2212,1,1,1,3,0415,125),
(2747,1,1,1,4,0620,29),
(2281,1,1,1,5,0615,60),
(2747,1,1,1,6,0440,79),
(2281,1,1,1,1,0620,83),
(2281,1,1,1,2,0610,117),
(2281,1,1,1,3,0640,28),
(2747,1,1,1,4,0630,119),
(2758,1,1,1,5,0415,53),
(2763,1,1,1,6,0620,94),
(2281,1,1,1,1,0625,43),
(2763,1,1,1,2,0440,87),
(2281,1,1,1,3,0430,50),
(2281,1,1,1,4,0440,56),
(2758,1,1,1,5,0610,22),
(3317,1,1,1,6,0615,22),
(2758,1,1,1,1,0615,62),
(2281,1,1,1,2,0615,35),
(2334,1,1,1,3,0430,78),
(2281,1,1,1,4,0630,25),
(4424,1,1,1,5,0630,75),
(2281,1,1,1,6,0410,93),
(4424,1,1,1,1,0610,108),
(2747,1,1,1,2,0610,115),
(2281,1,1,1,3,0640,55),
(3317,1,1,1,4,0640,106),
(2747,1,1,1,5,0430,93),
(3317,1,1,1,6,0425,69),
(2212,1,1,1,1,0615,85),
(2281,1,1,1,2,0420,29),
(3317,1,1,1,3,0420,96),
(2758,1,1,1,4,0440,69),
(2281,1,1,1,5,0425,69),
(2282,1,1,1,6,0610,34),
(2758,1,1,1,1,0630,61),
(2747,1,1,1,2,0440,25),
(2750,1,1,1,3,0615,23),
(4424,1,1,1,4,0415,84),
(2281,1,1,1,5,0610,95),
(2747,1,1,1,6,0615,36),
(4424,1,1,1,1,0630,26),
(2758,1,1,1,2,0615,25),
(4424,1,1,1,3,0415,90),
(2281,1,1,1,4,0425,87),
(2763,1,1,1,5,0420,59),
(3317,1,1,1,6,0410,19),
(2282,1,1,1,1,0620,125),
(2212,1,1,1,2,0625,30),
(4424,1,1,1,3,0630,85),
(2281,1,1,1,4,0430,56),
(3317,1,1,1,5,0625,22),
(2281,1,1,1,6,0440,116),
(2334,1,1,1,1,0610,63),
(4424,1,1,1,2,0630,124),
(2763,1,1,1,3,0610,68),
(2282,1,1,1,4,0615,40),
(4424,1,1,1,5,0615,109),
(2747,1,1,1,6,0430,120),
(4424,1,1,1,1,0625,32),
(2281,1,1,1,2,0640,23),
(2747,1,1,1,3,0620,27),
(2758,1,1,1,4,0620,28),
(4424,1,1,1,5,0640,31),
(3317,1,1,1,6,0640,102),
(2281,1,1,1,1,0610,64),
(2281,1,1,1,2,0630,83),
(2281,1,1,1,3,0625,30),
(2758,1,1,1,4,0420,42),
(3317,1,1,1,5,0430,62),
(2281,1,1,1,6,0625,103),
(2281,1,1,1,1,0615,44),
(4424,1,1,1,2,0625,47),
(2758,1,1,1,3,0425,40),
(2281,1,1,1,4,0630,75),
(2747,1,1,1,5,0620,82),
(2281,1,1,1,6,0625,94),
(2282,1,1,1,1,0410,92),
(2212,1,1,1,2,0610,90),
(2747,1,1,1,3,0625,125),
(2281,1,1,1,4,0625,21),
(2281,1,1,1,5,0440,65),
(2747,1,1,1,6,0625,117),
(2747,1,1,1,1,0420,54),
(2281,1,1,1,2,0410,120),
(2758,1,1,1,3,0610,69),
(2281,1,1,1,4,0610,80),
(2281,1,1,1,5,0610,23),
(4424,1,1,1,6,0610,84),
(2281,1,1,1,1,0630,104),
(2282,1,1,1,2,0620,85),
(2334,1,1,1,3,0620,108),
(3317,1,1,1,4,0630,44),
(2282,1,1,1,5,0620,33),
(2763,1,1,1,6,0630,76),
(4424,1,1,1,1,0415,49),
(2282,1,1,1,2,0620,46),
(2758,1,1,1,3,0610,76),
(2747,1,1,1,4,0640,89),
(3317,1,1,1,5,0610,18),
(2281,1,1,1,6,0410,22),
(2281,1,1,1,1,0640,70),
(3317,1,1,1,2,0420,50),
(2747,1,1,1,3,0420,30),
(2758,1,1,1,4,0410,78),
(2758,1,1,1,5,0440,93),
(3317,1,1,1,6,0610,93),
(4424,1,1,1,1,0630,62),
(2758,1,1,1,2,0625,94),
(4424,1,1,1,3,0615,73),
(2281,1,1,1,4,0425,108),
(2747,1,1,1,5,0620,59),
(2758,1,1,1,6,0620,125),
(2281,1,1,1,1,0610,38),
(2750,1,1,1,2,0420,50),
(2281,1,1,1,3,0440,121),
(4424,1,1,1,4,0615,118),
(2281,1,1,1,5,0440,114),
(2747,1,1,1,6,0640,102),
(2747,1,1,1,1,0625,66),
(3317,1,1,1,2,0410,121),
(2212,1,1,1,3,0630,95),
(2212,1,1,1,4,0620,92),
(2281,1,1,1,5,0415,105),
(4424,1,1,1,6,0625,95),
(2763,1,1,1,1,0420,48),
(2281,1,1,1,2,0615,54),
(2758,1,1,1,3,0640,48),
(3317,1,1,1,4,0615,73),
(2281,1,1,1,5,0640,94),
(4424,1,1,1,6,0615,100),
(2281,1,1,1,1,0640,47),
(2750,1,1,1,2,0630,64),
(3317,1,1,1,3,0630,99),
(2282,1,1,1,4,0420,24),
(4424,1,1,1,5,0410,35),
(2758,1,1,1,6,0615,121),
(2212,1,1,1,1,0630,64),
(2281,1,1,1,2,0625,30),
(2747,1,1,1,3,0630,24),
(4424,1,1,1,4,0615,59),
(2758,1,1,1,5,0615,15),
(2334,1,1,1,6,0625,16),
(2281,1,1,1,1,0625,124),
(2758,1,1,1,2,0410,73),
(2281,1,1,1,3,0425,22),
(2212,1,1,1,4,0425,57),
(4424,1,1,1,5,0625,122),
(2758,1,1,1,6,0625,21),
(3317,1,1,1,1,0615,52),
(2281,1,1,1,2,0625,70),
(2763,1,1,1,3,0640,51),
(4424,1,1,1,4,0625,91),
(2282,1,1,1,5,0610,28),
(2281,1,1,1,6,0630,77),
(2281,1,1,1,1,0620,25),
(2281,1,1,1,2,0415,60),
(4424,1,1,1,3,0615,28),
(2747,1,1,1,4,0630,119),
(2747,1,1,1,5,0430,61),
(4424,1,1,1,6,0610,39),
(2763,1,1,1,1,0440,93),
(2747,1,1,1,2,0625,26),
(2281,1,1,1,3,0615,40),
(2758,1,1,1,4,0610,86),
(4424,1,1,1,5,0420,19),
(2758,1,1,1,6,0620,81),
(2281,1,1,1,1,0430,75),
(2747,1,1,1,2,0640,118),
(3317,1,1,1,3,0415,22),
(3317,1,1,1,4,0630,41),
(2281,1,1,1,5,0430,36),
(2758,1,1,1,6,0640,20),
(3317,1,1,1,1,0610,102),
(3317,1,1,1,2,0615,104),
(2281,1,1,1,3,0625,16),
(2747,1,1,1,4,0620,92),
(2281,1,1,1,5,0425,92),
(2281,1,1,1,6,0640,94),
(2281,1,1,1,1,0425,56),
(2281,1,1,1,2,0430,88),
(2212,1,1,1,3,0610,38),
(3317,1,1,1,4,0425,121),
(2281,1,1,1,5,0620,112),
(2747,1,1,1,6,0620,71),
(2281,1,1,1,1,0615,31),
(2281,1,1,1,2,0415,36),
(2212,1,1,1,3,0420,102),
(2281,1,1,1,4,0640,93),
(2281,1,1,1,5,0425,116),
(4424,1,1,1,6,0640,65),
(2747,1,1,1,1,0630,87),
(2281,1,1,1,2,0440,87),
(2758,1,1,1,3,0615,94),
(2334,1,1,1,4,0415,20),
(2747,1,1,1,5,0630,88),
(4424,1,1,1,6,0440,112),
(4424,1,1,1,1,0625,118),
(2747,1,1,1,2,0620,21),
(2281,1,1,1,3,0430,45),
(2281,1,1,1,4,0615,33),
(2281,1,1,1,5,0415,101),
(2747,1,1,1,6,0630,106),
(2281,1,1,1,1,0620,117),
(2282,1,1,1,2,0625,51),
(2212,1,1,1,3,0625,21),
(2212,1,1,1,4,0610,82),
(2750,1,1,1,5,0620,26),
(2747,1,1,1,6,0625,110),
(2747,1,1,1,1,0425,75),
(3317,1,1,1,2,0615,26),
(2281,1,1,1,3,0415,76),
(2282,1,1,1,4,0630,105),
(2281,1,1,1,5,0430,29),
(2758,1,1,1,6,0410,71),
(2758,1,1,1,1,0620,46),
(3317,1,1,1,2,0625,122),
(2281,1,1,1,3,0610,112),
(2281,1,1,1,4,0625,38),
(2282,1,1,1,5,0410,59),
(4424,1,1,1,6,0430,83),
(3317,1,1,1,1,0415,85),
(2281,1,1,1,2,0410,70),
(4424,1,1,1,3,0425,19),
(2281,1,1,1,4,0625,49),
(4424,1,1,1,5,0625,81),
(3317,1,1,1,6,0640,84),
(2281,1,1,1,1,0615,48),
(2763,1,1,1,2,0630,61),
(2747,1,1,1,3,0615,70),
(2747,1,1,1,4,0620,71),
(2747,1,1,1,5,0615,75),
(2281,1,1,1,6,0625,67),
(4424,1,1,1,1,0440,45),
(2281,1,1,1,2,0630,117),
(2281,1,1,1,3,0420,50),
(4424,1,1,1,4,0640,108),
(2282,1,1,1,5,0610,35),
(3317,1,1,1,6,0630,77),
(2747,1,1,1,1,0610,82),
(2334,1,1,1,2,0640,26),
(2281,1,1,1,3,0430,64),
(2758,1,1,1,4,0610,26),
(2747,1,1,1,5,0615,71),
(2747,1,1,1,6,0410,100),
(2747,1,1,1,1,0640,48),
(2758,1,1,1,2,0620,59),
(2281,1,1,1,3,0640,62),
(2281,1,1,1,4,0620,55),
(2281,1,1,1,5,0615,44),
(4424,1,1,1,6,0440,85),
(2758,1,1,1,1,0610,60),
(2281,1,1,1,2,0610,41),
(2212,1,1,1,3,0625,33),
(2281,1,1,1,4,0610,37),
(2747,1,1,1,5,0625,33),
(2763,1,1,1,6,0440,100),
(2281,1,1,1,1,0610,75),
(2758,1,1,1,2,0440,18),
(2750,1,1,1,3,0625,35),
(2758,1,1,1,4,0425,29),
(2281,1,1,1,5,0610,73),
(4424,1,1,1,6,0625,53),
(2281,1,1,1,1,0415,117),
(2281,1,1,1,2,0425,35),
(2281,1,1,1,3,0420,77),
(2334,1,1,1,4,0620,87),
(2282,1,1,1,5,0625,108),
(2758,1,1,1,6,0630,110),
(2747,1,1,1,1,0640,75),
(2281,1,1,1,2,0640,113),
(4424,1,1,1,3,0615,22),
(2281,1,1,1,4,0630,74),
(2281,1,1,1,5,0610,17),
(4424,1,1,1,6,0640,72),
(3317,1,1,1,1,0610,25),
(2212,1,1,1,2,0440,124),
(2281,1,1,1,3,0425,92),
(3317,1,1,1,4,0640,51),
(2281,1,1,1,5,0620,17),
(2281,1,1,1,6,0640,106),
(2758,1,1,1,1,0610,35),
(2763,1,1,1,2,0610,55),
(4424,1,1,1,3,0625,79),
(2282,1,1,1,4,0430,66),
(2281,1,1,1,5,0615,76),
(4424,1,1,1,6,0440,99),
(2747,1,1,1,1,0640,110),
(3317,1,1,1,2,0625,122),
(2747,1,1,1,3,0440,107),
(2758,1,1,1,4,0620,78),
(2281,1,1,1,5,0625,47),
(3317,1,1,1,6,0625,28),
(2281,1,1,1,1,0615,51),
(2758,1,1,1,2,0615,84),
(2281,1,1,1,3,0620,64),
(2281,1,1,1,4,0625,101),
(3317,1,1,1,5,0610,116),
(2758,1,1,1,6,0610,99),
(3317,1,1,1,1,0625,122),
(2281,1,1,1,2,0430,23),
(2763,1,1,1,3,0640,117),
(2281,1,1,1,4,0440,90),
(2747,1,1,1,5,0620,80),
(2281,1,1,1,6,0425,93),
(2282,1,1,1,1,0625,69),
(2758,1,1,1,2,0620,95),
(2763,1,1,1,3,0640,106),
(2281,1,1,1,4,0625,34),
(4424,1,1,1,5,0410,19),
(4424,1,1,1,6,0640,75),
(2281,1,1,1,1,0620,50),
(2281,1,1,1,2,0630,17),
(2281,1,1,1,3,0625,123),
(3317,1,1,1,4,0630,74),
(4424,1,1,1,5,0625,77),
(2281,1,1,1,6,0440,106),
(2758,1,1,1,1,0630,61),
(2281,1,1,1,2,0630,16),
(2763,1,1,1,3,0415,45),
(2747,1,1,1,4,0410,91),
(2281,1,1,1,5,0625,97),
(2758,1,1,1,6,0640,35),
(2763,1,1,1,1,0640,35),
(2747,1,1,1,2,0640,50),
(2212,1,1,1,3,0620,76),
(4424,1,1,1,4,0630,100),
(2334,1,1,1,5,0630,105),
(3317,1,1,1,6,0640,91),
(3317,1,1,1,1,0420,60),
(2758,1,1,1,2,0430,113),
(2281,1,1,1,3,0615,122),
(4424,1,1,1,4,0620,97),
(4424,1,1,1,5,0615,28),
(2281,1,1,1,6,0410,89),
(3317,1,1,1,1,0640,46),
(2334,1,1,1,2,0410,94),
(2212,1,1,1,3,0430,111),
(2281,1,1,1,4,0610,68),
(2281,1,1,1,5,0625,87),
(4424,1,1,1,6,0440,38),
(2281,1,1,1,1,0615,92),
(2747,1,1,1,2,0430,65),
(2758,1,1,1,3,0625,112),
(2747,1,1,1,4,0615,98),
(4424,1,1,1,5,0630,116),
(2281,1,1,1,6,0630,15),
(2758,1,1,1,1,0615,22),
(2747,1,1,1,2,0440,77),
(2281,1,1,1,3,0440,117),
(2747,1,1,1,4,0610,58),
(2212,1,1,1,5,0630,73),
(2747,1,1,1,6,0610,97),
(3317,1,1,1,1,0440,16),
(4424,1,1,1,2,0440,111),
(3317,1,1,1,3,0410,79),
(2758,1,1,1,4,0425,39),
(4424,1,1,1,5,0410,100),
(2281,1,1,1,6,0440,21),
(2747,1,1,1,1,0410,75),
(2281,1,1,1,2,0420,70),
(2281,1,1,1,3,0625,121),
(2281,1,1,1,4,0615,58),
(2747,1,1,1,5,0430,38),
(4424,1,1,1,6,0410,66),
(2763,1,1,1,1,0430,25),
(2763,1,1,1,2,0640,26),
(2281,1,1,1,3,0410,32),
(2281,1,1,1,4,0640,36),
(2758,1,1,1,5,0425,77),
(2212,1,1,1,6,0625,54),
(2281,1,1,1,1,0615,83),
(2747,1,1,1,2,0610,53),
(2282,1,1,1,3,0425,94),
(2281,1,1,1,4,0415,23),
(2281,1,1,1,5,0620,47),
(3317,1,1,1,6,0425,87),
(2212,1,1,1,1,0620,85),
(4424,1,1,1,2,0640,35),
(2281,1,1,1,3,0620,54),
(2334,1,1,1,4,0425,86),
(2281,1,1,1,5,0425,22),
(2281,1,1,1,6,0440,98),
(2758,1,1,1,1,0410,118),
(2282,1,1,1,2,0640,22),
(3317,1,1,1,3,0615,95),
(2763,1,1,1,4,0415,117),
(2747,1,1,1,5,0420,44),
(2281,1,1,1,6,0625,120),
(2758,1,1,1,1,0630,112),
(2281,1,1,1,2,0620,78),
(2212,1,1,1,3,0410,21),
(2747,1,1,1,4,0425,92),
(4424,1,1,1,5,0430,73),
(2747,1,1,1,6,0615,54),
(2758,1,1,1,1,0640,75),
(2282,1,1,1,2,0430,113),
(2758,1,1,1,3,0625,120),
(2334,1,1,1,4,0640,55),
(2281,1,1,1,5,0610,56),
(2281,1,1,1,6,0430,103),
(2281,1,1,1,1,0610,24),
(3317,1,1,1,2,0615,80),
(4424,1,1,1,3,0420,72),
(4424,1,1,1,4,0440,18),
(2281,1,1,1,5,0430,59),
(2212,1,1,1,6,0620,87),
(2750,1,1,1,1,0625,25),
(3317,1,1,1,2,0640,122),
(3317,1,1,1,3,0410,102),
(3317,1,1,1,4,0610,47),
(2281,1,1,1,5,0630,42),
(2281,1,1,1,6,0640,40),
(2282,1,1,1,1,0630,82),
(2281,1,1,1,2,0610,111),
(2212,1,1,1,3,0625,74),
(2281,1,1,1,4,0625,92),
(2758,1,1,1,5,0620,35),
(4424,1,1,1,6,0610,106),
(4424,1,1,1,1,0440,23),
(2281,1,1,1,2,0415,30),
(3317,1,1,1,3,0630,118),
(2758,1,1,1,4,0430,39),
(2282,1,1,1,5,0425,109),
(2758,1,1,1,6,0625,116),
(2747,1,1,1,1,0440,88),
(2281,1,1,1,2,0615,123),
(2281,1,1,1,3,0620,103),
(2281,1,1,1,4,0640,114),
(2747,1,1,1,5,0425,23),
(2334,1,1,1,6,0615,116),
(2747,1,1,1,1,0430,115),
(3317,1,1,1,2,0620,64),
(2758,1,1,1,3,0630,115),
(2758,1,1,1,4,0610,29),
(2747,1,1,1,5,0625,24),
(2282,1,1,1,6,0415,30),
(2281,1,1,1,1,0625,72),
(2281,1,1,1,2,0625,18),
(2282,1,1,1,3,0625,37),
(2758,1,1,1,4,0410,61),
(2747,1,1,1,5,0610,80),
(2747,1,1,1,6,0415,21),
(3317,1,1,1,1,0610,68),
(4424,1,1,1,2,0640,106),
(2747,1,1,1,3,0610,119),
(2282,1,1,1,4,0420,99),
(2763,1,1,1,5,0630,55),
(2281,1,1,1,6,0630,78),
(2281,1,1,1,1,0415,53),
(2281,1,1,1,2,0615,57),
(3317,1,1,1,3,0630,100),
(2281,1,1,1,4,0610,69),
(4424,1,1,1,5,0620,111),
(2281,1,1,1,6,0420,21),
(2281,1,1,1,1,0425,96),
(2281,1,1,1,2,0630,102),
(2758,1,1,1,3,0420,109),
(2758,1,1,1,4,0610,51),
(2758,1,1,1,5,0610,107),
(2750,1,1,1,6,0640,119),
(2212,1,1,1,1,0620,102),
(2747,1,1,1,2,0615,77),
(3317,1,1,1,3,0615,44),
(2758,1,1,1,4,0620,88),
(3317,1,1,1,5,0430,32),
(2281,1,1,1,6,0425,89),
(2758,1,1,1,1,0630,29),
(2281,1,1,1,2,0610,59),
(3317,1,1,1,3,0610,103),
(2212,1,1,1,4,0410,97),
(2747,1,1,1,5,0610,48),
(2747,1,1,1,6,0410,15),
(2281,1,1,1,1,0640,31),
(2281,1,1,1,2,0415,92),
(4424,1,1,1,3,0440,85),
(2281,1,1,1,4,0610,86),
(2281,1,1,1,5,0410,21),
(2282,1,1,1,6,0440,102),
(2763,1,1,1,1,0640,58),
(2281,1,1,1,2,0410,109),
(2281,1,1,1,3,0610,28),
(2747,1,1,1,4,0610,42),
(2758,1,1,1,5,0615,57),
(2747,1,1,1,6,0610,78),
(4424,1,1,1,1,0625,73),
(2281,1,1,1,2,0425,81),
(2282,1,1,1,3,0625,58),
(2212,1,1,1,4,0640,76),
(2758,1,1,1,5,0615,53),
(2281,1,1,1,6,0625,28),
(3317,1,1,1,1,0420,121),
(4424,1,1,1,2,0420,68),
(4424,1,1,1,3,0610,38),
(2758,1,1,1,4,0415,56),
(2281,1,1,1,5,0430,32),
(2758,1,1,1,6,0630,113),
(2281,1,1,1,1,0620,17),
(2750,1,1,1,2,0625,17),
(2334,1,1,1,3,0410,85),
(4424,1,1,1,4,0420,108),
(2282,1,1,1,5,0610,31),
(2758,1,1,1,6,0640,85),
(2281,1,1,1,1,0630,57),
(3317,1,1,1,2,0610,45),
(2747,1,1,1,3,0610,81),
(4424,1,1,1,4,0410,18),
(2212,1,1,1,5,0610,39),
(2212,1,1,1,6,0430,96),
(2281,1,1,1,1,0630,121),
(4424,1,1,1,2,0430,45),
(2763,1,1,1,3,0615,67),
(3317,1,1,1,4,0640,26),
(2281,1,1,1,5,0440,44),
(2281,1,1,1,6,0415,27),
(2281,1,1,1,1,0615,73),
(2747,1,1,1,2,0630,24),
(2282,1,1,1,3,0610,53),
(3317,1,1,1,4,0625,34),
(2281,1,1,1,5,0610,82),
(2281,1,1,1,6,0440,27),
(4424,1,1,1,1,0420,124),
(2747,1,1,1,2,0640,21),
(4424,1,1,1,3,0615,19),
(2758,1,1,1,4,0610,84),
(2747,1,1,1,5,0620,112),
(2758,1,1,1,6,0430,45),
(3317,1,1,1,1,0420,111),
(2758,1,1,1,2,0420,32),
(2758,1,1,1,3,0640,73),
(2281,1,1,1,4,0410,113),
(4424,1,1,1,5,0625,24),
(2758,1,1,1,6,0425,115),
(2281,1,1,1,1,0610,103),
(2281,1,1,1,2,0620,41),
(2281,1,1,1,3,0430,111),
(3317,1,1,1,4,0420,18),
(2282,1,1,1,5,0610,78),
(2747,1,1,1,6,0610,21),
(2747,1,1,1,1,0615,92),
(2281,1,1,1,2,0430,78),
(2281,1,1,1,3,0630,100),
(2212,1,1,1,4,0610,104),
(2281,1,1,1,5,0410,118),
(3317,1,1,1,6,0620,20),
(2282,1,1,1,1,0640,22),
(2758,1,1,1,2,0630,16),
(2763,1,1,1,3,0620,22),
(3317,1,1,1,4,0415,59),
(2747,1,1,1,5,0415,76),
(2758,1,1,1,6,0440,52),
(2747,1,1,1,1,0615,125),
(2281,1,1,1,2,0430,16),
(4424,1,1,1,3,0620,98),
(2281,1,1,1,4,0610,49),
(2747,1,1,1,5,0615,85),
(2758,1,1,1,6,0430,62),
(2212,1,1,1,1,0630,72),
(2747,1,1,1,2,0420,114),
(3317,1,1,1,3,0425,40),
(2281,1,1,1,4,0610,125),
(2281,1,1,1,5,0625,27),
(2281,1,1,1,6,0410,95),
(2281,1,1,1,1,0610,38),
(2281,1,1,1,2,0615,24),
(4424,1,1,1,3,0640,92),
(2282,1,1,1,4,0430,43),
(2281,1,1,1,5,0415,59),
(2758,1,1,1,6,0625,70),
(2758,1,1,1,1,0420,37),
(2763,1,1,1,2,0410,76),
(2281,1,1,1,3,0410,103),
(3317,1,1,1,4,0640,93),
(2281,1,1,1,5,0625,24),
(3317,1,1,1,6,0430,39),
(4424,1,1,1,1,0410,59),
(2747,1,1,1,2,0640,124),
(3317,1,1,1,3,0440,68),
(2281,1,1,1,4,0615,29),
(4424,1,1,1,5,0640,98),
(2281,1,1,1,6,0610,36),
(4424,1,1,1,1,0415,66),
(2747,1,1,1,2,0625,94),
(2334,1,1,1,3,0415,52),
(2758,1,1,1,4,0415,82),
(2747,1,1,1,5,0610,41),
(2747,1,1,1,6,0630,34),
(4424,1,1,1,1,0610,19),
(2747,1,1,1,2,0430,71),
(2281,1,1,1,3,0420,42),
(2212,1,1,1,4,0625,94),
(2281,1,1,1,5,0630,89),
(3317,1,1,1,6,0620,84),
(2281,1,1,1,1,0615,30),
(2212,1,1,1,2,0630,48),
(2758,1,1,1,3,0415,33),
(2282,1,1,1,4,0615,22),
(2212,1,1,1,5,0610,70),
(3317,1,1,1,6,0610,73),
(4424,1,1,1,1,0415,48),
(2758,1,1,1,2,0415,109),
(2750,1,1,1,3,0630,88),
(2281,1,1,1,4,0425,48),
(2747,1,1,1,5,0610,72),
(2281,1,1,1,6,0625,85),
(2281,1,1,1,1,0615,78),
(2747,1,1,1,2,0425,40),
(4424,1,1,1,3,0440,100),
(2281,1,1,1,4,0630,124),
(2281,1,1,1,5,0640,28),
(2281,1,1,1,6,0620,50),
(2281,1,1,1,1,0440,48),
(4424,1,1,1,2,0610,124),
(3317,1,1,1,3,0410,31),
(2747,1,1,1,4,0615,107),
(2281,1,1,1,5,0420,92),
(4424,1,1,1,6,0415,42),
(2281,1,1,1,1,0640,80),
(2281,1,1,1,2,0620,113),
(2747,1,1,1,3,0610,88),
(2281,1,1,1,4,0440,28),
(3317,1,1,1,5,0430,78),
(2750,1,1,1,6,0620,53),
(2281,1,1,1,1,0620,31),
(2281,1,1,1,2,0410,101),
(2758,1,1,1,3,0610,24),
(2212,1,1,1,4,0620,25),
(2212,1,1,1,5,0615,111),
(2747,1,1,1,6,0610,75),
(2281,1,1,1,1,0630,26),
(4424,1,1,1,2,0425,24),
(2747,1,1,1,3,0615,72),
(2334,1,1,1,4,0630,100),
(2281,1,1,1,5,0430,40),
(2282,1,1,1,6,0415,38),
(2281,1,1,1,1,0415,35),
(4424,1,1,1,2,0610,114),
(2281,1,1,1,3,0630,74),
(2758,1,1,1,4,0640,78),
(2281,1,1,1,5,0410,47),
(2281,1,1,1,6,0625,73),
(2212,1,1,1,1,0630,55),
(3317,1,1,1,2,0610,79),
(2763,1,1,1,3,0625,113),
(2747,1,1,1,4,0625,17),
(2747,1,1,1,5,0640,16),
(3317,1,1,1,6,0625,42),
(2281,1,1,1,1,0620,35),
(2758,1,1,1,2,0625,90),
(2747,1,1,1,3,0620,52),
(2282,1,1,1,4,0610,117),
(2747,1,1,1,5,0415,86),
(3317,1,1,1,6,0610,65),
(4424,1,1,1,1,0440,55),
(4424,1,1,1,2,0430,120),
(3317,1,1,1,3,0615,81),
(2281,1,1,1,4,0620,59),
(2747,1,1,1,5,0610,61),
(2758,1,1,1,6,0610,60),
(2212,1,1,1,1,0610,113),
(2281,1,1,1,2,0640,23),
(4424,1,1,1,3,0615,111),
(2758,1,1,1,4,0625,102),
(3317,1,1,1,5,0415,59),
(2281,1,1,1,6,0620,82),
(2212,1,1,1,1,0610,117),
(3317,1,1,1,2,0410,33),
(2281,1,1,1,3,0615,65),
(2758,1,1,1,4,0610,41),
(2747,1,1,1,5,0410,63),
(2282,1,1,1,6,0620,65),
(2747,1,1,1,1,0615,16),
(2281,1,1,1,2,0440,113),
(2281,1,1,1,3,0430,59),
(2758,1,1,1,4,0420,57),
(4424,1,1,1,5,0615,105),
(2763,1,1,1,6,0610,24),
(2281,1,1,1,1,0625,29),
(2281,1,1,1,2,0615,121),
(4424,1,1,1,3,0430,76),
(2281,1,1,1,4,0620,115),
(2281,1,1,1,5,0415,44),
(3317,1,1,1,6,0430,87),
(4424,1,1,1,1,0640,46),
(2758,1,1,1,2,0430,23),
(3317,1,1,1,3,0610,118),
(2281,1,1,1,4,0625,41),
(2747,1,1,1,5,0440,116),
(4424,1,1,1,6,0425,116),
(2212,1,1,1,1,0610,114),
(2281,1,1,1,2,0625,113),
(2758,1,1,1,3,0425,35),
(2281,1,1,1,4,0620,29),
(2281,1,1,1,5,0425,49),
(2334,1,1,1,6,0430,59),
(2758,1,1,1,1,0630,68),
(2281,1,1,1,2,0410,65),
(2282,1,1,1,3,0420,84),
(2747,1,1,1,4,0640,20),
(2758,1,1,1,5,0610,118),
(2281,1,1,1,6,0440,60),
(2758,1,1,1,1,0610,100),
(4424,1,1,1,2,0625,73),
(2281,1,1,1,3,0640,107),
(4424,1,1,1,4,0630,90),
(2281,1,1,1,5,0440,21),
(2281,1,1,1,6,0610,27),
(3317,1,1,1,1,0630,73),
(2281,1,1,1,2,0410,88),
(2747,1,1,1,3,0640,62),
(2747,1,1,1,4,0620,22),
(4424,1,1,1,5,0610,64),
(2282,1,1,1,6,0420,81),
(3317,1,1,1,1,0630,74),
(2281,1,1,1,2,0415,72),
(3317,1,1,1,3,0630,78),
(2758,1,1,1,4,0615,53),
(3317,1,1,1,5,0615,87),
(2281,1,1,1,6,0425,88),
(2758,1,1,1,1,0630,38),
(2281,1,1,1,2,0610,30),
(2281,1,1,1,3,0430,72),
(2758,1,1,1,4,0615,39),
(2747,1,1,1,5,0430,104),
(2281,1,1,1,6,0420,77),
(2747,1,1,1,1,0615,21),
(2281,1,1,1,2,0420,63),
(2281,1,1,1,3,0440,79),
(2758,1,1,1,4,0625,95),
(2281,1,1,1,5,0610,35),
(2212,1,1,1,6,0420,110),
(4424,1,1,1,1,0625,61),
(2747,1,1,1,2,0615,41),
(2281,1,1,1,3,0410,94),
(2750,1,1,1,4,0425,117),
(4424,1,1,1,5,0620,72),
(2212,1,1,1,6,0610,90),
(4424,1,1,1,1,0430,20),
(2281,1,1,1,2,0625,110),
(2281,1,1,1,3,0640,50),
(2282,1,1,1,4,0420,105),
(2281,1,1,1,5,0625,61),
(4424,1,1,1,6,0415,22),
(2281,1,1,1,1,0420,39),
(2281,1,1,1,2,0610,33),
(2281,1,1,1,3,0440,29),
(2758,1,1,1,4,0625,125),
(2334,1,1,1,5,0620,43),
(4424,1,1,1,6,0615,125),
(2281,1,1,1,1,0615,80),
(4424,1,1,1,2,0440,93),
(2281,1,1,1,3,0640,74),
(3317,1,1,1,4,0620,23),
(2281,1,1,1,5,0620,81),
(2282,1,1,1,6,0630,117),
(2763,1,1,1,1,0640,61),
(2758,1,1,1,2,0425,75),
(2281,1,1,1,3,0420,102),
(4424,1,1,1,4,0425,118),
(2758,1,1,1,5,0430,119),
(2758,1,1,1,6,0615,33),
(3317,1,1,1,1,0415,36),
(2281,1,1,1,2,0615,104),
(2758,1,1,1,3,0630,23),
(2282,1,1,1,4,0630,89),
(2282,1,1,1,5,0410,51),
(3317,1,1,1,6,0630,116),
(4424,1,1,1,1,0630,120),
(4424,1,1,1,2,0415,37),
(2747,1,1,1,3,0625,22),
(2747,1,1,1,4,0410,41),
(2758,1,1,1,5,0640,94),
(4424,1,1,1,6,0625,68),
(2747,1,1,1,1,0625,88),
(2281,1,1,1,2,0640,57),
(2334,1,1,1,3,0625,89),
(2212,1,1,1,4,0640,60),
(2747,1,1,1,5,0440,100),
(2281,1,1,1,6,0415,116),
(2212,1,1,1,1,0610,88),
(2763,1,1,1,2,0610,65),
(2758,1,1,1,3,0620,28),
(2281,1,1,1,4,0620,43),
(2282,1,1,1,5,0430,54),
(2281,1,1,1,6,0415,94),
(4424,1,1,1,1,0630,72),
(4424,1,1,1,2,0625,79),
(2282,1,1,1,3,0430,93),
(2747,1,1,1,4,0420,116),
(3317,1,1,1,5,0630,16),
(2281,1,1,1,6,0610,73),
(2212,1,1,1,1,0625,58),
(4424,1,1,1,2,0625,125),
(3317,1,1,1,3,0620,79),
(2281,1,1,1,4,0640,81),
(2281,1,1,1,5,0630,40),
(2763,1,1,1,6,0430,80),
(2281,1,1,1,1,0610,71),
(2747,1,1,1,2,0610,61),
(4424,1,1,1,3,0425,43),
(2758,1,1,1,4,0420,93),
(2758,1,1,1,5,0430,60),
(2282,1,1,1,6,0610,49),
(2281,1,1,1,1,0410,45),
(2750,1,1,1,2,0615,100),
(2281,1,1,1,3,0640,57),
(2281,1,1,1,4,0425,21),
(4424,1,1,1,5,0440,99),
(2758,1,1,1,6,0640,28),
(2281,1,1,1,1,0620,116),
(2758,1,1,1,2,0415,64),
(4424,1,1,1,3,0620,52),
(2212,1,1,1,4,0420,17),
(4424,1,1,1,5,0625,49),
(3317,1,1,1,6,0620,109),
(2281,1,1,1,1,0630,56),
(2758,1,1,1,2,0620,94),
(2281,1,1,1,3,0640,91),
(2281,1,1,1,4,0610,93),
(4424,1,1,1,5,0620,115),
(2747,1,1,1,6,0630,82),
(2758,1,1,1,1,0620,67),
(3317,1,1,1,2,0630,123),
(2212,1,1,1,3,0610,107),
(3317,1,1,1,4,0630,90),
(2282,1,1,1,5,0620,113),
(2282,1,1,1,6,0610,67),
(2758,1,1,1,1,0425,79),
(2758,1,1,1,2,0630,33),
(2763,1,1,1,3,0615,39),
(2747,1,1,1,4,0415,53),
(4424,1,1,1,5,0625,51),
(2281,1,1,1,6,0430,95),
(2758,1,1,1,1,0625,22),
(4424,1,1,1,2,0425,74),
(2281,1,1,1,3,0640,43),
(2750,1,1,1,4,0615,26),
(2281,1,1,1,5,0615,74),
(2747,1,1,1,6,0425,104),
(4424,1,1,1,1,0425,88),
(2281,1,1,1,2,0615,88),
(4424,1,1,1,3,0425,53),
(2763,1,1,1,4,0640,22),
(3317,1,1,1,5,0625,97),
(2747,1,1,1,6,0415,119),
(2334,1,1,1,1,0640,74),
(2281,1,1,1,2,0630,97),
(2281,1,1,1,3,0615,118),
(3317,1,1,1,4,0425,109),
(2747,1,1,1,5,0630,43),
(2282,1,1,1,6,0420,95),
(2212,1,1,1,1,0430,99),
(2281,1,1,1,2,0410,118),
(2758,1,1,1,3,0415,85),
(2281,1,1,1,4,0410,67),
(2747,1,1,1,5,0625,81),
(2758,1,1,1,6,0630,78),
(4424,1,1,1,1,0615,70),
(2758,1,1,1,2,0440,102),
(2763,1,1,1,3,0620,27),
(2758,1,1,1,4,0430,65),
(2281,1,1,1,5,0430,34),
(3317,1,1,1,6,0425,104),
(2281,1,1,1,1,0640,25),
(2281,1,1,1,2,0430,82),
(2763,1,1,1,3,0615,41),
(4424,1,1,1,4,0410,83),
(2747,1,1,1,5,0640,49),
(3317,1,1,1,6,0625,72),
(2747,1,1,1,1,0610,25),
(2281,1,1,1,2,0440,66),
(2750,1,1,1,3,0615,107),
(2758,1,1,1,4,0640,28),
(2747,1,1,1,5,0615,93),
(2758,1,1,1,6,0620,114),
(2281,1,1,1,1,0620,108),
(2758,1,1,1,2,0620,115),
(2281,1,1,1,3,0625,44),
(2281,1,1,1,4,0420,32),
(2763,1,1,1,5,0440,99),
(2750,1,1,1,6,0610,43),
(4424,1,1,1,1,0440,22),
(2281,1,1,1,2,0615,27),
(2281,1,1,1,3,0420,115),
(2281,1,1,1,4,0420,43),
(2282,1,1,1,5,0625,101),
(3317,1,1,1,6,0440,63),
(2282,1,1,1,1,0625,17),
(2212,1,1,1,2,0430,98),
(2747,1,1,1,3,0625,116),
(3317,1,1,1,4,0415,81),
(2281,1,1,1,5,0640,105),
(2758,1,1,1,6,0620,99),
(2281,1,1,1,1,0410,83),
(2281,1,1,1,2,0640,89),
(2763,1,1,1,3,0625,19),
(2747,1,1,1,4,0625,111),
(4424,1,1,1,5,0625,84),
(2281,1,1,1,6,0615,107),
(2747,1,1,1,1,0620,63),
(2747,1,1,1,2,0425,121),
(3317,1,1,1,3,0630,30),
(2758,1,1,1,4,0630,66),
(4424,1,1,1,5,0410,80),
(2281,1,1,1,6,0440,73),
(2281,1,1,1,1,0630,89),
(2281,1,1,1,2,0610,19),
(2281,1,1,1,3,0625,54),
(2281,1,1,1,4,0625,63),
(2758,1,1,1,5,0625,35),
(3317,1,1,1,6,0430,67),
(4424,1,1,1,1,0610,67),
(2747,1,1,1,2,0615,35),
(2747,1,1,1,3,0430,119),
(2334,1,1,1,4,0440,59),
(2758,1,1,1,5,0615,83),
(2281,1,1,1,6,0625,87),
(2282,1,1,1,1,0630,68),
(2281,1,1,1,2,0415,60),
(2212,1,1,1,3,0415,115),
(2758,1,1,1,4,0620,123),
(2281,1,1,1,5,0640,36),
(3317,1,1,1,6,0640,73),
(2758,1,1,1,1,0625,58),
(2758,1,1,1,2,0620,116),
(2281,1,1,1,3,0630,123),
(4424,1,1,1,4,0420,65),
(4424,1,1,1,5,0630,20),
(3317,1,1,1,6,0615,118),
(2212,1,1,1,1,0410,31),
(2282,1,1,1,2,0630,50),
(4424,1,1,1,3,0415,82),
(2281,1,1,1,4,0625,49),
(3317,1,1,1,5,0625,95),
(2750,1,1,1,6,0420,59),
(2747,1,1,1,1,0625,95),
(2763,1,1,1,2,0630,42),
(3317,1,1,1,3,0610,103),
(2281,1,1,1,4,0615,59),
(2281,1,1,1,5,0415,48),
(2281,1,1,1,6,0410,112),
(4424,1,1,1,1,0425,31),
(3317,1,1,1,2,0610,60),
(2747,1,1,1,3,0610,23),
(2758,1,1,1,4,0620,109),
(2281,1,1,1,5,0610,93),
(3317,1,1,1,6,0620,80),
(4424,1,1,1,1,0420,87),
(2758,1,1,1,2,0615,101),
(2281,1,1,1,3,0420,41),
(2747,1,1,1,4,0620,91),
(2281,1,1,1,5,0640,34),
(2281,1,1,1,6,0615,117),
(2747,1,1,1,1,0620,68),
(2282,1,1,1,2,0620,115),
(2281,1,1,1,3,0625,61),
(2763,1,1,1,4,0610,45),
(2750,1,1,1,5,0640,37),
(4424,1,1,1,6,0640,45),
(4424,1,1,1,1,0640,102),
(2747,1,1,1,2,0610,61),
(2334,1,1,1,3,0625,101),
(2747,1,1,1,4,0625,53),
(2763,1,1,1,5,0615,107),
(2747,1,1,1,6,0640,40),
(4424,1,1,1,1,0630,89),
(2281,1,1,1,2,0640,75),
(2281,1,1,1,3,0630,45),
(2747,1,1,1,4,0425,45),
(2758,1,1,1,5,0440,19),
(2747,1,1,1,6,0615,86),
(3317,1,1,1,1,0625,65),
(4424,1,1,1,2,0625,34),
(2758,1,1,1,3,0630,86),
(3317,1,1,1,4,0410,21),
(2212,1,1,1,5,0610,63),
(2747,1,1,1,6,0430,19),
(2281,1,1,1,1,0430,17),
(4424,1,1,1,2,0625,89),
(4424,1,1,1,3,0640,82),
(2281,1,1,1,4,0420,122),
(2281,1,1,1,5,0410,38),
(2747,1,1,1,6,0410,120),
(2758,1,1,1,1,0640,17),
(2758,1,1,1,2,0415,122),
(2281,1,1,1,3,0615,81),
(2281,1,1,1,4,0625,87),
(2282,1,1,1,5,0630,91),
(2281,1,1,1,6,0640,110),
(2281,1,1,1,1,0615,60),
(2747,1,1,1,2,0620,75),
(2281,1,1,1,3,0625,61),
(2758,1,1,1,4,0415,22),
(2212,1,1,1,5,0615,37),
(3317,1,1,1,6,0630,106),
(2747,1,1,1,1,0425,33),
(2750,1,1,1,2,0420,124),
(3317,1,1,1,3,0430,105),
(2281,1,1,1,4,0410,57),
(2758,1,1,1,5,0610,109),
(2281,1,1,1,6,0420,105),
(2282,1,1,1,1,0440,21),
(4424,1,1,1,2,0430,16),
(4424,1,1,1,3,0610,117),
(4424,1,1,1,4,0610,28),
(2758,1,1,1,5,0610,57),
(2281,1,1,1,6,0625,69),
(2747,1,1,1,1,0615,41),
(4424,1,1,1,2,0640,90),
(4424,1,1,1,3,0615,55),
(2763,1,1,1,4,0620,121),
(2281,1,1,1,5,0610,74),
(2747,1,1,1,6,0440,31),
(2758,1,1,1,1,0420,28),
(4424,1,1,1,2,0630,66),
(2281,1,1,1,3,0610,124),
(2281,1,1,1,4,0425,97),
(2281,1,1,1,5,0430,46),
(2281,1,1,1,6,0625,115),
(3317,1,1,1,1,0625,114),
(2281,1,1,1,2,0425,49),
(2282,1,1,1,3,0610,78),
(2281,1,1,1,4,0425,56),
(2281,1,1,1,5,0440,64),
(2747,1,1,1,6,0610,33),
(4424,1,1,1,1,0630,77),
(2758,1,1,1,2,0430,78),
(2747,1,1,1,3,0420,32),
(2282,1,1,1,4,0425,64),
(3317,1,1,1,5,0640,36),
(2281,1,1,1,6,0620,115),
(2281,1,1,1,1,0430,42),
(2281,1,1,1,2,0620,82),
(2281,1,1,1,3,0640,18),
(2212,1,1,1,4,0630,51),
(2758,1,1,1,5,0625,51),
(2281,1,1,1,6,0410,43),
(3317,1,1,1,1,0610,117),
(2763,1,1,1,2,0440,103),
(2758,1,1,1,3,0420,98),
(2750,1,1,1,4,0425,113),
(2758,1,1,1,5,0415,29),
(3317,1,1,1,6,0420,84),
(2763,1,1,1,1,0640,55),
(4424,1,1,1,2,0640,26),
(2281,1,1,1,3,0430,121),
(2750,1,1,1,4,0620,114),
(2281,1,1,1,5,0625,82),
(2281,1,1,1,6,0420,106),
(2747,1,1,1,1,0410,20),
(2334,1,1,1,2,0615,16),
(2281,1,1,1,3,0425,62),
(2763,1,1,1,4,0630,25),
(3317,1,1,1,5,0625,16),
(4424,1,1,1,6,0425,32),
(2763,1,1,1,1,0640,68),
(2281,1,1,1,2,0420,39),
(2747,1,1,1,3,0610,68),
(3317,1,1,1,4,0415,30),
(2747,1,1,1,5,0630,29),
(4424,1,1,1,6,0630,115),
(2747,1,1,1,1,0615,70),
(2281,1,1,1,2,0410,122),
(2281,1,1,1,3,0440,37),
(4424,1,1,1,4,0615,23),
(2758,1,1,1,5,0615,63),
(2281,1,1,1,6,0430,107),
(4424,1,1,1,1,0440,21),
(2282,1,1,1,2,0630,110),
(2758,1,1,1,3,0615,49),
(2281,1,1,1,4,0640,80),
(4424,1,1,1,5,0630,98),
(3317,1,1,1,6,0630,22),
(2281,1,1,1,1,0630,58),
(2281,1,1,1,2,0410,96),
(2282,1,1,1,3,0630,85),
(2747,1,1,1,4,0640,95),
(2334,1,1,1,5,0630,15),
(2282,1,1,1,6,0640,23),
(4424,1,1,1,1,0625,23),
(2281,1,1,1,2,0430,37),
(2281,1,1,1,3,0425,59),
(2282,1,1,1,4,0430,96),
(2212,1,1,1,5,0620,94),
(2758,1,1,1,6,0415,17),
(2281,1,1,1,1,0625,116),
(2758,1,1,1,2,0615,31),
(2758,1,1,1,3,0640,40),
(2758,1,1,1,4,0410,26),
(2281,1,1,1,5,0625,119),
(2281,1,1,1,6,0625,98),
(3317,1,1,1,1,0630,18),
(3317,1,1,1,2,0640,117),
(4424,1,1,1,3,0640,114),
(2758,1,1,1,4,0640,123),
(2758,1,1,1,5,0615,18),
(2758,1,1,1,6,0430,108),
(2747,1,1,1,1,0410,15),
(2758,1,1,1,2,0420,76),
(2758,1,1,1,3,0625,108),
(2763,1,1,1,4,0430,67),
(2282,1,1,1,5,0620,72),
(2281,1,1,1,6,0610,71),
(2281,1,1,1,1,0630,122),
(2282,1,1,1,2,0410,32),
(2763,1,1,1,3,0430,18),
(2281,1,1,1,4,0425,116),
(2281,1,1,1,5,0615,68),
(2281,1,1,1,6,0640,92),
(3317,1,1,1,1,0610,39),
(2281,1,1,1,2,0420,55),
(4424,1,1,1,3,0640,53),
(2750,1,1,1,4,0610,112),
(2212,1,1,1,5,0610,115),
(2281,1,1,1,6,0620,55),
(2281,1,1,1,1,0610,78),
(3317,1,1,1,2,0615,23),
(2282,1,1,1,3,0620,20),
(2281,1,1,1,4,0620,75),
(2747,1,1,1,5,0630,76),
(2747,1,1,1,6,0620,112),
(2763,1,1,1,1,0610,42),
(2758,1,1,1,2,0625,68),
(2281,1,1,1,3,0615,99),
(2281,1,1,1,4,0430,104),
(2281,1,1,1,5,0610,81),
(2282,1,1,1,6,0625,25),
(2747,1,1,1,1,0640,93),
(2281,1,1,1,2,0420,76),
(2758,1,1,1,3,0610,63),
(2747,1,1,1,4,0620,82),
(2281,1,1,1,5,0620,54),
(4424,1,1,1,6,0610,87),
(4424,1,1,1,1,0420,74),
(4424,1,1,1,2,0630,83),
(3317,1,1,1,3,0610,28),
(2281,1,1,1,4,0625,123),
(2763,1,1,1,5,0615,32),
(2281,1,1,1,6,0640,27),
(2281,1,1,1,1,0410,108),
(2281,1,1,1,2,0625,97),
(2281,1,1,1,3,0615,67),
(3317,1,1,1,4,0610,59),
(4424,1,1,1,5,0610,51),
(2747,1,1,1,6,0625,105),
(4424,1,1,1,1,0620,93),
(2281,1,1,1,2,0640,26),
(2758,1,1,1,3,0610,89),
(4424,1,1,1,4,0615,60),
(2281,1,1,1,5,0430,108),
(2758,1,1,1,6,0420,18),
(2763,1,1,1,1,0440,67),
(3317,1,1,1,2,0625,119),
(3317,1,1,1,3,0610,97),
(2747,1,1,1,4,0425,62),
(2763,1,1,1,5,0630,87),
(2747,1,1,1,6,0630,89);

-- DIM_VOLUNTARIO
INSERT INTO dim_voluntario (id_voluntario, nome_voluntario, genero, idade) VALUES (1,'Juliana','F',34),
(2,'Natália','F',66),
(6,'Ana','F',37),
(4,'Lucas','F',70),
(5,'Mariana','F',26),
(6,'Priscila','F',42),
(7,'Gabriela','F',35),
(8,'Henrique','F',43),
(9,'Larissa','F',51),
(10,'Vinicius','F',33),
(11,'Patrícia','F',39),
(12,'Michele','F',20),
(13,'Carlos','F',68),
(14,'Amanda','F',26),
(15,'João','F',63),
(16,'Caio','F',60),
(17,'Natália','F',60),
(18,'Márcio','F',23),
(19,'Otávio','F',37),
(20,'Rafael','F',21),
(21,'Isabela','F',33),
(22,'Murilo','F',42),
(23,'Thiago','F',29),
(24,'Renato','F',20),
(25,'Gustavo','F',19),
(26,'Elaine','F',67),
(27,'Clara','F',41),
(28,'Bianca','F',49),
(29,'Vanessa','F',24),
(30,'Cristina','F',22),
(31,'Aline','F',38),
(32,'Tatiane','F',54),
(33,'Larissa','F',28),
(34,'Sabrina','F',62),
(35,'Carlos','F',44),
(36,'Lucas','F',37),
(37,'Diego','F',45),
(38,'Camila','F',60),
(39,'Henrique','F',31),
(40,'Michele','F',62),
(41,'Isabela','F',18),
(42,'Mateus','F',34),
(43,'Juliana','F',24),
(44,'André','F',25),
(45,'Letícia','F',67),
(46,'Caio','F',59),
(47,'Gustavo','F',41),
(48,'Bruno','F',53),
(49,'Renato','F',42),
(50,'Ana','F',31),
(51,'Débora','F',46),
(52,'Mariana','F',43),
(53,'Márcio','F',56),
(54,'Rodrigo','F',42),
(55,'Eduardo','F',26),
(56,'Daniel','F',34),
(57,'Bianca','F',29),
(58,'Ana','F',38),
(59,'Paula','F',51),
(60,'Fábio','F',46),
(61,'Renato','F',34),
(62,'Elaine','F',27),
(63,'Bruno','F',19),
(64,'Sabrina','F',49),
(65,'Henrique','F',64),
(66,'Rafael','F',25),
(67,'Luana','F',26),
(68,'André','F',46),
(69,'Natália','F',35),
(70,'Letícia','F',29),
(71,'Vanessa','F',39),
(72,'Leonardo','F',22),
(73,'Isabela','F',30),
(74,'Mateus','F',26),
(75,'Vinicius','F',62),
(76,'Daniel','F',62),
(77,'Camila','F',55),
(78,'Ricardo','F',41),
(79,'Clara','F',33),
(80,'Renato','F',66),
(81,'Tatiane','F',69),
(82,'Márcio','F',52),
(83,'Ana','F',43),
(84,'Juliana','F',53),
(85,'Larissa','F',41),
(86,'Carlos','F',21),
(87,'Murilo','F',44),
(88,'Cristina','F',32),
(89,'João','F',43),
(90,'Bianca','F',52),
(91,'Patrícia','F',53),
(92,'Thiago','F',49),
(93,'Elaine','F',48),
(94,'Eduardo','F',63),
(95,'Beatriz','F',24),
(96,'Paula','F',30),
(97,'Mateus','F',37),
(98,'Priscila','F',36),
(99,'André','F',54),
(100,'Mariana','F',26),
(101,'Amanda','F',33),
(102,'Diego','F',29),
(103,'Paula','F',69),
(104,'Márcio','F',38),
(105,'Larissa','F',40),
(106,'Mateus','F',18),
(107,'Rafael','F',57),
(108,'Michele','F',50),
(109,'Beatriz','F',30),
(110,'Gustavo','F',61),
(111,'Cristina','F',18),
(112,'Daniel','F',57),
(113,'Lucas','F',20),
(114,'Elaine','F',50),
(115,'Aline','F',67),
(116,'Gabriela','F',58),
(117,'Murilo','F',49),
(118,'Débora','F',35),
(119,'Tatiane','F',57),
(120,'Bianca','F',19),
(121,'Luana','F',32),
(122,'Renato','F',24),
(123,'Amanda','F',31),
(124,'Caio','F',35),
(125,'Fábio','F',26),
(126,'Diego','F',28),
(127,'Vanessa','F',25),
(128,'André','F',19),
(129,'Mariana','F',32),
(130,'Daniel','F',55),
(131,'Cristina','F',30),
(132,'Murilo','F',55),
(133,'Bianca','F',41),
(134,'Michele','F',44),
(135,'Débora','F',20),
(136,'Natália','F',55),
(137,'Diego','F',26),
(138,'Leonardo','F',57),
(139,'Fernanda','F',45),
(140,'Patrícia','F',69),
(141,'Paula','F',64),
(142,'Rafael','F',37),
(143,'Elaine','F',53),
(144,'Renato','F',30),
(145,'Priscila','F',49),
(146,'Márcio','F',27),
(147,'Vanessa','F',19),
(148,'Diego','F',69),
(149,'Mateus','F',54),
(150,'Vinicius','F',49),
(151,'Larissa','F',59),
(152,'Beatriz','F',51),
(153,'João','F',70),
(154,'Lucas','F',45),
(155,'Caio','F',70),
(156,'Felipe','F',53),
(157,'Isabela','F',48),
(158,'Camila','F',59),
(159,'Juliana','F',33),
(160,'Márcio','F',44),
(161,'Ana','F',66),
(162,'Aline','F',65),
(163,'Renato','F',18),
(164,'Eduardo','F',31),
(165,'Henrique','F',38),
(166,'Otávio','F',59),
(167,'Letícia','F',56),
(168,'Leonardo','F',61),
(169,'Bruno','F',49),
(170,'Luana','F',60),
(171,'Priscila','F',57),
(172,'Elaine','F',65),
(173,'Murilo','F',44),
(174,'Mariana','F',56),
(175,'Thiago','F',30),
(176,'Felipe','F',37),
(177,'Fernanda','F',20),
(178,'Juliana','F',34),
(179,'Isabela','F',48),
(180,'Clara','F',61),
(181,'Tatiane','F',38),
(182,'Letícia','F',27),
(183,'Natália','F',70),
(184,'Vanessa','F',44),
(185,'Gabriela','F',62),
(186,'Henrique','F',48),
(187,'Otávio','F',54),
(188,'Michele','F',24),
(189,'Amanda','F',37),
(190,'Rodrigo','F',36),
(191,'Bruno','F',49),
(192,'Lucas','F',62),
(193,'Priscila','F',24),
(194,'Felipe','F',62),
(195,'Aline','F',68),
(196,'Isabela','F',70),
(197,'Amanda','F',67),
(198,'Renato','F',58),
(199,'Larissa','F',37),
(200,'Gabriela','F',68),
(201,'Vinicius','F',65),
(202,'Otávio','F',69),
(203,'Rafael','F',23),
(204,'Beatriz','F',37),
(205,'Gustavo','F',68),
(206,'Tatiane','F',25),
(207,'Juliana','F',35),
(208,'Daniel','F',69),
(209,'Ricardo','F',28),
(210,'Fábio','F',42),
(211,'Mariana','F',37),
(212,'André','F',53),
(213,'Sabrina','F',42),
(214,'Vanessa','F',42),
(215,'Rodrigo','F',63),
(216,'Murilo','F',55),
(217,'Letícia','F',55),
(218,'Eduardo','F',66),
(219,'Bianca','F',60),
(220,'Diego','F',41),
(221,'Débora','F',37),
(222,'Camila','F',38),
(223,'Mateus','F',30),
(224,'Gabriela','F',18),
(225,'Rafael','F',29),
(226,'Amanda','F',53),
(227,'Letícia','F',27),
(228,'Daniel','F',52),
(229,'Isabela','F',50),
(230,'Fernanda','F',61),
(231,'Renato','F',57),
(232,'Murilo','F',38),
(233,'Michele','F',55),
(234,'Leonardo','F',47),
(235,'Lucas','F',62),
(236,'Patrícia','F',31),
(237,'Paula','F',51),
(238,'Priscila','F',27),
(239,'Mariana','F',24),
(240,'Carlos','F',55),
(241,'Vanessa','F',57),
(242,'Beatriz','F',67),
(243,'Fábio','F',30),
(244,'Thiago','F',53),
(245,'Rodrigo','F',44),
(246,'Letícia','F',39),
(247,'Murilo','F',44),
(248,'Patrícia','F',34),
(249,'Débora','F',40),
(250,'André','F',55),
(251,'Gabriela','F',45),
(252,'Larissa','F',58),
(253,'Michele','F',60),
(254,'Diego','F',35),
(255,'Felipe','F',68),
(256,'Ricardo','F',29),
(257,'Mateus','F',38),
(258,'Renato','F',45),
(259,'Carlos','F',46),
(260,'Paula','F',18),
(261,'Bianca','F',56),
(262,'Clara','F',67),
(263,'Camila','F',19),
(264,'Isabela','F',70),
(265,'Natália','F',50),
(266,'Bruno','F',28),
(267,'Ana','F',22),
(268,'Rodrigo','F',63),
(269,'Bruno','F',48),
(270,'Bianca','F',33),
(271,'Gabriela','F',29),
(272,'Cristina','F',46),
(273,'Daniel','F',62),
(274,'Vanessa','F',18),
(275,'Vinicius','F',18),
(276,'Letícia','F',41),
(277,'Amanda','F',66),
(278,'Eduardo','F',51),
(279,'Carlos','F',50),
(280,'Clara','F',24),
(281,'Caio','F',20),
(282,'Larissa','F',67),
(283,'Michele','F',22),
(284,'Lucas','F',55),
(285,'Tatiane','F',47),
(286,'Gustavo','F',22),
(287,'Beatriz','F',66),
(288,'Natália','F',58),
(289,'Débora','F',30),
(290,'João','F',39),
(291,'Mateus','F',35),
(292,'Aline','F',42),
(293,'Juliana','F',26),
(294,'Mariana','F',27),
(295,'Paula','F',18),
(296,'Luana','F',20),
(297,'Camila','F',67),
(298,'Tatiane','F',27),
(299,'Rodrigo','F',57),
(300,'Henrique','F',29),
(301,'André','F',23),
(302,'Natália','F',62),
(303,'Lucas','F',58),
(304,'Ana','F',41),
(305,'Beatriz','F',56),
(306,'Carlos','F',29),
(307,'Leonardo','F',25),
(308,'Gustavo','F',42),
(309,'Eduardo','F',27),
(310,'Aline','F',38),
(311,'Mateus','F',57),
(312,'Mariana','F',19),
(313,'Murilo','F',27),
(314,'Caio','F',28),
(315,'Michele','F',31),
(316,'Márcio','F',18),
(317,'Daniel','F',60),
(318,'Débora','F',63),
(319,'Amanda','F',59),
(320,'Ricardo','F',45),
(321,'Rafael','F',27),
(322,'Cristina','F',25),
(323,'Rafael','F',61),
(324,'Mariana','F',61),
(325,'Mateus','F',70),
(326,'Henrique','F',60),
(327,'Bianca','F',36),
(328,'Felipe','F',69),
(329,'Larissa','F',63),
(330,'Paula','F',65),
(331,'Michele','F',64),
(332,'Aline','F',62),
(333,'Patrícia','F',25),
(334,'Carlos','F',64),
(335,'André','F',19),
(336,'Leonardo','F',41),
(337,'Letícia','F',52),
(338,'Isabela','F',36),
(339,'Thiago','F',38),
(340,'Diego','F',40),
(341,'Priscila','F',53),
(342,'Tatiane','F',63),
(343,'Clara','F',51),
(344,'Débora','F',44),
(345,'Otávio','F',54),
(346,'Bruno','F',70),
(347,'Sabrina','F',39),
(348,'Vanessa','F',63),
(349,'Paula','F',69),
(350,'Beatriz','F',47),
(351,'Felipe','F',54),
(352,'Leonardo','F',47),
(353,'Aline','F',30),
(354,'Renato','F',19),
(355,'Daniel','F',47),
(356,'Carlos','F',23),
(357,'Ricardo','F',33),
(358,'Camila','F',43),
(359,'Cristina','F',54),
(360,'Rodrigo','F',19),
(361,'Letícia','F',42),
(362,'Patrícia','F',42),
(363,'Amanda','F',53),
(364,'Lucas','F',23),
(365,'Vinicius','F',64),
(366,'Fábio','F',56),
(367,'Sabrina','F',61),
(368,'Débora','F',45),
(369,'Gustavo','F',61),
(370,'Fernanda','F',63),
(371,'Murilo','F',44),
(372,'Michele','F',20),
(373,'André','F',23),
(374,'Fábio','F',45),
(375,'Natália','F',64),
(376,'Renato','F',58),
(377,'Vanessa','F',18),
(378,'Daniel','F',57),
(379,'Gabriela','F',42),
(380,'Michele','F',46),
(381,'Henrique','F',47),
(382,'Beatriz','F',46),
(383,'Patrícia','F',24),
(384,'Camila','F',42),
(385,'Murilo','F',61),
(386,'Felipe','F',47),
(387,'Ana','F',47),
(388,'Sabrina','F',55),
(389,'Elaine','F',24),
(390,'Márcio','F',69),
(391,'Fernanda','F',52),
(392,'Eduardo','F',53),
(393,'Isabela','F',52),
(394,'Lucas','F',30),
(395,'Gustavo','F',68),
(396,'Tatiane','F',24),
(397,'Vinicius','F',68),
(398,'Isabela','F',56),
(399,'Vanessa','F',65),
(400,'Patrícia','F',65),
(401,'Rafael','F',59),
(402,'Ana','F',41),
(403,'Clara','F',34),
(404,'Murilo','F',34),
(405,'Luana','F',47),
(406,'Fábio','F',20),
(407,'Letícia','F',30),
(408,'André','F',56),
(409,'Bruno','F',43),
(410,'Felipe','F',30),
(411,'Paula','F',24),
(412,'Tatiane','F',39),
(413,'Natália','F',40),
(414,'Daniel','F',24),
(415,'Ricardo','F',43),
(416,'Juliana','F',48),
(417,'Carlos','F',51),
(418,'Beatriz','F',68),
(419,'Fernanda','F',47),
(420,'Sabrina','F',68),
(421,'Mariana','F',47),
(422,'Caio','F',18),
(423,'Michele','F',43),
(424,'Henrique','F',58),
(425,'Priscila','F',18),
(426,'Débora','F',37),
(427,'Thiago','F',70),
(428,'Larissa','F',37),
(429,'Priscila','F',63),
(430,'Bruno','F',45),
(431,'Beatriz','F',22),
(432,'Ricardo','F',27),
(433,'Carlos','F',22),
(434,'Clara','F',37),
(435,'Mariana','F',65),
(436,'André','F',65),
(437,'Juliana','F',65),
(438,'Amanda','F',25),
(439,'Leonardo','F',35),
(440,'Thiago','F',54),
(441,'Rafael','F',37),
(442,'Luana','F',59),
(443,'Letícia','F',50),
(444,'Elaine','F',58),
(445,'Caio','F',59),
(446,'Cristina','F',45),
(447,'Aline','F',30),
(448,'Natália','F',57),
(449,'Daniel','F',35),
(450,'Diego','F',55),
(451,'Eduardo','F',26),
(452,'Vanessa','F',58),
(453,'Isabela','F',68),
(454,'Daniel','F',41),
(455,'Thiago','F',62),
(456,'Beatriz','F',25),
(457,'Elaine','F',42),
(458,'Vanessa','F',63),
(459,'Paula','F',47),
(460,'Mateus','F',63),
(461,'Márcio','F',37),
(462,'Larissa','F',56),
(463,'André','F',70),
(464,'Letícia','F',36),
(465,'Rafael','F',30),
(466,'João','F',45),
(467,'Otávio','F',34),
(468,'Aline','F',67),
(469,'Caio','F',39),
(470,'Débora','F',51),
(471,'Lucas','F',70),
(472,'Tatiane','F',62),
(473,'Amanda','F',21),
(474,'Vinicius','F',25),
(475,'Clara','F',37),
(476,'Rodrigo','F',67),
(477,'Diego','F',25),
(478,'Beatriz','F',24),
(479,'Letícia','F',20),
(480,'Amanda','F',45),
(481,'Murilo','F',48),
(482,'Diego','F',58),
(483,'Aline','F',54),
(484,'Juliana','F',37),
(485,'Gabriela','F',52),
(486,'André','F',64),
(487,'Natália','F',22),
(488,'Cristina','F',60),
(489,'Leonardo','F',67),
(490,'Lucas','F',25),
(491,'Michele','F',30),
(492,'Bruno','F',59),
(493,'Fernanda','F',32),
(494,'Clara','F',70),
(495,'Caio','F',45),
(496,'Renato','F',65),
(497,'Thiago','F',53),
(498,'Felipe','F',45),
(499,'Fábio','F',43),
(500,'Camila','F',19),
(501,'Isabela','F',68),
(502,'Luana','F',68),
(503,'Márcio','F',63),
(504,'Paula','F',21),
(505,'Michele','F',54),
(506,'Rodrigo','F',59),
(507,'Clara','F',54),
(508,'Carlos','F',28),
(509,'Daniel','F',51),
(510,'Mateus','F',67),
(511,'Gabriela','F',26),
(512,'Débora','F',39),
(513,'Mariana','F',34),
(514,'Bruno','F',43),
(515,'Fernanda','F',47),
(516,'João','F',39),
(517,'Tatiane','F',48),
(518,'Letícia','F',19),
(519,'Amanda','F',57),
(520,'Murilo','F',43),
(521,'Gustavo','F',25),
(522,'Renato','F',50),
(523,'André','F',37),
(524,'Diego','F',53),
(525,'Isabela','F',49),
(526,'Eduardo','F',51),
(527,'Patrícia','F',45),
(528,'Otávio','F',65),
(529,'Larissa','F',32),
(530,'Leonardo','F',19),
(531,'Beatriz','F',22),
(532,'Michele','F',39),
(533,'Amanda','F',62),
(534,'Isabela','F',61),
(535,'Eduardo','F',24),
(536,'Otávio','F',30),
(537,'Débora','F',18),
(538,'Rafael','F',19),
(539,'Bruno','F',36),
(540,'Diego','F',57),
(541,'Felipe','F',46),
(542,'Luana','F',34),
(543,'Sabrina','F',40),
(544,'Clara','F',35),
(545,'Larissa','F',45),
(546,'Caio','F',32),
(547,'Cristina','F',44),
(548,'Gustavo','F',34),
(549,'Fábio','F',29),
(550,'Camila','F',28),
(551,'Beatriz','F',40),
(552,'Felipe','F',70),
(553,'Bianca','F',34),
(554,'Aline','F',27),
(555,'Débora','F',48),
(556,'Priscila','F',38),
(557,'Renato','F',58),
(558,'Rodrigo','F',43),
(559,'Tatiane','F',19),
(560,'Patrícia','F',63),
(561,'Natália','F',61),
(562,'Gustavo','F',40),
(563,'André','F',31),
(564,'Sabrina','F',36),
(565,'Clara','F',50),
(566,'Fernanda','F',50),
(567,'Ricardo','F',58),
(568,'Camila','F',52),
(569,'Caio','F',55),
(570,'Michele','F',40),
(571,'Fábio','F',57),
(572,'Diego','F',33),
(573,'Juliana','F',67),
(574,'Cristina','F',57),
(575,'Mateus','F',38),
(576,'Mariana','F',26),
(577,'Gustavo','F',33),
(578,'Daniel','F',40),
(579,'Márcio','F',44),
(580,'Amanda','F',68),
(581,'Patrícia','F',19),
(582,'Renato','F',53),
(583,'Aline','F',31),
(584,'Vinicius','F',22),
(585,'Leonardo','F',21),
(586,'Camila','F',46),
(587,'Eduardo','F',24),
(588,'Michele','F',29),
(589,'Bruno','F',33),
(590,'Gabriela','F',41),
(591,'Sabrina','F',59),
(592,'Mariana','F',34),
(593,'Elaine','F',30),
(594,'Henrique','F',21),
(595,'Ricardo','F',70),
(596,'Fernanda','F',34),
(597,'Beatriz','F',64),
(598,'Rafael','F',67),
(599,'Otávio','F',22),
(600,'Felipe','F',66),
(601,'Cristina','F',22),
(602,'Daniel','F',67),
(603,'Leonardo','F',64),
(604,'Ricardo','F',57),
(605,'Fernanda','F',32),
(606,'Priscila','F',35),
(607,'Letícia','F',18),
(608,'Fábio','F',23),
(609,'Ana','F',33),
(610,'Gabriela','F',29),
(611,'Vanessa','F',48),
(612,'Mariana','F',68),
(613,'Otávio','F',27),
(614,'Diego','F',67),
(615,'Larissa','F',42),
(616,'Mateus','F',55),
(617,'Carlos','F',34),
(618,'Vinicius','F',48),
(619,'Amanda','F',61),
(620,'Luana','F',67),
(621,'Rodrigo','F',69),
(622,'Tatiane','F',56),
(623,'Vanessa','F',32),
(624,'Rafael','F',52),
(625,'Isabela','F',26),
(626,'Gabriela','F',23),
(627,'Amanda','F',24),
(628,'Henrique','F',21),
(629,'Camila','F',62),
(630,'Paula','F',60),
(631,'Renato','F',69),
(632,'Mateus','F',32),
(633,'Otávio','F',69),
(634,'Patrícia','F',54),
(635,'Felipe','F',49),
(636,'Letícia','F',32),
(637,'Daniel','F',34),
(638,'Luana','F',28),
(639,'Ana','F',48),
(640,'Cristina','F',62),
(641,'Ricardo','F',56),
(642,'Fábio','F',25),
(643,'Murilo','F',67),
(644,'Mariana','F',30),
(645,'Larissa','F',58),
(646,'Lucas','F',51),
(647,'Juliana','F',28),
(648,'Daniel','F',35),
(649,'Gustavo','F',27),
(650,'Murilo','F',69),
(651,'Luana','F',69),
(652,'Paula','F',41),
(653,'Beatriz','F',65),
(654,'Carlos','F',38),
(655,'Mariana','F',19),
(656,'Isabela','F',31),
(657,'Eduardo','F',24),
(658,'Tatiane','F',42),
(659,'Fernanda','F',44),
(660,'Otávio','F',70),
(661,'Diego','F',50),
(662,'Camila','F',62),
(663,'Bianca','F',27),
(664,'Fábio','F',65),
(665,'Bruno','F',42),
(666,'Aline','F',50),
(667,'Ricardo','F',56),
(668,'Vanessa','F',70),
(669,'Daniel','F',32),
(670,'Márcio','F',39),
(671,'Vinicius','F',63),
(672,'Gustavo','F',51),
(673,'Natália','F',55),
(674,'Renato','F',51),
(675,'Eduardo','F',56),
(676,'Felipe','F',57),
(677,'Sabrina','F',35),
(678,'Bruno','F',68),
(679,'Carlos','F',51),
(680,'Lucas','F',20),
(681,'Rodrigo','F',66),
(682,'Fábio','F',55),
(683,'Henrique','F',53),
(684,'Amanda','F',47),
(685,'Débora','F',47),
(686,'Mateus','F',54),
(687,'Murilo','F',25),
(688,'Ana','F',47),
(689,'Vanessa','F',52),
(690,'Camila','F',31),
(691,'Paula','F',36),
(692,'Isabela','F',38),
(693,'Mateus','F',41),
(694,'Fábio','F',53),
(695,'Gabriela','F',58),
(696,'Tatiane','F',33),
(697,'João','F',46),
(698,'Beatriz','F',50),
(699,'Rafael','F',24),
(700,'Eduardo','F',63),
(701,'Henrique','F',18),
(702,'Bruno','F',21),
(703,'Márcio','F',30),
(704,'Murilo','F',66),
(705,'André','F',45),
(706,'Michele','F',34),
(707,'Leonardo','F',18),
(708,'Mariana','F',35),
(709,'Letícia','F',19),
(710,'Sabrina','F',61),
(711,'Isabela','F',31),
(712,'Priscila','F',18),
(713,'Vinicius','F',53),
(714,'Thiago','F',51),
(715,'Luana','F',55),
(716,'Carlos','F',63),
(717,'Vanessa','F',33),
(718,'Natália','F',33),
(719,'Bruno','F',53),
(720,'Caio','F',46),
(721,'Cristina','F',63),
(722,'Mariana','F',52),
(723,'Rafael','F',42),
(724,'Renato','F',66),
(725,'Gustavo','F',57),
(726,'Débora','F',69),
(727,'Luana','F',19),
(728,'Murilo','F',49),
(729,'Vinicius','F',61),
(730,'Elaine','F',43),
(731,'Larissa','F',21),
(732,'Amanda','F',65),
(733,'Clara','F',58),
(734,'Camila','F',64),
(735,'Fábio','F',31),
(736,'Tatiane','F',20),
(737,'Natália','F',18),
(738,'Diego','F',39),
(739,'André','F',41),
(740,'Patrícia','F',69),
(741,'Ana','F',64),
(742,'Rodrigo','F',21),
(743,'Sabrina','F',30),
(744,'João','F',48),
(745,'Leonardo','F',43),
(746,'Vanessa','F',42),
(747,'Fábio','F',68),
(748,'Vanessa','F',26),
(749,'Natália','F',60),
(750,'Larissa','F',45),
(751,'Márcio','F',53),
(752,'Ana','F',34),
(753,'Paula','F',37),
(754,'Sabrina','F',60),
(755,'Diego','F',25),
(756,'Lucas','F',25),
(757,'Mateus','F',51),
(758,'Gustavo','F',18),
(759,'Luana','F',57),
(760,'Carlos','F',54),
(761,'André','F',48),
(762,'Débora','F',40),
(763,'Camila','F',36),
(764,'Letícia','F',43),
(765,'Otávio','F',25),
(766,'Aline','F',27),
(767,'Cristina','F',57),
(768,'Letícia','F',40),
(769,'Carlos','F',19),
(770,'Ana','F',33),
(771,'Elaine','F',69),
(772,'Mariana','F',67),
(773,'Michele','F',19),
(774,'João','F',19),
(775,'Priscila','F',46),
(776,'Rafael','F',38),
(777,'Fábio','F',41),
(778,'Camila','F',56),
(779,'Luana','F',20),
(780,'Mateus','F',24),
(781,'Márcio','F',67),
(782,'Henrique','F',19),
(783,'Rodrigo','F',41),
(784,'Larissa','F',49),
(785,'Tatiane','F',32),
(786,'Vinicius','F',32),
(787,'André','F',53),
(788,'Juliana','F',50),
(789,'Beatriz','F',52),
(790,'Bianca','F',61),
(791,'Cristina','F',62),
(792,'Sabrina','F',51),
(793,'Fábio','F',54),
(794,'Daniel','F',25),
(795,'Mateus','F',68),
(796,'Luana','F',42),
(797,'Eduardo','F',69),
(798,'Michele','F',37),
(799,'Thiago','F',56),
(800,'Carlos','F',56),
(801,'Natália','F',26),
(802,'Caio','F',68),
(803,'Lucas','F',44),
(804,'Felipe','F',53),
(805,'Diego','F',60),
(806,'Juliana','F',39),
(807,'Gustavo','F',55),
(808,'Ricardo','F',30),
(809,'Vinicius','F',24),
(810,'Patrícia','F',27),
(811,'Vanessa','F',61),
(812,'Paula','F',32),
(813,'Rafael','F',68),
(814,'Beatriz','F',56),
(815,'Letícia','F',52),
(816,'Tatiane','F',46),
(817,'Bianca','F',32),
(818,'Renato','F',56),
(819,'Isabela','F',62),
(820,'Paula','F',66),
(821,'Caio','F',70),
(822,'Mateus','F',47),
(823,'Gustavo','F',70),
(824,'Fernanda','F',32),
(825,'Vinicius','F',67),
(826,'Larissa','F',48),
(827,'Felipe','F',44),
(828,'Clara','F',53),
(829,'Luana','F',31),
(830,'Amanda','F',70),
(831,'Priscila','F',38),
(832,'Bruno','F',64),
(833,'Henrique','F',26),
(834,'Rafael','F',53),
(835,'Márcio','F',37),
(836,'Sabrina','F',33),
(837,'Elaine','F',46),
(838,'Eduardo','F',32),
(839,'Rodrigo','F',54),
(840,'Diego','F',46),
(841,'Thiago','F',41),
(842,'Vanessa','F',58),
(843,'Ana','F',66),
(844,'Murilo','F',39),
(845,'Ricardo','F',20),
(846,'Patrícia','F',25),
(847,'Natália','F',46),
(848,'Elaine','F',64),
(849,'Isabela','F',45),
(850,'Sabrina','F',33),
(851,'João','F',46),
(852,'Mariana','F',42),
(853,'Gabriela','F',24),
(854,'Rodrigo','F',46),
(855,'Larissa','F',48),
(856,'Fernanda','F',20),
(857,'Renato','F',29),
(858,'Thiago','F',41),
(859,'Paula','F',65),
(860,'Vanessa','F',57),
(861,'Camila','F',19),
(862,'Amanda','F',69),
(863,'Otávio','F',65),
(864,'Diego','F',56),
(865,'Felipe','F',33),
(866,'Bianca','F',41),
(867,'Diego','F',47),
(868,'Letícia','F',18),
(869,'Beatriz','F',69),
(870,'Caio','F',69),
(871,'Larissa','F',68),
(872,'Lucas','F',28),
(873,'Michele','F',24),
(874,'Bianca','F',67),
(875,'Natália','F',52),
(876,'Camila','F',22),
(877,'Daniel','F',66),
(878,'André','F',54),
(879,'Fábio','F',67),
(880,'Luana','F',57),
(881,'Isabela','F',36),
(882,'Vinicius','F',50),
(883,'João','F',65),
(884,'Henrique','F',40),
(885,'Aline','F',18),
(886,'Leonardo','F',47),
(887,'Rafael','F',42),
(888,'Gabriela','F',38),
(889,'Paula','F',55),
(890,'Eduardo','F',36),
(891,'Juliana','F',46),
(892,'Tatiane','F',26),
(893,'Clara','F',28),
(894,'Paula','F',37),
(895,'Bianca','F',49),
(896,'Gabriela','F',29),
(897,'Rodrigo','F',30),
(898,'Michele','F',35),
(899,'Ricardo','F',66),
(900,'Letícia','F',63),
(901,'Rafael','F',45),
(902,'Cristina','F',36),
(903,'Murilo','F',58),
(904,'Sabrina','F',44),
(905,'Fernanda','F',57),
(906,'Bruno','F',32),
(907,'Leonardo','F',55),
(908,'Renato','F',33),
(909,'Vinicius','F',57),
(910,'João','F',58),
(911,'Gustavo','F',56),
(912,'Lucas','F',22),
(913,'Débora','F',50),
(914,'Henrique','F',70),
(915,'Gabriela','F',67),
(916,'Fernanda','F',57),
(917,'Vanessa','F',45),
(918,'Gustavo','F',64),
(919,'Amanda','F',68),
(920,'Clara','F',33),
(921,'Natália','F',38),
(922,'Patrícia','F',24),
(923,'Paula','F',37),
(924,'Diego','F',59),
(925,'Rodrigo','F',47),
(926,'Priscila','F',63),
(927,'Elaine','F',37),
(928,'Márcio','F',70),
(929,'Murilo','F',30),
(930,'Isabela','F',63),
(931,'André','F',25),
(932,'Vinicius','F',23),
(933,'Tatiane','F',37),
(934,'Ricardo','F',67),
(935,'Bianca','F',20),
(936,'Mariana','F',22),
(937,'Caio','F',23),
(938,'Vanessa','F',24),
(939,'Bianca','F',30),
(940,'Michele','F',67),
(941,'Fábio','F',55),
(942,'Clara','F',26),
(943,'Renato','F',18),
(944,'Rafael','F',22),
(945,'Thiago','F',40),
(946,'Leonardo','F',29),
(947,'Daniel','F',62),
(948,'Vinicius','F',26),
(949,'Henrique','F',30),
(950,'Patrícia','F',68),
(951,'Sabrina','F',43),
(952,'Ricardo','F',58),
(953,'Diego','F',47),
(954,'Beatriz','F',65),
(955,'Felipe','F',20),
(956,'Gabriela','F',27),
(957,'Larissa','F',54),
(958,'Carlos','F',58),
(959,'Cristina','F',45),
(960,'Elaine','F',18),
(961,'Bruno','F',69),
(962,'Carlos','F',21),
(963,'Priscila','F',56),
(964,'Ricardo','F',30),
(965,'Michele','F',70),
(966,'Thiago','F',66),
(967,'Mateus','F',68),
(968,'Clara','F',48),
(969,'Henrique','F',38),
(970,'Isabela','F',57),
(971,'André','F',65),
(972,'Bianca','F',66),
(973,'Ana','F',63),
(974,'Caio','F',63),
(975,'Amanda','F',51),
(976,'Renato','F',62),
(977,'Felipe','F',55),
(978,'Patrícia','F',31),
(979,'Daniel','F',65),
(980,'Sabrina','F',29),
(981,'Cristina','F',45),
(982,'Sabrina','F',65),
(983,'Elaine','F',52),
(984,'Camila','F',55),
(985,'Clara','F',55),
(986,'Lucas','F',18),
(987,'Rodrigo','F',43),
(988,'Rafael','F',45),
(989,'Amanda','F',69),
(990,'Natália','F',22),
(991,'Beatriz','F',70),
(992,'Vinicius','F',20),
(993,'Letícia','F',35),
(994,'Larissa','F',60),
(995,'Otávio','F',19),
(996,'Felipe','F',26),
(997,'Vanessa','F',23),
(998,'João','F',59),
(999,'Leonardo','F',64),
(1000,'Mariana','F',38),
(1001,'Luana','F',19),
(1002,'Bianca','F',30),
(1003,'Beatriz','F',52),
(1004,'Caio','F',43),
(1005,'Cristina','F',37),
(1006,'Eduardo','F',40),
(1007,'Patrícia','F',45),
(1008,'Amanda','F',49),
(1009,'Felipe','F',53),
(1010,'Ricardo','F',59),
(1011,'João','F',44),
(1012,'Juliana','F',19),
(1013,'Vanessa','F',46),
(1014,'Murilo','F',61),
(1015,'Lucas','F',30),
(1016,'Leonardo','F',44),
(1017,'Fernanda','F',68),
(1018,'Aline','F',21),
(1019,'Larissa','F',65),
(1020,'Elaine','F',31),
(1021,'Ana','F',66),
(1022,'Gustavo','F',59),
(1023,'Priscila','F',41),
(1024,'Natália','F',69),
(1025,'Mariana','F',20),
(1026,'Gabriela','F',59),
(1027,'Tatiane','F',62),
(1028,'Bruno','F',70),
(1029,'Caio','F',54),
(1030,'Daniel','F',28),
(1031,'Sabrina','F',27),
(1032,'Otávio','F',68),
(1033,'Paula','F',39),
(1034,'Cristina','F',68),
(1035,'Gabriela','F',70),
(1036,'Ana','F',69),
(1037,'André','F',67),
(1038,'Larissa','F',21),
(1039,'Mariana','F',63),
(1040,'Bianca','F',39),
(1041,'João','F',24),
(1042,'Eduardo','F',19),
(1043,'Luana','F',40),
(1044,'Débora','F',24),
(1045,'Gustavo','F',26),
(1046,'Diego','F',43),
(1047,'Priscila','F',66),
(1048,'Márcio','F',42),
(1049,'Felipe','F',45),
(1050,'Henrique','F',33),
(1051,'Renato','F',30),
(1052,'Mariana','F',48),
(1053,'Eduardo','F',42),
(1054,'Lucas','F',30),
(1055,'Caio','F',23),
(1056,'Juliana','F',59),
(1057,'Otávio','F',51),
(1058,'Beatriz','F',39),
(1059,'Ana','F',38),
(1060,'Bruno','F',28),
(1061,'Diego','F',33),
(1062,'Isabela','F',42),
(1063,'Felipe','F',22),
(1064,'Natália','F',55),
(1065,'Mateus','F',20),
(1066,'Tatiane','F',53),
(1067,'Vinicius','F',36),
(1068,'Carlos','F',21),
(1069,'Priscila','F',59),
(1070,'Gabriela','F',29),
(1071,'Luana','F',31),
(1072,'Sabrina','F',60),
(1073,'Thiago','F',36),
(1074,'Débora','F',26),
(1075,'Cristina','F',62),
(1076,'Fernanda','F',56),
(1077,'Priscila','F',30),
(1078,'Patrícia','F',41),
(1079,'Bianca','F',30),
(1080,'Bruno','F',46),
(1081,'Rodrigo','F',66),
(1082,'Natália','F',48),
(1083,'Michele','F',42),
(1084,'Tatiane','F',67),
(1085,'Beatriz','F',54),
(1086,'Juliana','F',44),
(1087,'Mateus','F',44),
(1088,'Amanda','F',34),
(1089,'Caio','F',69),
(1090,'Isabela','F',51),
(1091,'Renato','F',62),
(1092,'Murilo','F',60),
(1093,'Felipe','F',34),
(1094,'André','F',59),
(1095,'Isabela','F',46),
(1096,'Sabrina','F',19),
(1097,'Daniel','F',68),
(1098,'Vanessa','F',53),
(1099,'Elaine','F',21),
(1100,'Henrique','F',50),
(1101,'Amanda','F',18),
(1102,'Beatriz','F',61),
(1103,'Luana','F',42),
(1104,'Márcio','F',70),
(1105,'Camila','F',56),
(1106,'Gustavo','F',30),
(1107,'Thiago','F',49),
(1108,'Fábio','F',38),
(1109,'Aline','F',26),
(1110,'Otávio','F',69),
(1111,'Rodrigo','F',63),
(1112,'Lucas','F',20),
(1113,'Mateus','F',39),
(1114,'Letícia','F',63),
(1115,'Patrícia','F',33),
(1116,'Diego','F',57),
(1117,'Leonardo','F',54),
(1118,'Priscila','F',55),
(1119,'Tatiane','F',50),
(1120,'João','F',33),
(1121,'Elaine','F',69),
(1122,'Aline','F',31),
(1123,'Márcio','F',64),
(1124,'Letícia','F',36),
(1125,'Gabriela','F',62),
(1126,'Diego','F',43),
(1127,'Murilo','F',42),
(1128,'Renato','F',51),
(1129,'João','F',34),
(1130,'Camila','F',27),
(1131,'Daniel','F',58),
(1132,'Bianca','F',31),
(1133,'Ana','F',31),
(1134,'Fábio','F',18),
(1135,'André','F',26),
(1136,'Henrique','F',66),
(1137,'Luana','F',41),
(1138,'Amanda','F',70),
(1139,'Beatriz','F',66),
(1140,'Larissa','F',20),
(1141,'Bruno','F',39),
(1142,'Eduardo','F',33),
(1143,'Fábio','F',53),
(1144,'Beatriz','F',49),
(1145,'Vinicius','F',31),
(1146,'Eduardo','F',26),
(1147,'Isabela','F',21),
(1148,'Débora','F',37),
(1149,'Mariana','F',52),
(1150,'Tatiane','F',45),
(1151,'Sabrina','F',69),
(1152,'Mateus','F',54),
(1153,'Renato','F',48),
(1154,'Larissa','F',58),
(1155,'Patrícia','F',31),
(1156,'Daniel','F',69),
(1157,'Bianca','F',33),
(1158,'Clara','F',32),
(1159,'Aline','F',70),
(1160,'Felipe','F',21),
(1161,'Camila','F',50),
(1162,'Caio','F',61),
(1163,'Ricardo','F',22),
(1164,'João','F',54),
(1165,'Paula','F',38),
(1166,'Eduardo','F',49),
(1167,'Rodrigo','F',23),
(1168,'Amanda','F',64),
(1169,'Patrícia','F',67),
(1170,'Juliana','F',53),
(1171,'Michele','F',44),
(1172,'Bruno','F',64),
(1173,'Henrique','F',41),
(1174,'Mateus','F',41),
(1175,'Débora','F',37),
(1176,'André','F',20),
(1177,'Letícia','F',54),
(1178,'Thiago','F',61),
(1179,'Márcio','F',60),
(1180,'Renato','F',66),
(1181,'Caio','F',59),
(1182,'Ricardo','F',47),
(1183,'Elaine','F',68),
(1184,'Sabrina','F',24),
(1185,'Luana','F',24),
(1186,'Natália','F',22),
(1187,'Beatriz','F',39),
(1188,'Cristina','F',35),
(1189,'Vinicius','F',55),
(1190,'Larissa','F',53),
(1191,'Rafael','F',51),
(1192,'Carlos','F',69),
(1193,'Vinicius','F',50),
(1194,'Aline','F',39),
(1195,'Márcio','F',30),
(1196,'Murilo','F',63),
(1197,'Cristina','F',69),
(1198,'Fábio','F',18),
(1199,'Elaine','F',49),
(1200,'Larissa','F',69),
(1201,'Vanessa','F',32),
(1202,'Camila','F',34),
(1203,'Carlos','F',42),
(1204,'Gabriela','F',62),
(1205,'Eduardo','F',43),
(1206,'Isabela','F',53),
(1207,'Amanda','F',70),
(1208,'Luana','F',53),
(1209,'Rodrigo','F',69),
(1210,'Débora','F',65),
(1211,'Tatiane','F',22),
(1212,'Otávio','F',32),
(1213,'Caio','F',70),
(1214,'Beatriz','F',19),
(1215,'Gabriela','F',26),
(1216,'Carlos','F',67),
(1217,'Natália','F',44),
(1218,'Amanda','F',30),
(1219,'Diego','F',65),
(1220,'Tatiane','F',54),
(1221,'Felipe','F',47),
(1222,'Daniel','F',69),
(1223,'Bianca','F',38),
(1224,'João','F',30),
(1225,'Gustavo','F',21),
(1226,'Paula','F',62),
(1227,'Vinicius','F',21),
(1228,'Bruno','F',31),
(1229,'Eduardo','F',52),
(1230,'Mariana','F',31),
(1231,'Aline','F',31),
(1232,'Leonardo','F',51),
(1233,'Juliana','F',21),
(1234,'Felipe','F',19),
(1235,'Vanessa','F',63),
(1236,'Aline','F',45),
(1237,'Murilo','F',50),
(1238,'Thiago','F',43),
(1239,'Letícia','F',54),
(1240,'Luana','F',53),
(1241,'Daniel','F',54),
(1242,'Gustavo','F',41),
(1243,'Amanda','F',21),
(1244,'André','F',58),
(1245,'Ana','F',22),
(1246,'Vinicius','F',48),
(1247,'Natália','F',47),
(1248,'Otávio','F',23),
(1249,'João','F',47),
(1250,'Henrique','F',21),
(1251,'Mariana','F',28),
(1252,'Bianca','F',48),
(1253,'Rafael','F',66),
(1254,'Rodrigo','F',63),
(1255,'Cristina','F',18),
(1256,'Gabriela','F',50),
(1257,'Tatiane','F',41),
(1258,'Sabrina','F',38),
(1259,'Fábio','F',51),
(1260,'Eduardo','F',28),
(1261,'Priscila','F',44),
(1262,'Bruno','F',18),
(1263,'Renato','F',34),
(1264,'Clara','F',66),
(1265,'Rafael','F',65),
(1266,'Débora','F',48),
(1267,'Márcio','F',37),
(1268,'Letícia','F',50),
(1269,'Carlos','F',34),
(1270,'Rodrigo','F',20),
(1271,'Thiago','F',55),
(1272,'Caio','F',52),
(1273,'Camila','F',49),
(1274,'Tatiane','F',33),
(1275,'Sabrina','F',53),
(1276,'Lucas','F',30),
(1277,'Luana','F',40),
(1278,'Vanessa','F',55),
(1279,'Mariana','F',36),
(1280,'Gustavo','F',68),
(1281,'Vinicius','F',66),
(1282,'João','F',58),
(1283,'Patrícia','F',57),
(1284,'Natália','F',61),
(1285,'Murilo','F',39),
(1286,'Diego','F',43),
(1287,'Mateus','F',36),
(1288,'Aline','F',34),
(1289,'Fábio','F',45),
(1290,'Vanessa','F',21),
(1291,'Leonardo','F',43),
(1292,'Gabriela','F',36),
(1293,'Tatiane','F',64),
(1294,'Sabrina','F',68),
(1295,'Rafael','F',30),
(1296,'Camila','F',36),
(1297,'Amanda','F',54),
(1298,'Clara','F',37),
(1299,'Mariana','F',56),
(1300,'Ricardo','F',45),
(1301,'Thiago','F',39),
(1302,'Beatriz','F',22),
(1303,'Elaine','F',31),
(1304,'Mateus','F',51),
(1305,'Vinicius','F',38),
(1306,'Luana','F',68),
(1307,'Rodrigo','F',39),
(1308,'Débora','F',49),
(1309,'Gustavo','F',35),
(1310,'Tatiane','F',53),
(1311,'Sabrina','F',29),
(1312,'Aline','F',24),
(1313,'Ricardo','F',59),
(1314,'Elaine','F',66),
(1315,'Natália','F',36),
(1316,'Vinicius','F',66),
(1317,'Thiago','F',46),
(1318,'Amanda','F',31),
(1319,'Mariana','F',22),
(1320,'Márcio','F',25),
(1321,'Lucas','F',22),
(1322,'Carlos','F',38),
(1323,'Mateus','F',57),
(1324,'Beatriz','F',21),
(1325,'Daniel','F',30),
(1326,'Juliana','F',51),
(1327,'Camila','F',52),
(1328,'Letícia','F',57),
(1329,'Rafael','F',23),
(1330,'Bruno','F',23),
(1331,'Henrique','F',68),
(1332,'Leonardo','F',58),
(1333,'Luana','F',59),
(1334,'Ana','F',33),
(1335,'Rodrigo','F',25),
(1336,'Débora','F',19),
(1337,'Clara','F',46),
(1338,'João','F',40),
(1339,'Eduardo','F',23),
(1340,'Mateus','F',30),
(1341,'Cristina','F',54),
(1342,'João','F',36),
(1343,'Débora','F',46),
(1344,'Fernanda','F',19),
(1345,'Carlos','F',19),
(1346,'Lucas','F',55),
(1347,'Gabriela','F',59),
(1348,'Letícia','F',36),
(1349,'Michele','F',54),
(1350,'Priscila','F',34),
(1351,'Fábio','F',19),
(1352,'Patrícia','F',64),
(1353,'Renato','F',67),
(1354,'Ricardo','F',68),
(1355,'Elaine','F',23),
(1356,'Juliana','F',42),
(1357,'Thiago','F',51),
(1358,'Caio','F',21),
(1359,'Diego','F',59),
(1360,'Amanda','F',19),
(1361,'André','F',24),
(1362,'Mariana','F',40),
(1363,'Márcio','F',62),
(1364,'Aline','F',26),
(1365,'Gustavo','F',70),
(1366,'Clara','F',45),
(1367,'Bruno','F',52),
(1368,'Vanessa','F',24),
(1369,'Vinicius','F',30),
(1370,'Larissa','F',20),
(1371,'Felipe','F',27),
(1372,'Beatriz','F',56),
(1373,'Ricardo','F',18),
(1374,'Henrique','F',61),
(1375,'Paula','F',62),
(1376,'Elaine','F',18),
(1377,'Thiago','F',52),
(1378,'Renato','F',69),
(1379,'Juliana','F',58),
(1380,'Bianca','F',26),
(1381,'Lucas','F',28),
(1382,'Otávio','F',44),
(1383,'Luana','F',40),
(1384,'Márcio','F',42),
(1385,'Tatiane','F',21),
(1386,'Carlos','F',64),
(1387,'Amanda','F',39),
(1388,'André','F',64),
(1389,'Mateus','F',53),
(1390,'Aline','F',18),
(1391,'Débora','F',47),
(1392,'Gabriela','F',35),
(1393,'Michele','F',58),
(1394,'Patrícia','F',56),
(1395,'João','F',52),
(1396,'Mariana','F',52),
(1397,'Thiago','F',36),
(1398,'Letícia','F',66),
(1399,'Leonardo','F',66),
(1400,'Rafael','F',38),
(1401,'Murilo','F',66),
(1402,'Ricardo','F',67),
(1403,'Bianca','F',25),
(1404,'Cristina','F',32),
(1405,'Márcio','F',29),
(1406,'Ana','F',41),
(1407,'Felipe','F',32),
(1408,'Aline','F',34),
(1409,'André','F',55),
(1410,'Rodrigo','F',32),
(1411,'Diego','F',67),
(1412,'Daniel','F',56),
(1413,'Henrique','F',57),
(1414,'Tatiane','F',54),
(1415,'Juliana','F',18),
(1416,'Michele','F',48),
(1417,'Gabriela','F',50),
(1418,'Carlos','F',40),
(1419,'Amanda','F',25),
(1420,'Patrícia','F',28),
(1421,'Carlos','F',65),
(1422,'Letícia','F',32),
(1423,'Gustavo','F',30),
(1424,'Michele','F',70),
(1425,'Fernanda','F',41),
(1426,'Renato','F',24),
(1427,'Débora','F',28),
(1428,'Juliana','F',29),
(1429,'Mateus','F',34),
(1430,'Bianca','F',56),
(1431,'Larissa','F',36),
(1432,'Otávio','F',41),
(1433,'Felipe','F',67),
(1434,'Cristina','F',70),
(1435,'Eduardo','F',52),
(1436,'Mariana','F',28),
(1437,'Beatriz','F',21),
(1438,'Patrícia','F',58),
(1439,'Ricardo','F',63),
(1440,'Márcio','F',20),
(1441,'Fábio','F',60),
(1442,'Camila','F',46),
(1443,'Rodrigo','F',52),
(1444,'Isabela','F',28),
(1445,'Gabriela','F',57),
(1446,'Luana','F',60),
(1447,'Gabriela','F',68),
(1448,'Renato','F',24),
(1449,'Priscila','F',26),
(1450,'Márcio','F',31),
(1451,'Fernanda','F',53),
(1452,'Eduardo','F',61),
(1453,'Tatiane','F',38),
(1454,'Henrique','F',58),
(1455,'Rodrigo','F',53),
(1456,'Caio','F',43),
(1457,'Bruno','F',41),
(1458,'Camila','F',23),
(1459,'Mariana','F',47),
(1460,'Murilo','F',63),
(1461,'Letícia','F',26),
(1462,'Felipe','F',28),
(1463,'Leonardo','F',43),
(1464,'Débora','F',26),
(1465,'Daniel','F',62),
(1466,'Vanessa','F',54),
(1467,'Juliana','F',62),
(1468,'Sabrina','F',28),
(1469,'Bianca','F',20),
(1470,'Elaine','F',25),
(1471,'Letícia','F',62),
(1472,'Felipe','F',27),
(1473,'Daniel','F',55),
(1474,'Leonardo','F',38),
(1475,'Murilo','F',40),
(1476,'Renato','F',23),
(1477,'Diego','F',28),
(1478,'Patrícia','F',42),
(1479,'Amanda','F',53),
(1480,'Natália','F',34),
(1481,'Fernanda','F',27),
(1482,'Aline','F',36),
(1483,'Luana','F',26),
(1484,'Vinicius','F',54),
(1485,'Juliana','F',23),
(1486,'Gabriela','F',49),
(1487,'Bianca','F',70),
(1488,'Ana','F',55),
(1489,'Fábio','F',23),
(1490,'Lucas','F',55),
(1491,'Caio','F',28),
(1492,'Carlos','F',58),
(1493,'Ricardo','F',36),
(1494,'Priscila','F',41),
(1495,'Gustavo','F',54),
(1496,'Bruno','F',28),
(1497,'Márcio','F',22),
(1498,'Tatiane','F',36),
(1499,'Mateus','F',27),
(1500,'Vanessa','F',19),
(1501,'Fábio','F',21),
(1502,'Gabriela','F',29),
(1503,'Priscila','F',69),
(1504,'Daniel','F',34),
(1505,'Murilo','F',43),
(1506,'Beatriz','F',37),
(1507,'Felipe','F',47),
(1508,'Patrícia','F',43),
(1509,'Cristina','F',60),
(1510,'Ana','F',31),
(1511,'Lucas','F',31),
(1512,'Fernanda','F',18),
(1513,'Juliana','F',62),
(1514,'Otávio','F',46),
(1515,'Michele','F',65),
(1516,'Mariana','F',37),
(1517,'Thiago','F',40),
(1518,'Fábio','F',66),
(1519,'Murilo','F',53),
(1520,'Renato','F',33),
(1521,'Clara','F',25),
(1522,'Vinicius','F',28),
(1523,'Camila','F',70),
(1524,'Luana','F',28),
(1525,'Aline','F',60),
(1526,'Bruno','F',64),
(1527,'Gabriela','F',67),
(1528,'Otávio','F',41),
(1529,'Caio','F',31),
(1530,'Priscila','F',35),
(1531,'Rafael','F',47),
(1532,'Paula','F',22),
(1533,'Larissa','F',70),
(1534,'Mateus','F',23),
(1535,'Fernanda','F',63),
(1536,'Carlos','F',46),
(1537,'Thiago','F',29),
(1538,'Vanessa','F',67),
(1539,'Isabela','F',29),
(1540,'André','F',54),
(1541,'Leonardo','F',43),
(1542,'Ana','F',57),
(1543,'Felipe','F',19),
(1544,'Eduardo','F',51),
(1545,'Bianca','F',25),
(1546,'Mateus','F',65),
(1547,'Isabela','F',34),
(1548,'Letícia','F',70),
(1549,'Débora','F',53),
(1550,'Thiago','F',52),
(1551,'Márcio','F',64),
(1552,'Michele','F',46),
(1553,'Aline','F',33),
(1554,'Juliana','F',47),
(1555,'André','F',56),
(1556,'Bruno','F',21),
(1557,'Mariana','F',42),
(1558,'Felipe','F',44),
(1559,'Caio','F',60),
(1560,'Rafael','F',33),
(1561,'Rodrigo','F',70),
(1562,'Murilo','F',28),
(1563,'Gustavo','F',37),
(1564,'Paula','F',45),
(1565,'Bianca','F',66),
(1566,'Eduardo','F',43),
(1567,'Henrique','F',51),
(1568,'Diego','F',42),
(1569,'Natália','F',69),
(1570,'João','F',66),
(1571,'Ricardo','F',68),
(1572,'Michele','F',47),
(1573,'Paula','F',41),
(1574,'Clara','F',53),
(1575,'Rafael','F',50),
(1576,'Lucas','F',42),
(1577,'Rodrigo','F',54),
(1578,'Luana','F',67),
(1579,'Daniel','F',20),
(1580,'Renato','F',26),
(1581,'Márcio','F',63),
(1582,'Tatiane','F',46),
(1583,'Juliana','F',41),
(1584,'Vanessa','F',20),
(1585,'Henrique','F',22),
(1586,'Elaine','F',43),
(1587,'Diego','F',64),
(1588,'Débora','F',43),
(1589,'Beatriz','F',50),
(1590,'Ana','F',40),
(1591,'André','F',70),
(1592,'Murilo','F',50),
(1593,'Tatiane','F',31),
(1594,'Rodrigo','F',63),
(1595,'Amanda','F',67),
(1596,'Paula','F',57),
(1597,'Ana','F',63),
(1598,'Vinicius','F',43),
(1599,'Diego','F',37),
(1600,'Thiago','F',43),
(1601,'Juliana','F',36),
(1602,'Natália','F',33),
(1603,'Michele','F',59),
(1604,'Caio','F',39),
(1605,'Mateus','F',69),
(1606,'Bianca','F',33),
(1607,'Márcio','F',23),
(1608,'Mariana','F',67),
(1609,'Leonardo','F',70),
(1610,'Camila','F',55),
(1611,'Gabriela','F',23),
(1612,'Otávio','F',44),
(1613,'Beatriz','F',25),
(1614,'Eduardo','F',34),
(1615,'Daniel','F',25),
(1616,'Letícia','F',29),
(1617,'Patrícia','F',47),
(1618,'Luana','F',60),
(1619,'Mariana','F',45),
(1620,'Carlos','F',60),
(1621,'Juliana','F',66),
(1622,'Tatiane','F',45),
(1623,'Michele','F',27),
(1624,'Thiago','F',30),
(1625,'Cristina','F',22),
(1626,'Felipe','F',20),
(1627,'Eduardo','F',23),
(1628,'Sabrina','F',47),
(1629,'Renato','F',28),
(1630,'João','F',38),
(1631,'Murilo','F',34),
(1632,'Henrique','F',42),
(1633,'Otávio','F',58),
(1634,'Vanessa','F',21),
(1635,'Lucas','F',61),
(1636,'Rodrigo','F',59),
(1637,'Elaine','F',38),
(1638,'Daniel','F',24),
(1639,'Bianca','F',52),
(1640,'Natália','F',19),
(1641,'Vinicius','F',64),
(1642,'Amanda','F',54),
(1643,'Patrícia','F',67),
(1644,'Priscila','F',34),
(1645,'Henrique','F',62),
(1646,'Mariana','F',68),
(1647,'Renato','F',35),
(1648,'Thiago','F',20),
(1649,'Bruno','F',44),
(1650,'Beatriz','F',47),
(1651,'Márcio','F',33),
(1652,'Michele','F',28),
(1653,'Ricardo','F',67),
(1654,'João','F',66),
(1655,'Fernanda','F',66),
(1656,'Leonardo','F',53),
(1657,'Rafael','F',68),
(1658,'Diego','F',31),
(1659,'Mateus','F',67),
(1660,'Débora','F',41),
(1661,'Lucas','F',39),
(1662,'Larissa','F',31),
(1663,'Camila','F',54),
(1664,'Carlos','F',64),
(1665,'Gabriela','F',68),
(1666,'Caio','F',48),
(1667,'André','F',31),
(1668,'João','F',66),
(1669,'Diego','F',40),
(1670,'Bianca','F',70),
(1671,'Priscila','F',41),
(1672,'Rodrigo','F',31),
(1673,'Aline','F',18),
(1674,'Renato','F',53),
(1675,'Letícia','F',34),
(1676,'Beatriz','F',26),
(1677,'André','F',66),
(1678,'Vinicius','F',22),
(1679,'Carlos','F',62),
(1680,'Vanessa','F',31),
(1681,'Michele','F',21),
(1682,'Gabriela','F',42),
(1683,'Henrique','F',70),
(1684,'Natália','F',32),
(1685,'Elaine','F',62),
(1686,'Camila','F',43),
(1687,'Sabrina','F',58),
(1688,'Tatiane','F',65),
(1689,'Ricardo','F',60),
(1690,'Aline','F',33),
(1691,'Ana','F',51),
(1692,'Thiago','F',56),
(1693,'Priscila','F',20),
(1694,'João','F',48),
(1695,'Bruno','F',25),
(1696,'Rodrigo','F',56),
(1697,'Renato','F',20),
(1698,'Natália','F',20),
(1699,'Felipe','F',51),
(1700,'Carlos','F',59),
(1701,'Daniel','F',24),
(1702,'Isabela','F',64),
(1703,'Márcio','F',67),
(1704,'Mateus','F',52),
(1705,'Leonardo','F',55),
(1706,'Fernanda','F',29),
(1707,'Murilo','F',40),
(1708,'André','F',20),
(1709,'Letícia','F',62),
(1710,'Caio','F',24),
(1711,'Felipe','F',44),
(1712,'João','F',45),
(1713,'Ana','F',66),
(1714,'Renato','F',49),
(1715,'Ricardo','F',60),
(1716,'Leonardo','F',51),
(1717,'Sabrina','F',21),
(1718,'Fernanda','F',65),
(1719,'Michele','F',34),
(1720,'Larissa','F',36),
(1721,'Bianca','F',34),
(1722,'Bruno','F',19),
(1723,'Vinicius','F',28),
(1724,'Camila','F',46),
(1725,'Clara','F',66),
(1726,'Thiago','F',52),
(1727,'Murilo','F',69),
(1728,'Henrique','F',27),
(1729,'Fábio','F',64),
(1730,'Thiago','F',28),
(1731,'Bianca','F',49),
(1732,'Carlos','F',26),
(1733,'Elaine','F',67),
(1734,'Rodrigo','F',27),
(1735,'Camila','F',34),
(1736,'Beatriz','F',46),
(1737,'Paula','F',42),
(1738,'Ricardo','F',64),
(1739,'Henrique','F',49),
(1740,'Natália','F',51),
(1741,'Ana','F',43),
(1742,'Luana','F',44),
(1743,'Letícia','F',54),
(1744,'Gustavo','F',40),
(1745,'Isabela','F',30),
(1746,'Débora','F',59),
(1747,'Clara','F',26),
(1748,'Eduardo','F',29),
(1749,'Caio','F',29),
(1750,'Felipe','F',21),
(1751,'Tatiane','F',32),
(1752,'Juliana','F',29),
(1753,'Fábio','F',67),
(1754,'Cristina','F',48),
(1755,'Vanessa','F',57),
(1756,'Mariana','F',38),
(1757,'Patrícia','F',64),
(1758,'Elaine','F',46),
(1759,'Leonardo','F',43),
(1760,'Priscila','F',33),
(1761,'Gustavo','F',53),
(1762,'Caio','F',46),
(1763,'Cristina','F',25),
(1764,'Michele','F',45),
(1765,'Fernanda','F',51),
(1766,'Camila','F',65),
(1767,'Sabrina','F',26),
(1768,'Aline','F',65),
(1769,'Lucas','F',41),
(1770,'Luana','F',35),
(1771,'Mateus','F',50),
(1772,'Natália','F',24),
(1773,'Ricardo','F',55),
(1774,'Rodrigo','F',52),
(1775,'Débora','F',56),
(1776,'Murilo','F',64),
(1777,'Otávio','F',45),
(1778,'Isabela','F',44),
(1779,'Márcio','F',61),
(1780,'Vinicius','F',55),
(1781,'João','F',61),
(1782,'Rafael','F',31),
(1783,'Fábio','F',41),
(1784,'Aline','F',43),
(1785,'Otávio','F',65),
(1786,'Caio','F',63),
(1787,'Eduardo','F',37),
(1788,'Bianca','F',66),
(1789,'Fábio','F',43),
(1790,'Ricardo','F',57),
(1791,'Gabriela','F',34),
(1792,'Amanda','F',44),
(1793,'Felipe','F',29),
(1794,'Leonardo','F',19),
(1795,'Gustavo','F',35),
(1796,'Rodrigo','F',48),
(1797,'Patrícia','F',36),
(1798,'Elaine','F',40),
(1799,'Thiago','F',46),
(1800,'Felipe','F',20),
(1801,'Rodrigo','F',35),
(1802,'Daniel','F',19),
(1803,'Lucas','F',56),
(1804,'Juliana','F',32),
(1805,'Carlos','F',37),
(1806,'Gustavo','F',19),
(1807,'Paula','F',41),
(1808,'Ricardo','F',21),
(1809,'Elaine','F',31),
(1810,'Renato','F',25),
(1811,'Clara','F',50),
(1812,'Vinicius','F',24),
(1813,'Letícia','F',26),
(1814,'Camila','F',30),
(1815,'Mariana','F',40),
(1816,'Bruno','F',67),
(1817,'Isabela','F',21),
(1818,'Priscila','F',23),
(1819,'Amanda','F',44),
(1820,'Otávio','F',24),
(1821,'Márcio','F',52),
(1822,'Diego','F',25),
(1823,'Murilo','F',24),
(1824,'Beatriz','F',56),
(1825,'Mariana','F',29),
(1826,'Patrícia','F',51),
(1827,'Thiago','F',47),
(1828,'Vanessa','F',28),
(1829,'Débora','F',23),
(1830,'Caio','F',45),
(1831,'Mateus','F',38),
(1832,'Fábio','F',40),
(1833,'Tatiane','F',40),
(1834,'Camila','F',23),
(1835,'Priscila','F',68),
(1836,'Leonardo','F',33),
(1837,'Ricardo','F',61),
(1838,'Otávio','F',57),
(1839,'Carlos','F',21),
(1840,'Natália','F',38),
(1841,'Henrique','F',20),
(1842,'Letícia','F',42),
(1843,'Rafael','F',52),
(1844,'Juliana','F',65),
(1845,'Luana','F',58),
(1846,'Beatriz','F',34),
(1847,'Bianca','F',25),
(1848,'Lucas','F',38),
(1849,'Márcio','F',38),
(1850,'Aline','F',38),
(1851,'Cristina','F',50),
(1852,'Thiago','F',29),
(1853,'Elaine','F',31),
(1854,'Otávio','F',37),
(1855,'Isabela','F',53),
(1856,'Diego','F',62),
(1857,'Vanessa','F',52),
(1858,'Caio','F',58),
(1859,'Letícia','F',18),
(1860,'Larissa','F',27),
(1861,'Vinicius','F',40),
(1862,'Murilo','F',68),
(1863,'Juliana','F',24),
(1864,'Débora','F',63),
(1865,'Rodrigo','F',43),
(1866,'Ricardo','F',66),
(1867,'Daniel','F',20),
(1868,'Renato','F',64),
(1869,'Mariana','F',22),
(1870,'Luana','F',41),
(1871,'Michele','F',26),
(1872,'Rodrigo','F',55),
(1873,'Ricardo','F',43),
(1874,'Bruno','F',27),
(1875,'Priscila','F',60),
(1876,'Camila','F',25),
(1877,'Carlos','F',36),
(1878,'Elaine','F',28),
(1879,'Paula','F',51),
(1880,'Bianca','F',66),
(1881,'André','F',37),
(1882,'Aline','F',48),
(1883,'Juliana','F',67),
(1884,'Gustavo','F',64),
(1885,'Vanessa','F',32),
(1886,'Eduardo','F',20),
(1887,'Leonardo','F',44),
(1888,'Beatriz','F',61),
(1889,'Isabela','F',49),
(1890,'Letícia','F',65),
(1891,'Renato','F',37),
(1892,'Caio','F',41),
(1893,'Cristina','F',21),
(1894,'João','F',58),
(1895,'Tatiane','F',38),
(1896,'Rafael','F',33),
(1897,'Patrícia','F',38),
(1898,'Daniel','F',27),
(1899,'Débora','F',64),
(1900,'Ana','F',59),
(1901,'Fábio','F',25),
(1902,'Letícia','F',61),
(1903,'André','F',61),
(1904,'Renato','F',58),
(1905,'Rafael','F',18),
(1906,'Patrícia','F',52),
(1907,'Vinicius','F',55),
(1908,'Diego','F',43),
(1909,'Aline','F',63),
(1910,'Lucas','F',37),
(1911,'Thiago','F',49),
(1912,'Juliana','F',19),
(1913,'Fernanda','F',24),
(1914,'Ricardo','F',42),
(1915,'Priscila','F',35),
(1916,'Eduardo','F',68),
(1917,'Débora','F',55),
(1918,'Amanda','F',60),
(1919,'Bruno','F',29),
(1920,'João','F',40),
(1921,'Elaine','F',28),
(1922,'Rodrigo','F',68),
(1923,'Juliana','F',38),
(1924,'Elaine','F',36),
(1925,'Vanessa','F',70),
(1926,'Ricardo','F',54),
(1927,'João','F',69),
(1928,'Renato','F',49),
(1929,'André','F',42),
(1930,'Tatiane','F',64),
(1931,'Gustavo','F',42),
(1932,'Vinicius','F',38),
(1933,'Ana','F',33),
(1934,'Henrique','F',33),
(1935,'Sabrina','F',31),
(1936,'Thiago','F',51),
(1937,'Caio','F',54),
(1938,'Aline','F',56),
(1939,'Rodrigo','F',42),
(1940,'Murilo','F',51),
(1941,'Márcio','F',32),
(1942,'Paula','F',29),
(1943,'Fábio','F',52),
(1944,'Aline','F',18),
(1945,'Bianca','F',63),
(1946,'Otávio','F',37),
(1947,'Ricardo','F',39),
(1948,'Mariana','F',35),
(1949,'Diego','F',36),
(1950,'Vanessa','F',54),
(1951,'Amanda','F',21),
(1952,'Sabrina','F',28),
(1953,'Felipe','F',59),
(1954,'Carlos','F',22),
(1955,'Débora','F',68),
(1956,'Isabela','F',49),
(1957,'Clara','F',67),
(1958,'Murilo','F',30),
(1959,'Eduardo','F',40),
(1960,'Rafael','F',48),
(1961,'Natália','F',23),
(1962,'Vinicius','F',67),
(1963,'Leonardo','F',65),
(1964,'Patrícia','F',28),
(1965,'Daniel','F',49),
(1966,'Caio','F',53),
(1967,'Camila','F',59),
(1968,'Fernanda','F',56),
(1969,'Gabriela','F',60),
(1970,'Priscila','F',65),
(1971,'Bianca','F',28),
(1972,'Murilo','F',28),
(1973,'Caio','F',40),
(1974,'Vinicius','F',68),
(1975,'Fernanda','F',19),
(1976,'Cristina','F',19),
(1977,'Camila','F',27),
(1978,'Michele','F',62),
(1979,'Clara','F',26),
(1980,'Rafael','F',40),
(1981,'Luana','F',43),
(1982,'Aline','F',35),
(1983,'Gustavo','F',38),
(1984,'Vanessa','F',34),
(1985,'Elaine','F',45),
(1986,'Bruno','F',40),
(1987,'Larissa','F',49),
(1988,'Amanda','F',49),
(1989,'Ana','F',65),
(1990,'Patrícia','F',33),
(1991,'Gabriela','F',49),
(1992,'Thiago','F',66),
(1993,'Otávio','F',36),
(1994,'Natália','F',33),
(1995,'Carlos','F',36),
(1996,'Tatiane','F',68),
(1997,'Vanessa','F',36),
(1998,'Amanda','F',41),
(1999,'Thiago','F',37),
(2000,'Beatriz','F',65),
(2001,'Natália','F',62),
(2002,'Gustavo','F',40),
(2003,'Fábio','F',67),
(2004,'Letícia','F',61),
(2005,'Murilo','F',68),
(2006,'Priscila','F',23),
(2007,'Rodrigo','F',55),
(2008,'Patrícia','F',27),
(2009,'Larissa','F',40),
(2010,'Márcio','F',39),
(2011,'Otávio','F',61),
(2012,'Ana','F',67),
(2013,'Henrique','F',40),
(2014,'Fernanda','F',47),
(2015,'Eduardo','F',60),
(2016,'Michele','F',43),
(2017,'Caio','F',47),
(2018,'Camila','F',62),
(2019,'Vinicius','F',63),
(2020,'Lucas','F',57),
(2021,'Paula','F',19),
(2022,'Amanda','F',53),
(2023,'Isabela','F',58),
(2024,'Renato','F',48),
(2025,'Juliana','F',21),
(2026,'Elaine','F',50),
(2027,'Eduardo','F',35),
(2028,'Michele','F',51),
(2029,'Murilo','F',27),
(2030,'Letícia','F',26),
(2031,'Lucas','F',18),
(2032,'Larissa','F',54),
(2033,'Bianca','F',38),
(2034,'Leonardo','F',33),
(2035,'Clara','F',19),
(2036,'Ana','F',56),
(2037,'Felipe','F',22),
(2038,'Gabriela','F',35),
(2039,'Diego','F',20),
(2040,'Cristina','F',31),
(2041,'Carlos','F',33),
(2042,'Otávio','F',70),
(2043,'Débora','F',34),
(2044,'Mariana','F',59),
(2045,'Larissa','F',68),
(2046,'Fernanda','F',62),
(2047,'Aline','F',32),
(2048,'Daniel','F',22),
(2049,'Juliana','F',58),
(2050,'Leonardo','F',27),
(2051,'Thiago','F',60),
(2052,'Cristina','F',19),
(2053,'Rodrigo','F',60),
(2054,'Gustavo','F',63),
(2055,'Camila','F',40),
(2056,'Débora','F',68),
(2057,'João','F',27),
(2058,'Caio','F',52),
(2059,'Beatriz','F',24),
(2060,'Lucas','F',67),
(2061,'Mateus','F',50),
(2062,'Amanda','F',32),
(2063,'Márcio','F',61),
(2064,'Gabriela','F',52),
(2065,'Bianca','F',67),
(2066,'Otávio','F',64),
(2067,'Luana','F',39),
(2068,'Isabela','F',49),
(2069,'Letícia','F',38),
(2070,'Vinicius','F',69),
(2071,'Felipe','F',64),
(2072,'Elaine','F',60),
(2073,'Ricardo','F',35),
(2074,'Amanda','F',18),
(2075,'Márcio','F',33),
(2076,'Letícia','F',20),
(2077,'Felipe','F',45),
(2078,'Natália','F',54),
(2079,'Tatiane','F',46),
(2080,'Patrícia','F',19),
(2081,'Sabrina','F',19),
(2082,'Henrique','F',59),
(2083,'Aline','F',61),
(2084,'Fernanda','F',66),
(2085,'Diego','F',67),
(2086,'Mariana','F',61),
(2087,'Luana','F',66),
(2088,'Débora','F',43),
(2089,'André','F',58),
(2090,'Rodrigo','F',53),
(2091,'Isabela','F',33),
(2092,'Beatriz','F',40),
(2093,'Cristina','F',55),
(2094,'Renato','F',30),
(2095,'Larissa','F',52),
(2096,'Ana','F',38),
(2097,'Rafael','F',47),
(2098,'Murilo','F',39),
(2099,'Márcio','F',49),
(2100,'Aline','F',61),
(2101,'Bruno','F',32),
(2102,'Ricardo','F',53),
(2103,'Beatriz','F',19),
(2104,'Rodrigo','F',48),
(2105,'Fábio','F',33),
(2106,'Larissa','F',32),
(2107,'Priscila','F',66),
(2108,'Bianca','F',21),
(2109,'Henrique','F',39),
(2110,'Diego','F',48),
(2111,'Gabriela','F',48),
(2112,'Eduardo','F',37),
(2113,'Cristina','F',26),
(2114,'Luana','F',53),
(2115,'Letícia','F',45),
(2116,'João','F',67),
(2117,'Sabrina','F',23),
(2118,'Carlos','F',67),
(2119,'Thiago','F',54),
(2120,'Lucas','F',24),
(2121,'Mariana','F',57),
(2122,'Larissa','F',21),
(2123,'Vinicius','F',21),
(2124,'João','F',62),
(2125,'Sabrina','F',61),
(2126,'Letícia','F',67),
(2127,'Michele','F',42),
(2128,'Clara','F',43),
(2129,'Otávio','F',38),
(2130,'Thiago','F',44),
(2131,'Henrique','F',60),
(2132,'Daniel','F',27),
(2133,'Fábio','F',64),
(2134,'Ricardo','F',57),
(2135,'Luana','F',51),
(2136,'Lucas','F',40),
(2137,'André','F',31),
(2138,'Bianca','F',57),
(2139,'Caio','F',64),
(2140,'Amanda','F',48),
(2141,'Tatiane','F',40),
(2142,'Felipe','F',61),
(2143,'Débora','F',61),
(2144,'Mariana','F',22),
(2145,'Diego','F',40),
(2146,'Fernanda','F',22),
(2147,'Patrícia','F',54),
(2148,'Caio','F',70),
(2149,'Gustavo','F',52),
(2150,'Beatriz','F',62),
(2151,'André','F',68),
(2152,'Diego','F',46),
(2153,'Ricardo','F',55),
(2154,'Lucas','F',34),
(2155,'Leonardo','F',29),
(2156,'Priscila','F',25),
(2157,'Rafael','F',20),
(2158,'Daniel','F',55),
(2159,'Juliana','F',58),
(2160,'Vanessa','F',70),
(2161,'Sabrina','F',46),
(2162,'Larissa','F',20),
(2163,'Michele','F',56),
(2164,'Eduardo','F',47),
(2165,'Paula','F',30),
(2166,'Otávio','F',19),
(2167,'João','F',24),
(2168,'Vinicius','F',38),
(2169,'Clara','F',43),
(2170,'Vinicius','F',26),
(2171,'Felipe','F',59),
(2172,'Carlos','F',45),
(2173,'Luana','F',25),
(2174,'Diego','F',31),
(2175,'Paula','F',61),
(2176,'Ricardo','F',27),
(2177,'Leonardo','F',42),
(2178,'Thiago','F',47),
(2179,'Camila','F',35),
(2180,'Mateus','F',54),
(2181,'Fernanda','F',51),
(2182,'Renato','F',36),
(2183,'Michele','F',19),
(2184,'Gustavo','F',69),
(2185,'Isabela','F',52),
(2186,'Tatiane','F',43),
(2187,'Mariana','F',25),
(2188,'Fábio','F',51),
(2189,'Rafael','F',41),
(2190,'Elaine','F',70),
(2191,'Henrique','F',39),
(2192,'Natália','F',40),
(2193,'Sabrina','F',66),
(2194,'Bianca','F',60),
(2195,'André','F',65),
(2196,'Patrícia','F',31),
(2197,'Otávio','F',66),
(2198,'Ana','F',61),
(2199,'Beatriz','F',58),
(2200,'Rodrigo','F',54),
(2201,'Leonardo','F',37),
(2202,'Michele','F',30),
(2203,'Sabrina','F',35),
(2204,'Elaine','F',30),
(2205,'Vinicius','F',62),
(2206,'Eduardo','F',34),
(2207,'Larissa','F',45),
(2208,'Márcio','F',61),
(2209,'Natália','F',22),
(2210,'Priscila','F',65),
(2211,'Rafael','F',39),
(2212,'Aline','F',70),
(2213,'Ricardo','F',30),
(2214,'Gustavo','F',21),
(2215,'Carlos','F',26),
(2216,'Letícia','F',63),
(2217,'Luana','F',34),
(2218,'Clara','F',64),
(2219,'Diego','F',39),
(2220,'Larissa','F',51),
(2221,'Lucas','F',19),
(2222,'Mariana','F',28),
(2223,'Aline','F',39),
(2224,'Ricardo','F',33),
(2225,'Natália','F',40),
(2226,'Felipe','F',61),
(2227,'Juliana','F',64),
(2228,'Fábio','F',70),
(2229,'Henrique','F',36),
(2230,'Amanda','F',19),
(2231,'Daniel','F',54),
(2232,'Camila','F',30),
(2233,'Sabrina','F',44),
(2234,'Vanessa','F',24),
(2235,'Otávio','F',66),
(2236,'Bruno','F',70),
(2237,'Michele','F',35),
(2238,'André','F',21),
(2239,'João','F',54),
(2240,'Elaine','F',59),
(2241,'Letícia','F',51),
(2242,'Cristina','F',42),
(2243,'Isabela','F',59),
(2244,'Renato','F',19),
(2245,'Elaine','F',44),
(2246,'Juliana','F',58),
(2247,'Diego','F',23),
(2248,'Otávio','F',20),
(2249,'Débora','F',33),
(2250,'Thiago','F',54),
(2251,'Gustavo','F',69),
(2252,'Natália','F',26),
(2253,'Bianca','F',36),
(2254,'Camila','F',20),
(2255,'Leonardo','F',58),
(2256,'Ana','F',25),
(2257,'Fábio','F',67),
(2258,'Letícia','F',29),
(2259,'Priscila','F',50),
(2260,'Clara','F',34),
(2261,'Mateus','F',25),
(2262,'Paula','F',44),
(2263,'Daniel','F',27),
(2264,'Larissa','F',21),
(2265,'Otávio','F',19),
(2266,'Tatiane','F',54),
(2267,'Luana','F',26),
(2268,'Eduardo','F',51),
(2269,'João','F',62),
(2270,'Vinicius','F',40),
(2271,'Fernanda','F',34),
(2272,'Fábio','F',66),
(2273,'Priscila','F',33),
(2274,'Gabriela','F',18),
(2275,'Natália','F',29),
(2276,'Leonardo','F',23),
(2277,'Carlos','F',39),
(2278,'Juliana','F',43),
(2279,'Bianca','F',58),
(2280,'Márcio','F',45),
(2281,'Ana','F',39),
(2282,'Felipe','F',27),
(2283,'Isabela','F',43),
(2284,'Beatriz','F',23),
(2285,'Thiago','F',58),
(2286,'Camila','F',38),
(2287,'Sabrina','F',34),
(2288,'Larissa','F',54),
(2289,'Rafael','F',48),
(2290,'Fábio','F',26),
(2291,'Bruno','F',39),
(2292,'Vanessa','F',30),
(2293,'Cristina','F',42),
(2294,'Luana','F',64),
(2295,'Henrique','F',65),
(2296,'Débora','F',40),
(2297,'Priscila','F',69),
(2298,'Tatiane','F',49),
(2299,'Elaine','F',35),
(2300,'Mariana','F',58),
(2301,'Leonardo','F',53),
(2302,'Márcio','F',62),
(2303,'Carlos','F',30),
(2304,'João','F',61),
(2305,'Eduardo','F',66),
(2306,'Letícia','F',69),
(2307,'Paula','F',23),
(2308,'Lucas','F',59),
(2309,'Sabrina','F',52),
(2310,'Bianca','F',66),
(2311,'Beatriz','F',54),
(2312,'Fernanda','F',67),
(2313,'Caio','F',28),
(2314,'Murilo','F',33),
(2315,'Gustavo','F',48),
(2316,'Isabela','F',54),
(2317,'Márcio','F',49),
(2318,'Camila','F',23),
(2319,'Daniel','F',30),
(2320,'Renato','F',62),
(2321,'Ana','F',30),
(2322,'Amanda','F',35),
(2323,'Vanessa','F',67),
(2324,'Thiago','F',59),
(2325,'Gabriela','F',25),
(2326,'Mateus','F',51),
(2327,'Ricardo','F',49),
(2328,'Bruno','F',63),
(2329,'Michele','F',36),
(2330,'Natália','F',32),
(2331,'Otávio','F',24),
(2332,'Bianca','F',56),
(2333,'Lucas','F',59),
(2334,'André','F',51),
(2335,'Renato','F',68),
(2336,'Sabrina','F',19),
(2337,'Cristina','F',26),
(2338,'Letícia','F',63),
(2339,'João','F',26),
(2340,'Fernanda','F',21),
(2341,'Henrique','F',28),
(2342,'Bruno','F',49),
(2343,'Otávio','F',34),
(2344,'Elaine','F',58),
(2345,'Amanda','F',41),
(2346,'Natália','F',51),
(2347,'Bianca','F',61),
(2348,'Larissa','F',59),
(2349,'Vanessa','F',28),
(2350,'Isabela','F',25),
(2351,'Márcio','F',46),
(2352,'Paula','F',53),
(2353,'Ricardo','F',39),
(2354,'Luana','F',31),
(2355,'Gabriela','F',29),
(2356,'Ana','F',53),
(2357,'Paula','F',62),
(2358,'Henrique','F',64),
(2359,'João','F',43),
(2360,'André','F',66),
(2361,'Caio','F',24),
(2362,'Elaine','F',62),
(2363,'Bruno','F',58),
(2364,'Otávio','F',33),
(2365,'Ricardo','F',25),
(2366,'Débora','F',25),
(2367,'Beatriz','F',45),
(2368,'Leonardo','F',47),
(2369,'Daniel','F',67),
(2370,'Michele','F',44),
(2371,'Letícia','F',20),
(2372,'Larissa','F',44),
(2373,'Mariana','F',59),
(2374,'Mateus','F',48),
(2375,'Sabrina','F',37),
(2376,'Bianca','F',23),
(2377,'Eduardo','F',48),
(2378,'Carlos','F',64),
(2379,'Renato','F',36),
(2380,'André','F',67),
(2381,'Clara','F',23),
(2382,'Diego','F',57),
(2383,'Cristina','F',28),
(2384,'Felipe','F',69),
(2385,'Mariana','F',68),
(2386,'Juliana','F',40),
(2387,'Murilo','F',27),
(2388,'Caio','F',19),
(2389,'Beatriz','F',40),
(2390,'Vinicius','F',21),
(2391,'Michele','F',52),
(2392,'Thiago','F',53),
(2393,'Tatiane','F',46),
(2394,'Bruno','F',64),
(2395,'Isabela','F',53),
(2396,'Henrique','F',23),
(2397,'Amanda','F',67),
(2398,'Natália','F',59),
(2399,'Patrícia','F',53),
(2400,'Fernanda','F',45),
(2401,'Márcio','F',61),
(2402,'João','F',66),
(2403,'Ana','F',32),
(2404,'Leonardo','F',21),
(2405,'Cristina','F',47),
(2406,'Fábio','F',56),
(2407,'Lucas','F',28),
(2408,'Patrícia','F',51),
(2409,'Bianca','F',43),
(2410,'Elaine','F',39),
(2411,'Renato','F',57),
(2412,'Vanessa','F',19),
(2413,'Eduardo','F',58),
(2414,'Ana','F',20),
(2415,'Letícia','F',67),
(2416,'Michele','F',20),
(2417,'Natália','F',39),
(2418,'Mateus','F',54),
(2419,'Fernanda','F',56),
(2420,'Otávio','F',41),
(2421,'Carlos','F',61),
(2422,'Rodrigo','F',45),
(2423,'Clara','F',63),
(2424,'Rafael','F',26),
(2425,'Ricardo','F',67),
(2426,'Paula','F',26),
(2427,'Márcio','F',51),
(2428,'Vinicius','F',21),
(2429,'João','F',41),
(2430,'Thiago','F',20),
(2431,'Tatiane','F',41),
(2432,'Letícia','F',52),
(2433,'Ana','F',20),
(2434,'Vinicius','F',27),
(2435,'Murilo','F',45),
(2436,'Fábio','F',28),
(2437,'Sabrina','F',37),
(2438,'Gabriela','F',61),
(2439,'Daniel','F',56),
(2440,'Clara','F',37),
(2441,'Renato','F',42),
(2442,'Natália','F',34),
(2443,'Juliana','F',46),
(2444,'Michele','F',57),
(2445,'Fernanda','F',63),
(2446,'Larissa','F',22),
(2447,'Beatriz','F',45),
(2448,'Elaine','F',43),
(2449,'Henrique','F',40),
(2450,'Lucas','F',30),
(2451,'Thiago','F',19),
(2452,'Luana','F',40),
(2453,'Rafael','F',25),
(2454,'Cristina','F',27),
(2455,'Thiago','F',29),
(2456,'Fernanda','F',65),
(2457,'Elaine','F',33),
(2458,'Clara','F',48),
(2459,'Isabela','F',52),
(2460,'Camila','F',43),
(2461,'Michele','F',49),
(2462,'Mateus','F',41),
(2463,'Felipe','F',55),
(2464,'Ricardo','F',27),
(2465,'Gustavo','F',53),
(2466,'Henrique','F',63),
(2467,'Otávio','F',59),
(2468,'Tatiane','F',34),
(2469,'Márcio','F',21),
(2470,'Diego','F',32),
(2471,'Gabriela','F',56),
(2472,'Bianca','F',48),
(2473,'Juliana','F',58),
(2474,'Renato','F',41),
(2475,'Vinicius','F',58),
(2476,'Gabriela','F',41),
(2477,'Débora','F',50),
(2478,'Natália','F',37),
(2479,'Ana','F',65),
(2480,'Eduardo','F',37),
(2481,'Amanda','F',20),
(2482,'Isabela','F',47),
(2483,'Leonardo','F',40),
(2484,'Michele','F',57),
(2485,'Tatiane','F',60),
(2486,'Mateus','F',64),
(2487,'André','F',40),
(2488,'Henrique','F',48),
(2489,'Márcio','F',60),
(2490,'Larissa','F',42),
(2491,'Juliana','F',70),
(2492,'Cristina','F',33),
(2493,'Mariana','F',27),
(2494,'Luana','F',47),
(2495,'Rafael','F',53),
(2496,'Beatriz','F',39),
(2497,'Gustavo','F',46),
(2498,'Elaine','F',53),
(2499,'Sabrina','F',58),
(2500,'Vanessa','F',69),
(2501,'João','F',19),
(2502,'Cristina','F',54),
(2503,'Isabela','F',35),
(2504,'Mariana','F',45),
(2505,'Gustavo','F',69),
(2506,'Larissa','F',50),
(2507,'Felipe','F',27),
(2508,'Otávio','F',68),
(2509,'Tatiane','F',58),
(2510,'Thiago','F',38),
(2511,'Caio','F',59),
(2512,'Bruno','F',69),
(2513,'Amanda','F',38),
(2514,'Vinicius','F',39),
(2515,'André','F',55),
(2516,'Paula','F',18),
(2517,'Letícia','F',31),
(2518,'Felipe','F',23),
(2519,'Isabela','F',26),
(2520,'Débora','F',51),
(2521,'Mateus','F',48),
(2522,'Daniel','F',44),
(2523,'Otávio','F',56),
(2524,'Paula','F',53),
(2525,'Aline','F',70),
(2526,'Sabrina','F',19),
(2527,'Camila','F',60),
(2528,'Michele','F',57),
(2529,'Rafael','F',58),
(2530,'Gustavo','F',20),
(2531,'Eduardo','F',41),
(2532,'Leonardo','F',27),
(2533,'Carlos','F',30),
(2534,'Lucas','F',62),
(2535,'Mariana','F',65),
(2536,'Bruno','F',54),
(2537,'Juliana','F',24),
(2538,'João','F',35),
(2539,'Beatriz','F',63),
(2540,'Bianca','F',35),
(2541,'Márcio','F',60),
(2542,'Murilo','F',45),
(2543,'Fernanda','F',49),
(2544,'Rafael','F',47),
(2545,'Clara','F',63),
(2546,'Leonardo','F',56),
(2547,'Beatriz','F',43),
(2548,'Ricardo','F',25),
(2549,'Gustavo','F',42),
(2550,'Bianca','F',23),
(2551,'Rodrigo','F',57),
(2552,'Luana','F',37),
(2553,'Ana','F',44),
(2554,'Lucas','F',46),
(2555,'Larissa','F',55),
(2556,'Isabela','F',57),
(2557,'Débora','F',54),
(2558,'Elaine','F',28),
(2559,'Camila','F',47),
(2560,'Bruno','F',41),
(2561,'Eduardo','F',61),
(2562,'Natália','F',49),
(2563,'Letícia','F',27),
(2564,'Renato','F',40),
(2565,'Tatiane','F',20),
(2566,'Paula','F',46),
(2567,'Michele','F',39),
(2568,'Aline','F',19),
(2569,'Michele','F',30),
(2570,'Bruno','F',57),
(2571,'Priscila','F',55),
(2572,'Leonardo','F',46),
(2573,'Gabriela','F',61),
(2574,'Murilo','F',65),
(2575,'Natália','F',18),
(2576,'André','F',62),
(2577,'Márcio','F',62),
(2578,'Ricardo','F',65),
(2579,'Fábio','F',42),
(2580,'Tatiane','F',44),
(2581,'Amanda','F',53),
(2582,'Gustavo','F',41),
(2583,'Rodrigo','F',63),
(2584,'Cristina','F',36),
(2585,'Diego','F',51),
(2586,'Patrícia','F',64),
(2587,'Márcio','F',33),
(2588,'Lucas','F',61),
(2589,'Rafael','F',44),
(2590,'Carlos','F',62),
(2591,'Beatriz','F',70),
(2592,'Elaine','F',28),
(2593,'Aline','F',62),
(2594,'Renato','F',54),
(2595,'Fernanda','F',70),
(2596,'Henrique','F',66),
(2597,'Caio','F',64),
(2598,'Rodrigo','F',67),
(2599,'Ricardo','F',44),
(2600,'Bruno','F',65),
(2601,'Sabrina','F',46),
(2602,'Amanda','F',52),
(2603,'Otávio','F',57),
(2604,'Priscila','F',60),
(2605,'Letícia','F',53),
(2606,'Mariana','F',28),
(2607,'Mateus','F',51),
(2608,'Michele','F',45),
(2609,'Ana','F',30),
(2610,'Leonardo','F',38),
(2611,'Natália','F',48),
(2612,'Vinicius','F',55),
(2613,'Eduardo','F',47),
(2614,'Bianca','F',19),
(2615,'Murilo','F',64),
(2616,'Paula','F',23),
(2617,'Larissa','F',36),
(2618,'Juliana','F',29),
(2619,'Patrícia','F',51),
(2620,'Gabriela','F',66),
(2621,'Diego','F',40),
(2622,'Aline','F',30),
(2623,'Beatriz','F',28),
(2624,'Letícia','F',53),
(2625,'André','F',43),
(2626,'Amanda','F',63),
(2627,'Sabrina','F',34),
(2628,'Débora','F',64),
(2629,'Bianca','F',41),
(2630,'Márcio','F',70),
(2631,'Fernanda','F',60),
(2632,'Isabela','F',50),
(2633,'João','F',37),
(2634,'Patrícia','F',19),
(2635,'Daniel','F',68),
(2636,'Vinicius','F',24),
(2637,'Natália','F',51),
(2638,'Lucas','F',48),
(2639,'Camila','F',58),
(2640,'Paula','F',34),
(2641,'Murilo','F',54),
(2642,'Leonardo','F',42),
(2643,'Felipe','F',61),
(2644,'Clara','F',25),
(2645,'Lucas','F',32),
(2646,'Camila','F',47),
(2647,'Mariana','F',22),
(2648,'Otávio','F',51),
(2649,'Aline','F',60),
(2650,'Felipe','F',53),
(2651,'Patrícia','F',57),
(2652,'Paula','F',54),
(2653,'Márcio','F',44),
(2654,'Sabrina','F',24),
(2655,'André','F',41),
(2656,'Murilo','F',56),
(2657,'Bianca','F',55),
(2658,'Vinicius','F',58),
(2659,'Bruno','F',53),
(2660,'Leonardo','F',37),
(2661,'Priscila','F',26),
(2662,'Gabriela','F',25),
(2663,'Rafael','F',29),
(2664,'Natália','F',31),
(2665,'Fábio','F',37),
(2666,'Juliana','F',40),
(2667,'Beatriz','F',19),
(2668,'Renato','F',68),
(2669,'Henrique','F',37),
(2670,'Paula','F',55),
(2671,'Bruno','F',48),
(2672,'Bianca','F',38),
(2673,'Lucas','F',43),
(2674,'Mariana','F',36),
(2675,'Vanessa','F',30),
(2676,'Michele','F',59),
(2677,'Renato','F',60),
(2678,'Mateus','F',53),
(2679,'Otávio','F',56),
(2680,'Gustavo','F',44),
(2681,'Patrícia','F',49),
(2682,'Eduardo','F',43),
(2683,'Caio','F',69),
(2684,'Thiago','F',24),
(2685,'Tatiane','F',42),
(2686,'Amanda','F',22),
(2687,'Letícia','F',66),
(2688,'Diego','F',27),
(2689,'Priscila','F',33),
(2690,'Ricardo','F',45),
(2691,'Fábio','F',37),
(2692,'Carlos','F',63),
(2693,'João','F',51),
(2694,'Sabrina','F',26),
(2695,'Beatriz','F',68),
(2696,'Ricardo','F',56),
(2697,'Rafael','F',28),
(2698,'Leonardo','F',22),
(2699,'Cristina','F',25),
(2700,'Isabela','F',42),
(2701,'Bianca','F',28),
(2702,'Gustavo','F',67),
(2703,'Eduardo','F',20),
(2704,'Lucas','F',66),
(2705,'João','F',54),
(2706,'Elaine','F',65),
(2707,'Ana','F',60),
(2708,'Amanda','F',70),
(2709,'Michele','F',38),
(2710,'Bruno','F',40),
(2711,'Fernanda','F',43),
(2712,'Henrique','F',18),
(2713,'Carlos','F',30),
(2714,'Márcio','F',33),
(2715,'Paula','F',35),
(2716,'Otávio','F',31),
(2717,'André','F',37),
(2718,'Caio','F',60),
(2719,'Patrícia','F',53),
(2720,'Mariana','F',53),
(2721,'Elaine','F',59),
(2722,'Ricardo','F',35),
(2723,'Natália','F',47),
(2724,'Vanessa','F',62),
(2725,'Rodrigo','F',21),
(2726,'Carlos','F',41),
(2727,'Leonardo','F',52),
(2728,'Thiago','F',49),
(2729,'Henrique','F',44),
(2730,'Aline','F',33),
(2731,'Bianca','F',28),
(2732,'Tatiane','F',24),
(2733,'Daniel','F',27),
(2734,'Bruno','F',65),
(2735,'Cristina','F',19),
(2736,'João','F',59),
(2737,'Amanda','F',30),
(2738,'Murilo','F',43),
(2739,'Gabriela','F',46),
(2740,'Felipe','F',45),
(2741,'Gustavo','F',27),
(2742,'Márcio','F',48),
(2743,'Eduardo','F',36),
(2744,'João','F',31),
(2745,'Sabrina','F',69),
(2746,'Mateus','F',70),
(2747,'Amanda','F',35),
(2748,'Thiago','F',32),
(2749,'Luana','F',49),
(2750,'Bruno','F',30),
(2751,'Vanessa','F',52),
(2752,'Otávio','F',49),
(2753,'Fernanda','F',21),
(2754,'Murilo','F',34),
(2755,'Leonardo','F',23),
(2756,'Lucas','F',56),
(2757,'Cristina','F',70),
(2758,'Ana','F',26),
(2759,'Patrícia','F',32),
(2760,'Natália','F',56),
(2761,'Felipe','F',36),
(2762,'Bianca','F',37),
(2763,'Juliana','F',53),
(2764,'Vanessa','F',37),
(2765,'Patrícia','F',25),
(2766,'Gustavo','F',32),
(2767,'Aline','F',53),
(2768,'Felipe','F',42),
(2769,'Amanda','F',65),
(2770,'Mateus','F',62),
(2771,'Isabela','F',55),
(2772,'Eduardo','F',26),
(2773,'Paula','F',22),
(2774,'Henrique','F',48),
(2775,'Rodrigo','F',70),
(2776,'Renato','F',50),
(2777,'Rafael','F',49),
(2778,'Tatiane','F',26),
(2779,'Ana','F',29),
(2780,'Débora','F',38),
(2781,'Gabriela','F',66),
(2782,'Natália','F',22),
(2783,'Cristina','F',49),
(2784,'Camila','F',21),
(2785,'Thiago','F',51),
(2786,'Patrícia','F',20),
(2787,'Tatiane','F',36),
(2788,'Otávio','F',28),
(2789,'Vinicius','F',34),
(2790,'Elaine','F',38),
(2791,'Carlos','F',31),
(2792,'Thiago','F',54),
(2793,'Rafael','F',27),
(2794,'Letícia','F',35),
(2795,'Gustavo','F',68),
(2796,'Gabriela','F',20),
(2797,'Larissa','F',49),
(2798,'Lucas','F',70),
(2799,'Bianca','F',48),
(2800,'André','F',38),
(2801,'Isabela','F',47),
(2802,'Rodrigo','F',23),
(2803,'Luana','F',27),
(2804,'Gabriela','F',55),
(2805,'André','F',33),
(2806,'João','F',24),
(2807,'Mariana','F',67),
(2808,'Paula','F',31),
(2809,'Larissa','F',47),
(2810,'Bruno','F',62),
(2811,'Rafael','F',26),
(2812,'Beatriz','F',42),
(2813,'Fernanda','F',33),
(2814,'Otávio','F',49),
(2815,'Carlos','F',40),
(2816,'Juliana','F',46),
(2817,'Vinicius','F',47),
(2818,'Henrique','F',58),
(2819,'Leonardo','F',69),
(2820,'Vanessa','F',40),
(2821,'Clara','F',53),
(2822,'Patrícia','F',21),
(2823,'Cristina','F',21),
(2824,'Elaine','F',70),
(2825,'Murilo','F',70),
(2826,'Michele','F',62),
(2827,'André','F',32),
(2828,'Carlos','F',69),
(2829,'Thiago','F',65),
(2830,'Clara','F',43),
(2831,'Beatriz','F',57),
(2832,'Tatiane','F',41),
(2833,'Vanessa','F',26),
(2834,'Aline','F',65),
(2835,'Larissa','F',57),
(2836,'Felipe','F',31),
(2837,'Isabela','F',65),
(2838,'Ana','F',39),
(2839,'Ricardo','F',52),
(2840,'Juliana','F',26),
(2841,'Gabriela','F',63),
(2842,'Cristina','F',19),
(2843,'Márcio','F',53),
(2844,'Michele','F',51),
(2845,'Eduardo','F',42),
(2846,'Fernanda','F',44),
(2847,'Caio','F',47),
(2848,'Bruno','F',28),
(2849,'Ricardo','F',25),
(2850,'Rafael','F',70),
(2851,'Felipe','F',36),
(2852,'Amanda','F',40),
(2853,'Thiago','F',62),
(2854,'Vanessa','F',46),
(2855,'Otávio','F',30),
(2856,'Priscila','F',22),
(2857,'Mateus','F',67),
(2858,'Renato','F',21),
(2859,'Vinicius','F',70),
(2860,'Camila','F',35),
(2861,'Elaine','F',63),
(2862,'Aline','F',35),
(2863,'Natália','F',37),
(2864,'Michele','F',56),
(2865,'Murilo','F',46),
(2866,'Diego','F',33),
(2867,'Fábio','F',33),
(2868,'Daniel','F',70),
(2869,'Rodrigo','F',61),
(2870,'Fernanda','F',54),
(2871,'Bianca','F',39),
(2872,'Lucas','F',67),
(2873,'Cristina','F',61),
(2874,'Tatiane','F',37),
(2875,'Leonardo','F',46),
(2876,'Larissa','F',38),
(2877,'João','F',52),
(2878,'Isabela','F',49),
(2879,'Eduardo','F',53),
(2880,'Caio','F',29),
(2881,'Márcio','F',22),
(2882,'Henrique','F',20),
(2883,'Tatiane','F',42),
(2884,'Luana','F',42),
(2885,'Carlos','F',57),
(2886,'André','F',31),
(2887,'Aline','F',56),
(2888,'Rodrigo','F',42),
(2889,'Lucas','F',27),
(2890,'Vanessa','F',28),
(2891,'Gabriela','F',39),
(2892,'Ana','F',59),
(2893,'Vinicius','F',27),
(2894,'Paula','F',42),
(2895,'Mateus','F',70),
(2896,'Rafael','F',19),
(2897,'Thiago','F',25),
(2898,'Felipe','F',22),
(2899,'Débora','F',22),
(2900,'Murilo','F',39),
(2901,'Michele','F',19),
(2902,'Luana','F',24),
(2903,'Renato','F',35),
(2904,'Tatiane','F',34),
(2905,'Fábio','F',26),
(2906,'Carlos','F',37),
(2907,'Rafael','F',51),
(2908,'Ana','F',19),
(2909,'Márcio','F',56),
(2910,'Otávio','F',28),
(2911,'Cristina','F',48),
(2912,'Diego','F',28),
(2913,'Beatriz','F',31),
(2914,'Vinicius','F',45),
(2915,'Leonardo','F',21),
(2916,'Thiago','F',51),
(2917,'Michele','F',34),
(2918,'Aline','F',56),
(2919,'Mateus','F',56),
(2920,'Fernanda','F',42),
(2921,'Amanda','F',66),
(2922,'Letícia','F',24),
(2923,'Natália','F',60),
(2924,'Felipe','F',68),
(2925,'André','F',38),
(2926,'Elaine','F',43),
(2927,'Paula','F',24),
(2928,'João','F',40),
(2929,'Gustavo','F',50),
(2930,'Débora','F',25),
(2931,'Camila','F',63),
(2932,'Mateus','F',32),
(2933,'Renato','F',66),
(2934,'Caio','F',54),
(2935,'João','F',24),
(2936,'Amanda','F',29),
(2937,'Michele','F',52),
(2938,'Bianca','F',58),
(2939,'Bruno','F',68),
(2940,'Aline','F',52),
(2941,'Eduardo','F',59),
(2942,'Patrícia','F',57),
(2943,'Fernanda','F',47),
(2944,'Débora','F',69),
(2945,'Daniel','F',70),
(2946,'Juliana','F',37),
(2947,'Otávio','F',64),
(2948,'Carlos','F',64),
(2949,'Murilo','F',32),
(2950,'Natália','F',70),
(2951,'Diego','F',54),
(2952,'Thiago','F',52),
(2953,'Sabrina','F',18),
(2954,'Cristina','F',58),
(2955,'Priscila','F',33),
(2956,'Isabela','F',32),
(2957,'Henrique','F',29),
(2958,'Elaine','F',61),
(2959,'Letícia','F',53),
(2960,'Paula','F',52),
(2961,'Carlos','F',62),
(2962,'Aline','F',29),
(2963,'Eduardo','F',48),
(2964,'Michele','F',54),
(2965,'Natália','F',70),
(2966,'Beatriz','F',42),
(2967,'Diego','F',18),
(2968,'Thiago','F',38),
(2969,'Mateus','F',30),
(2970,'Elaine','F',58),
(2971,'Patrícia','F',66),
(2972,'Priscila','F',19),
(2973,'Caio','F',37),
(2974,'Juliana','F',29),
(2975,'Otávio','F',66),
(2976,'Sabrina','F',50),
(2977,'Leonardo','F',51),
(2978,'Felipe','F',46),
(2979,'Rafael','F',59),
(2980,'Bruno','F',21),
(2981,'Fábio','F',67),
(2982,'Ana','F',65),
(2983,'Ricardo','F',40),
(2984,'Beatriz','F',67),
(2985,'Cristina','F',21),
(2986,'Henrique','F',59),
(2987,'Michele','F',51),
(2988,'Bruno','F',64),
(2989,'Vinicius','F',63),
(2990,'Leonardo','F',46),
(2991,'Rafael','F',45),
(2992,'André','F',35),
(2993,'Rodrigo','F',28),
(2994,'Felipe','F',63),
(2995,'Thiago','F',47),
(2996,'Otávio','F',41),
(2997,'Luana','F',53),
(2998,'Diego','F',53),
(2999,'Ana','F',20),
(3000,'Márcio','F',31),
(3001,'Tatiane','F',40),
(3002,'Natália','F',49),
(3003,'Priscila','F',38),
(3004,'Elaine','F',51),
(3005,'Murilo','F',33),
(3006,'Isabela','F',63),
(3007,'Mariana','F',30),
(3008,'Letícia','F',52),
(3009,'João','F',22),
(3010,'Ana','F',23),
(3011,'Lucas','F',66),
(3012,'Murilo','F',63),
(3013,'Elaine','F',53),
(3014,'Ricardo','F',36),
(3015,'Amanda','F',49),
(3016,'Daniel','F',34),
(3017,'Juliana','F',69),
(3018,'Eduardo','F',30),
(3019,'Priscila','F',44),
(3020,'Caio','F',54),
(3021,'Vanessa','F',27),
(3022,'Thiago','F',64),
(3023,'Aline','F',65),
(3024,'Michele','F',56),
(3025,'Mariana','F',66),
(3026,'Mateus','F',55),
(3027,'Felipe','F',36),
(3028,'Bruno','F',62),
(3029,'Fernanda','F',49),
(3030,'Débora','F',59),
(3031,'André','F',57),
(3032,'Rodrigo','F',68),
(3033,'Natália','F',60),
(3034,'Priscila','F',32),
(3035,'Larissa','F',38),
(3036,'Carlos','F',37),
(3037,'Ana','F',36),
(3038,'Beatriz','F',63),
(3039,'Caio','F',60),
(3040,'Tatiane','F',36),
(3041,'Gustavo','F',51),
(3042,'Daniel','F',33),
(3043,'Patrícia','F',70),
(3044,'Camila','F',61),
(3045,'Lucas','F',26),
(3046,'Vanessa','F',25),
(3047,'Felipe','F',70),
(3048,'Juliana','F',36),
(3049,'Amanda','F',34),
(3050,'Diego','F',18),
(3051,'Clara','F',61),
(3052,'Renato','F',52),
(3053,'Fábio','F',61),
(3054,'João','F',59),
(3055,'Letícia','F',61),
(3056,'Elaine','F',26),
(3057,'Rodrigo','F',30),
(3058,'Isabela','F',61),
(3059,'Cristina','F',20),
(3060,'Michele','F',20),
(3061,'Isabela','F',63),
(3062,'Aline','F',46),
(3063,'Diego','F',33),
(3064,'Caio','F',65),
(3065,'Vanessa','F',29),
(3066,'Gustavo','F',29),
(3067,'André','F',44),
(3068,'Thiago','F',64),
(3069,'Amanda','F',33),
(3070,'Larissa','F',34),
(3071,'Daniel','F',52),
(3072,'Leonardo','F',45),
(3073,'Camila','F',21),
(3074,'Fábio','F',52),
(3075,'Eduardo','F',29),
(3076,'Juliana','F',24),
(3077,'Mateus','F',35),
(3078,'Natália','F',35),
(3079,'Caio','F',26),
(3080,'Otávio','F',64),
(3081,'Débora','F',25),
(3082,'André','F',68),
(3083,'Michele','F',56),
(3084,'Renato','F',51),
(3085,'Murilo','F',55),
(3086,'Diego','F',20),
(3087,'Gustavo','F',50),
(3088,'Elaine','F',37),
(3089,'Sabrina','F',18),
(3090,'Carlos','F',69),
(3091,'Vinicius','F',68),
(3092,'Henrique','F',64),
(3093,'Beatriz','F',32),
(3094,'Paula','F',19),
(3095,'Isabela','F',58),
(3096,'Rafael','F',62),
(3097,'Aline','F',51),
(3098,'Ana','F',34),
(3099,'Rafael','F',28),
(3100,'Murilo','F',30),
(3101,'Camila','F',28),
(3102,'Felipe','F',28),
(3103,'Mariana','F',22),
(3104,'Henrique','F',49),
(3105,'Luana','F',43),
(3106,'Sabrina','F',24),
(3107,'Beatriz','F',37),
(3108,'Juliana','F',25),
(3109,'Thiago','F',68),
(3110,'Michele','F',35),
(3111,'Vanessa','F',31),
(3112,'Daniel','F',64),
(3113,'Natália','F',61),
(3114,'Patrícia','F',55),
(3115,'Fernanda','F',68),
(3116,'Amanda','F',62),
(3117,'Tatiane','F',65),
(3118,'Fábio','F',59),
(3119,'Renato','F',65),
(3120,'Clara','F',22),
(3121,'Gustavo','F',34),
(3122,'Ricardo','F',54),
(3123,'Otávio','F',20),
(3124,'Felipe','F',31),
(3125,'Vinicius','F',51),
(3126,'Juliana','F',33),
(3127,'Sabrina','F',46),
(3128,'André','F',66),
(3129,'Henrique','F',23),
(3130,'Lucas','F',50),
(3131,'Vanessa','F',54),
(3132,'Patrícia','F',24),
(3133,'Carlos','F',20),
(3134,'Eduardo','F',35),
(3135,'Elaine','F',25),
(3136,'Mateus','F',24),
(3137,'Rafael','F',55),
(3138,'Débora','F',61),
(3139,'Camila','F',20),
(3140,'Rodrigo','F',45),
(3141,'Márcio','F',25),
(3142,'Beatriz','F',20),
(3143,'Leonardo','F',37),
(3144,'Bianca','F',35),
(3145,'Gabriela','F',68),
(3146,'Aline','F',33),
(3147,'Larissa','F',23),
(3148,'Bruno','F',51),
(3149,'Beatriz','F',19),
(3150,'Leonardo','F',42),
(3151,'Henrique','F',57),
(3152,'Bianca','F',25),
(3153,'Lucas','F',44),
(3154,'Clara','F',55),
(3155,'Caio','F',44),
(3156,'Sabrina','F',51),
(3157,'Carlos','F',52),
(3158,'Fernanda','F',56),
(3159,'Gustavo','F',42),
(3160,'Patrícia','F',22),
(3161,'Gabriela','F',31),
(3162,'Natália','F',63),
(3163,'Rodrigo','F',36),
(3164,'Felipe','F',47),
(3165,'Mariana','F',65),
(3166,'Juliana','F',44),
(3167,'Renato','F',58),
(3168,'Ana','F',62),
(3169,'Fábio','F',34),
(3170,'Priscila','F',53),
(3171,'João','F',53),
(3172,'Mateus','F',52),
(3173,'Murilo','F',24),
(3174,'Priscila','F',37),
(3175,'Tatiane','F',34),
(3176,'Mariana','F',24),
(3177,'Rodrigo','F',27),
(3178,'Cristina','F',56),
(3179,'Isabela','F',55),
(3180,'Lucas','F',68),
(3181,'Camila','F',55),
(3182,'Luana','F',38),
(3183,'Elaine','F',58),
(3184,'Thiago','F',37),
(3185,'André','F',41),
(3186,'Leonardo','F',29),
(3187,'João','F',29),
(3188,'Renato','F',43),
(3189,'Aline','F',64),
(3190,'Amanda','F',27),
(3191,'Fábio','F',28),
(3192,'Ricardo','F',63),
(3193,'Natália','F',63),
(3194,'Eduardo','F',61),
(3195,'Michele','F',26),
(3196,'Patrícia','F',34),
(3197,'Beatriz','F',20),
(3198,'Vanessa','F',24),
(3199,'Ana','F',41),
(3200,'Luana','F',34),
(3201,'Priscila','F',39),
(3202,'Gabriela','F',42),
(3203,'Tatiane','F',26),
(3204,'Mateus','F',29),
(3205,'Aline','F',24),
(3206,'Carlos','F',40),
(3207,'Isabela','F',58),
(3208,'Sabrina','F',28),
(3209,'Márcio','F',18),
(3210,'Gustavo','F',43),
(3211,'Bianca','F',55),
(3212,'Mariana','F',40),
(3213,'Camila','F',52),
(3214,'Amanda','F',23),
(3215,'Vinicius','F',19),
(3216,'Michele','F',59),
(3217,'Patrícia','F',33),
(3218,'Eduardo','F',41),
(3219,'Natália','F',28),
(3220,'Ricardo','F',39),
(3221,'Felipe','F',41),
(3222,'Ana','F',30),
(3223,'Fábio','F',37),
(3224,'Clara','F',21),
(3225,'Tatiane','F',43),
(3226,'Henrique','F',30),
(3227,'Larissa','F',26),
(3228,'Ricardo','F',67),
(3229,'Otávio','F',42),
(3230,'Juliana','F',58),
(3231,'Ana','F',64),
(3232,'Mariana','F',54),
(3233,'Rodrigo','F',25),
(3234,'Mateus','F',68),
(3235,'Beatriz','F',30),
(3236,'Letícia','F',20),
(3237,'Priscila','F',41),
(3238,'Renato','F',46),
(3239,'Fábio','F',33),
(3240,'Lucas','F',24),
(3241,'Paula','F',52),
(3242,'Patrícia','F',43),
(3243,'Bianca','F',23),
(3244,'João','F',25),
(3245,'André','F',23),
(3246,'Camila','F',47),
(3247,'Caio','F',54),
(3248,'Débora','F',61),
(3249,'Aline','F',55),
(3250,'Priscila','F',63),
(3251,'Cristina','F',29),
(3252,'Henrique','F',59),
(3253,'Clara','F',22),
(3254,'Diego','F',25),
(3255,'Amanda','F',42),
(3256,'Bianca','F',23),
(3257,'Eduardo','F',21),
(3258,'Ricardo','F',37),
(3259,'Leonardo','F',53),
(3260,'Daniel','F',24),
(3261,'Mariana','F',30),
(3262,'Gustavo','F',54),
(3263,'Juliana','F',64),
(3264,'Tatiane','F',68),
(3265,'Rodrigo','F',50),
(3266,'Letícia','F',23),
(3267,'Caio','F',22),
(3268,'Elaine','F',55),
(3269,'André','F',51),
(3270,'João','F',39),
(3271,'Beatriz','F',54),
(3272,'Gabriela','F',70),
(3273,'Aline','F',56),
(3274,'Amanda','F',69),
(3275,'Luana','F',31),
(3276,'Isabela','F',62),
(3277,'Larissa','F',65),
(3278,'Renato','F',59),
(3279,'Caio','F',23),
(3280,'Gabriela','F',33),
(3281,'Elaine','F',63),
(3282,'Mateus','F',49),
(3283,'Márcio','F',67),
(3284,'Priscila','F',48),
(3285,'Clara','F',29),
(3286,'Débora','F',61),
(3287,'Fernanda','F',40),
(3288,'Rodrigo','F',36),
(3289,'Patrícia','F',43),
(3290,'Daniel','F',27),
(3291,'Thiago','F',21),
(3292,'Beatriz','F',47),
(3293,'Ricardo','F',39),
(3294,'Paula','F',22),
(3295,'Ana','F',20),
(3296,'Otávio','F',43),
(3297,'Henrique','F',20),
(3298,'João','F',21),
(3299,'Juliana','F',20),
(3300,'André','F',55),
(3301,'Sabrina','F',24),
(3302,'Eduardo','F',30),
(3303,'André','F',53),
(3304,'Vanessa','F',49),
(3305,'Felipe','F',62),
(3306,'Priscila','F',53),
(3307,'Juliana','F',46),
(3308,'Gustavo','F',54),
(3309,'Débora','F',25),
(3310,'Mariana','F',22),
(3311,'Isabela','F',30),
(3312,'Letícia','F',27),
(3313,'Leonardo','F',66),
(3314,'Lucas','F',57),
(3315,'Bruno','F',51),
(3316,'Fábio','F',68),
(3317,'Cristina','F',57),
(3318,'Ricardo','F',23),
(3319,'Murilo','F',21),
(3320,'Diego','F',27),
(3321,'Amanda','F',46),
(3322,'Clara','F',21),
(3323,'João','F',55),
(3324,'Otávio','F',38),
(3325,'Camila','F',21),
(3326,'Mateus','F',34),
(3327,'Luana','F',60),
(3328,'Murilo','F',44),
(3329,'Ana','F',41),
(3330,'Ricardo','F',23),
(3331,'Camila','F',56),
(3332,'Daniel','F',46),
(3333,'Caio','F',50),
(3334,'Gustavo','F',20),
(3335,'Fernanda','F',56),
(3336,'Michele','F',21),
(3337,'Juliana','F',60),
(3338,'Fábio','F',62),
(3339,'Tatiane','F',56),
(3340,'Bianca','F',47),
(3341,'Elaine','F',59),
(3342,'Vanessa','F',49),
(3343,'Renato','F',38),
(3344,'Amanda','F',64),
(3345,'Débora','F',53),
(3346,'Priscila','F',23),
(3347,'André','F',49),
(3348,'Diego','F',58),
(3349,'Mateus','F',38),
(3350,'Otávio','F',43),
(3351,'Rodrigo','F',18),
(3352,'Gabriela','F',60),
(3353,'Clara','F',67),
(3354,'Vinicius','F',19),
(3355,'Juliana','F',47),
(3356,'Paula','F',32),
(3357,'Henrique','F',27),
(3358,'Lucas','F',65),
(3359,'Clara','F',68),
(3360,'Renato','F',58),
(3361,'Cristina','F',42),
(3362,'Mateus','F',49),
(3363,'André','F',24),
(3364,'Camila','F',24),
(3365,'Patrícia','F',27),
(3366,'Murilo','F',30),
(3367,'Rafael','F',22),
(3368,'Ana','F',61),
(3369,'Otávio','F',25),
(3370,'Bruno','F',19),
(3371,'João','F',37),
(3372,'Daniel','F',37),
(3373,'Gabriela','F',69),
(3374,'Márcio','F',26),
(3375,'Natália','F',44),
(3376,'Bianca','F',48),
(3377,'Ricardo','F',45),
(3378,'Rodrigo','F',25),
(3379,'Eduardo','F',21),
(3380,'Débora','F',62),
(3381,'Elaine','F',24),
(3382,'Priscila','F',25),
(3383,'Vanessa','F',60),
(3384,'Bruno','F',58),
(3385,'Mateus','F',28),
(3386,'Cristina','F',37),
(3387,'Natália','F',62),
(3388,'Henrique','F',68),
(3389,'Diego','F',32),
(3390,'Márcio','F',23),
(3391,'Otávio','F',48),
(3392,'João','F',60),
(3393,'Amanda','F',19),
(3394,'Vanessa','F',32),
(3395,'Gustavo','F',43),
(3396,'Priscila','F',33),
(3397,'Paula','F',25),
(3398,'Mariana','F',66),
(3399,'Elaine','F',37),
(3400,'Rodrigo','F',18),
(3401,'Sabrina','F',50),
(3402,'Clara','F',42),
(3403,'Renato','F',38),
(3404,'Gustavo','F',44),
(3405,'Aline','F',28),
(3406,'André','F',44),
(3407,'Beatriz','F',53),
(3408,'Sabrina','F',35),
(3409,'Cristina','F',65),
(3410,'Leonardo','F',63),
(3411,'Márcio','F',37),
(3412,'Isabela','F',32),
(3413,'Vanessa','F',43),
(3414,'Clara','F',43),
(3415,'Michele','F',67),
(3416,'Letícia','F',58),
(3417,'Diego','F',38),
(3418,'Juliana','F',40),
(3419,'Amanda','F',53),
(3420,'Larissa','F',34),
(3421,'Rafael','F',67),
(3422,'Ricardo','F',20),
(3423,'Priscila','F',25),
(3424,'Lucas','F',66),
(3425,'Tatiane','F',19),
(3426,'Ana','F',70),
(3427,'Henrique','F',27),
(3428,'Carlos','F',23),
(3429,'Elaine','F',44),
(3430,'Daniel','F',44),
(3431,'Isabela','F',48),
(3432,'Rodrigo','F',67),
(3433,'Otávio','F',30),
(3434,'Natália','F',19),
(3435,'Camila','F',59),
(3436,'André','F',66),
(3437,'Murilo','F',27),
(3438,'Amanda','F',53),
(3439,'Ana','F',32),
(3440,'Henrique','F',62),
(3441,'Fernanda','F',62),
(3442,'Diego','F',34),
(3443,'Cristina','F',27),
(3444,'Renato','F',61),
(3445,'Aline','F',53),
(3446,'Tatiane','F',36),
(3447,'Bianca','F',55),
(3448,'Gustavo','F',65),
(3449,'Eduardo','F',35),
(3450,'Caio','F',39),
(3451,'Mariana','F',63),
(3452,'Fernanda','F',35),
(3453,'Patrícia','F',26),
(3454,'Natália','F',69),
(3455,'Henrique','F',66),
(3456,'Camila','F',20),
(3457,'Mateus','F',59),
(3458,'André','F',33),
(3459,'Aline','F',65),
(3460,'Letícia','F',61),
(3461,'Vinicius','F',50),
(3462,'Leonardo','F',52),
(3463,'Murilo','F',54),
(3464,'Felipe','F',62),
(3465,'Mariana','F',63),
(3466,'Gustavo','F',33),
(3467,'Cristina','F',38),
(3468,'Ana','F',20),
(3469,'Fábio','F',26),
(3470,'Renato','F',68),
(3471,'Rodrigo','F',38),
(3472,'Tatiane','F',61),
(3473,'Clara','F',21),
(3474,'Amanda','F',62),
(3475,'Luana','F',56),
(3476,'Priscila','F',36),
(3477,'Paula','F',22),
(3478,'Renato','F',30),
(3479,'Fábio','F',35),
(3480,'Clara','F',38),
(3481,'Felipe','F',42),
(3482,'Carlos','F',64),
(3483,'Aline','F',59),
(3484,'Bruno','F',35),
(3485,'Mariana','F',24),
(3486,'Vanessa','F',20),
(3487,'Thiago','F',28),
(3488,'Camila','F',61),
(3489,'Rafael','F',51),
(3490,'Michele','F',70),
(3491,'Fernanda','F',41),
(3492,'Murilo','F',26),
(3493,'Larissa','F',19),
(3494,'Eduardo','F',43),
(3495,'André','F',54),
(3496,'Bianca','F',27),
(3497,'Henrique','F',25),
(3498,'Gustavo','F',28),
(3499,'Letícia','F',29),
(3500,'Paula','F',46),
(3501,'Márcio','F',20),
(3502,'Lucas','F',39),
(3503,'João','F',36),
(3504,'Gabriela','F',38),
(3505,'Caio','F',53),
(3506,'Camila','F',39),
(3507,'Fernanda','F',52),
(3508,'Márcio','F',42),
(3509,'Letícia','F',23),
(3510,'Leonardo','F',36),
(3511,'Priscila','F',18),
(3512,'Vinicius','F',29),
(3513,'Henrique','F',38),
(3514,'Felipe','F',26),
(3515,'Natália','F',37),
(3516,'Diego','F',22),
(3517,'Bianca','F',70),
(3518,'Beatriz','F',53),
(3519,'Renato','F',42),
(3520,'Daniel','F',25),
(3521,'Sabrina','F',24),
(3522,'Ana','F',61),
(3523,'Clara','F',58),
(3524,'Elaine','F',30),
(3525,'Mateus','F',67),
(3526,'Lucas','F',45),
(3527,'Michele','F',41),
(3528,'Luana','F',64),
(3529,'Amanda','F',52),
(3530,'Isabela','F',21),
(3531,'Rafael','F',34),
(3532,'Murilo','F',51),
(3533,'Rafael','F',18),
(3534,'Clara','F',69),
(3535,'Mateus','F',33),
(3536,'Débora','F',25),
(3537,'Renato','F',35),
(3538,'Aline','F',47),
(3539,'Leonardo','F',37),
(3540,'Henrique','F',49),
(3541,'Bruno','F',42),
(3542,'Daniel','F',40),
(3543,'Vanessa','F',56),
(3544,'Diego','F',52),
(3545,'Cristina','F',20),
(3546,'Fernanda','F',48),
(3547,'Natália','F',25),
(3548,'Beatriz','F',52),
(3549,'Caio','F',49),
(3550,'Juliana','F',31),
(3551,'Michele','F',48),
(3552,'João','F',23),
(3553,'Ricardo','F',54),
(3554,'Elaine','F',33),
(3555,'Gabriela','F',68),
(3556,'Amanda','F',65),
(3557,'Márcio','F',62),
(3558,'Beatriz','F',25),
(3559,'Renato','F',45),
(3560,'Thiago','F',59),
(3561,'Rodrigo','F',65),
(3562,'Lucas','F',20),
(3563,'Clara','F',23),
(3564,'Mateus','F',25),
(3565,'Bianca','F',39),
(3566,'Luana','F',39),
(3567,'Gustavo','F',51),
(3568,'Sabrina','F',23),
(3569,'Gabriela','F',46),
(3570,'Mariana','F',39),
(3571,'André','F',27),
(3572,'Rafael','F',58),
(3573,'Juliana','F',23),
(3574,'Ricardo','F',26),
(3575,'Aline','F',64),
(3576,'Amanda','F',44),
(3577,'Fábio','F',46),
(3578,'Vanessa','F',66),
(3579,'Otávio','F',32),
(3580,'Priscila','F',32),
(3581,'Carlos','F',21),
(3582,'Ana','F',49),
(3583,'Bruno','F',25),
(3584,'Henrique','F',30),
(3585,'Felipe','F',45),
(3586,'Paula','F',29),
(3587,'Bianca','F',20),
(3588,'Caio','F',36),
(3589,'Thiago','F',37),
(3590,'Letícia','F',21),
(3591,'Rodrigo','F',36),
(3592,'Michele','F',56),
(3593,'Isabela','F',43),
(3594,'Márcio','F',53),
(3595,'Rafael','F',42),
(3596,'Lucas','F',25),
(3597,'Murilo','F',22),
(3598,'Ana','F',52),
(3599,'Vinicius','F',27),
(3600,'Mariana','F',22),
(3601,'Bruno','F',37),
(3602,'Camila','F',36),
(3603,'André','F',58),
(3604,'Paula','F',26),
(3605,'Felipe','F',26),
(3606,'Larissa','F',39),
(3607,'Juliana','F',27),
(3608,'Beatriz','F',67),
(3609,'Daniel','F',66),
(3610,'Aline','F',34),
(3611,'Débora','F',36),
(3612,'Patrícia','F',69),
(3613,'Gabriela','F',60),
(3614,'Murilo','F',44),
(3615,'Natália','F',33),
(3616,'Paula','F',44),
(3617,'Henrique','F',52),
(3618,'Lucas','F',63),
(3619,'Isabela','F',57),
(3620,'Clara','F',41),
(3621,'Vanessa','F',30),
(3622,'Elaine','F',23),
(3623,'Juliana','F',46),
(3624,'Márcio','F',32),
(3625,'Amanda','F',59),
(3626,'Letícia','F',70),
(3627,'Priscila','F',31),
(3628,'André','F',56),
(3629,'Diego','F',23),
(3630,'Bianca','F',66),
(3631,'Fábio','F',41),
(3632,'Caio','F',69),
(3633,'Vanessa','F',33),
(3634,'Felipe','F',33),
(3635,'Bianca','F',47),
(3636,'Mariana','F',24),
(3637,'Márcio','F',60),
(3638,'Otávio','F',69),
(3639,'Camila','F',69),
(3640,'Patrícia','F',60),
(3641,'André','F',31),
(3642,'Priscila','F',24),
(3643,'Sabrina','F',36),
(3644,'Leonardo','F',59),
(3645,'Renato','F',58),
(3646,'Clara','F',44),
(3647,'Thiago','F',54),
(3648,'Carlos','F',21),
(3649,'Tatiane','F',24),
(3650,'Isabela','F',58),
(3651,'Gustavo','F',54),
(3652,'Michele','F',56),
(3653,'Juliana','F',46),
(3654,'Larissa','F',47),
(3655,'Rodrigo','F',23),
(3656,'João','F',52),
(3657,'Eduardo','F',37),
(3658,'Amanda','F',25),
(3659,'Bruno','F',68),
(3660,'Rafael','F',63),
(3661,'Clara','F',22),
(3662,'Amanda','F',53),
(3663,'Mariana','F',66),
(3664,'Felipe','F',49),
(3665,'Aline','F',57),
(3666,'Patrícia','F',50),
(3667,'Vinicius','F',23),
(3668,'Mateus','F',57),
(3669,'Luana','F',29),
(3670,'Fábio','F',68),
(3671,'João','F',67),
(3672,'Beatriz','F',70),
(3673,'Diego','F',19),
(3674,'Letícia','F',24),
(3675,'Vanessa','F',63),
(3676,'Eduardo','F',40),
(3677,'André','F',24),
(3678,'Bianca','F',46),
(3679,'Cristina','F',24),
(3680,'Rodrigo','F',59),
(3681,'Paula','F',47),
(3682,'Larissa','F',25),
(3683,'Diego','F',34),
(3684,'Rodrigo','F',43),
(3685,'Carlos','F',22),
(3686,'Bianca','F',18),
(3687,'João','F',22),
(3688,'Elaine','F',59),
(3689,'Priscila','F',44),
(3690,'Luana','F',30),
(3691,'Cristina','F',52),
(3692,'Camila','F',37),
(3693,'Mariana','F',65),
(3694,'Aline','F',40),
(3695,'Amanda','F',24),
(3696,'Isabela','F',38),
(3697,'André','F',58),
(3698,'Sabrina','F',66),
(3699,'Henrique','F',27),
(3700,'Gustavo','F',25),
(3701,'Débora','F',26),
(3702,'Fernanda','F',30),
(3703,'Clara','F',53),
(3704,'Thiago','F',32),
(3705,'Caio','F',56),
(3706,'Murilo','F',61),
(3707,'Ana','F',63),
(3708,'Diego','F',38),
(3709,'Aline','F',36),
(3710,'Rafael','F',31),
(3711,'Natália','F',54),
(3712,'Larissa','F',27),
(3713,'João','F',66),
(3714,'Renato','F',52),
(3715,'Débora','F',54),
(3716,'Michele','F',21),
(3717,'Henrique','F',57),
(3718,'Gabriela','F',65),
(3719,'Isabela','F',34),
(3720,'Patrícia','F',49),
(3721,'Thiago','F',39),
(3722,'Vanessa','F',54),
(3723,'Paula','F',64),
(3724,'Carlos','F',53),
(3725,'Juliana','F',34),
(3726,'Mariana','F',61),
(3727,'Amanda','F',41),
(3728,'Caio','F',51),
(3729,'Ricardo','F',21),
(3730,'Murilo','F',57),
(3731,'Priscila','F',38),
(3732,'Eduardo','F',19),
(3733,'Amanda','F',63),
(3734,'Rafael','F',65),
(3735,'Camila','F',22),
(3736,'Lucas','F',27),
(3737,'Leonardo','F',27),
(3738,'Gabriela','F',34),
(3739,'Letícia','F',35),
(3740,'Caio','F',63),
(3741,'Beatriz','F',24),
(3742,'Márcio','F',20),
(3743,'Rodrigo','F',52),
(3744,'Otávio','F',53),
(3745,'Fábio','F',66),
(3746,'Diego','F',25),
(3747,'Tatiane','F',23),
(3748,'Daniel','F',31),
(3749,'Débora','F',29),
(3750,'Paula','F',31),
(3751,'Thiago','F',30),
(3752,'Michele','F',58),
(3753,'Priscila','F',23),
(3754,'Clara','F',37),
(3755,'João','F',37),
(3756,'Vinicius','F',54),
(3757,'Aline','F',38),
(3758,'Fábio','F',43),
(3759,'Mateus','F',36),
(3760,'Daniel','F',37),
(3761,'Diego','F',57),
(3762,'Gustavo','F',37),
(3763,'Márcio','F',18),
(3764,'André','F',42),
(3765,'Gabriela','F',19),
(3766,'João','F',35),
(3767,'Mariana','F',30),
(3768,'Cristina','F',23),
(3769,'Lucas','F',51),
(3770,'Ricardo','F',63),
(3771,'Beatriz','F',21),
(3772,'Vanessa','F',55),
(3773,'Clara','F',42),
(3774,'Bianca','F',19),
(3775,'Renato','F',69),
(3776,'Ana','F',55),
(3777,'Isabela','F',56),
(3778,'Leonardo','F',69),
(3779,'Rodrigo','F',62),
(3780,'Felipe','F',68),
(3781,'Rafael','F',57),
(3782,'Camila','F',48),
(3783,'Patrícia','F',56),
(3784,'Lucas','F',26),
(3785,'Renato','F',22),
(3786,'Bruno','F',37),
(3787,'Mariana','F',61),
(3788,'Bianca','F',70),
(3789,'Cristina','F',31),
(3790,'Márcio','F',59),
(3791,'Letícia','F',60),
(3792,'Débora','F',36),
(3793,'Larissa','F',68),
(3794,'Eduardo','F',33),
(3795,'Elaine','F',37),
(3796,'Murilo','F',26),
(3797,'Carlos','F',21),
(3798,'Aline','F',24),
(3799,'Vanessa','F',63),
(3800,'Leonardo','F',36),
(3801,'Fábio','F',27),
(3802,'Luana','F',45),
(3803,'Vanessa','F',43),
(3804,'Amanda','F',69),
(3805,'Tatiane','F',22),
(3806,'Fábio','F',20),
(3807,'Bruno','F',45),
(3808,'Felipe','F',63),
(3809,'Diego','F',20),
(3810,'Sabrina','F',43),
(3811,'Carlos','F',61),
(3812,'Bianca','F',65),
(3813,'Daniel','F',21),
(3814,'Mariana','F',58),
(3815,'Gustavo','F',52),
(3816,'Ricardo','F',48),
(3817,'Caio','F',26),
(3818,'Rodrigo','F',44),
(3819,'Cristina','F',26),
(3820,'Paula','F',31),
(3821,'Camila','F',29),
(3822,'Gabriela','F',37),
(3823,'Natália','F',18),
(3824,'Murilo','F',69),
(3825,'Daniel','F',38),
(3826,'Ricardo','F',31),
(3827,'Mateus','F',54),
(3828,'Lucas','F',24),
(3829,'Renato','F',65),
(3830,'Caio','F',19),
(3831,'Márcio','F',26),
(3832,'Felipe','F',19),
(3833,'Fernanda','F',54),
(3834,'Priscila','F',53),
(3835,'Sabrina','F',62),
(3836,'Tatiane','F',24),
(3837,'Isabela','F',22),
(3838,'Larissa','F',19),
(3839,'Mariana','F',20),
(3840,'Vinicius','F',26),
(3841,'Juliana','F',40),
(3842,'Carlos','F',38),
(3843,'Gustavo','F',34),
(3844,'Aline','F',56),
(3845,'Letícia','F',18),
(3846,'André','F',39),
(3847,'Amanda','F',59),
(3848,'Natália','F',25),
(3849,'Michele','F',70),
(3850,'Camila','F',52),
(3851,'Felipe','F',22),
(3852,'Carlos','F',59),
(3853,'Sabrina','F',63),
(3854,'Tatiane','F',49),
(3855,'Gabriela','F',51),
(3856,'Isabela','F',70),
(3857,'Paula','F',46),
(3858,'André','F',36),
(3859,'Aline','F',63),
(3860,'Rodrigo','F',19),
(3861,'Rafael','F',53),
(3862,'Clara','F',44),
(3863,'Cristina','F',57),
(3864,'Natália','F',58),
(3865,'Ana','F',20),
(3866,'Henrique','F',67),
(3867,'Thiago','F',69),
(3868,'Lucas','F',42),
(3869,'Mateus','F',70),
(3870,'Felipe','F',33),
(3871,'Fábio','F',44),
(3872,'Luana','F',22),
(3873,'Cristina','F',23),
(3874,'Camila','F',38),
(3875,'Vinicius','F',45),
(3876,'Mateus','F',47),
(3877,'Clara','F',38),
(3878,'Murilo','F',40),
(3879,'Tatiane','F',22),
(3880,'Aline','F',48),
(3881,'Sabrina','F',58),
(3882,'Priscila','F',52),
(3883,'Ana','F',21),
(3884,'Márcio','F',66),
(3885,'Elaine','F',59),
(3886,'Eduardo','F',43),
(3887,'Ricardo','F',44),
(3888,'Leonardo','F',18),
(3889,'Michele','F',21),
(3890,'Paula','F',28),
(3891,'Amanda','F',58),
(3892,'Patrícia','F',59),
(3893,'Felipe','F',42),
(3894,'Gabriela','F',33),
(3895,'Mateus','F',60),
(3896,'Murilo','F',34),
(3897,'Otávio','F',40),
(3898,'Isabela','F',18),
(3899,'Rodrigo','F',57),
(3900,'Bianca','F',29),
(3901,'Márcio','F',58),
(3902,'Ricardo','F',18),
(3903,'Daniel','F',56),
(3904,'Luana','F',28),
(3905,'Fábio','F',64),
(3906,'Leonardo','F',21),
(3907,'Tatiane','F',31),
(3908,'Cristina','F',19),
(3909,'Vinicius','F',18),
(3910,'Natália','F',18),
(3911,'Paula','F',35),
(3912,'Larissa','F',47),
(3913,'Gustavo','F',64),
(3914,'Ana','F',59),
(3915,'Débora','F',38),
(3916,'Patrícia','F',32),
(3917,'Leonardo','F',55),
(3918,'Gabriela','F',23),
(3919,'Aline','F',31),
(3920,'Daniel','F',32),
(3921,'Mateus','F',28),
(3922,'Ana','F',24),
(3923,'Larissa','F',24),
(3924,'Michele','F',67),
(3925,'Tatiane','F',47),
(3926,'Márcio','F',53),
(3927,'Otávio','F',32),
(3928,'Lucas','F',62),
(3929,'Bianca','F',40),
(3930,'Paula','F',48),
(3931,'Diego','F',37),
(3932,'Clara','F',31),
(3933,'Natália','F',27),
(3934,'Vanessa','F',50),
(3935,'João','F',41),
(3936,'Patrícia','F',30),
(3937,'Isabela','F',49),
(3938,'Camila','F',30),
(3939,'Luana','F',63),
(3940,'Michele','F',24),
(3941,'João','F',54),
(3942,'Mateus','F',34),
(3943,'Clara','F',27),
(3944,'Mariana','F',51),
(3945,'Bruno','F',28),
(3946,'Bianca','F',33),
(3947,'Natália','F',49),
(3948,'Luana','F',70),
(3949,'Rodrigo','F',40),
(3950,'Beatriz','F',68),
(3951,'Cristina','F',33),
(3952,'André','F',60),
(3953,'Gabriela','F',60),
(3954,'Rafael','F',22),
(3955,'Fernanda','F',57),
(3956,'Amanda','F',39),
(3957,'Larissa','F',32),
(3958,'Priscila','F',47),
(3959,'Daniel','F',28),
(3960,'Márcio','F',29),
(3961,'Elaine','F',44),
(3962,'Diego','F',67),
(3963,'Natália','F',64),
(3964,'João','F',54),
(3965,'Ricardo','F',44),
(3966,'Carlos','F',20),
(3967,'Juliana','F',27),
(3968,'Letícia','F',29),
(3969,'Renato','F',43),
(3970,'Mariana','F',24),
(3971,'Vinicius','F',38),
(3972,'Eduardo','F',48),
(3973,'Camila','F',33),
(3974,'Caio','F',24),
(3975,'Débora','F',51),
(3976,'Bianca','F',56),
(3977,'Michele','F',53),
(3978,'Paula','F',64),
(3979,'Tatiane','F',67),
(3980,'Larissa','F',20),
(3981,'Isabela','F',20),
(3982,'Gustavo','F',39),
(3983,'Márcio','F',66),
(3984,'Cristina','F',24),
(3985,'Gabriela','F',50),
(3986,'Beatriz','F',42),
(3987,'Amanda','F',63),
(3988,'Mateus','F',21),
(3989,'Clara','F',20),
(3990,'Patrícia','F',48),
(3991,'Lucas','F',33),
(3992,'Michele','F',33),
(3993,'Ana','F',38),
(3994,'Vinicius','F',42),
(3995,'Rodrigo','F',60),
(3996,'Rafael','F',28),
(3997,'Amanda','F',24),
(3998,'Fernanda','F',66),
(3999,'Thiago','F',22),
(4000,'Caio','F',49),
(4001,'Patrícia','F',27),
(4002,'Luana','F',43),
(4003,'Juliana','F',70),
(4004,'Otávio','F',51),
(4005,'Priscila','F',53),
(4006,'Diego','F',39),
(4007,'Bruno','F',55),
(4008,'André','F',44),
(4009,'Vanessa','F',31),
(4010,'Paula','F',59),
(4011,'João','F',19),
(4012,'Márcio','F',24),
(4013,'Clara','F',20),
(4014,'Priscila','F',50),
(4015,'Rodrigo','F',68),
(4016,'Márcio','F',31),
(4017,'Elaine','F',23),
(4018,'Letícia','F',23),
(4019,'Beatriz','F',31),
(4020,'Fábio','F',26),
(4021,'Henrique','F',45),
(4022,'Gabriela','F',25),
(4023,'Débora','F',48),
(4024,'Natália','F',47),
(4025,'Luana','F',40),
(4026,'Tatiane','F',21),
(4027,'Sabrina','F',69),
(4028,'Isabela','F',67),
(4029,'Gustavo','F',67),
(4030,'Larissa','F',18),
(4031,'Otávio','F',24),
(4032,'Leonardo','F',70),
(4033,'Vinicius','F',59),
(4034,'Bruno','F',35),
(4035,'Diego','F',36),
(4036,'Letícia','F',25),
(4037,'Mateus','F',64),
(4038,'João','F',58),
(4039,'Rafael','F',31),
(4040,'Vinicius','F',26),
(4041,'Lucas','F',32),
(4042,'Patrícia','F',30),
(4043,'Aline','F',54),
(4044,'Larissa','F',44),
(4045,'Débora','F',68),
(4046,'Ricardo','F',67),
(4047,'Thiago','F',43),
(4048,'Daniel','F',52),
(4049,'Carlos','F',39),
(4050,'Leonardo','F',30),
(4051,'Márcio','F',66),
(4052,'Michele','F',41),
(4053,'Bruno','F',52),
(4054,'Bianca','F',61),
(4055,'Gabriela','F',60),
(4056,'Eduardo','F',52),
(4057,'Elaine','F',51),
(4058,'Henrique','F',66),
(4059,'Camila','F',27),
(4060,'Mariana','F',18),
(4061,'Aline','F',68),
(4062,'Priscila','F',33),
(4063,'Juliana','F',33),
(4064,'Luana','F',53),
(4065,'Paula','F',41),
(4066,'Camila','F',32),
(4067,'Mateus','F',30),
(4068,'Daniel','F',70),
(4069,'Felipe','F',20),
(4070,'Tatiane','F',62),
(4071,'Vinicius','F',64),
(4072,'Vanessa','F',66),
(4073,'Márcio','F',44),
(4074,'Caio','F',65),
(4075,'Isabela','F',61),
(4076,'Ricardo','F',43),
(4077,'Thiago','F',67),
(4078,'Otávio','F',33),
(4079,'Clara','F',37),
(4080,'Letícia','F',27),
(4081,'Murilo','F',18),
(4082,'Rodrigo','F',30),
(4083,'Elaine','F',70),
(4084,'Beatriz','F',23),
(4085,'Cristina','F',57),
(4086,'Diego','F',27),
(4087,'Renato','F',24),
(4088,'Daniel','F',41),
(4089,'Gabriela','F',18),
(4090,'Clara','F',64),
(4091,'Débora','F',34),
(4092,'Henrique','F',51),
(4093,'Vinicius','F',33),
(4094,'Murilo','F',55),
(4095,'Larissa','F',69),
(4096,'Fernanda','F',20),
(4097,'Rafael','F',26),
(4098,'Camila','F',29),
(4099,'Bruno','F',48),
(4100,'Eduardo','F',40),
(4101,'Diego','F',69),
(4102,'Aline','F',69),
(4103,'Márcio','F',27),
(4104,'Carlos','F',66),
(4105,'Priscila','F',70),
(4106,'Otávio','F',43),
(4107,'Michele','F',66),
(4108,'Luana','F',54),
(4109,'Mariana','F',63),
(4110,'Renato','F',32),
(4111,'Natália','F',20),
(4112,'Rodrigo','F',47),
(4113,'Bruno','F',24),
(4114,'Luana','F',26),
(4115,'Débora','F',37),
(4116,'Carlos','F',52),
(4117,'Juliana','F',68),
(4118,'Gustavo','F',30),
(4119,'Camila','F',39),
(4120,'Otávio','F',36),
(4121,'Renato','F',60),
(4122,'Ricardo','F',50),
(4123,'Natália','F',43),
(4124,'Cristina','F',68),
(4125,'João','F',30),
(4126,'Priscila','F',41),
(4127,'Letícia','F',24),
(4128,'Vinicius','F',30),
(4129,'Henrique','F',46),
(4130,'Diego','F',68),
(4131,'Fábio','F',61),
(4132,'Vanessa','F',29),
(4133,'Mateus','F',57),
(4134,'Eduardo','F',67),
(4135,'Sabrina','F',25),
(4136,'Felipe','F',22),
(4137,'Murilo','F',27),
(4138,'Carlos','F',39),
(4139,'Vanessa','F',54),
(4140,'Paula','F',33),
(4141,'André','F',36),
(4142,'Diego','F',19),
(4143,'Gabriela','F',69),
(4144,'Henrique','F',40),
(4145,'Gustavo','F',58),
(4146,'Fernanda','F',62),
(4147,'Ricardo','F',21),
(4148,'Bianca','F',25),
(4149,'Elaine','F',44),
(4150,'Felipe','F',59),
(4151,'Amanda','F',54),
(4152,'Murilo','F',58),
(4153,'Clara','F',39),
(4154,'Mateus','F',57),
(4155,'Márcio','F',50),
(4156,'Lucas','F',23),
(4157,'Débora','F',58),
(4158,'Camila','F',27),
(4159,'Renato','F',69),
(4160,'Priscila','F',39),
(4161,'Thiago','F',66),
(4162,'Murilo','F',52),
(4163,'Michele','F',35),
(4164,'Mateus','F',25),
(4165,'Isabela','F',67),
(4166,'Mariana','F',44),
(4167,'Márcio','F',42),
(4168,'Otávio','F',42),
(4169,'Felipe','F',36),
(4170,'Clara','F',51),
(4171,'Carlos','F',66),
(4172,'Gabriela','F',59),
(4173,'Natália','F',30),
(4174,'Débora','F',65),
(4175,'Elaine','F',59),
(4176,'Daniel','F',59),
(4177,'Paula','F',37),
(4178,'Bianca','F',53),
(4179,'Rodrigo','F',63),
(4180,'Luana','F',67),
(4181,'Aline','F',58),
(4182,'Diego','F',53),
(4183,'Ana','F',29),
(4184,'Patrícia','F',22),
(4185,'Gabriela','F',21),
(4186,'Caio','F',58),
(4187,'João','F',36),
(4188,'Isabela','F',60),
(4189,'Natália','F',38),
(4190,'Murilo','F',26),
(4191,'Beatriz','F',40),
(4192,'André','F',32),
(4193,'Diego','F',32),
(4194,'Felipe','F',42),
(4195,'Henrique','F',56),
(4196,'Camila','F',67),
(4197,'Lucas','F',66),
(4198,'Leonardo','F',30),
(4199,'Fábio','F',19),
(4200,'Tatiane','F',59),
(4201,'Vanessa','F',40),
(4202,'Vinicius','F',58),
(4203,'Rafael','F',51),
(4204,'Eduardo','F',48),
(4205,'Otávio','F',35),
(4206,'Débora','F',32),
(4207,'Bianca','F',22),
(4208,'Camila','F',65),
(4209,'Daniel','F',30),
(4210,'Patrícia','F',67),
(4211,'Thiago','F',29),
(4212,'Henrique','F',51),
(4213,'Vanessa','F',36),
(4214,'Elaine','F',38),
(4215,'Mateus','F',30),
(4216,'Rodrigo','F',58),
(4217,'Caio','F',41),
(4218,'Márcio','F',40),
(4219,'Natália','F',46),
(4220,'Renato','F',19),
(4221,'Rafael','F',27),
(4222,'João','F',58),
(4223,'Otávio','F',32),
(4224,'Leonardo','F',35);

-- Dim_Hospital
INSERT INTO DIM_HOSPITAL (id_hospital, nome_hospital) VALUES (1,'Hospital Samaritano'),
(2,'Hospital das Clínicas'),
(3,'Hospital Getúlio Vargas'),
(4,'Hospital Estadual'),
(5,'Hospital Geral de Fortaleza'),
(6,'Hospital Unimed'),
(7,'Hospital Municipal'),
(8,'Hospital Evangélico'),
(9,'Hospital Regional'),
(10,'Hospital São Paulo'),
(11,'Hospital Albert Einstein'),
(12,'Hospital Nossa Senhora das Graças'),
(13,'Hospital da Restauração'),
(14,'Hospital Infantil Sabará'),
(15,'Hospital Sírio-Libanês'),
(16,'Hospital Beneficência Portuguesa'),
(17,'Hospital de Base'),
(18,'Hospital Metropolitano'),
(19,'Hospital Universitário'),
(20,'Hospital Santa Casa de Misericórdia'),
(21,'Hospital Israelita Albert Einstein'),
(22,'Santa Casa de Misericórdia de São Paulo'),
(23,'Hospital Regional de Taguatinga'),
(24,'Hospital Estadual Mário Covas'),
(25,'Hospital de Base do Distrito Federal'),
(26,'Hospital Evangélico Mackenzie'),
(27,'Hospital João XXIII'),
(28,'Hospital do Coração'),
(29,'Hospital Municipal Dr. Moysés Deutsch'),
(30,'Hospital Santa Izabel'),
(31,'Hospital Santa Marcelina'),
(32,'Hospital Ana Nery'),
(33,'Hospital Metropolitano de Urgência e Emergência'),
(34,'Hospital Cristo Redentor'),
(35,'Hospital Universitário Clementino Fraga Filho'),
(36,'Hospital Universitário Walter Cantídio'),
(37,'Hospital Madre Teresa'),
(38,'Hospital Unimed Recife'),
(39,'Hospital das Forças Armadas'),
(40,'Hospital Regional do Oeste');
